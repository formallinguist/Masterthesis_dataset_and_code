# %%
# Clone the BARTScore repository
# !git clone https://github.com/neulab/BARTScore.git
# Out:
# Cloning into 'BARTScore'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 220 (delta 18), reused 14 (delta 14), pack-reused 194 (from 1)
# Receiving objects: 100% (220/220), 101.98 MiB | 15.15 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (192/192), done.

# %%
# %cd /content/BARTScore
# Out:
# /content/BARTScore

# %%
# Import libraries
from bart_score import BARTScorer
import torch

# %%
# Install necessary libraries
# !pip install --upgrade pip  # ensures that pip is current
# !pip install tensorflow tensorflow_hub transformers
# !pip install git+https://github.com/google-research/bleurt.git
# !pip install pandas
# !pip install groq
# !pip install scikit-learn
# !pip install matplotlib
# !pip install nltk
# !pip install rouge
# !pip install sacrebleu
# !pip install bert-score
# !pip install rouge
# Navigate to the repository directory
# %cd /content/BARTScore

# Download and unzip BLEURT checkpoint
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# !unzip BLEURT-20.zip


# Import libraries
from bart_score import BARTScorer
import torch

# Initialize BART-Scorer
bart_scorer = BARTScorer(device='cuda:0' if torch.cuda.is_available() else 'cpu',
                         checkpoint='facebook/bart-large-cnn')
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (2.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.5.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-z1_4xxye
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-z1_4xxye
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=5136304913356f5c19d447fb0aa8d6b22ab1870a449649818a767e3249dba310
#   Stored in directory: /tmp/pip-ephem-wheel-cache-torsemrx/wheels/64/f4/2c/509a6c31b8ebde891a81029fd94f199b1b92f0e7cfc20d417a
# Successfully built BLEURT
# Installing collected packages: BLEURT
# Successfully installed BLEURT-0.0.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting groq
#   Downloading groq-0.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.15.0-py3-none-any.whl (109 kB)
# Installing collected packages: groq
# Successfully installed groq-0.15.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# /content/BARTScore
# --2025-01-14 13:10:56--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.207, 74.125.130.207, 74.125.68.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G  21.7MB/s    in 92s
#
# 2025-01-14 13:12:28 (22.3 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]
#
# Archive:  BLEURT-20.zip
#    creating: BLEURT-20/
#   inflating: BLEURT-20/bert_config.json
#   inflating: BLEURT-20/saved_model.pb
#    creating: BLEURT-20/variables/
#   inflating: BLEURT-20/variables/variables.index
#   inflating: BLEURT-20/variables/variables.data-00000-of-00001  y
#
#   inflating: BLEURT-20/sent_piece.vocab
#   inflating: BLEURT-20/bleurt_config.json
#   inflating: BLEURT-20/sent_piece.model
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from sacrebleu.metrics import CHRF, TER
from bert_score import score
from bleurt import score as bleurt_score
import json
import pandas as pd
import random
import warnings
from groq import Groq
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
from nltk.translate.meteor_score import meteor_score
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Suppress specific warning messages
import logging
logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)

# Function to read JSON file and extract claims
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/last_fake_claims.json'
claims_file_2 = '/content/Modified_true_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# Extract relevant information and convert to DataFrame
claims_list = []
for claim in combined_claims:
    claims_list.append({
        'Text': claim['claim'],
        'classification_label': claim['label'],
        'justification': claim['justification']
    })

claims_df = pd.DataFrame(claims_list)

# Process only the first 10 claims
claims_df = claims_df.head(5006)

# Initialize Groq API client
client = Groq(api_key="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")

# Initialize label map
label_map = {'true': 'true', 'fake': 'fake', "correct": "true", "false": "fake", "incorrect": "fake", "not true": "fake","true:" : "true","fake:": "fake"}

# Define the function to get predictions
def get_claim_predictions(claim):
    prompt = f"Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: {claim}"

    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="gemma2-9b-it",
            max_tokens=4000,
        )

        predicted_result = response.choices[0].message.content.strip().splitlines()
        print(predicted_result)
        predicted_label_justification = predicted_result[0].strip(' .,*').lower()
        if ':' in predicted_label_justification:
            predicted_label, predicted_justification = predicted_label_justification.split(':', 1)
            predicted_label = predicted_label.strip()
            predicted_justification = predicted_justification.strip()
        else:
            predicted_label = predicted_label_justification
            predicted_justification = " ".join(predicted_result[1:]).strip().lower()

        if predicted_label in label_map:
            predicted_label = label_map[predicted_label]
        else:
            # Handle cases where the label is not clear
            predicted_label = "unknown"
            predicted_justification = " ".join(predicted_result).strip().lower()
    except Exception as e:
        print(f"Error processing claim '{claim}': {e}")
        return ("", "", "")

    return (prompt, predicted_label, predicted_justification)

# Evaluate claims
results = []
actual_labels = []
predicted_labels = []
predicted_justifications = []
actual_justifications = []

correct_predictions = 0
total_processed_claims = 0

for index, row in claims_df.iterrows():
    claim = row['Text']
    actual_label = str(row['classification_label'].strip().lower())
    actual_justification = str(row['justification'].strip().lower())

    prompt, predicted_label, predicted_justification = get_claim_predictions(claim)

    total_processed_claims += 1

    if (predicted_label, predicted_justification) == ("", ""):
        continue

    actual_labels.append(actual_label)
    actual_justifications.append(actual_justification)
    predicted_labels.append(predicted_label)
    predicted_justifications.append(predicted_justification)

    if predicted_label == actual_label:
        correct_predictions += 1
    print(f"Claim #{total_processed_claims}")
    print(f"Prompt: {prompt}")
    print(f"Claim: {claim}")
    print(f"Predicted Label: {predicted_label}")
    print(f"Actual Label: {actual_label}")
    print(f"Predicted Justification: {predicted_justification}")
    print(f"Actual Justification: {actual_justification}")
    print('-' * 50)

# Metrics initialization
rouge = Rouge()
smoothing_function = SmoothingFunction().method4
chrf = CHRF()
ter = TER()
bleurt_scorer = bleurt_score.BleurtScorer("BLEURT-20")

# Filter out empty justifications
filtered_justifications = [
    (actual, predicted)
    for actual, predicted in zip(actual_justifications, predicted_justifications)
    if predicted.strip()
]

# Calculate metrics
def calculate_metrics_extended(justifications):
    bleu_scores = []
    rouge_scores = []
    meteor_scores = []
    chrf_scores = []
    ter_scores = []
    bert_scores = []
    bleurt_scores = []
    bart_scores = []

    for ref, pred in justifications:
        # BLEU score
        bleu = sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothing_function)
        bleu_scores.append(bleu)

        # ROUGE score
        rouge_score = rouge.get_scores(pred, ref, avg=True)
        rouge_scores.append(rouge_score)

        # METEOR score
        meteor = meteor_score([ref.split()], pred.split())
        meteor_scores.append(meteor)

        # ChrF
        chrf_scores.append(chrf.corpus_score([pred], [[ref]]).score)

        # TER
        ter_scores.append(ter.corpus_score([pred], [[ref]]).score)

        # BERTScore
        P, R, F1 = score([pred], [ref], lang="en")
        bert_scores.append(F1.mean().item())

        # BLEURT
        bleurt_scores.append(bleurt_scorer.score(references=[ref], candidates=[pred])[0])

        # BARTScore
        bart_scores.append(bart_scorer.score([pred], [ref])[0])

    return bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores

# Calculate metrics
bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores = calculate_metrics_extended(filtered_justifications)

# Summarize and print results
avg_rouge_1 = sum([score['rouge-1']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_2 = sum([score['rouge-2']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_l = sum([score['rouge-l']['f'] for score in rouge_scores]) / len(rouge_scores)

print(f"Average BLEU Score: {sum(bleu_scores) / len(bleu_scores):.4f}")
print(f"Average METEOR Score: {sum(meteor_scores) / len(meteor_scores):.4f}")
print(f"Average ChrF Score: {sum(chrf_scores) / len(chrf_scores):.4f}")
print(f"Average TER Score: {sum(ter_scores) / len(ter_scores):.4f}")
print(f"Average BERTScore F1: {sum(bert_scores) / len(bert_scores):.4f}")
print(f"Average BLEURT Score: {sum(bleurt_scores) / len(bleurt_scores):.4f}")
print(f"Average BARTScore: {sum(bart_scores) / len(bart_scores):.4f}")
print(f"Average ROUGE-1 F1 Score: {avg_rouge_1:.4f}")
print(f"Average ROUGE-2 F1 Score: {avg_rouge_2:.4f}")
print(f"Average ROUGE-L F1 Score: {avg_rouge_l:.4f}")

# Calculate accuracy
accuracy = (correct_predictions / total_processed_claims) * 100 if total_processed_claims > 0 else 0
print(f"Model Accuracy: {accuracy:.2f}%")

# Calculate the F1 score
f1 = f1_score(actual_labels, predicted_labels, average='weighted', labels=["true", "fake"])
print(f"F1 Score Average: {f1}")

# Confusion matrix
cm = confusion_matrix(actual_labels, predicted_labels, labels=["true", "fake"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["true", "fake"])
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: there have been numerous credible reports and photographic evidence documenting mass graves containing the bodies of ukrainian civilians and soldiers killed during the russian invasion.
# Actual Justification: the video in question is much older and shows a mass grave burial from 2020 in syria, not related to the russia-ukraine conflict. the video was misleadingly repurposed to create a false narrative about ukraine's situation.
# --------------------------------------------------
# ['TRUE', 'Delhi court has indeed issued a production warrant against Jammu and Kashmir officer Davinder Singh in connection with a terrorism case.']
# Claim #4452
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: delhi court issues production warrant against j&k officer davinder singh.
# Claim: delhi court issues production warrant against j&k officer davinder singh.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: delhi court has indeed issued a production warrant against jammu and kashmir officer davinder singh in connection with a terrorism case.
# Actual Justification: according to the hindu, a delhi court issued a production warrant against jammu and kashmir officer davinder singh in connection with charges related to his alleged involvement in a terror-related case.
# --------------------------------------------------
# ['FAKE ', 'There is no officially confirmed trust for building a mosque in a 5-acre plot in Ayodhya.']
# Claim #4453
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Trust constituted for building mosque in 5-acre plot in ayodhya
# Claim: Trust constituted for building mosque in 5-acre plot in ayodhya
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no officially confirmed trust for building a mosque in a 5-acre plot in ayodhya.
# Actual Justification: the article confirms that a trust named the indo-islamic cultural foundation has been constituted to oversee the construction of a mosque on a 5-acre plot allocated in ayodhya, as per the supreme court's 2019 verdict.
# --------------------------------------------------
# ['TRUE ', 'Deputy US Secretary of State Stephen Biegun did indeed visit Delhi and call for a "Pax Indo-Pacific" during his tenure in the Trump administration.']
# Claim #4454
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: In delhi, deputy us secretary of state stephen biegun pitches for pax indo-pacifica.
# Claim: In delhi, deputy us secretary of state stephen biegun pitches for pax indo-pacifica.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: deputy us secretary of state stephen biegun did indeed visit delhi and call for a "pax indo-pacific" during his tenure in the trump administration.
# Actual Justification: the claim that deputy us secretary of state stephen biegun pitched for pax indo-pacifica was made during his visit to india on october 12, 2020. according to a dna india article, biegun described pax indo-pacifica as a vision of a region at peace, protected, and made prosperous by the countries of the indo-pacific. he emphasized a pluralistic vision that ensures the prosperity and sovereignty of the region's diverse countries in a free and open indo-pacific. this statement was made at the india-us forum in delhi, alongside indian foreign secretary harsh shringla.
# --------------------------------------------------
# ['TRUE ', 'PGIMER Chandigarh frequently releases recruitment notifications, and their official website is pgimer.edu.in.']
# Claim #4455
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pgimer chandigarh recruitment applications invited for various posts, apply till october 3 at pgimer.edu.in
# Claim: Pgimer chandigarh recruitment applications invited for various posts, apply till october 3 at pgimer.edu.in
# Predicted Label: true
# Actual Label: true
# Predicted Justification: pgimer chandigarh frequently releases recruitment notifications, and their official website is pgimer.edu.in.
# Actual Justification: the claim is supported by a report from *the statesman*, which confirms that pgimer chandigarh invited applications for various posts, with a deadline for submission on october 3, through the official website pgimer.edu.in.
# --------------------------------------------------
# ['TRUE', 'A bomb blast targeting a mosque in Peshawar, Pakistan, on January 30, 2023, resulted in the deaths of over 80 people and numerous injuries.']
# Claim #4456
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: The horrific bomb blast that killed more than 80 people in a Peshawar mosque on January 30, 2023.
# Claim: The horrific bomb blast that killed more than 80 people in a Peshawar mosque on January 30, 2023.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: a bomb blast targeting a mosque in peshawar, pakistan, on january 30, 2023, resulted in the deaths of over 80 people and numerous injuries.
# Actual Justification: the video shared in this claim is not related to the peshawar mosque bombing on january 30, 2023. it actually shows footage from a 2021 factory explosion in lahore, pakistan, falsely circulated as the recent blast in peshawar. the claim is inaccurate as the video is from an unrelated incident.
# --------------------------------------------------
# ['FAKE', 'The claim lacks credible evidence and often appears in manipulated contexts to promote a specific political narrative.']
# Claim #4457
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A man keeps on saying 'Jai Shri Ram' while West Bengal police continue to thrash him.
# Claim: A man keeps on saying 'Jai Shri Ram' while West Bengal police continue to thrash him.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim lacks credible evidence and often appears in manipulated contexts to promote a specific political narrative.
# Actual Justification: the video in question is not from west bengal and has been circulated since 2014. it has been misattributed to a recent event involving police brutality in west bengal. the incident shown in the video is unrelated to the state or the claim about the police attacking the man for chanting 'jai shri ram.'
# --------------------------------------------------
# ['FAKE ', 'There is no credible evidence or reporting supporting this claim.']
# Claim #4458
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pankaja munde posts picture with bjp symbol in tribute to rajendra prasad amid rumours
# Claim: Pankaja munde posts picture with bjp symbol in tribute to rajendra prasad amid rumours
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no credible evidence or reporting supporting this claim.
# Actual Justification: the claim is accurate as pankaja munde shared a picture of the bjp symbol, which she linked to a tribute to rajendra prasad, amidst speculations regarding her political future.
# --------------------------------------------------
# ['TRUE', 'The Government of India, under Prime Minister Narendra Modi, has initiated a survey to assess the water quality and quantity of 6 crore tap connections installed in villages under the Jal Jeevan Mission.']
# Claim #4459
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Modi govt begins survey of 6 cr tap connections in villages to assess water quality, quantity.
# Claim: Modi govt begins survey of 6 cr tap connections in villages to assess water quality, quantity.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the government of india, under prime minister narendra modi, has initiated a survey to assess the water quality and quantity of 6 crore tap connections installed in villages under the jal jeevan mission.
# Actual Justification: the article confirms that the modi government has initiated a survey of 6 crore tap connections in villages to assess water quality and quantity.
# --------------------------------------------------
# ['TRUE', 'Abrogation of Article 370 significantly altered the political relationship between Jammu and Kashmir, New Delhi, and Kashmiri opposition parties, leading to heightened tensions and a shift in power dynamics.']
# Claim #4460
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Abrogation of article 370 has changed relationship between j&k, new delhi, kashmir opposition parties.
# Claim: Abrogation of article 370 has changed relationship between j&k, new delhi, kashmir opposition parties.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: abrogation of article 370 significantly altered the political relationship between jammu and kashmir, new delhi, and kashmiri opposition parties, leading to heightened tensions and a shift in power dynamics.
# Actual Justification: the abrogation of article 370 has led to significant shifts in the relationship between jammu and kashmir and the central government, as well as affecting the dynamics within the region's opposition parties.
# --------------------------------------------------
# ['FAKE ', 'This event has not occurred. As a factual AI, I do not have information about future events.']
# Claim #4461
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Hezbollah’s attack on israel’s haifa city on september 27, 2024.
# Claim: Hezbollah’s attack on israel’s haifa city on september 27, 2024.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this event has not occurred. as a factual ai, i do not have information about future events.
# Actual Justification: the claim that this video shows hezbollah’s attack on israel’s haifa city on september 27, 2024, is false. according to pesacheck, the video is actually from a different incident and has no connection to recent events involving hezbollah and haifa.
# --------------------------------------------------
# ['FAKE', 'This scenario is highly improbable and likely fictional. ', '', "Here's why:", '', '* **Massive Hacking**: Stealing millions from 217 banks simultaneously is a level of hacking sophistication rarely seen and practically impossible to pull off without leaving traceable digital footprints.', '* **Donations**: Proving the money was truly donated to specific beneficiaries in Africa and Palestine would be incredibly difficult, given the vastness and complexity of financial transactions. ', '* **Death Sentence**:  Hackers are rarely sentenced to death, even for significant financial crimes.  The penalties typically involve imprisonment and fines.', '', '', 'The combination of these elements points to a fabricated story.']
# Claim #4462
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A hacker stole millions of dollars from 217 banks, donated all the money to the poor people of Africa and Palestine, and accepted his death sentence with a smile.
# Claim: A hacker stole millions of dollars from 217 banks, donated all the money to the poor people of Africa and Palestine, and accepted his death sentence with a smile.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this scenario is highly improbable and likely fictional.   here's why:  * **massive hacking**: stealing millions from 217 banks simultaneously is a level of hacking sophistication rarely seen and practically impossible to pull off without leaving traceable digital footprints. * **donations**: proving the money was truly donated to specific beneficiaries in africa and palestine would be incredibly difficult, given the vastness and complexity of financial transactions.  * **death sentence**:  hackers are rarely sentenced to death, even for significant financial crimes.  the penalties typically involve imprisonment and fines.   the combination of these elements points to a fabricated story.
# Actual Justification: the claim that a hacker stole millions of dollars from 217 banks and donated the money to the poor in africa and palestine is a hoax. there is no verifiable evidence or credible report to support this story. the claim of a death sentence and the hacker's robin hood-like actions is also fabricated. this claim appears to be an exaggerated or fictional narrative with no factual basis.
# --------------------------------------------------
# ['FAKE ', '', 'The prompt provides a potentially inflammatory statement without sources or context, making it difficult to verify its accuracy.']
# Claim #4463
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Late night clashes at sabarimala, bjp and rss protest outside cm’s house
# Claim: Late night clashes at sabarimala, bjp and rss protest outside cm’s house
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the prompt provides a potentially inflammatory statement without sources or context, making it difficult to verify its accuracy.
# Actual Justification: the claim is supported by the business standard article, which reports that late-night clashes occurred at sabarimala, followed by protests led by bjp and rss workers outside the kerala chief minister's residence, opposing the supreme court's order on women's entry to the temple.
# --------------------------------------------------
# ['TRUE', 'A funeral procession for the pregnant elephant that died in Kerala after consuming a pineapple filled with fireworks was held on May 29, 2020, with significant public participation and media attention.']
# Claim #4464
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: There was a funeral procession of the pregnant elephant that died in kerala on 27 may 2020.
# Claim: There was a funeral procession of the pregnant elephant that died in kerala on 27 may 2020.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: a funeral procession for the pregnant elephant that died in kerala after consuming a pineapple filled with fireworks was held on may 29, 2020, with significant public participation and media attention.
# Actual Justification: the claim that the video shows the funeral procession of the pregnant elephant that died in kerala on 27 may 2020 is false. according to factly, the video being shared is actually an old, unrelated video that has been edited together. the video has no connection to the incident involving the pregnant elephant in kerala.
# --------------------------------------------------
# ['FAKE ', '', 'The provided information is not a verifiable claim and appears to be a fragment of a news story.']
# Claim #4465
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: It's family matter, rohit pawar on ncp chief rebuking parth.
# Claim: It's family matter, rohit pawar on ncp chief rebuking parth.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the provided information is not a verifiable claim and appears to be a fragment of a news story.
# Actual Justification: the claim is accurate as per the article, which reports that rohit pawar referred to the rebuke between ncp chief sharad pawar and parth pawar as a family matter.
# --------------------------------------------------
# ['FAKE', 'There is no credible evidence from reliable sources to support the claim that Jyotiraditya Scindia is leaving the BJP.']
# Claim #4466
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: According to Twitter handle 'India TV', Jyotiraditya Scindia is on his way out of BJP.
# Claim: According to Twitter handle 'India TV', Jyotiraditya Scindia is on his way out of BJP.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence from reliable sources to support the claim that jyotiraditya scindia is leaving the bjp.
# Actual Justification: the claim is false. there is no indication that jyotiraditya scindia is leaving the bjp. according to recent reports, scindia will stay in the bjp for the time being.
# --------------------------------------------------
# ['FAKE ', "Despite the sentiment being widely circulated online, there's no credible evidence showing the Motherland Monument was ever illuminated with this phrase."]
# Claim #4467
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Motherland Monument of Kyiv being lit with the phrase 'Russian warships f**k yourself'.
# Claim: Motherland Monument of Kyiv being lit with the phrase 'Russian warships f**k yourself'.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: despite the sentiment being widely circulated online, there's no credible evidence showing the motherland monument was ever illuminated with this phrase.
# Actual Justification: the image in question is not recent and does not show the motherland monument in kyiv with the phrase mentioned. the image is from 2018 and was a light installation event unrelated to the ongoing war in ukraine. the claim is misleading and misrepresents the context.
# --------------------------------------------------
# ['FAKE ', '', 'There is no credible evidence to support this claim. Spreading misinformation about communal violence can be harmful and incite further conflict.']
# Claim #4468
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A policeman was heckled by muslims in haldwani amid communal violence there.
# Claim: A policeman was heckled by muslims in haldwani amid communal violence there.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence to support this claim. spreading misinformation about communal violence can be harmful and incite further conflict.
# Actual Justification: the video actually shows an incident that happened in madhya pradesh’s damoh district. it has been falsely linked to the violence in haldwani.
# --------------------------------------------------
# ['TRUE ', 'The stated claim is true. The car used in the murder of Hindu leader Kamlesh Tiwari was seized by the Special Task Force (STF) in 2019.']
# Claim #4469
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Car used in hindu leader kamlesh tiwari's murder seized by stf
# Claim: Car used in hindu leader kamlesh tiwari's murder seized by stf
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the stated claim is true. the car used in the murder of hindu leader kamlesh tiwari was seized by the special task force (stf) in 2019.
# Actual Justification: the uttar pradesh special task force (stf) seized the car allegedly used in the murder of hindu leader kamlesh tiwari.
# --------------------------------------------------
# ['FAKE', 'According to historical records, Coca-Cola sold around 9,000 bottles in its first year.']
# Claim #4470
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Coca-Cola sold just 25 bottles in its first year.
# Claim: Coca-Cola sold just 25 bottles in its first year.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: according to historical records, coca-cola sold around 9,000 bottles in its first year.
# Actual Justification: the claim is false. coca-cola did not sell only 25 bottles in its first year. while it did have limited sales in its early days, it sold more than just 25 bottles. the claim is a misinterpretation of coca-cola's early sales history.
# --------------------------------------------------
# ['TRUE ', 'Leaving full bottles of sanitizer in a hot car can cause them to explode due to the pressure buildup from the heat.']
# Claim #4471
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Delhi sanitizer blast in heat at rohini flyover, delhi, please, never keep full bottles of sanitizer in your car carry just very little bottle never leave it in the car and expose it to heat.
# Claim: Delhi sanitizer blast in heat at rohini flyover, delhi, please, never keep full bottles of sanitizer in your car carry just very little bottle never leave it in the car and expose it to heat.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: leaving full bottles of sanitizer in a hot car can cause them to explode due to the pressure buildup from the heat.
# Actual Justification: the claim that a sanitizer blast occurred in the heat at rohini flyover, delhi, and that it is dangerous to keep full bottles of sanitizer in your car is false. according to newsmeter, the incident did not involve a hand sanitizer blast. the fire incident at rohini flyover was not caused by hand sanitizer.
# --------------------------------------------------
# ['FAKE', 'The claim lacks credible sources and context, making it difficult to verify if this is true.']
# Claim #4472
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Farmers from rajasthan, haryana, to move towards delhi on sunday.
# Claim: Farmers from rajasthan, haryana, to move towards delhi on sunday.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim lacks credible sources and context, making it difficult to verify if this is true.
# Actual Justification: farmers from rajasthan and haryana planned to move towards delhi on sunday to protest against the central government's new farm laws, as reported in media coverage of the ongoing farmer protests.
# --------------------------------------------------
# ['FAKE', 'The Arvind Kejriwal government imposed a weekend lockdown in Delhi from  April 17-19, 2021.']
# Claim #4473
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: The Arvind Kejriwal government has not imposed any lockdown in Delhi until March 31
# Claim: The Arvind Kejriwal government has not imposed any lockdown in Delhi until March 31
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the arvind kejriwal government imposed a weekend lockdown in delhi from  april 17-19, 2021.
# Actual Justification: the claim is based on an old video from march 2020 when a lockdown was announced in delhi. the video has resurfaced and is being shared as recent. delhi health minister satyendar jain has confirmed that there is no plan to impose another lockdown in delhi as of now.
# --------------------------------------------------
# ['TRUE', "Manish Tiwari, a politician from the Indian National Congress, has indeed publicly urged the Prime Minister to award Bharat Ratna, India's highest civilian award, posthumously to Bhagat Singh, Sukhdev, and Rajguru."]
# Claim #4474
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Manish tiwari urges pm to give bharat ratna to bhagat singh, sukhdev, and rajguru
# Claim: Manish tiwari urges pm to give bharat ratna to bhagat singh, sukhdev, and rajguru
# Predicted Label: true
# Actual Label: true
# Predicted Justification: manish tiwari, a politician from the indian national congress, has indeed publicly urged the prime minister to award bharat ratna, india's highest civilian award, posthumously to bhagat singh, sukhdev, and rajguru.
# Actual Justification: the claim is accurate as manish tiwari, a congress leader, urged the prime minister to award the bharat ratna to freedom fighters bhagat singh, sukhdev, and rajguru.
# --------------------------------------------------
# ['FAKE', '', 'There is no credible evidence or reporting suggesting that Ashok Tanwar is facing bribery charges or that he is likely to be sacked based on such allegations.']
# Claim #4475
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Ashok tanwar could end up sacked like margaret alva for bribery charges against congress.
# Claim: Ashok tanwar could end up sacked like margaret alva for bribery charges against congress.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no credible evidence or reporting suggesting that ashok tanwar is facing bribery charges or that he is likely to be sacked based on such allegations.
# Actual Justification: the article from *the print* discusses the possibility of ashok tanwar being sacked over bribery charges, similar to the case of margaret alva.
# --------------------------------------------------
# ['FAKE', 'This statement is fabricated and misleading. No official statement from Shantanu Thakur, BJP MP, supports this claim.']
# Claim #4476
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Matuas don't need patta land, we only want caa in west bengal, says bjp mp shantanu thakur.
# Claim: Matuas don't need patta land, we only want caa in west bengal, says bjp mp shantanu thakur.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this statement is fabricated and misleading. no official statement from shantanu thakur, bjp mp, supports this claim.
# Actual Justification: the claim is verified by the article, which reports that bjp mp shantanu thakur stated that the matua community does not require patta land but wants the implementation of the caa in west bengal.
# --------------------------------------------------
# ['TRUE', 'This claim likely refers to a real event where Amarinder Singh, a former Chief Minister of Punjab, criticized Union Minister Prakash Javadekar for attributing blame to the Congress party for violence in Delhi.']
# Claim #4477
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Amarinder slams union minister javadekar for trying to blame congress for delhi violence.
# Claim: Amarinder slams union minister javadekar for trying to blame congress for delhi violence.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this claim likely refers to a real event where amarinder singh, a former chief minister of punjab, criticized union minister prakash javadekar for attributing blame to the congress party for violence in delhi.
# Actual Justification: the article from the print confirms that amarinder singh criticized union minister prakash javadekar for attempting to blame the congress party for the delhi violence.
# --------------------------------------------------
# ['FAKE ', 'The Dalai Lama has not been publicly listed as an invitee for any recent "bhumi pujan" ceremonies.']
# Claim #4478
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Dalai lama among the invitees for bhumi pujan.
# Claim: Dalai lama among the invitees for bhumi pujan.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the dalai lama has not been publicly listed as an invitee for any recent "bhumi pujan" ceremonies.
# Actual Justification: the article confirms that the dalai lama was invited to attend the bhumi pujan ceremony in himachal pradesh.
# --------------------------------------------------
# ['FAKE', 'There is no credible information or news reports supporting the claim that a CPI(M) leader tripped Sitaram Yechury to enter the Rajya Sabha.']
# Claim #4479
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: The cpi(m) leader who tripped party boss sitaram yechury to enter rajya sabha.
# Claim: The cpi(m) leader who tripped party boss sitaram yechury to enter rajya sabha.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no credible information or news reports supporting the claim that a cpi(m) leader tripped sitaram yechury to enter the rajya sabha.
# Actual Justification: a cpi(m) leader, who had a significant role in sitaram yechury not securing a rajya sabha seat in 2016, later entered the rajya sabha himself.
# --------------------------------------------------
# ['TRUE', 'PM Modi has spoken about the history of Vadnagar assisting Tansen, a famous musician from Rewa, during events in Madhya Pradesh.']
# Claim #4480
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: My birthplace vadnagar once helped rewa's famous musician tansen, says pm modi in madhya pradesh.
# Claim: My birthplace vadnagar once helped rewa's famous musician tansen, says pm modi in madhya pradesh.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: pm modi has spoken about the history of vadnagar assisting tansen, a famous musician from rewa, during events in madhya pradesh.
# Actual Justification: the article confirms that pm modi mentioned how his birthplace, vadnagar, once helped tansen, the famous musician from rewa, during a speech in madhya pradesh.
# --------------------------------------------------
# ['FAKE', '', 'This statement cannot be verified without a source and a specific date.']
# Claim #4481
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: 46 covid deaths reported in Punjab.
# Claim: 46 covid deaths reported in Punjab.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this statement cannot be verified without a source and a specific date.
# Actual Justification: recent reports indicate that 46 covid-19 related deaths have been recorded in punjab.
# --------------------------------------------------
# ['TRUE', 'The Supreme Court of India has indeed issued notices to the government on a PIL seeking mandatory display of the country of origin on products sold on e-commerce platforms.']
# Claim #4482
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: SC notice to govt on PIL seeking mandatory display of country of origin on products on e-commerce portals
# Claim: SC notice to govt on PIL seeking mandatory display of country of origin on products on e-commerce portals
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the supreme court of india has indeed issued notices to the government on a pil seeking mandatory display of the country of origin on products sold on e-commerce platforms.
# Actual Justification: the claim is accurate as the supreme court issued a notice to the government on a pil that seeks the mandatory display of the country of origin for products sold on e-commerce platforms.
# --------------------------------------------------
# ['FAKE', '', 'There is no credible evidence to support this claim.']
# Claim #4483
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Israel bombed Palestinian children who had gathered to drink water in Gaza.
# Claim: Israel bombed Palestinian children who had gathered to drink water in Gaza.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence to support this claim.
# Actual Justification: the claim is false. the video is from sudan and shows a drone attack by the sudanese army on the paramilitary force 'rapid support force' near khartoum airport. it has no connection to the ongoing israel-hamas conflict.
# --------------------------------------------------
# ['TRUE', 'The Allahabad High Court granted bail to journalist Prashant Kanojia two months after his arrest in 2019.']
# Claim #4484
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Two months after his arrest, the allahabad high court granted bail to journalist prashant kanojia.
# Claim: Two months after his arrest, the allahabad high court granted bail to journalist prashant kanojia.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the allahabad high court granted bail to journalist prashant kanojia two months after his arrest in 2019.
# Actual Justification: the allahabad high court granted bail to journalist prashant kanojia, who was arrested over alleged objectionable social media posts, nearly two months after his detention.
# --------------------------------------------------
# ['TRUE', 'The incident occurred at a press conference in Telangana in 2019 and was widely reported.']
# Claim #4485
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: During a press conference, when Rahul Gandhi was asked to show the backside of a poster, he turned around, showing his back to reporters instead.
# Claim: During a press conference, when Rahul Gandhi was asked to show the backside of a poster, he turned around, showing his back to reporters instead.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the incident occurred at a press conference in telangana in 2019 and was widely reported.
# Actual Justification: the claim that rahul gandhi turned around and showed his back to reporters during a press conference when asked to show the backside of a poster is false. the incident was misrepresented and edited in a way to make it seem like rahul gandhi made a mistake. in reality, he was responding to a question and his turning around was unrelated to the poster request.
# --------------------------------------------------
# ['TRUE', "Sangeeta Phogat lost to American Jennifer Page Rogers 10-0 in the women's 57kg freestyle wrestling at the World Championships in Belgrade."]
# Claim #4486
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Sangeeta Phogat, one of the six wrestlers who protested against WFI Chief Brij Bhushan Sharan Singh, lost to American Jennifer Page Rogers 10-0.
# Claim: Sangeeta Phogat, one of the six wrestlers who protested against WFI Chief Brij Bhushan Sharan Singh, lost to American Jennifer Page Rogers 10-0.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: sangeeta phogat lost to american jennifer page rogers 10-0 in the women's 57kg freestyle wrestling at the world championships in belgrade.
# Actual Justification: while sangeeta phogat did lose to jennifer page rogers 10-0 in a match, the claim is misleading. she went on to win the bronze medal in the tournament, disproving the assertion that her loss was the end of her competition performance.
# --------------------------------------------------
# ['FAKE ', '', 'This claim is likely fabricated and intended to spread misinformation during a sensitive conflict. Sharing unverified information can be harmful and contribute to the spread of propaganda.']
# Claim #4487
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A hamas leader caught in a compromising position with a sex worker in a hotel amid the ongoing conflict in gaza.
# Claim: A hamas leader caught in a compromising position with a sex worker in a hotel amid the ongoing conflict in gaza.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is likely fabricated and intended to spread misinformation during a sensitive conflict. sharing unverified information can be harmful and contribute to the spread of propaganda.
# Actual Justification: the video is from 2021 and predates the ongoing gaza conflict by over two years. it shows hamas leader abdel rahim abou fanah in a compromising position with a woman in an israeli hotel.
# --------------------------------------------------
# ['FAKE', 'The claim lacks credible sources and appears to be a misleading statement. There is no official policy or announcement from Congress indicating they will bear the cost of rail travel for all needy migrant workers.']
# Claim #4488
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Congress to bear cost of rail travel of every needy migrant worker, sonia.
# Claim: Congress to bear cost of rail travel of every needy migrant worker, sonia.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim lacks credible sources and appears to be a misleading statement. there is no official policy or announcement from congress indicating they will bear the cost of rail travel for all needy migrant workers.
# Actual Justification: the article reports that sonia gandhi announced that congress would bear the cost of rail travel for every needy migrant worker during the covid-19 crisis.
# --------------------------------------------------
# ['FAKE', 'The claim is likely a politically motivated generalization and lacks credible evidence.']
# Claim #4489
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Muslim brutalities on Hindus in Hooghly district of West Bengal.
# Claim: Muslim brutalities on Hindus in Hooghly district of West Bengal.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is likely a politically motivated generalization and lacks credible evidence.
# Actual Justification: the claim is false. the video being circulated is unrelated to any incident of muslim brutality on hindus in hooghly. the video was taken in a different context and does not depict the claimed events in west bengal.
# --------------------------------------------------
# ['TRUE', 'This type of news announcement is common and aligns with government practices of honoring essential workers during national holidays.']
# Claim #4490
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Independence day celebration: gujarat govt to felicitate 50 covid warriors today.
# Claim: Independence day celebration: gujarat govt to felicitate 50 covid warriors today.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this type of news announcement is common and aligns with government practices of honoring essential workers during national holidays.
# Actual Justification: the gujarat government planned to honor 50 covid-19 warriors during the independence day celebrations.
# --------------------------------------------------
# ['TRUE', 'The Government of India has announced a waiver of interest on interest (also known as "RoI") for loans up to Rs 2 crore taken by individuals and MSMEs under specific schemes during the Covid-19 pandemic.']
# Claim #4491
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Govt waives interest on interest for loans up to rs 2 crore
# Claim: Govt waives interest on interest for loans up to rs 2 crore
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the government of india has announced a waiver of interest on interest (also known as "roi") for loans up to rs 2 crore taken by individuals and msmes under specific schemes during the covid-19 pandemic.
# Actual Justification: the government of india decided to waive the compound interest (interest on interest) on loans up to rs 2 crore for individuals, msmes, and other borrowers who did not avail of the moratorium during the covid-19 pandemic. this measure was aimed at providing relief to borrowers facing financial hardships due to the economic impact of the pandemic.
# --------------------------------------------------
# ['FAKE', 'Gujarat has seen significant infrastructure development in the last two decades, including new universities, airports, and metro lines, such as the Ahmedabad Metro.']
# Claim #4492
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: no new university, airport or metro in Gujarat in the last two decades
# Claim: no new university, airport or metro in Gujarat in the last two decades
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: gujarat has seen significant infrastructure development in the last two decades, including new universities, airports, and metro lines, such as the ahmedabad metro.
# Actual Justification: the claim is false. over the last two decades, gujarat has established more than nine universities, several new airports, and the ahmedabad metro was inaugurated in 2022. these developments have occurred under the bjp government.
# --------------------------------------------------
# ['FAKE', 'Accusations of faking funerals are deeply insensitive and lack evidence. Spreading such misinformation perpetuates harmful stereotypes and hinders understanding of the humanitarian crisis in Gaza.']
# Claim #4493
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line:  Gaza people faking a man’s funeral to gain international sympathy for Palestine.
# Claim:  Gaza people faking a man’s funeral to gain international sympathy for Palestine.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: accusations of faking funerals are deeply insensitive and lack evidence. spreading such misinformation perpetuates harmful stereotypes and hinders understanding of the humanitarian crisis in gaza.
# Actual Justification: the claim is false. the video actually shows jordanians participating in a creative act to escape a lockdown, not palestinians faking a funeral. the video was misrepresented and misidentified as taking place in gaza.
# --------------------------------------------------
# ['FAKE', 'The sentence implies a definitive policy or action by the education minister, which is likely an oversimplification of complex issues related to talent and patent migration.']
# Claim #4494
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Will stop talent and patent from leaving country, education minister nishank.
# Claim: Will stop talent and patent from leaving country, education minister nishank.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the sentence implies a definitive policy or action by the education minister, which is likely an oversimplification of complex issues related to talent and patent migration.
# Actual Justification: the claim is accurate as the article reports that union education minister ramesh pokhriyal nishank stated that measures will be taken to prevent talent and patents from leaving india.
# --------------------------------------------------
# ['FAKE ', 'Lacking reliable source or evidence to confirm the claim.']
# Claim #4495
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Robbery at gunpoint in broad daylight is from Punjab’s Ludhiana.
# Claim: Robbery at gunpoint in broad daylight is from Punjab’s Ludhiana.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: lacking reliable source or evidence to confirm the claim.
# Actual Justification: the claim is false. the video is not from ludhiana, punjab. it is from an earlier incident in south africa, not india.
# --------------------------------------------------
# ['FAKE', '', "The claim uses a tragic incident to spread harmful and inaccurate stereotypes about refugees, implying they are inherently dangerous. It's important to remember that violence is never justified and generalizing about entire groups of people is dangerous and irresponsible."]
# Claim #4496
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: The person mentioned is the same teacher who was beheaded by a jihadi in Paris. A few years ago, he was welcoming refugees coming to France, but little did he know that the refugees would behead him. This is for those who want Rohingyas to settle in India.
# Claim: The person mentioned is the same teacher who was beheaded by a jihadi in Paris. A few years ago, he was welcoming refugees coming to France, but little did he know that the refugees would behead him. This is for those who want Rohingyas to settle in India.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim uses a tragic incident to spread harmful and inaccurate stereotypes about refugees, implying they are inherently dangerous. it's important to remember that violence is never justified and generalizing about entire groups of people is dangerous and irresponsible.
# ...
# Claim: Russian president vladimir putin did not come to the airport to receive pm modi, whereas putin had received chinese president xi jinping.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: this claim is based on publicly available information regarding recent diplomatic visits and receptions.
# Actual Justification: the claim that russian president vladimir putin did not come to the airport to receive pm modi, whereas putin had received chinese president xi jinping is false. according to the quint, neither pm modi nor xi jinping was received by putin at the airport. pm modi was welcomed by russia's first deputy prime minister denis manturov, while xi jinping was received by russian deputy prime minister dmitry chernyshenko.
# --------------------------------------------------
# ['FAKE', "The claim is false and likely a piece of misinformation spreading. There's no credible evidence of a cathedral surviving both World Wars only to be burnt down by illegal immigrants during recent French protests.  Attribution of such events requires careful verification from reliable sources."]
# Claim #4994
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A cathedral which survived both world wars was burnt down by illegal immigrants during the recent violent protests following a police killing in France.
# Claim: A cathedral which survived both world wars was burnt down by illegal immigrants during the recent violent protests following a police killing in France.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is false and likely a piece of misinformation spreading. there's no credible evidence of a cathedral surviving both world wars only to be burnt down by illegal immigrants during recent french protests.  attribution of such events requires careful verification from reliable sources.
# Actual Justification: the claim is false. the fire at the cathedral occurred in 2020, not during the recent protests in france. the cathedral did not survive the two world wars as claimed, and the fire was not related to the recent violence. it was caused by an electrical fault.
# --------------------------------------------------
# ['FAKE', "Ayesha Azhar's death was officially attributed to a cardiac arrest."]
# Claim #4995
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pakistani social media personality Ayesha Azhar of ‘Mera Dil Ye Pukare Aaja’ fame died of a drug overdose.
# Claim: Pakistani social media personality Ayesha Azhar of ‘Mera Dil Ye Pukare Aaja’ fame died of a drug overdose.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: ayesha azhar's death was officially attributed to a cardiac arrest.
# Actual Justification: the claim that ayesha azhar has died of a drug overdose is false. the content creator is alive, and rumors of her death are baseless.
# --------------------------------------------------
# ['FAKE ', ' ', 'There is no credible evidence or documentation of a bird helping people unfurl a national flag during Independence Day celebrations in Kerala.']
# Claim #4996
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A bird helping people unfurl the national flag during independence day celebrations in kerala.
# Claim: A bird helping people unfurl the national flag during independence day celebrations in kerala.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence or documentation of a bird helping people unfurl a national flag during independence day celebrations in kerala.
# Actual Justification: the claim that this video shows a bird helping people unfurl the national flag during independence day celebrations in kerala is false. according to hindustan times, the video is an optical illusion created by the camera angle. the bird actually sat on a coconut tree behind the flag and did not aid in its unfurling.
# --------------------------------------------------
# ['FAKE', 'The claim lacks context and requires further information to be assessed for validity.']
# Claim #4997
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Delhi journalist appeals for financial help
# Claim: Delhi journalist appeals for financial help
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim lacks context and requires further information to be assessed for validity.
# Actual Justification: the article describes a video shared by rahul gandhi, where a delhi journalist appeals for financial help, and the aap government responds by offering assistance.
# --------------------------------------------------
# ['TRUE', 'A bus carrying BSF jawans on election duty overturned in Darbhanga, Bihar, resulting in the death of nine personnel.']
# Claim #4998
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Nine BSF jawans on way to bihar election duty were killed after a bus carrying them overturned in darbhanga district.
# Claim: Nine BSF jawans on way to bihar election duty were killed after a bus carrying them overturned in darbhanga district.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: a bus carrying bsf jawans on election duty overturned in darbhanga, bihar, resulting in the death of nine personnel.
# Actual Justification: the claim that nine bsf jawans on their way to bihar election duty were killed after a bus carrying them overturned in darbhanga district is false. according to india today, the incident did occur, but no lives were lost. ten bsf personnel, including the driver, were injured when their bus overturned at the darbhanga-muzaffarpur border on november 4, 2020. all the injured personnel were treated and discharged the same day with minor injuries.
# --------------------------------------------------
# ['FAKE ', 'The Preamble to the Indian Constitution does not have a blank reverse side.']
# Claim #4999
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Amit Shah is reading the blank reverse side of the preamble.
# Claim: Amit Shah is reading the blank reverse side of the preamble.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the preamble to the indian constitution does not have a blank reverse side.
# Actual Justification: the image of amit shah is not showing him reading the blank reverse side of the preamble. the document is the preamble of the indian constitution, and the claim is a misinterpretation.
# --------------------------------------------------
# ['TRUE ', 'The Government of India has frequently announced plans, and sometimes implemented changes, to the salary structure of contractual workers under the National Health Mission (NHM).']
# Claim #5000
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Govt to modify salary structure of contractual workers under nhm
# Claim: Govt to modify salary structure of contractual workers under nhm
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the government of india has frequently announced plans, and sometimes implemented changes, to the salary structure of contractual workers under the national health mission (nhm).
# Actual Justification: the claim that the government will modify the salary structure of contractual workers under the national health mission (nhm) is true. according to the indian express, the maharashtra government approved a proposal to improve the pay structure of 22,500 contractual employees under the nhm. this decision aims to address pay disparities and ensure that at least 12,000 employees benefit as per the minimum wage requirement.
# --------------------------------------------------
# ['FAKE', 'The provided statement is incomplete and lacks context to determine its validity.  "Opposition slams" is too general and could apply to various actions, not necessarily a negative outcome for the government.']
# Claim #5001
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Opposition slams modi govt after lok sabha passes amendment to rti act.
# Claim: Opposition slams modi govt after lok sabha passes amendment to rti act.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the provided statement is incomplete and lacks context to determine its validity.  "opposition slams" is too general and could apply to various actions, not necessarily a negative outcome for the government.
# Actual Justification: the claim is accurate as the article reports that the opposition parties criticized the modi government following the passing of the amendment to the rti act in the lok sabha.
# --------------------------------------------------
# ['TRUE', 'The Uttar Pradesh government announced the establishment of 218 fast-track courts dedicated to cases involving women and children in the wake of the Unnao rape case in 2019.']
# Claim #5002
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: After unnao case, up cabinet orders setting up of 218 fast-track courts for women, children.
# Claim: After unnao case, up cabinet orders setting up of 218 fast-track courts for women, children.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the uttar pradesh government announced the establishment of 218 fast-track courts dedicated to cases involving women and children in the wake of the unnao rape case in 2019.
# Actual Justification: the claim is accurate as per the article, which reports that the up cabinet ordered the establishment of 218 fast-track courts for women and children in the wake of the unnao case.
# --------------------------------------------------
# ['FAKE', "The statement expresses an opinion and makes a prediction about the BJP's future performance in Telangana. It lacks concrete evidence and relies on subjective assessments of strategy and leadership."]
# Claim #5003
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: With lack of strategy and state leadership, bjp prepares to flounder in Telangana.
# Claim: With lack of strategy and state leadership, bjp prepares to flounder in Telangana.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the statement expresses an opinion and makes a prediction about the bjp's future performance in telangana. it lacks concrete evidence and relies on subjective assessments of strategy and leadership.
# Actual Justification: the claim is accurate as per the article, which reports that the bjp is facing challenges due to a lack of strategy and state leadership in telangana, leading to concerns about its performance in the state.
# --------------------------------------------------
# ['TRUE', "There have been multiple reports of Maoist attacks in Chhattisgarh's Dantewada district resulting in the deaths of security personnel, including incidents on April 26th."]
# Claim #5004
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: April 26 Maoist attack in Chhattisgarh’s Dantewada which killed at least ten jawans.
# Claim: April 26 Maoist attack in Chhattisgarh’s Dantewada which killed at least ten jawans.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: there have been multiple reports of maoist attacks in chhattisgarh's dantewada district resulting in the deaths of security personnel, including incidents on april 26th.
# Actual Justification: the photographs being circulated are not from the recent april 26 maoist attack in dantewada. they are old images from previous incidents, including from 2013, 2018, and 2019, and have been falsely linked to the recent attack.
# --------------------------------------------------
# ['FAKE ', "This claim is based on unfounded and potentially discriminatory stereotypes about Molenbeek and Belgium's demographic makeup."]
# Claim #5005
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Molenbeek city in Belgium has become the first European city with 100 per cent Muslim population. By 2021, Belgium will become an Islamic country.
# Claim: Molenbeek city in Belgium has become the first European city with 100 per cent Muslim population. By 2021, Belgium will become an Islamic country.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is based on unfounded and potentially discriminatory stereotypes about molenbeek and belgium's demographic makeup.
# Actual Justification: the claim is false. molenbeek has not become a city with 100% muslim population. while it has a significant muslim population, it is not a homogenous muslim city. additionally, belgium is not on track to become an islamic country by 2021. the claim is an exaggeration and misrepresentation.
# --------------------------------------------------
# ['FAKE', 'The claim lacks credible sources and could be misinformation or propaganda.']
# Claim #5006
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Jammu and kashmir: top let terrorist saifullah killed in encounter with security forces.
# Claim: Jammu and kashmir: top let terrorist saifullah killed in encounter with security forces.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim lacks credible sources and could be misinformation or propaganda.
# Actual Justification: the claim that top lashkar-e-taiba (let) terrorist saifullah was killed in an encounter with security forces in jammu and kashmir was reported by dna india. according to the article, saifullah, a senior commander of the let, was killed during an operation by security forces in the khanyar area of srinagar. the encounter took place on october 12, 2020, and resulted in the death of saifullah, who was involved in several terrorist activities in the region.
# --------------------------------------------------
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Average BLEU Score: 0.0674
# Average METEOR Score: 0.2082
# Average ChrF Score: 31.8127
# Average TER Score: 89.1971
# Average BERTScore F1: 0.8821
# Average BLEURT Score: 0.4717
# Average BARTScore: -3.3805
# Average ROUGE-1 F1 Score: 0.3098
# Average ROUGE-2 F1 Score: 0.1248
# Average ROUGE-L F1 Score: 0.2732
# Model Accuracy: 65.12%
# F1 Score Average: 0.6473280150670979
