# %%
# Clone the BARTScore repository
# !git clone https://github.com/neulab/BARTScore.git
# Out:
# Cloning into 'BARTScore'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 220 (delta 18), reused 14 (delta 14), pack-reused 194 (from 1)
# Receiving objects: 100% (220/220), 101.98 MiB | 24.42 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (192/192), done.

# %%
# %cd /content/BARTScore
# Out:
# /content/BARTScore

# %%
# Import libraries
from bart_score import BARTScorer
import torch

# %%
# Install necessary libraries
# !pip install --upgrade pip  # ensures that pip is current
# !pip install tensorflow tensorflow_hub transformers
# !pip install git+https://github.com/google-research/bleurt.git
# !pip install pandas
# !pip install groq
# !pip install scikit-learn
# !pip install matplotlib
# !pip install nltk
# !pip install rouge
# !pip install sacrebleu
# !pip install bert-score
# !pip install rouge
# Navigate to the repository directory
# %cd /content/BARTScore

# Download and unzip BLEURT checkpoint
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# !unzip BLEURT-20.zip


# Import libraries
from bart_score import BARTScorer
import torch

# Initialize BART-Scorer
bart_scorer = BARTScorer(device='cuda:0' if torch.cuda.is_available() else 'cpu',
                         checkpoint='facebook/bart-large-cnn')
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (2.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-lzam879y
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-lzam879y
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=75e58ebaf90310f5c96e3935db6d40b7fa6d9acfb76b5052eb25c782cb7592b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x1h88wr7/wheels/64/f4/2c/509a6c31b8ebde891a81029fd94f199b1b92f0e7cfc20d417a
# Successfully built BLEURT
# Installing collected packages: BLEURT
# Successfully installed BLEURT-0.0.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting groq
#   Downloading groq-0.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Downloading groq-0.15.0-py3-none-any.whl (109 kB)
# Installing collected packages: groq
# Successfully installed groq-0.15.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# /content/BARTScore
# --2025-01-14 19:26:40--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.193.207, 173.194.194.207, 172.217.214.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.193.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G   192MB/s    in 12s
#
# 2025-01-14 19:26:52 (172 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]
#
# Archive:  BLEURT-20.zip
#    creating: BLEURT-20/
#   inflating: BLEURT-20/bert_config.json
#   inflating: BLEURT-20/saved_model.pb
#    creating: BLEURT-20/variables/
#   inflating: BLEURT-20/variables/variables.index
#   inflating: BLEURT-20/variables/variables.data-00000-of-00001  y
# y
#
#   inflating: BLEURT-20/sent_piece.vocab
#   inflating: BLEURT-20/bleurt_config.json
#   inflating: BLEURT-20/sent_piece.model
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from sacrebleu.metrics import CHRF, TER
from bert_score import score
from bleurt import score as bleurt_score
import json
import pandas as pd
import random
import warnings
from groq import Groq
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
from nltk.translate.meteor_score import meteor_score
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Suppress specific warning messages
import logging
logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)

# Function to read JSON file and extract claims
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/last_fake_claims.json'
claims_file_2 = '/content/Modified_true_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# Extract relevant information and convert to DataFrame
claims_list = []
for claim in combined_claims:
    claims_list.append({
        'Text': claim['claim'],
        'classification_label': claim['label'],
        'justification': claim['justification']
    })

claims_df = pd.DataFrame(claims_list)

# Process only the first 10 claims
claims_df = claims_df.head(5006)

# Initialize Groq API client
client = Groq(api_key="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")

# Initialize label map
label_map = {'true': 'true', 'fake': 'fake', "correct": "true", "false": "fake", "incorrect": "fake", "not true": "fake","true:" : "true","fake:": "fake"}

# Define the function to get predictions
def get_claim_predictions(claim):
    prompt = f"Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: {claim}"

    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="llama3-70b-8192",
            max_tokens=4000,
        )

        predicted_result = response.choices[0].message.content.strip().splitlines()
        print(predicted_result)
        predicted_label_justification = predicted_result[0].strip(' .,*').lower()
        if ':' in predicted_label_justification:
            predicted_label, predicted_justification = predicted_label_justification.split(':', 1)
            predicted_label = predicted_label.strip()
            predicted_justification = predicted_justification.strip()
        else:
            predicted_label = predicted_label_justification
            predicted_justification = " ".join(predicted_result[1:]).strip().lower()

        if predicted_label in label_map:
            predicted_label = label_map[predicted_label]
        else:
            # Handle cases where the label is not clear
            predicted_label = "unknown"
            predicted_justification = " ".join(predicted_result).strip().lower()
    except Exception as e:
        print(f"Error processing claim '{claim}': {e}")
        return ("", "", "")

    return (prompt, predicted_label, predicted_justification)

# Evaluate claims
results = []
actual_labels = []
predicted_labels = []
predicted_justifications = []
actual_justifications = []

correct_predictions = 0
total_processed_claims = 0

for index, row in claims_df.iterrows():
    claim = row['Text']
    actual_label = str(row['classification_label'].strip().lower())
    actual_justification = str(row['justification'].strip().lower())

    prompt, predicted_label, predicted_justification = get_claim_predictions(claim)

    total_processed_claims += 1

    if (predicted_label, predicted_justification) == ("", ""):
        continue

    actual_labels.append(actual_label)
    actual_justifications.append(actual_justification)
    predicted_labels.append(predicted_label)
    predicted_justifications.append(predicted_justification)

    if predicted_label == actual_label:
        correct_predictions += 1
    print(f"Claim #{total_processed_claims}")
    print(f"Prompt: {prompt}")
    print(f"Claim: {claim}")
    print(f"Predicted Label: {predicted_label}")
    print(f"Actual Label: {actual_label}")
    print(f"Predicted Justification: {predicted_justification}")
    print(f"Actual Justification: {actual_justification}")
    print('-' * 50)

# Metrics initialization
rouge = Rouge()
smoothing_function = SmoothingFunction().method4
chrf = CHRF()
ter = TER()
bleurt_scorer = bleurt_score.BleurtScorer("BLEURT-20")

# Filter out empty justifications
filtered_justifications = [
    (actual, predicted)
    for actual, predicted in zip(actual_justifications, predicted_justifications)
    if predicted.strip()
]

# Calculate metrics
def calculate_metrics_extended(justifications):
    bleu_scores = []
    rouge_scores = []
    meteor_scores = []
    chrf_scores = []
    ter_scores = []
    bert_scores = []
    bleurt_scores = []
    bart_scores = []

    for ref, pred in justifications:
        # BLEU score
        bleu = sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothing_function)
        bleu_scores.append(bleu)

        # ROUGE score
        rouge_score = rouge.get_scores(pred, ref, avg=True)
        rouge_scores.append(rouge_score)

        # METEOR score
        meteor = meteor_score([ref.split()], pred.split())
        meteor_scores.append(meteor)

        # ChrF
        chrf_scores.append(chrf.corpus_score([pred], [[ref]]).score)

        # TER
        ter_scores.append(ter.corpus_score([pred], [[ref]]).score)

        # BERTScore
        P, R, F1 = score([pred], [ref], lang="en")
        bert_scores.append(F1.mean().item())

        # BLEURT
        bleurt_scores.append(bleurt_scorer.score(references=[ref], candidates=[pred])[0])

        # BARTScore
        bart_scores.append(bart_scorer.score([pred], [ref])[0])

    return bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores

# Calculate metrics
bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores = calculate_metrics_extended(filtered_justifications)

# Summarize and print results
avg_rouge_1 = sum([score['rouge-1']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_2 = sum([score['rouge-2']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_l = sum([score['rouge-l']['f'] for score in rouge_scores]) / len(rouge_scores)

print(f"Average BLEU Score: {sum(bleu_scores) / len(bleu_scores):.4f}")
print(f"Average METEOR Score: {sum(meteor_scores) / len(meteor_scores):.4f}")
print(f"Average ChrF Score: {sum(chrf_scores) / len(chrf_scores):.4f}")
print(f"Average TER Score: {sum(ter_scores) / len(ter_scores):.4f}")
print(f"Average BERTScore F1: {sum(bert_scores) / len(bert_scores):.4f}")
print(f"Average BLEURT Score: {sum(bleurt_scores) / len(bleurt_scores):.4f}")
print(f"Average BARTScore: {sum(bart_scores) / len(bart_scores):.4f}")
print(f"Average ROUGE-1 F1 Score: {avg_rouge_1:.4f}")
print(f"Average ROUGE-2 F1 Score: {avg_rouge_2:.4f}")
print(f"Average ROUGE-L F1 Score: {avg_rouge_l:.4f}")

# Calculate accuracy
accuracy = (correct_predictions / total_processed_claims) * 100 if total_processed_claims > 0 else 0
print(f"Model Accuracy: {accuracy:.2f}%")

# Calculate the F1 score
f1 = f1_score(actual_labels, predicted_labels, average='weighted', labels=["true", "fake"])
print(f"F1 Score Average: {f1}")

# Confusion matrix
cm = confusion_matrix(actual_labels, predicted_labels, labels=["true", "fake"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["true", "fake"])
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence or record of us president joe biden stepping on a cat while delivering a speech. this claim appears to be a fabricated and humorous anecdote with no basis in reality.
# Actual Justification: the claim is false. the video was edited to add the sound of a cat screaming. in reality, president biden stumbled on a floor wire during his speech, and there was no cat involved.
# --------------------------------------------------
# ['FAKE', '', 'There is no evidence to suggest that Niagara Falls in Canada has ever been lit up specifically in honor of Bangladesh Victory Day. While Niagara Falls is often illuminated in various colors to celebrate different events and holidays, there is no record of it being lit up for Bangladesh Victory Day, which is a national holiday in Bangladesh celebrated on December 16.']
# Claim #4452
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A picture shows Niagara Falls in Canada lit up in honour of Bangladesh Victory Day.
# Claim: A picture shows Niagara Falls in Canada lit up in honour of Bangladesh Victory Day.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no evidence to suggest that niagara falls in canada has ever been lit up specifically in honor of bangladesh victory day. while niagara falls is often illuminated in various colors to celebrate different events and holidays, there is no record of it being lit up for bangladesh victory day, which is a national holiday in bangladesh celebrated on december 16.
# Actual Justification: the claim is false. while niagara falls was indeed illuminated in green and red, it was not in honor of bangladesh's victory day. the illumination was part of a different event and did not have any official connection to bangladesh's victory day celebrations.
# --------------------------------------------------
# ['TRUE', 'This claim is true as it reports on a specific event that occurred on a particular day and location, which can be verified through news reports and eye-witness accounts.']
# Claim #4453
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A rally bearing green flags and playing loud music while passing by a temple in Khargone, MP — on the same day and at the same place where communal violence broke out on Ram Navami.
# Claim: A rally bearing green flags and playing loud music while passing by a temple in Khargone, MP — on the same day and at the same place where communal violence broke out on Ram Navami.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: this claim is true as it reports on a specific event that occurred on a particular day and location, which can be verified through news reports and eye-witness accounts.
# Actual Justification: the video is not related to the ram navami clashes in khargone, madhya pradesh. it shows a muharram procession from khargone, but it predates the communal violence and is unrelated to the events of ram navami.
# --------------------------------------------------
# ['TRUE', "Ali Fazal's mother, Uzma Fazal, passed away on June 17, 2020, due to health complications."]
# Claim #4454
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Actor ali fazal's mother passes away.
# Claim: Actor ali fazal's mother passes away.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: ali fazal's mother, uzma fazal, passed away on june 17, 2020, due to health complications.
# Actual Justification: the article reports the sad news of ali fazal's mother's passing due to health complications. ali fazal shared a heartfelt message on social media after her death.
# --------------------------------------------------
# ['TRUE', "The claim is stating a fact about a statement made by the Ministry of External Affairs (MEA) regarding a potential conversation between Indian Prime Minister Narendra Modi and US President Joe Biden, and theMEA's assessment of the bipartisan support for India-US ties in the US."]
# Claim #4455
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Modi, biden will speak at a mutually convenient time; ties have bipartisan support in the us, says mea.
# Claim: Modi, biden will speak at a mutually convenient time; ties have bipartisan support in the us, says mea.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is stating a fact about a statement made by the ministry of external affairs (mea) regarding a potential conversation between indian prime minister narendra modi and us president joe biden, and themea's assessment of the bipartisan support for india-us ties in the us.
# Actual Justification: the claim is consistent with the statement made by india's ministry of external affairs (mea), which indicated that pm modi and president biden will find a suitable time for their conversation. additionally, the mea mentioned that india-us ties enjoy bipartisan support in the us.
# --------------------------------------------------
# ['TRUE', 'This statement is reporting a specific event or announcement made by a railway authority or news source, and does not make a general claim that can be verified or debunked. The claim is likely based on an official statement or report.']
# Claim #4456
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Around 39 lakh train tickets will be cancelled between april 15 and may 3, reports.
# Claim: Around 39 lakh train tickets will be cancelled between april 15 and may 3, reports.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this statement is reporting a specific event or announcement made by a railway authority or news source, and does not make a general claim that can be verified or debunked. the claim is likely based on an official statement or report.
# Actual Justification: due to the extension of the nationwide lockdown in india amid the covid-19 pandemic, indian railways announced the cancellation of approximately 39 lakh tickets booked for travel between april 15 and may 3. passengers were informed that full refunds would be processed automatically.
# --------------------------------------------------
# ['TRUE', 'This claim appears to be a genuine quote from Amit Shah, the Home Minister of India, regarding the Citizenship Amendment Act (CAA) protests, and has been reported by several reputable news sources.']
# Claim #4457
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Not going back on caa, those who want to protest may continue, says amit shah.
# Claim: Not going back on caa, those who want to protest may continue, says amit shah.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this cla

# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is likely fake because it appears to be a sensationalized and emotional appeal, using a disturbing image to make a point about the plight of people in "atmanirbhar bharat" (a term coined by india's prime minister narendra modi to promote self-reliance). without any credible source or context, it's hard to verify the authenticity of the image and the claim.
# Actual Justification: the image circulating on social media is not related to india’s 'atmanirbhar bharat' initiative. it is an image from bangladesh showing a tragic incident unrelated to the claim.
# --------------------------------------------------
# ['FAKE', '', "This claim appears to be a jumbled collection of words and phrases that don't form a coherent sentence or statement. There is no clear meaning or context to determine its validity."]
# Claim #4475
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Can explore more issues in coming 22 talks us deputy secretary stephen biegun
# Claim: Can explore more issues in coming 22 talks us deputy secretary stephen biegun
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this claim appears to be a jumbled collection of words and phrases that don't form a coherent sentence or statement. there is no clear meaning or context to determine its validity.
# Actual Justification: us deputy secretary of state stephen biegun indicated that future discussions would cover a broader range of issues, signaling ongoing diplomatic engagement with india over multiple matters in the coming talks.
# --------------------------------------------------
# ['FAKE', '', 'There is no credible source or evidence to suggest that Imran Khan, the former Prime Minister of Pakistan, was unable to answer or mumbled when asked about conspiracy theories related to his cancer hospital. Imran Khan has been a vocal advocate for the Shaukat Khanum Memorial Cancer Hospital and Research Centre, which he founded in 1994, and has consistently spoken about its mission and achievements in public forums.']
# Claim #4476
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Imran Khan was unable to answer and mumbled when he was asked about conspiracy theories about his cancer hospital.
# Claim: Imran Khan was unable to answer and mumbled when he was asked about conspiracy theories about his cancer hospital.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible source or evidence to suggest that imran khan, the former prime minister of pakistan, was unable to answer or mumbled when asked about conspiracy theories related to his cancer hospital. imran khan has been a vocal advocate for the shaukat khanum memorial cancer hospital and research centre, which he founded in 1994, and has consistently spoken about its mission and achievements in public forums.
# Actual Justification: the claim is false. imran khan was not unable to answer or mumbling when asked about conspiracy theories related to his cancer hospital. the video circulating was misleadingly edited to make it appear that he was stuttering. in reality, the footage was part of a broader conversation, and khan responded to the questions clearly.
# --------------------------------------------------
# ['TRUE', '', 'The claim is true because there have been instances reported in the past where the signboard of a road named after Swami Vivekananda in Jawaharlal Nehru University (JNU) has been vandalized, and the Akhil Bharatiya Vidyarthi Parishad (ABVP) has made such allegations.']
# Claim #4477
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: ABVP alleges signboard of road named after swami vivekananda vandalised in jnu.
# Claim: ABVP alleges signboard of road named after swami vivekananda vandalised in jnu.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is true because there have been instances reported in the past where the signboard of a road named after swami vivekananda in jawaharlal nehru university (jnu) has been vandalized, and the akhil bharatiya vidyarthi parishad (abvp) has made such allegations.
# Actual Justification: the article reports that abvp accused a group in jnu of vandalising the signboard of a road named after swami vivekananda.
# --------------------------------------------------
# ['FAKE', '', 'This claim cannot be verified without more information, such as a specific incident or news article, and without evidence, it is impossible to determine the validity of the claim.']
# Claim #4478
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A UP policeman brutally thrashing an elderly man at a railway station.
# Claim: A UP policeman brutally thrashing an elderly man at a railway station.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim cannot be verified without more information, such as a specific incident or news article, and without evidence, it is impossible to determine the validity of the claim.
# Actual Justification: the claim that the viral video shows a up policeman brutally thrashing an elderly man at a railway station is false. according to factly, the video is old and from madhya pradesh, not uttar pradesh. it has been falsely shared as recent visuals from up.
# --------------------------------------------------
# ['TRUE', 'This claim appears to be a factual statement about a specific event, where students from a varsity (university) have joined a stir (protest) at Kundli, likely referring to a specific location or incident.']
# Claim #4479
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line:
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: No truth in clean chit to deepika padukone, sara ali khan, shraddha kapoor, ncb.
# Claim: No truth in clean chit to deepika padukone, sara ali khan, shraddha kapoor, ncb.
# Predicted Label: true
# Actual Label: true
# ...
# --------------------------------------------------
# ['TRUE', "This is a real incident that occurred in June 2022, where violent protests erupted in Bihar and other parts of India against the Centre's Agnipath scheme, a new recruitment process for the Indian armed forces."]
# Claim #4996
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: People in Bihar attacking a police van during a protest against the Agnipath scheme.
# Claim: People in Bihar attacking a police van during a protest against the Agnipath scheme.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: this is a real incident that occurred in june 2022, where violent protests erupted in bihar and other parts of india against the centre's agnipath scheme, a new recruitment process for the indian armed forces.
# Actual Justification: the video is not from bihar or related to the agnipath protests. it shows an unrelated incident from odisha in 2021.
# --------------------------------------------------
# ['FAKE', '', 'There is no credible evidence to suggest that people in Paris are protesting against namaaz (Islamic prayer) by blocking streets and sidewalks following the beheading of a French teacher. In fact, the beheading of Samuel Paty, a French teacher, led to widespread outrage and protests in France against Islamic extremism and terrorism, not against Muslim prayers.']
# Claim #4997
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: In Paris, after the beheading of a French teacher, people are protesting against namaaz offered by blocking streets and sidewalks.
# Claim: In Paris, after the beheading of a French teacher, people are protesting against namaaz offered by blocking streets and sidewalks.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence to suggest that people in paris are protesting against namaaz (islamic prayer) by blocking streets and sidewalks following the beheading of a french teacher. in fact, the beheading of samuel paty, a french teacher, led to widespread outrage and protests in france against islamic extremism and terrorism, not against muslim prayers.
# Actual Justification: the video in question is from three years ago, related to a protest against street prayers in paris, not connected to the recent beheading of the teacher. the claim is based on an old video revived with misleading context.
# --------------------------------------------------
# ['FAKE', '', "The Serum Institute of India's CEO, Adar Poonawalla, has clarified that the Oxford-AstraZeneca COVID-19 vaccine, Covishield, will be priced at around ₹200-₹300 per dose, not ₹1,000. This information is based on multiple credible news sources, including interviews and statements from Adar Poonawalla himself."]
# Claim #4998
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: oxford vaccine to be priced at rs 1,000, serum institute ceo.
# Claim: oxford vaccine to be priced at rs 1,000, serum institute ceo.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the serum institute of india's ceo, adar poonawalla, has clarified that the oxford-astrazeneca covid-19 vaccine, covishield, will be priced at around ₹200-₹300 per dose, not ₹1,000. this information is based on multiple credible news sources, including interviews and statements from adar poonawalla himself.
# Actual Justification: the article confirms that serum institute ceo, adar poonawalla, stated that the oxford covid-19 vaccine would be priced at rs 1,000.
# --------------------------------------------------
# ['FAKE', '', 'The claim is considered fake because there is no evidence to support the assertion that the third wave of COVID-19 has begun in Delhi and Madhya Pradesh specifically due to the delta plus variant. While the delta plus variant has been detected in some cases, its impact on the overall pandemic situation is still being studied and monitored by health authorities. Additionally, the Indian government and health organizations have not officially declared the start of a third wave in these specific regions.']
# Claim #4999
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: With reports of delta plus variant cases emerging, the third wave of covid has already begun in Delhi and Madhya Pradesh.
# Claim: With reports of delta plus variant cases emerging, the third wave of covid has already begun in Delhi and Madhya Pradesh.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is considered fake because there is no evidence to support the assertion that the third wave of covid-19 has begun in delhi and madhya pradesh specifically due to the delta plus variant. while the delta plus variant has been detected in some cases, its impact on the overall pandemic situation is still being studied and monitored by health authorities. additionally, the indian government and health organizations have not officially declared the start of a third wave in these specific regions.
# Actual Justification: the emergence of the delta plus variant does not indicate the beginning of the third wave of covid-19 in delhi or madhya pradesh. the claim is not substantiated by official data or health experts.
# --------------------------------------------------
# ['TRUE', "The claim appears to be a news headline, and a quick search online reveals that there have been several instances where the Delhi High Court has dismissed pleas against the Indian Army's ban on using social media platforms, making the claim plausible and likely true."]
# Claim #5000
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Delhi hc dismisses senior officer's plea against army ban on using social media platforms.
# Claim: Delhi hc dismisses senior officer's plea against army ban on using social media platforms.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be a news headline, and a quick search online reveals that there have been several instances where the delhi high court has dismissed pleas against the indian army's ban on using social media platforms, making the claim plausible and likely true.
# Actual Justification: the article reports that the delhi high court dismissed a senior officer's plea challenging the indian army's ban on the use of social media platforms by its personnel.
# --------------------------------------------------
# ['FAKE', '', "This claim is likely a misconception or misinformation. While the Taliban's takeover of Afghanistan has led to concerns about women's rights, there is no credible evidence to suggest that women are being forced to walk in chains behind men. The image of women in burqas walking behind a man is a stereotype and not based on factual reporting."]
# Claim #5001
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Women in burqas walking in chains behind a man in Afghanistan after Taliban took over the country.
# Claim: Women in burqas walking in chains behind a man in Afghanistan after Taliban took over the country.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is likely a misconception or misinformation. while the taliban's takeover of afghanistan has led to concerns about women's rights, there is no credible evidence to suggest that women are being forced to walk in chains behind men. the image of women in burqas walking behind a man is a stereotype and not based on factual reporting.
# Actual Justification: the image showing women in burqas walking in chains behind a man is edited. the original image is unrelated to the taliban's actions in afghanistan, and the claim is misleading.
# --------------------------------------------------
# ['FAKE', '', "Rana Ayyub did not make such a tweet. Afzal Guru was a Kashmiri separatist who was convicted of conspiracy in the 2001 Indian Parliament attack and was hanged in 2013. Pranab Mukherjee was the President of India from 2012 to 2017 and had rejected Guru's mercy plea in 2013. There is no record of Rana Ayyub making such a tweet, and it is likely a fabrication."]
# Claim #5002
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Journalist Rana Ayyub has tweeted that 'martyr' Afzal Guru will now feel at peace after the demise of former president Pranab Mukherjee who’d rejected his mercy plea.
# Claim: Journalist Rana Ayyub has tweeted that 'martyr' Afzal Guru will now feel at peace after the demise of former president Pranab Mukherjee who’d rejected his mercy plea.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: rana ayyub did not make such a tweet. afzal guru was a kashmiri separatist who was convicted of conspiracy in the 2001 indian parliament attack and was hanged in 2013. pranab mukherjee was the president of india from 2012 to 2017 and had rejected guru's mercy plea in 2013. there is no record of rana ayyub making such a tweet, and it is likely a fabrication.
# Actual Justification: the claim that rana ayyub tweeted this statement is false. there is no evidence of rana ayyub making such a tweet. the tweet in question was fabricated and is part of a misinformation campaign.
# --------------------------------------------------
# ['FAKE', '', "There is no credible evidence to suggest that Canadian Prime Minister Justin Trudeau has ever sat for a 'dharna' (a form of peaceful protest or sit-in) in support of protesting farmers in India. While Trudeau's government has expressed support for the farmers' protests, there is no record of him participating in a 'dharna' or any other form of direct protest."]
# Claim #5003
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Canadian Prime Minister Justin Trudeau sat for a ‘dharna’ in support of protesting farmers in India.
# Claim: Canadian Prime Minister Justin Trudeau sat for a ‘dharna’ in support of protesting farmers in India.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence to suggest that canadian prime minister justin trudeau has ever sat for a 'dharna' (a form of peaceful protest or sit-in) in support of protesting farmers in india. while trudeau's government has expressed support for the farmers' protests, there is no record of him participating in a 'dharna' or any other form of direct protest.
# Actual Justification: the claim is false. justin trudeau did not sit for a ‘dharna’ in support of the farmers' protest in india.
# --------------------------------------------------
# ['FAKE', '', 'This claim appears to be a quote or statement attributed to Amit Shah, but without further context or evidence, it cannot be verified as true. Additionally, the language used is informal and lacks a reliable source, making it suspect.']
# Claim #5004
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Give one chance to narendra modi, will make sonar bangla in 5 years, says amit shah in bolpur.
# Claim: Give one chance to narendra modi, will make sonar bangla in 5 years, says amit shah in bolpur.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this claim appears to be a quote or statement attributed to amit shah, but without further context or evidence, it cannot be verified as true. additionally, the language used is informal and lacks a reliable source, making it suspect.
# Actual Justification: amit shah made this statement in bolpur, promising that if given a chance, narendra modi would transform bengal into a 'sonar bangla' (golden bengal) within five years. this is a direct quote from the article published by the statesman.
# --------------------------------------------------
# ['FAKE', '', 'This claim is not supported by any credible evidence or sources. There is no record of Uttar Pradesh Chief Minister Yogi Adityanath being involved in burning crackers on Diwali, nor is there any evidence of poor traders being arrested for selling fireworks during his tenure as Chief Minister. The claim appears to be a fabrication intended to create a false narrative.']
# Claim #5005
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: While Uttar Pradesh Chief Minister Yogi Adityanath was burning crackers on Diwali, poor traders were arrested for selling fireworks.
# Claim: While Uttar Pradesh Chief Minister Yogi Adityanath was burning crackers on Diwali, poor traders were arrested for selling fireworks.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is not supported by any credible evidence or sources. there is no record of uttar pradesh chief minister yogi adityanath being involved in burning crackers on diwali, nor is there any evidence of poor traders being arrested for selling fireworks during his tenure as chief minister. the claim appears to be a fabrication intended to create a false narrative.
# Actual Justification: the claim is false. the video showing yogi adityanath burning crackers is not from diwali. it is an old video, and the claims regarding the arrest of poor traders for selling fireworks are not connected to this incident.
# --------------------------------------------------
# ['TRUE', 'Rasheed Masood, a former Union Minister of Health and Family Welfare, passed away on November 13, 2020, at the age of 73.']
# Claim #5006
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Former union minister rasheed masood passes away
# Claim: Former union minister rasheed masood passes away
# Predicted Label: true
# Actual Label: true
# Predicted Justification: rasheed masood, a former union minister of health and family welfare, passed away on november 13, 2020, at the age of 73.
# Actual Justification: the claim is accurate as former union minister rasheed masood passed away at the age of 73 after recovering from covid-19.
# --------------------------------------------------
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Average BLEU Score: 0.0806
# Average METEOR Score: 0.2886
# Average ChrF Score: 39.9119
# Average TER Score: 121.1168
# Average BERTScore F1: 0.8854
# Average BLEURT Score: 0.4982
# Average BARTScore: -3.0075
# Average ROUGE-1 F1 Score: 0.3428
# Average ROUGE-2 F1 Score: 0.1333
# Average ROUGE-L F1 Score: 0.2939
# Model Accuracy: 80.14%
# F1 Score Average: 0.8015877420702431
