# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)

# %%
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
import time

# %%
import re


# Initialize Groq API client
client = Groq(api_key="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")



def convert_to_json(llm_response):
    responseQuestions = []
    pattern = r'\[(.*?)\]'
    matches = re.findall(pattern, llm_response, re.DOTALL)

    if not matches:
        return responseQuestions  # Return an empty list if no matches are found

    json_str = matches[0]
    questions_llm = re.findall(r'\{(.*?)\}', json_str, re.DOTALL)

    for question in questions_llm:
        question_json = {}
        q = re.findall(r'.?question.?:\s*.?(.*),[\s\n]+.?questionType', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip().strip('"')
        qt = re.findall(r'.?questionType.?:\s*.?(.*)[\'\"]', question, re.DOTALL)
        if qt:
            question_json['questionType'] = qt[0].strip().strip('"')
        responseQuestions.append(question_json)

    return responseQuestions


def get_response_llm(claim, questions, max_retries=3, retry_delay=2):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions."
  response = None
  for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="mixtral-8x7b-32768",
            max_tokens=4000,
        )
        response_content = response.choices[0].message.content.strip()
        if response_content:
            response_json = convert_to_json(response_content)
            return response_json
        else:
             print(f"Empty response on attempt {attempt + 1} for claim: '{claim}'")

    except Exception as e:
        if response and response.choices and response.choices[0].message:
            print(f"Error on attempt {attempt + 1} for claim '{claim}': {e}, {response.choices[0].message.content}")
        else:
            print(f"Error on attempt {attempt + 1} for claim '{claim}': {e}, Response not available")
        if attempt < max_retries - 1:
            time.sleep(retry_delay) # Wait before retrying
        continue # Try again
  print(f"Failed to get response after {max_retries} attempts for claim: '{claim}'")
  return [] # Return empty list if all retries fail

# %%
new_data = []

for data in combined_claims[:5008]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    #q['answer'] = answer['answer']
    q['questionType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
new_data
# Out:
# [{'claim': 'Autopsy report says west bengal MLA debendra roy died by hanging.',
#   'generatedQuestions': [{'question': 'How did Debendra Roy die, according to the autopsy report?',
#     'questionType': 'Extractive'},
#    {'question': 'What method of death did the autopsy report find for Debendra Roy?',
#     'questionType': 'Abstractive'},
#    {'question': "Did the autopsy report suggest that Debendra Roy's death was a suicide?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Bengaluru’s Victoria Hospital shows a huge crowd of patients in a small space outside an OPD.',
#   'generatedQuestions': [],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'narendra modi to launch fit india movement, administer fitness pledge today.',
#   'generatedQuestions': [{'question': "Will Narendra Modi launch the Fit India Movement today?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the purpose of Narendra Modi's Fit India Movement?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is involved in the Fit India Movement's fitness pledge?'",
#     'questionType': 'Extractive'},
#    {'question': "Has Narendra Modi announced a date for the Fit India Movement's launch before?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the expected impact of the Fit India Movement on the country?'",
#     'questionType': 'Abstractive'},
#    {'question': "What steps will be taken to implement the Fit India Movement?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara.',
#   'generatedQuestions': [{'question': 'What is depicted on the rooftop of Kartarpur Gurudwara?',
#     'questionType': 'Extractive'},
#    {'question': 'How does the rooftop of Kartarpur Gurudwara appear?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did Pakistan paint its national flag on the Kartarpur Gurudwara?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Indian-origin physician wins award for covid-19 work in uk.',
#   'generatedQuestions': [{'question': 'Who is the Indian-origin physician who won the award for covid-19 work in the UK?',
#     'questionType': 'Extractive'},
#    {'question': 'What is the name of the award won by the Indian-origin physician for covid-19 work in the UK?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did an Indian-origin physician win an award for covid-19 work in the UK?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "man from bihar kills 9 in telangana by tossing them into well to hide lover's murder, say police.",
#   'generatedQuestions': [{'question': "Who killed the nine people in Telangana, according to the police?'",
#     'questionType': 'Extractive'},
#    {'question': 'What method was used to kill the nine people in Telangana, according to the police?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did the police mention a man from Bihar as the suspect in the Telangana case?',
#     'questionType': 'Boolean'},
#    {'question': "How did the police say the bodies were disposed of in the Telangana case?'",
#     'questionType': 'Extractive'},
#    {'question': 'What reason did the police give for the murders in Telangana?',
#     'questionType': 'Abstractive'},
#    {'question': "Did the police mention any connection between the murders in Telangana and a lover's murder?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A Muslim woman overturning the car of the man who burned a copy of the Quran in Sweden on January 21.',
#   'generatedQuestions': [{'question': "Who was the man who burned a copy of the Quran in Sweden on January 21?'",
#     'questionType': 'Extractive'},
#    {'question': 'What action did a Muslim woman take in response to the man burning a copy of the Quran in Sweden on January 21?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did a Muslim woman overturn the car of the man who burned a copy of the Quran in Sweden on January 21?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Ex-pm manmohan singh turns 88, wishes pour in',
#   'generatedQuestions': [{'question': 'How old is former prime minister Manmohan Singh now?',
#     'questionType': 'Extractive'},
#    {'question': "What are people saying on social media about Manmohan Singh's birthday?",
#     'questionType': 'Abstractive'},
#    {'question': "Is there any official celebration organized for Manmohan Singh's 88th birthday?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Itc sets up rs 150 cr coronavirus fund for vulnerable sections of society',
#   'generatedQuestions': [{'question': "What amount did ITC set up for their coronavirus fund?'",
#     'questionType': 'Extractive'},
#    {'question': "Who are the beneficiaries of ITC’s coronavirus fund?'",
#     'questionType': 'Abstractive'},
#    {'question': "Did ITC set up a coronavirus fund for vulnerable sections of society?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'CM or not, manoj tiwari says bjp will contest and win delhi polls under his leadership',
#   'generatedQuestions': [{'question': "Is Manoj Tiwari the current CM of Delhi?'",
#     'questionType': 'Boolean'},
#    {'question': "What is Manoj Tiwari's leadership role in the BJP for the Delhi polls?'",
#     'questionType': 'Extractive'},
#    {'question': "What does Manoj Tiwari say about the BJP's chances in the Delhi polls?'",
#     'questionType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'One should be careful of interacting with pets for animals can transmit COVID-19 to humans.',
#   'generatedQuestions': [{'question': "Can animals transmit COVID-19 to humans through interaction?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the ways through which COVID-19 can be transmitted from animals to humans?'",
#     'questionType': 'Abstractive'},
#    {'question': "Does the CDC recommend avoiding interaction with pets to prevent COVID-19 transmission?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'odisha: two sog commandos, five maoists killed in kalahandi encounter',
#   'generatedQuestions': [{'question': "How many people were killed in the encounter in Kalahandi?'",
#     'questionType': 'Extractive'},
#    {'question': 'What type of forces were involved in the Kalahandi encounter?',
#     'questionType': 'Abstractive'},
#    {'question': 'Was there any involvement of Maoists in the Kalahandi encounter?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Nupur Sharma in a new statement following the Prophet Muhammad controversy asked if being Hindu was a crime.',
#   'generatedQuestions': [{'question': "Did Nupur Sharma ask if being Hindu was a crime?'",
#     'questionType': 'Boolean'},
#    {'question': "What did Nupur Sharma say about being Hindu in the context of the Prophet Muhammad controversy?'",
#     'questionType': 'Abstractive'},
#    {'question': "In what statement did Nupur Sharma ask if being Hindu was a crime?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Farm protests eating into economy, will harm punjab more than centre.',
#   'generatedQuestions': [{'question': 'How might farm protests affect the Indian economy?',
#     'questionType': 'Extractive'},
#    {'question': "What is the predicted impact of farm protests on Punjab's economy compared to the central government's?",
#     'questionType': 'Abstractive'},
#    {'question': 'Is it true that farm protests are causing significant harm to the Indian economy?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Rohingya refugees and bangladeshi migrants attacking police in haldwani, uttarakhand.',
#   'generatedQuestions': [{'question': "Who are the individuals attacking the police in Haldwani, Uttarakhand?'",
#     'questionType': 'Extractive'},
#    {'question': 'What is the reason for the attack on the police in Haldwani, Uttarakhand?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is there evidence that Rohingya refugees and Bangladeshi migrants are involved in the attack on the police in Haldwani, Uttarakhand?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'SC rejects plea of former IAF officer seeking bail in spying case',
#   'generatedQuestions': [{'question': "Was the plea for bail rejected by the Supreme Court?'",
#     'questionType': 'Boolean'},
#    {'question': "What was the reason for the rejection of the bail plea by the Supreme Court?'",
#     'questionType': 'Abstractive'},
#    {'question': "Who was the former IAF officer seeking bail in the spying case?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Turkey: where a Muslim man can be seen defecating inside a rapid transit train’s coach.',
#   'generatedQuestions': [{'question': "What is the location of the incident in the claim?'",
#     'questionType': 'Extractive'},
#    {'question': "What religion is the man in the claim?'",
#     'questionType': 'Extractive'},
#    {'question': "What act is the man in the claim performing inside the train?'",
#     'questionType': 'Extractive'},
#    {'question': "Describe the location where the man in the claim was defecating'",
#     'questionType': 'Abstractive'},
#    {'question': "Does the claim state that the man was defecating in a public place?'",
#     'questionType': 'Boolean'},
#    {'question': "Does the claim provide information about the reason for the man\\'s actions?'",
#     'questionType': 'Boolean'},
#    {'question': "What type of transportation is mentioned in the claim?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Muslims rewriting Hindu holy books. This is how the Vedas, Puranas, and Upanishads are adulterated.',
#   'generatedQuestions': [{'question': "What is the claim that Muslims are rewriting Hindu holy books?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the claim suggest about the motivations behind the alleged rewriting of Hindu holy books?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is there any evidence to support the claim that Muslims are rewriting Hindu holy books?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'vhse kerala first year improvement results 2019 declared at keralaresults.nic.in. check now.',
#   'generatedQuestions': [{'question': "Which website has declared the VHSE Kerala first year improvement results for 2019?'",
#     'questionType': 'Extractive'},
#    {'question': 'What information can be found on keralaresults.nic.in regarding VHSE Kerala first year improvement results?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it true that the VHSE Kerala first year improvement results for 2019 have been declared?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'This is the farewell video of British Airways employees after the UK airline dismissed its entire workforce on June 15.',
#   'generatedQuestions': [{'question': "Which airline is mentioned in the video as dismissing its entire workforce?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the alleged reason for the dismissal of British Airways employees?'",
#     'questionType': 'Abstractive'},
#    {'question': "Is it confirmed that British Airways let go of all its employees on June 15?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Luxury ice cream is made from insects.',
#   'generatedQuestions': [{'question': "What are luxury ice creams made from?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the ingredients list of luxury ice cream reveal?',
#     'questionType': 'Abstractive'},
#    {'question': 'Does luxury ice cream contain any insect-derived ingredients?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Prime Minister Narendra Modi meeting his 'Chinese bosses'.",
#   'generatedQuestions': [{'question': "Who did Prime Minister Narendra Modi meet with during his visit to China?'",
#     'questionType': 'Extractive'},
#    {'question': "What was the purpose of Prime Minister Narendra Modi's meeting with Chinese officials?",
#     'questionType': 'Abstractive'},
#    {'question': 'Did Prime Minister Narendra Modi meet with any Chinese politicians or government officials during his visit?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Rajasthan: bjp slams state govt for priest's brutal killing, karauli-dholpur mp manoj rajoria to meet kin tomorrow.",
#   'generatedQuestions': [{'question': "Who was the priest that was brutally killed in Rajasthan?'",
#     'questionType': 'Extractive'},
#    {'question': "What did the BJP say about the state government in response to the priest's killing?",
#     'questionType': 'Abstractive'},
#    {'question': "Is there any suspicion of foul play in the priest's death?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A stack of stones naturally standing atop each other in the middle of the water.',
#   'generatedQuestions': [],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Do not block movement, supply of Oxygen, mha tells states',
#   'generatedQuestions': [{'question': "Has the Ministry of Home Affairs directed states to ensure uninterrupted movement and supply of oxygen?'",
#     'questionType': 'Extractive'},
#    {'question': "What measures has the MHA asked states to take regarding the movement and supply of oxygen?'",
#     'questionType': 'Abstractive'},
#    {'question': "Does the MHA's directive involve any restrictions on the movement or supply of oxygen in states?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'It is illegal to share PDFs of e-papers on WhatsApp.',
#   'generatedQuestions': [{'question': "What is the legal status of sharing PDFs of e-papers on WhatsApp?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the law say about distributing electronic copies of newspapers on messaging platforms?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it permissible to share PDFs of e-papers on WhatsApp according to copyright laws?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Bhima koregaon suspects' laptop was hacked to plant evidence, us firm claims. NIA rejects it.",
#   'generatedQuestions': [{'question': "Was there any evidence found that the Bhima Koregaon suspects' laptop was hacked?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the US firm that made the hacking claim say about the evidence they found?',
#     'questionType': 'Abstractive'},
#    {'question': "Did the NIA accept the US firm's claim that the Bhima Koregaon suspects' laptop was hacked?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'State failed to protect lives of poor labourers onboard trains, says nhrc; sends notices to gujarat, bihar, railways',
#   'generatedQuestions': [{'question': "Did the National Human Rights Commission (NHRC) send notices to Gujarat, Bihar, and the Railways?'",
#     'questionType': 'Boolean'},
#    {'question': "What did the NHRC say about the protection of poor laborers onboard trains?'",
#     'questionType': 'Abstractive'},
#    {'question': "Did the NHRC find any failure on the part of the state to protect the lives of poor laborers onboard trains?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Bjp's bhupender yadav, devendra fadnavis in patna to work out seat sharing with jd(u), ljp",
#   'generatedQuestions': [],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'White House is selling commemorative COVID-19 coins for $100.',
#   'generatedQuestions': [{'question': "Is the White House selling any commemorative coins related to COVID-19?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the price of the reported COVID-19 commemorative coins being sold by the White House?'",
#     'questionType': 'Extractive'},
#    {'question': "What do the commemorative coins being sold by the White House depict or celebrate about COVID-19?'",
#     'questionType': 'Abstractive'},
#    {'question': "Are the commemorative COVID-19 coins being sold by the White House official government merchandise?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the specific details of the White House commemorative COVID-19 coins, such as their design and material?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the purpose of the White House selling commemorative COVID-19 coins?'",
#     'questionType': 'Abstractive'},
#    {'question': "Who is authorized to sell commemorative coins on behalf of the White House?'",
#     'questionType': 'Extractive'},
#    {'question': "Have there been any criticisms or controversies surrounding the sale of commemorative COVID-19 coins by the White House?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A man complaining of vote tampering during the ongoing Uttar Pradesh assembly elections.',
#   'generatedQuestions': [{'question': 'Who was the man who complained about vote tampering during the Uttar Pradesh assembly elections?',
#     'questionType': 'Extractive'},
#    {'question': 'What evidence did the man provide to support his claim of vote tampering?',
#     'questionType': 'Abstractive'},
#    {'question': "Has there been any investigation into the man's claim of vote tampering?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Trees are being chopped down and it is being claimed that the indian government is destroying apple gardens of local kashmiris following the scrapping of article 370.',
#   'generatedQuestions': [{'question': 'What is the reason behind the alleged destruction of apple gardens in Kashmir?',
#     'questionType': 'Abstractive'},
#    {'question': 'Are there any reports of trees being chopped down in Kashmir after the removal of Article 370?',
#     'questionType': 'Boolean'},
#    {'question': 'Who is blaming the Indian government for destroying apple gardens in Kashmir?',
#     'questionType': 'Extractive'},
#    {'question': 'What evidence supports the claim that the Indian government is destroying apple gardens in Kashmir?',
#     'questionType': 'Extractive'},
#    {'question': 'Has the Indian government responded to the allegations of destroying apple gardens in Kashmir?',
#     'questionType': 'Extractive'},
#    {'question': 'What impact does the destruction of apple gardens have on the local Kashmiris?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is the alleged destruction of apple gardens a violation of the rights of local Kashmiris?',
#     'questionType': 'Boolean'},
#    {'question': 'What has been the response of the international community to the destruction of apple gardens in Kashmir?',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'An envelope with the ‘cycle’ symbol containing Rs 500 is proof that Samajwadi Party leader from Meerut Atul Pradhan is distributing money to lure voters.',
#   'generatedQuestions': [{'question': "What symbol was on the envelope containing the Rs 500 that was allegedly being distributed by Atul Pradhan?'",
#     'questionType': 'Extractive'},
#    {'question': "What does the evidence suggest about Atul Pradhan's alleged distribution of money to voters?",
#     'questionType': 'Abstractive'},
#    {'question': 'Is there any evidence of wrongdoing on the part of Atul Pradhan in the distribution of money to voters?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Nandi idol in the Kashi Vishwanath Temple in Varanasi faces the Gyanvapi mosque.',
#   'generatedQuestions': [{'question': 'Which direction does the Nandi idol in the Kashi Vishwanath Temple face?',
#     'questionType': 'Extractive'},
#    {'question': 'What religious structure is located near the Nandi idol in the Kashi Vishwanath Temple?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is there any controversy regarding the orientation of the Nandi idol in the Kashi Vishwanath Temple?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "ED opposes dk shivakumar's bail application, says he can influence investigation",
#   'generatedQuestions': [{'question': "Who is opposing DK Shivakumar\\'s bail application?'",
#     'questionType': 'Extractive'},
#    {'question': "What reason does the ED give for opposing DK Shivakumar\\'s bail application?'",
#     'questionType': 'Abstractive'},
#    {'question': "Does the ED believe DK Shivakumar can influence the investigation?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "those doubting bharat biotech's efficacy mentally challenged, says union minister pradhan.",
#   'generatedQuestions': [{'question': "What did Union Minister Pradhan say about those who doubt Bharat Biotech’s efficacy?'",
#     'questionType': 'Extractive'},
#    {'question': "What is Union Minister Pradhan's opinion on the mental state of those who question Bharat Biotech's efficacy?",
#     'questionType': 'Abstractive'},
#    {'question': "Did Union Minister Pradhan accuse those who doubt Bharat Biotech's efficacy of being mentally challenged?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Jitendra singh reviews darpg's covid-19 public grievances redressal progress report with states and union territories.",
#   'generatedQuestions': [{'question': "Which states and union territories did Jitendra Singh review COVID-19 public grievances redressal progress reports with?'",
#     'questionType': 'Extractive'},
#    {'question': "What was discussed during Jitendra Singh's review of the Darpg's COVID-19 public grievances redressal progress reports with states and union territories?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any criticism of the progress reports during Jitendra Singh's review?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'EC removes dcp in charge after firing incidents at anti-caa protest sites in delhi.',
#   'generatedQuestions': [],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Kerala adds 11,000 covid cases in two days; cm says situation grave.',
#   'generatedQuestions': [{'question': 'How many new COVID-19 cases has Kerala reported in the past two days?',
#     'questionType': 'Extractive'},
#    {'question': "What is the current assessment of Kerala's COVID-19 situation by the Chief Minister?",
#     'questionType': 'Abstractive'},
#    {'question': 'Does the recent surge in COVID-19 cases in Kerala indicate a serious situation?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Pm modi reviews covid-19 situation, reiterates need to observe personal hygiene, social discipline.',
#   'generatedQuestions': [{'question': "What actions did Prime Minister Modi emphasize during his review of the COVID-19 situation?'",
#     'questionType': 'Extractive'},
#    {'question': 'What did Prime Minister Modi reiterate during his review of the COVID-19 situation?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did Prime Minister Modi mention the need for social discipline during his review of the COVID-19 situation?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Indian railways extends mou with iit roorkee for undertaking joint research and development',
#   'generatedQuestions': [{'question': "What type of agreement has Indian Railways extended with IIT Roorkee?'",
#     'questionType': 'Extractive'},
#    {'question': 'What areas of research and development will Indian Railways and IIT Roorkee collaborate on?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is the agreement between Indian Railways and IIT Roorkee focused on joint research and development?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "India-eu summit postponed amid coronavirus fears; modi's bangladesh visit on.",
#   'generatedQuestions': [{'question': 'Has the India-EU summit been postponed due to coronavirus concerns?',
#     'questionType': 'Boolean'},
#    {'question': 'What are the reasons for the postponement of the India-EU summit?',
#     'questionType': 'Abstractive'},
#    {'question': 'Was the India-EU summit scheduled to take place recently?',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Soldiers bidding farewell to loved ones in Kyiv amid Russia’s invasion of Ukraine.',
#   'generatedQuestions': [{'question': "Are Ukrainian soldiers saying goodbye to their families due to Russia’s invasion?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the situation for soldiers and their families in Kyiv amid Russia’s invasion?'",
#     'questionType': 'Abstractive'},
#    {'question': "How are Ukrainian soldiers being affected by Russia’s invasion of their country?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Time magazine's new cover has the title 'Time...to go' and the silhouette of Donald Trump from the rear, exiting through a doorway.",
#   'generatedQuestions': [{'question': "What is the title of Time magazine''s latest cover?'",
#     'questionType': 'Extractive'},
#    {'question': "Who is depicted on Time magazine''s latest cover?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the direction in which Donald Trump is depicted as moving on Time magazine''s latest cover?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the significance of the doorway on Time magazine''s latest cover?'",
#     'questionType': 'Abstractive'},
#    {'question': "What message is conveyed by the image on Time magazine''s latest cover?'",
#     'questionType': 'Abstractive'},
#    {'question': "Is Donald Trump shown leaving or entering a building on Time magazine''s latest cover?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'North korea bombing a us tanker in taiwan waters.',
#   'generatedQuestions': [{'question': "Has North Korea ever bombed a US tanker in Taiwanese waters?'",
#     'questionType': 'Boolean'},
#    {'question': "What US tankers have been bombed in Taiwanese waters by North Korea?'",
#     'questionType': 'Extractive'},
#    {'question': "What does the report say about the alleged bombing of a US tanker by North Korea in Taiwanese waters?'",
#     'questionType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A drug cartel drive-by shootout in Brazil.',
#   'generatedQuestions': [{'question': "Who was the target of the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Extractive'},
#    {'question': "What was the motive behind the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Abstractive'},
#    {'question': "Did anyone die as a result of the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Boolean'},
#    {'question': "How many people were injured in the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Extractive'},
#    {'question': "What kind of weapons were used in the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Extractive'},
#    {'question': "Where in Brazil did the drug cartel drive-by shootout occur?'",
#     'questionType': 'Extractive'},
#    {'question': "Has there been any arrests related to the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Boolean'},
#    {'question': "What was the time and date of the drug cartel drive-by shootout in Brazil?'",
#     'questionType': 'Extractive'},
#    {'question': "What street in Brazil did the drug cartel drive-by shootout occur on?'",
#     'questionType': 'Extractive'},
#    {'question': "Was the drug cartel drive-by shootout in Brazil gang related?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the name of the drug cartel involved in the shootout?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'India committed towards strengthening ties with nepal, MEA.',
#   'generatedQuestions': [{'question': 'What steps has India taken to strengthen ties with Nepal recently?',
#     'questionType': 'Extractive'},
#    {'question': "What is the position of the Ministry of External Affairs (MEA) on India's relationship with Nepal?",
#     'questionType': 'Abstractive'},
#    {'question': 'Has there been any indication of heightened cooperation between India and Nepal?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Wife of the Vice President of Ukraine who has decided to join the fight against Russia.',
#   'generatedQuestions': [{'question': "Who is the wife of the Vice President of Ukraine?'",
#     'questionType': 'Extractive'},
#    {'question': 'What decision has the wife of the Vice President of Ukraine taken regarding the fight against Russia?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it true that the wife of the Vice President of Ukraine has decided to join the fight against Russia?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Abrogation of article 370 has changed relationship between j&k, new delhi, kashmir opposition parties.',
#   'generatedQuestions': [{'question': "How has the abrogation of Article 370 affected the relationship between Jammu and Kashmir and New Delhi?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the political analysis say about the impact of Article 370 abrogation on Kashmir opposition parties?',
#     'questionType': 'Abstractive'},
#    {'question': 'Has the abrogation of Article 370 led to any change in the political dynamics between Jammu and Kashmir and Kashmir opposition parties?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': " Nehru has been trashed on china war failure'.",
#   'generatedQuestions': [{'question': "How was Nehru's leadership during the China war viewed?'",
#     'questionType': 'Extractive'},
#    {'question': "What does the criticism of Nehru's China war policy focus on?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there widespread dissatisfaction with Nehru's handling of the China war?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'RSS member arrested for waving Pakistani flag while disguised in a burqa to defame Muslims.',
#   'generatedQuestions': [{'question': "Who was arrested for waving a Pakistani flag while disguised in a burqa?'",
#     'questionType': 'Extractive'},
#    {'question': 'What was the reason given for the arrest of the person disguised as a burqa?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did the person arrested have any affiliation with the RSS?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Walter Chandoha is the 'Godfather of Cat Photography",
#   'generatedQuestions': [{'question': 'Who is known as the "Godfather of Cat Photography"?\'',
#     'questionType': 'Extractive'},
#    {'question': "What is Walter Chandoha's title in the world of cat photography?",
#     'questionType': 'Abstractive'},
#    {'question': "Is it true that Walter Chandoha is referred to as the 'Godfather of Cat Photography'?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A  Delhi police personnel beating a young boy with a baton.',
#   'generatedQuestions': [{'question': 'Who was allegedly beaten by a Delhi police personnel with a baton?',
#     'questionType': 'Extractive'},
#    {'question': 'What object was used by the Delhi police personnel to beat the young boy, according to the claim?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it true that a young boy was beaten by a Delhi police personnel with a baton, as claimed?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Those who despise mahatma gandhi want to get rid of shaheen bagh, chidambaram hits out at amit shah',
#   'generatedQuestions': [{'question': 'Who are the people that want to get rid of Shaheen Bagh, according to Chidambaram?',
#     'questionType': 'Extractive'},
# ...
#     'questionType': 'Extractive'},
#    {'question': "What was the reason behind the slogans of 'Rahul Gandhi go back' in Manipur?",
#     'questionType': 'Abstractive'},
#    {'question': 'Did Rahul Gandhi face any protests during his visit to Manipur?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'These 69 seats may well decide the fate of tamil nadu elections',
#   'generatedQuestions': [{'question': "Which seats are considered crucial in the Tamil Nadu elections?'",
#     'questionType': 'Extractive'},
#    {'question': 'What is the significance of these 69 seats in the Tamil Nadu elections?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it accurate to say that these 69 seats will solely determine the outcome of the Tamil Nadu elections?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Lord ram’s image was projected on a clocktower in srinagar’s lal chowk ahead of ayodhya ram mandir’s consecration ceremony.',
#   'generatedQuestions': [{'question': "What was projected on a clocktower in Srinagar’s Lal Chowk ahead of Ayodhya Ram Mandir’s consecration ceremony?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the report say about the image projected on the clocktower in Srinagar’s Lal Chowk?',
#     'questionType': 'Abstractive'},
#    {'question': 'Was Lord Ram’s image the only thing projected on the clocktower in Srinagar’s Lal Chowk?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'People boycotting the Congress party in Rajasthan after communal violence in Karauli.',
#   'generatedQuestions': [{'question': 'Are people boycotting the Congress party in Rajasthan following the communal violence in Karauli?',
#     'questionType': 'Boolean'},
#    {'question': 'What is the reason for the alleged boycott of the Congress party in Rajasthan?',
#     'questionType': 'Abstractive'},
#    {'question': 'What evidence is there of a boycott of the Congress party in Rajasthan after the Karauli violence?',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Dalit youth has head tonsured, beaten up by police; SI arrested',
#   'generatedQuestions': [{'question': "Who was the victim of the alleged police brutality?'",
#     'questionType': 'Extractive'},
#    {'question': 'What was the nature of the injuries inflicted on the Dalit youth?',
#     'questionType': 'Abstractive'},
#    {'question': 'Was there any evidence of wrongdoing by the police officers involved?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Woman infected with coronavirus killed by Chinese police.',
#   'generatedQuestions': [{'question': "Who is said to have been killed by Chinese police according to the claim?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the claim allege Chinese police did to the woman infected with coronavirus?',
#     'questionType': 'Abstractive'},
#    {'question': 'Does the claim allege that the Chinese police committed a violent act against the woman?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Rajasthan governor bound by cabinet's advice, say legal experts.",
#   'generatedQuestions': [{'question': 'Is the Rajasthan governor required to follow the advice of the cabinet?',
#     'questionType': 'Boolean'},
#    {'question': "What do legal experts say about the relationship between the Rajasthan governor and the cabinet's advice?",
#     'questionType': 'Abstractive'},
#    {'question': 'What powers does the Rajasthan governor have in relation to the advice of the cabinet?',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': '50 crore Indian mobile subscribers are at risk of deactivation due to Aadhaar eKYC requirements.',
#   'generatedQuestions': [{'question': "How many mobile subscribers are at risk of deactivation due to Aadhaar eKYC requirements?'",
#     'questionType': 'Extractive'},
#    {'question': 'What does the claim say about the risk of mobile subscriber deactivation due to Aadhaar eKYC requirements?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is it true that 50 crore mobile subscribers are at risk of deactivation due to Aadhaar eKYC requirements?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': "Rows and rows of empty seats during prime minister narendra modi's rally at jamnagar, gujarat, on may 2.",
#   'generatedQuestions': [{'question': "How many people attended prime minister Narendra Modi\\'s rally in Jamnagar, Gujarat on May 2?'",
#     'questionType': 'Extractive'},
#    {'question': "What did the seating arrangement at prime minister Narendra Modi's rally in Jamnagar, Gujarat on May 2 look like?",
#     'questionType': 'Abstractive'},
#    {'question': "Was prime minister Narendra Modi's rally in Jamnagar, Gujarat on May 2 well-attended?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'After lavish midair birthday, tejashwi plays caste card to fight backlash.',
#   'generatedQuestions': [{'question': 'Did Tejashwi Yadav have a lavish midair birthday party?',
#     'questionType': 'Extractive'},
#    {'question': 'What did Tejashwi Yadav do to fight backlash after his midair birthday party?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did Tejashwi Yadav use caste politics to defend himself against criticism for his midair birthday party?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'police team attacked as it tries to arrest murder accused in up.',
#   'generatedQuestions': [{'question': "Was there any involvement of the police in the attack on the murder accused in UP?'",
#     'questionType': 'Extractive'},
#    {'question': "What does the investigation report say about the attack on the police team in UP?'",
#     'questionType': 'Abstractive'},
#    {'question': "Did the police team face resistance while trying to arrest the murder accused in UP?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Nia arrests key isi aide in vizag espionage case',
#   'generatedQuestions': [{'question': "Who was arrested by NIA in the Vizag espionage case?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the role of the person arrested by NIA in the Vizag espionage case?'",
#     'questionType': 'Abstractive'},
#    {'question': "Is the person arrested by NIA linked to the ISI?'",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'arvind kejriwal to address party volunteers across nation on independence day.',
#   'generatedQuestions': [{'question': "Which day is Arvind Kejriwal scheduled to address party volunteers nationwide?'",
#     'questionType': 'Extractive'},
#    {'question': "What is the purpose of Arvind Kejriwal's address to party volunteers on Independence Day?",
#     'questionType': 'Abstractive'},
#    {'question': "Is Arvind Kejriwal's address to party volunteers on Independence Day open to the public?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Patidar leader hardik patel missing for 20 days, claims wife, accuses gujarat govt of targeting him',
#   'generatedQuestions': [{'question': "Who is claiming that Hardik Patel has been missing for 20 days?'",
#     'questionType': 'Extractive'},
#    {'question': "What allegations is Hardik Patel's wife making against the Gujarat government?",
#     'questionType': 'Abstractive'},
#    {'question': 'Is there any evidence to support the claim that Hardik Patel is missing?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A man was beaten to death by shopkeepers over a headphone.',
#   'generatedQuestions': [{'question': "Who was beaten to death by shopkeepers according to the claim?'",
#     'questionType': 'Extractive'},
#    {'question': 'What object was the man allegedly beaten to death with, according to the claim?',
#     'questionType': 'Abstractive'},
#    {'question': "Did the claim allege that the man's death was caused by shopkeepers?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Last rites of gangster-turned-politician mukhtar ansari.',
#   'generatedQuestions': [{'question': "Was Mukhtar Ansari a gangster before becoming a politician?'",
#     'questionType': 'Extractive'},
#    {'question': "What were the circumstances surrounding Mukhtar Ansari's transformation from a gangster to a politician?",
#     'questionType': 'Abstractive'},
#    {'question': "Did Mukhtar Ansari's criminal past have any impact on his political career?",
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'A post circulating on social media shows Prime Minister Narendra Modi taking a dip in the river, being supported by a few people.',
#   'generatedQuestions': [{'question': "Who is supporting Prime Minister Narendra Modi in the river?'",
#     'questionType': 'Extractive'},
#    {'question': 'What is Prime Minister Narendra Modi doing in the river?',
#     'questionType': 'Abstractive'},
#    {'question': 'Is Prime Minister Narendra Modi in danger while taking a dip in the river?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': 'Eros now deletes vulgar navratri posts amid boycott call.',
#   'generatedQuestions': [{'question': "Did Eros Now delete any Navratri-related posts?'",
#     'questionType': 'Boolean'},
#    {'question': "What kind of Navratri posts did Eros Now delete?'",
#     'questionType': 'Abstractive'},
#    {'question': "Did Eros Now receive calls to boycott their platform before deleting the Navratri posts?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  {'claim': ' 1,000 buses arranged by Priyanka Gandhi in Uttar Pradesh to bring migrants home.',
#   'generatedQuestions': [{'question': 'How many buses did Priyanka Gandhi arrange for migrants in Uttar Pradesh?',
#     'questionType': 'Extractive'},
#    {'question': 'What has been the role of Priyanka Gandhi in providing transportation for migrants in Uttar Pradesh?',
#     'questionType': 'Abstractive'},
#    {'question': 'Did Priyanka Gandhi arrange 1,000 buses for migrants in Uttar Pradesh, as claimed?',
#     'questionType': 'Boolean'}],
#   'goldQuestions': [{'question': 'How did West Bengal MLA Debendra Roy die?',
#     'questionType': 'Extractive'},
#    {'question': "What does the autopsy report say about Debendra Roy's death?",
#     'questionType': 'Abstractive'},
#    {'question': "Was there any foul play in Debendra Roy's death?",
#     'questionType': 'Boolean'}]},
#  ...]

# %%
import numpy as np

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences

    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    try:
      row_ind, col_ind = linear_sum_assignment(cost_matrix)
    except ValueError as e:
      print(f"ravi,{generated_sequences},{reference_sequences},{scores}")
    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))


for data in new_data:
  generated_sequences = [question['question'] for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question'] for question in data['goldQuestions']]
  if not generated_sequences or not reference_sequences:
      continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generated Question 2: What were the slogans being chanted by the mob?'
# Best METEOR Score: 0.1261
# Generated Question 3: Where did the incident with the mob take place?'
# Best METEOR Score: 0.1087
# Generated Question 4: Was there any connection to religious extremism in the mob behavior?'
# Best METEOR Score: 0.3982
# Generated Question 5: What was the nature of the objects thrown by the mob?'
# Best METEOR Score: 0.1240
# Total METEOR Score (normalized): 0.2110
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has the Army version of HAL\'s light utility helicopter completed its trials in the Himalayas?'
# Best METEOR Score: 0.1282
# Generated Question 2: What is the current status of the Army version of HAL's light utility helicopter trials in the Himalayas?
# Best METEOR Score: 0.1562
# Generated Question 3: Is the Army version of HAL's light utility helicopter ready for operational clearance after completing trials in the Himalayas?
# Best METEOR Score: 0.1250
# Total METEOR Score (normalized): 0.1112
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Will Modi and Biden speak at the same time?'
# Best METEOR Score: 0.0840
# Generated Question 2: What has the MEA said about bipartisan support for India-US ties?'
# Best METEOR Score: 0.3074
# Generated Question 3: How does the MEA describe the current state of India-US relations?'
# Best METEOR Score: 0.1653
# Total METEOR Score (normalized): 0.1531
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Navjot Singh Sidhu resign as minister?'
# Best METEOR Score: 0.1111
# Generated Question 2: What did Navjot Singh Sidhu's resignation letter say?'
# Best METEOR Score: 0.1681
# Generated Question 3: When did Navjot Singh Sidhu send his resignation letter to Amarinder Singh?'
# Best METEOR Score: 0.1053
# Total METEOR Score (normalized): 0.1078
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: What type of weapon did India test?
# Best METEOR Score: 0.1124
# Generated Question 2: What are the capabilities of the tested torpedo system?
# Best METEOR Score: 0.1271
# Generated Question 3: Did the testing of the torpedo system encounter any issues?
# Best METEOR Score: 0.1087
# Total METEOR Score (normalized): 0.1101
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has Nyakim Gatwech been recognized by Guinness World Records?
# Best METEOR Score: 0.0549
# Generated Question 2: What recognition has Nyakim Gatwech received from Guinness World Records?
# Best METEOR Score: 0.0840
# Generated Question 3: What is unique about Nyakim Gatwech's skin according to Guinness World Records?
# Best METEOR Score: 0.1639
# Total METEOR Score (normalized): 0.0881
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Who is alleged to have kidnapped the child in the claim?'
# Best METEOR Score: 0.0893
# Generated Question 2: What is the religion of the woman who is said to have kidnapped the child?'
# Best METEOR Score: 0.1600
# Generated Question 3: How is the woman described in the claim?'
# Best METEOR Score: 0.1099
# Generated Question 4: Did the woman have any accomplices in the kidnapping, according to the claim?'
# Best METEOR Score: 0.1304
# Generated Question 5: What type of vehicle is mentioned as being used in the kidnapping?'
# Best METEOR Score: 0.1230
# Total METEOR Score (normalized): 0.1334
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Bill Gates create a video game called 'Omicron' in 1999?
# Best METEOR Score: 0.1064
# Generated Question 2: What is the plot of the video game 'Omicron' that Bill Gates allegedly created?
# Best METEOR Score: 0.1210
# Generated Question 3: What are the details of the video game 'Omicron' that Bill Gates is said to have released in 1999?
# Best METEOR Score: 0.1550
# Generated Question 4: Is it true that Bill Gates developed a video game where demons disguise themselves as humans and collect their souls?
# Best METEOR Score: 0.0490
# Generated Question 5: What is the nature of the gameplay in the video game 'Omicron' that Bill Gates supposedly created?
# Best METEOR Score: 0.1181
# Generated Question 6: What information is available about the video game 'Omicron', which is attributed to Bill Gates and released in 1999?
# Best METEOR Score: 0.1538
# Total METEOR Score (normalized): 0.1154
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Which states will receive special status if Congress wins, according to Rahul Gandhi?'
# Best METEOR Score: 0.0806
# Generated Question 2: What is Rahul Gandhi's stance on granting special status to northeast states?
# Best METEOR Score: 0.1639
# Generated Question 3: Did Rahul Gandhi promise to restore special status to all northeast states if Congress wins?
# Best METEOR Score: 0.1031
# Total METEOR Score (normalized): 0.1035
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Which military group is accused of launching the missile attack on Kramatorsk railway station?'
# Best METEOR Score: 0.0806
# Generated Question 2: What does the BBC report say about the Ukrainian army's involvement in the Kramatorsk railway station attack?
# Best METEOR Score: 0.5530
# Generated Question 3: Is there evidence to suggest the Ukrainian army was responsible for the Kramatorsk railway station attack?
# Best METEOR Score: 0.1293
# Total METEOR Score (normalized): 0.2446
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will the Maharashtra Congress force the Modi government to repeal the black farm legislations?'
# Best METEOR Score: 0.0806
# Generated Question 2: What are the demands of the Maharashtra Congress regarding the black farm legislations?'
# Best METEOR Score: 0.1220
# Generated Question 3: How does the Maharashtra Congress plan to make the Modi government repeal the black farm legislations?'
# Best METEOR Score: 0.1190
# Total METEOR Score (normalized): 0.0888
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was there a mermaid spotted at Mangalore beach?
# Best METEOR Score: 0.2366
# Generated Question 2: What did people report seeing at Mangalore beach?
# Best METEOR Score: 0.1282
# Generated Question 3: What evidence supports the mermaid sighting at Mangalore beach?
# Best METEOR Score: 0.1271
# Total METEOR Score (normalized): 0.1583
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Which court refused to quash the rape charges against Tarun Tejpal?'
# Best METEOR Score: 0.0826
# Generated Question 2: What order did the Supreme Court give regarding the completion of Tarun Tejpal''s trial?'
# Best METEOR Score: 0.1587
# Generated Question 3: Did the Supreme Court find any evidence of foul play in the Tarun Tejpal case?'
# Best METEOR Score: 0.3845
# Total METEOR Score (normalized): 0.1988
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who was the Israeli official that was allegedly beaten up in the parliament?'
# Best METEOR Score: 0.1316
# Generated Question 2: What details does the report provide about the alleged attack on the Israeli official in the parliament?
# Best METEOR Score: 0.2381
# Generated Question 3: Is it true that an Israeli official was physically assaulted in the parliament?
# Best METEOR Score: 0.1327
# Total METEOR Score (normalized): 0.1410
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: What issues will be discussed at the BJP national executive meet?
# Best METEOR Score: 0.1250
# Generated Question 2: Will the BJP national executive meet focus on caste-related issues?
# Best METEOR Score: 0.0909
# Generated Question 3: What is the BJP's proposed strategy for the upcoming elections?
# Best METEOR Score: 0.1667
# Total METEOR Score (normalized): 0.1038
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: When is NEET UG 2020 scheduled to be held now?'
# Best METEOR Score: 0.0538
# Generated Question 2: What does the latest announcement say about the date for NEET UG 2020?
# Best METEOR Score: 0.4189
# Generated Question 3: Is it true that NEET UG 2020 has been rescheduled for August?
# Best METEOR Score: 0.0532
# Total METEOR Score (normalized): 0.1724
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who broke into the White House in relation to George Floyd’s death?'
# Best METEOR Score: 0.2222
# Generated Question 2: What was the reason given for protesters breaking into the White House?
# Best METEOR Score: 0.1240
# Generated Question 3: Did protesters actually break into the White House in relation to George Floyd’s death?
# Best METEOR Score: 0.2203
# Total METEOR Score (normalized): 0.1777
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Shabana Azmi say that Muslims are not happy in India?'
# Best METEOR Score: 0.1064
# Generated Question 2: What did Shabana Azmi say about the happiness of Muslims in India?'
# Best METEOR Score: 0.3049
# Generated Question 3: According to Shabana Azmi, is India a great country for Muslims?'
# Best METEOR Score: 0.0526
# Total METEOR Score (normalized): 0.1518
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who are the Americans protesting in front of the White House?'
# Best METEOR Score: 0.0893
# Generated Question 2: What are the demands of the Americans protesting in front of the White House?
# Best METEOR Score: 0.1220
# Generated Question 3: Is there any evidence of Americans protesting in front of the White House for Ukraine?
# Best METEOR Score: 0.2745
# Total METEOR Score (normalized): 0.1499
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who slapped Arvind Kejriwal during the 2024 Lok Sabha election rally?'
# Best METEOR Score: 0.0826
# Generated Question 2: What circumstances led to Arvind Kejriwal being slapped at the election rally?
# Best METEOR Score: 0.1240
# Generated Question 3: Did Arvind Kejriwal suffer any injuries as a result of being slapped at the rally?
# Best METEOR Score: 0.1031
# Generated Question 4: What was Arvind Kejriwal's reaction to being slapped at the election rally?
# Best METEOR Score: 0.1639
# Generated Question 5: Was the man who slapped Arvind Kejriwal arrested?
# Best METEOR Score: 0.0926
# Generated Question 6: What was the motivation behind the man slapping Arvind Kejriwal at the rally?
# Best METEOR Score: 0.1230
# Generated Question 7: Did the incident affect Arvind Kejriwal's ability to continue with the election rally?
# Best METEOR Score: 0.1220
# Generated Question 8: How did the crowd at the election rally react to Arvind Kejriwal being slapped?
# Best METEOR Score: 0.2662
# Generated Question 9: Was there any security present at the election rally where Arvind Kejriwal was slapped?
# Best METEOR Score: 0.2769
# Generated Question 10: What steps have been taken to ensure the safety of Arvind Kejriwal at future election rallies?
# Best METEOR Score: 0.1200
# Total METEOR Score (normalized): 0.2357
# Optimal Matching from Hungarian Algorithm:
# Generated Question 4 matched with Reference Question 2
# Generated Question 8 matched with Reference Question 1
# Generated Question 9 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has Noida DM issued an order regarding rent collection during the lockdown?
# Best METEOR Score: 0.1240
# Generated Question 2: What are the new rent collection guidelines issued by the Noida DM during the lockdown?
# Best METEOR Score: 0.1210
# Generated Question 3: Did the Noida DM direct landlords to collect rent after a specific period during the lockdown?
# Best METEOR Score: 0.1020
# Total METEOR Score (normalized): 0.0898
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was the tractor rally organized in support of the protesting wrestlers?
# Best METEOR Score: 0.1351
# Generated Question 2: What was the purpose of the tractor rally?
# Best METEOR Score: 0.1282
# Generated Question 3: Which groups or individuals participated in the tractor rally to Jantar Mantar?
# Best METEOR Score: 0.0893
# Total METEOR Score (normalized): 0.1055
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: How many covid-19 deaths has India reported so far?'
# Best METEOR Score: 0.1261
# Generated Question 2: What does the latest data show about India's covid-19 death toll?
# Best METEOR Score: 0.4731
# Generated Question 3: Has there been a significant increase in India's covid-19 death toll?
# Best METEOR Score: 0.2232
# Generated Question 4: How many new covid-19 cases has India reported recently?'
# Best METEOR Score: 0.1087
# Generated Question 5: What does the latest data show about India's covid-19 case count?
# Best METEOR Score: 0.4224
# Generated Question 6: Has there been a record increase in India's covid-19 case count?
# Best METEOR Score: 0.1786
# Total METEOR Score (normalized): 0.2683
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a tiger carcass found in a wildlife sanctuary in Chhattisgarh?
# Best METEOR Score: 0.1351
# Generated Question 2: What are the details of the tiger carcass found in Chhattisgarh's wildlife sanctuary?
# Best METEOR Score: 0.1626
# Generated Question 3: How did the tiger carcass in Chhattisgarh's wildlife sanctuary die?
# Best METEOR Score: 0.4032
# Total METEOR Score (normalized): 0.2337
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What religious practices are being performed in the video?
# Best METEOR Score: 0.1271
# Generated Question 2: Who is seen performing Hindu rituals in the video?
# Best METEOR Score: 0.0917
# Generated Question 3: Is it common for Africans to participate in Hindu rituals?
# Best METEOR Score: 0.0909
# Total METEOR Score (normalized): 0.0911
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What is the Agusta fallout?'
# Best METEOR Score: 0.1304
# Generated Question 2: Who are the 78 veterans demanding fast-track courts for corruption in defense deals?'
# Best METEOR Score: 0.0877
# Generated Question 3: What is the reason given by the veterans for their demand for fast-track courts?'
# Best METEOR Score: 0.1210
# Generated Question 4: Do the veterans allege corruption in the Agusta deal?'
# Best METEOR Score: 0.0909
# Generated Question 5: What specific defense deals are the veterans referring to in their demand for fast-track courts?'
# Best METEOR Score: 0.1200
# Generated Question 6: Have any actions been taken in response to the veterans' demand for fast-track courts?'
# Best METEOR Score: 0.1293
# Generated Question 7: Is the demand for fast-track courts a direct consequence of the Agusta fallout?'
# Best METEOR Score: 0.0813
# Total METEOR Score (normalized): 0.1047
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# Generated Question 6 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Pakistan government provide security to the New Zealand cricket team?'
# Best METEOR Score: 0.1053
# Generated Question 2: What kind of security was provided to the New Zealand cricket team by the Pakistan government?'
# Best METEOR Score: 0.1190
# Generated Question 3: What does the report about the security provided by the Pakistan government to the New Zealand cricket team say?'
# Best METEOR Score: 0.3718
# Generated Question 4: Did any incidents occur during the New Zealand cricket team's tour in Pakistan that required government security intervention?'
# Best METEOR Score: 0.1667
# Generated Question 5: How did the Pakistan government ensure the safety of the New Zealand cricket team during their visit?'
# Best METEOR Score: 0.2556
# Generated Question 6: Was the security provided by the Pakistan government to the New Zealand cricket team sufficient?'
# Best METEOR Score: 0.0862
# Generated Question 7: What measures were taken by the Pakistan government to protect the New Zealand cricket team?'
# Best METEOR Score: 0.1200
# Total METEOR Score (normalized): 0.2647
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who said that justice has prevailed in regards to the Nirbhaya case?'
# Best METEOR Score: 0.1230
# Generated Question 2: What did PM Modi say about the Nirbhaya convicts hanging?'
# Best METEOR Score: 0.3100
# Generated Question 3: Did PM Modi express satisfaction with the hanging of the Nirbhaya convicts?'
# Best METEOR Score: 0.1053
# Generated Question 4: What was PM Modi\'s reaction to the execution of the Nirbhaya case convicts?'
# Best METEOR Score: 0.1613
# Generated Question 5: Did PM Modi make a statement regarding the Nirbhaya case convicts hanging?'
# Best METEOR Score: 0.1053
# Generated Question 6: What did PM Modi express in regards to the Nirbhaya case convicts being hanged?'
# Best METEOR Score: 0.1210
# Total METEOR Score (normalized): 0.1819
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the structure in the image a government-owned building?'
# Best METEOR Score: 0.0909
# Generated Question 2: What kind of building is depicted in the image based on its current state?'
# Best METEOR Score: 0.1613
# Generated Question 3: What can you tell about the condition of the roof of the building in the image?'
# Best METEOR Score: 0.2952
# Total METEOR Score (normalized): 0.1459
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Who is the Italian doctor in the claim?'
# Best METEOR Score: 0.0917
# Generated Question 2: What is the Italian doctor's condition in the claim?'
# Best METEOR Score: 0.1667
# Generated Question 3: Is the Italian doctor dying from the coronavirus in the claim?'
# Best METEOR Score: 0.1064
# Total METEOR Score (normalized): 0.1216
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who is the Pakistani journalist praising Prime Minister Narendra Modi?
# Best METEOR Score: 0.0840
# Generated Question 2: What are the reasons given by the Pakistani journalist for praising Prime Minister Narendra Modi?
# Best METEOR Score: 0.1210
# Generated Question 3: Is it common for Pakistani journalists to praise Indian Prime Ministers?
# Best METEOR Score: 0.0538
# Total METEOR Score (normalized): 0.0735
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who attacked Israeli soldiers in the incident?'
# Best METEOR Score: 0.0926
# Generated Question 2: What were the Israeli soldiers doing when they were attacked?
# Best METEOR Score: 0.1261
# Generated Question 3: Did the Israeli soldiers flee as a result of the attack?
# Best METEOR Score: 0.1075
# Total METEOR Score (normalized): 0.1087
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was West Bengal CM Mamata Banerjee mourning on Tuesday during the Cricket World Cup 2019?'
# Best METEOR Score: 0.2608
# Generated Question 2: What was the reason for West Bengal CM Mamata Banerjee's emotional state on Tuesday during the Cricket World Cup 2019?'
# Best METEOR Score: 0.2457
# Generated Question 3: Did India's victory over Bangladesh on Tuesday in the Cricket World Cup 2019 cause West Bengal CM Mamata Banerjee's reaction?'
# Best METEOR Score: 0.3006
# Total METEOR Score (normalized): 0.1925
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Which cadet received the sword of honor at the Indian Military Academy?'
# Best METEOR Score: 0.0820
# Generated Question 2: What is the significance of the sword of honor at the Indian Military Academy?'
# Best METEOR Score: 0.1210
# Generated Question 3: Is it common for a Punjab cadet to receive the sword of honor at the Indian Military Academy?'
# Best METEOR Score: 0.0781
# Total METEOR Score (normalized): 0.0719
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who has accused the MLA of assault?'
# Best METEOR Score: 0.1111
# Generated Question 2: What evidence supports the allegation of abduction against the MLA?'
# Best METEOR Score: 0.1250
# Generated Question 3: Has there been a criminal investigation into the rape allegation against the MLA?'
# Best METEOR Score: 0.1042
# Generated Question 4: What is the response of the MLA to the allegations of misconduct?'
# Best METEOR Score: 0.1230
# Generated Question 5: Have any charges been brought against the MLA in relation to the allegations?'
# Best METEOR Score: 0.1754
# Generated Question 6: What is the position of the political party of the MLA on the allegations?'
# Best METEOR Score: 0.1210
# Generated Question 7: Have there been any protests or public outcry over the allegations against the MLA?'
# Best METEOR Score: 0.1304
# Total METEOR Score (normalized): 0.1372
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who is the former Pakistani lawmaker seeking political asylum in India?
# Best METEOR Score: 0.0901
# Generated Question 2: What are the reasons given by the former Pakistani lawmaker for seeking political asylum in India?
# Best METEOR Score: 0.1200
# Generated Question 3: Is it true that a former Pakistani lawmaker is seeking political asylum in India?
# Best METEOR Score: 0.0877
# Total METEOR Score (normalized): 0.0874
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did SP Balasubrahmanyam's voice and music enthrall audiences for decades?'
# Best METEOR Score: 0.1064
# Generated Question 2: How did SP Balasubrahmanyam's voice and music impact his audience over the years?'
# Best METEOR Score: 0.2635
# Generated Question 3: What specific qualities of SP Balasubrahmanyam's voice and music made them so captivating?'
# Best METEOR Score: 0.1210
# Total METEOR Score (normalized): 0.1579
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Who was beaten up by members of his own community according to the claim?'
# Best METEOR Score: 0.0870
# Generated Question 2: What was the reason given for Abu Kamil being beaten up by members of his own community?'
# Best METEOR Score: 0.1181
# Generated Question 3: Did members of Abu Kamil’s own community beat him up as claimed?'
# Best METEOR Score: 0.1031
# Total METEOR Score (normalized): 0.1027
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who is the autorickshaw driver who died in Tenkasi, Tamil Nadu?
# Best METEOR Score: 0.1064
# Generated Question 2: What injuries did the autorickshaw driver sustain before his death?
# Best METEOR Score: 0.2652
# Generated Question 3: Is there any evidence suggesting police involvement in the autorickshaw driver's death?
# Best METEOR Score: 0.4978
# Generated Question 4: What was the cause of the autorickshaw driver's death?
# Best METEOR Score: 0.3748
# Generated Question 5: Were there any witnesses to the autorickshaw driver's injuries?
# Best METEOR Score: 0.2869
# Generated Question 6: What has been the response of the authorities to the allegations of police involvement in the autorickshaw driver's death?
# Best METEOR Score: 0.3457
# Total METEOR Score (normalized): 0.3271
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: What was the cause of the long crack in the Earth’s crust in Turkey-Syria?'
# Best METEOR Score: 0.1282
# Generated Question 2: What does the seismic data suggest about the cause of the crack in the Earth's crust in Turkey-Syria?
# Best METEOR Score: 0.3331
# Generated Question 3: Was there any geological activity, such as earthquakes, that could have caused a long crack in the Earth's crust in Turkey-Syria?
# Best METEOR Score: 0.4122
# Total METEOR Score (normalized): 0.2653
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: How many people were booked under sedition in Mumbai in connection with Sharjeel Imam?'
# Best METEOR Score: 0.1031
# Generated Question 2: What are the details of the sedition case filed against 51 people in Mumbai for supporting Sharjeel Imam?
# Best METEOR Score: 0.1181
# Generated Question 3: Is it true that 51 people were booked under sedition in Mumbai for allegedly supporting Sharjeel Imam?
# Best METEOR Score: 0.0855
# Total METEOR Score (normalized): 0.1022
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are there individuals in Delhi-NCR willing to donate plasma for COVID-19 patients?'
# Best METEOR Score: 0.1327
# Generated Question 2: Can you provide the names and contact details of plasma donors in Delhi-NCR?'
# Best METEOR Score: 0.0877
# Generated Question 3: What information can you provide about plasma donors in Delhi-NCR for COVID-19 patients?'
# Best METEOR Score: 0.1220
# Total METEOR Score (normalized): 0.1023
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Which day will Prime Minister Modi inaugurate the multistorey flats for MPs?
# Best METEOR Score: 0.0826
# Generated Question 2: What will be the purpose of Prime Minister Modi's inauguration on Monday?
# Best METEOR Score: 0.1639
# Generated Question 3: Will there be any new housing initiatives for MPs announced on Monday?
# Best METEOR Score: 0.1339
# Total METEOR Score (normalized): 0.1170
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did robbers engage in a gunfight with Noida cops?
# Best METEOR Score: 0.1099
# Generated Question 2: What led to the robbers returning to the scene after the gunfight?
# Best METEOR Score: 0.1240
# Generated Question 3: What was the reason for the robbers asking for the ATM card pin after the gunfight?
# Best METEOR Score: 0.1200
# Total METEOR Score (normalized): 0.1067
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: What is the purpose of the 'mining minister flying squad' that Haryana plans to set up?
# Best METEOR Score: 0.1190
# Generated Question 2: How will the 'mining minister flying squad' operate in Haryana?
# Best METEOR Score: 0.1075
# Generated Question 3: Will the 'mining minister flying squad' have the power to make arrests in Haryana?
# Best METEOR Score: 0.0870
# Total METEOR Score (normalized): 0.1045
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: What is the significance of the BJP reshuffling its state-in-charge ahead of the West Bengal elections?'
# Best METEOR Score: 0.2581
# Generated Question 2: Which state(s) have been assigned to new state-in-charge by the BJP ahead of the West Bengal elections?'
# Best METEOR Score: 0.2481
# Generated Question 3: Does the BJP reshuffling of state-in-charge indicate a change in the party's strategy for the West Bengal elections?'
# Best METEOR Score: 0.2505
# Total METEOR Score (normalized): 0.1662
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has Salman Khan's bodyguard joined a political party?
# Best METEOR Score: 0.0917
# Generated Question 2: Which political party has Salman Khan's bodyguard joined?
# Best METEOR Score: 0.0917
# Generated Question 3: What is the reaction of Aditya Thackeray, the leader of Shiv Sena, to Salman Khan's bodyguard joining the party?
# Best METEOR Score: 0.1527
# Generated Question 4: Did Salman Khan's bodyguard join Shiv Sena voluntarily or was he recruited?
# Best METEOR Score: 0.1327
# Generated Question 5: What is the role of Salman Khan's bodyguard in Shiv Sena?
# Best METEOR Score: 0.1653
# Generated Question 6: What are the implications of Salman Khan's bodyguard joining Shiv Sena for the film industry?
# Best METEOR Score: 0.1600
# Generated Question 7: Has Salman Khan reacted to his bodyguard joining Shiv Sena?
# Best METEOR Score: 0.0543
# Generated Question 8: What is the response of Salman Khan's fans to his bodyguard joining Shiv Sena?
# Best METEOR Score: 0.1613
# Generated Question 9: Is there any political motive behind Salman Khan's bodyguard joining Shiv Sena?
# Best METEOR Score: 0.2793
# Generated Question 10: What is the background of Salman Khan's bodyguard in the film industry and security services?
# Best METEOR Score: 0.1600
# Total METEOR Score (normalized): 0.1833
# Optimal Matching from Hungarian Algorithm:
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# Generated Question 9 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who asked Mohammad Nabi to choose bowling after Afghanistan won the toss in the match held on November 3?'
# Best METEOR Score: 0.0833
# Generated Question 2: What was Virat Kohli's request to Mohammad Nabi after the toss in the match on November 3?
# Best METEOR Score: 0.1695
# Generated Question 3: Did Virat Kohli engage in any suspicious activity during the toss of the match on November 3?
# Best METEOR Score: 0.1282
# Total METEOR Score (normalized): 0.1160
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What kind of special celebrations were held at Hyderabad zoo?'
# Best METEOR Score: 0.0833
# Generated Question 2: What was the age of the elephant named Rani at the celebrations?'
# Best METEOR Score: 0.1230
# Generated Question 3: Describe the celebrations held for the elephants at Hyderabad zoo.'
# Best METEOR Score: 0.0417
# Generated Question 4: Did the Hyderabad zoo celebrate any events for elephants recently?'
# Best METEOR Score: 0.1075
# Generated Question 5: What was the occasion for the special celebrations for elephants at Hyderabad zoo?'
# Best METEOR Score: 0.1220
# Total METEOR Score (normalized): 0.1061
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who was the victim of the gang rape in Buxar, Bihar?'
# Best METEOR Score: 0.1327
# Generated Question 2: What does the police report say about the woman and child tossed into the river in Buxar?
# Best METEOR Score: 0.5037
# Generated Question 3: Was there any criminal involvement in the incident of the woman and child in Buxar?
# Best METEOR Score: 0.3878
# Total METEOR Score (normalized): 0.3147
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has there been an improvement in the ease of doing business in Uttar Pradesh?'
# Best METEOR Score: 0.1304
# Generated Question 2: What factors have contributed to the improvement in the ease of doing business in Uttar Pradesh?'
# Best METEOR Score: 0.1190
# Generated Question 3: Is it true that law and order is the main factor behind the improvement in the ease of doing business in Uttar Pradesh?'
# Best METEOR Score: 0.1128
# Total METEOR Score (normalized): 0.0989
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who is the South African leader calling for violence against Indian and white communities?
# Best METEOR Score: 0.0813
# Generated Question 2: What specifically did the South African leader say about violence against Indian and white communities?
# Best METEOR Score: 0.3000
# Generated Question 3: Is it true that a South African leader is inciting violence against Indian and white communities?
# Best METEOR Score: 0.0510
# Total METEOR Score (normalized): 0.1317
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: What is the intention behind the BJP promoting the quota bill?'
# Best METEOR Score: 0.1240
# Generated Question 2: How is the opposition trying to mislead the SCS and STs?'
# Best METEOR Score: 0.1064
# Generated Question 3: Is there any evidence of foul play in the opposition's bid to mislead the SCS and STs?'
# Best METEOR Score: 0.5334
# Total METEOR Score (normalized): 0.2546
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Which party is predicted to win the Gujarat assembly elections 2022 according to exit polls?'
# Best METEOR Score: 0.1020
# Generated Question 2: What is the predicted range of seats that the Aam Aadmi Party will win in the Gujarat assembly elections 2022?
# Best METEOR Score: 0.1163
# Generated Question 3: Does the claim suggest that the Aam Aadmi Party will secure an outright majority in the Gujarat assembly elections 2022?
# Best METEOR Score: 0.1163
# Total METEOR Score (normalized): 0.1006
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who discovered the ancient Roman coins?'
# Best METEOR Score: 0.0862
# Generated Question 2: How long were the Roman coins underground before being discovered?'
# Best METEOR Score: 0.1075
# Generated Question 3: Describe the condition of the Roman coins when they were discovered.'
# Best METEOR Score: 0.0413
# Generated Question 4: Was this the first time the British man went on a treasure hunt?'
# Best METEOR Score: 0.1042
# Generated Question 5: What is the nationality of the person who discovered the Roman coins?'
# Best METEOR Score: 0.1230
# Generated Question 6: Where were the Roman coins found?'
# Best METEOR Score: 0.0862
# Total METEOR Score (normalized): 0.1061
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: What are disposable paper phones?'
# Best METEOR Score: 0.1304
# Generated Question 2: What are the features of the upcoming disposable paper phones?
# Best METEOR Score: 0.1681
# Generated Question 3: Are the disposable paper phones meant to be a sustainable alternative to traditional smartphones?
# Best METEOR Score: 0.1220
# Total METEOR Score (normalized): 0.0896
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did actress Deepika Padukone cry in response to the controversy over the song "Besharam Rang"?'
# Best METEOR Score: 0.1000
# Generated Question 2: What was the reason for Deepika Padukone's emotional reaction following the "Besharam Rang" controversy?'
# Best METEOR Score: 0.1575
# Generated Question 3: What was the public reaction to the song "Besharam Rang" in Deepika Padukone's film "Pathaan"?'
# Best METEOR Score: 0.1653
# Total METEOR Score (normalized): 0.1409
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: How many tunnels have been built on the Jammu border in the past four years?
# Best METEOR Score: 0.1031
# Generated Question 2: What features do the tunnels on the Jammu border have?
# Best METEOR Score: 0.1261
# Generated Question 3: Are there any walkways or air pipes in the tunnels on the Jammu border?
# Best METEOR Score: 0.2769
# Total METEOR Score (normalized): 0.1687
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who shot Donald Trump?
# Best METEOR Score: 0.0581
# Generated Question 2: What body part of Donald Trump was targeted in the shooting?
# Best METEOR Score: 0.1351
# Generated Question 3: Did a bulletproof vest save Donald Trump's life in a shooting incident?
# Best METEOR Score: 0.1327
# Total METEOR Score (normalized): 0.1053
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who has joined the Congress party, as reported in the claim?
# Best METEOR Score: 0.1240
# Generated Question 2: What is the relationship between the person who joined Congress and Madhya Pradesh CM Shivraj Chouhan?
# Best METEOR Score: 0.1200
# Generated Question 3: What was the reason for the person's decision to join Congress, as described in the claim?
# Best METEOR Score: 0.1695
# Generated Question 4: Is it true that Madhya Pradesh CM Shivraj Chouhan's brother-in-law has joined the Congress party, as stated in the claim?
# Best METEOR Score: 0.1527
# Generated Question 5: What is the reaction of Madhya Pradesh CM Shivraj Chouhan's party, the BJP, to the report of his brother-in-law joining Congress?
# Best METEOR Score: 0.1880
# Generated Question 6: How may this development impact the political landscape of Madhya Pradesh, in light of the claim?
# Best METEOR Score: 0.1010
# Total METEOR Score (normalized): 0.1528
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Which social media accounts will Prime Minister Narendra Modi give away for Women's Day?
# Best METEOR Score: 0.1210
# Generated Question 2: What is the purpose of Prime Minister Narendra Modi giving away his social media accounts for Women's Day?
# Best METEOR Score: 0.1953
# Generated Question 3: Is it true that Prime Minister Narendra Modi will give away his social media accounts on Women's Day?
# Best METEOR Score: 0.1172
# Total METEOR Score (normalized): 0.1106
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Were there any issues with oxygen supply at the hospital in Jammu?'
# Best METEOR Score: 0.2793
# Generated Question 2: What does the investigation report say about the oxygen supply issues at the Jammu hospital?
# Best METEOR Score: 0.5118
# Generated Question 3: Did the oxygen supply issues at the Jammu hospital lead to any fatalities?
# Best METEOR Score: 0.1053
# ...
# Generated Question 4: How has the snowfall affected air traffic in the Kashmir valley?'
# Best METEOR Score: 0.1064
# Generated Question 5: What is the status of flights coming in and going out of Kashmir?
# Best METEOR Score: 0.1230
# Generated Question 6: Is air traffic operating normally in Kashmir despite the snowfall?
# Best METEOR Score: 0.0909
# Total METEOR Score (normalized): 0.2229
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who has been called to resign by the Sri Lankan president, Sirisena?
# Best METEOR Score: 0.0820
# Generated Question 2: What positions do the individuals called to resign by Sirisena hold?
# Best METEOR Score: 0.1250
# Generated Question 3: Did Sirisena request the resignation of anyone other than the defence secretary and police chief?
# Best METEOR Score: 0.1031
# Total METEOR Score (normalized): 0.0908
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who are the two individuals that were killed in the air strike?
# Best METEOR Score: 0.0893
# Generated Question 2: What were the occupations of the two individuals killed in the air strike?
# Best METEOR Score: 0.1230
# Generated Question 3: Was the death of the two individuals a result of a direct air strike?
# Best METEOR Score: 0.1316
# Total METEOR Score (normalized): 0.1026
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who are 'bhakts' and why are they boycotting Shah Rukh Khan on Twitter?'
# Best METEOR Score: 0.0515
# Generated Question 2: What is the purpose of the boycott of Shah Rukh Khan by 'bhakts' on Twitter?
# Best METEOR Score: 0.1200
# Generated Question 3: Is there evidence that 'bhakts' are boycotting Shah Rukh Khan on Twitter?
# Best METEOR Score: 0.0885
# Generated Question 4: Is Twitter CEO Jack Dorsey at Shah Rukh Khan\'s residence, Mannat?'
# Best METEOR Score: 0.0877
# Generated Question 5: What is the significance of Twitter CEO Jack Dorsey being present at Shah Rukh Khan\'s residence, Mannat?
# Best METEOR Score: 0.1562
# Generated Question 6: Is there evidence that Twitter CEO Jack Dorsey is with Shah Rukh Khan at Mannat?
# Best METEOR Score: 0.0870
# Total METEOR Score (normalized): 0.0989
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: What was the result of the DDC elections in Jammu and Kashmir?'
# Best METEOR Score: 0.1327
# Generated Question 2: How did the people of Jammu and Kashmir vote in the DDC elections regarding the center's decision to scrap article 370?'
# Best METEOR Score: 0.2434
# Generated Question 3: Did the DDC election results show that a majority of people in Jammu and Kashmir rejected the center's decision to scrap article 370?'
# Best METEOR Score: 0.1200
# Total METEOR Score (normalized): 0.1627
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: What human rights abuses have been reported in Kashmir?'
# Best METEOR Score: 0.1261
# Generated Question 2: What does the report by the UN Human Rights Council say about police conduct in Kashmir?
# Best METEOR Score: 0.4580
# Generated Question 3: Is there evidence of excessive force by police in Kashmir?
# Best METEOR Score: 0.1364
# Total METEOR Score (normalized): 0.2162
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Who tore the Ayodhya map in Supreme Court?'
# Best METEOR Score: 0.0917
# Generated Question 2: What is the mobile number of the lawyer who tore the Ayodhya map in Supreme Court?
# Best METEOR Score: 0.1200
# Generated Question 3: Did lawyer Rajeev Dhavan tear the Ayodhya map in Supreme Court?
# Best METEOR Score: 0.1075
# Total METEOR Score (normalized): 0.1064
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Where was Volodymyr Zelenskyy photographed shirtless in 1999?
# Best METEOR Score: 0.1389
# Generated Question 2: What was Volodymyr Zelenskyy wearing at the 1999 Pride parade in New York City?
# Best METEOR Score: 0.1316
# Generated Question 3: Is it true that Volodymyr Zelenskyy attended a Pride parade in New York City in 1999 and was photographed shirtless?
# Best METEOR Score: 0.1250
# Total METEOR Score (normalized): 0.1033
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What activities were BJP workers engaged in during their rally in Kurhani, Bihar?'
# Best METEOR Score: 0.0870
# Generated Question 2: What does the evidence suggest about the distribution of alcohol at the BJP rally in Kurhani, Bihar?
# Best METEOR Score: 0.2929
# Generated Question 3: Is there any evidence of illegal activities, such as the distribution of alcohol, at the BJP rally in Kurhani, Bihar?
# Best METEOR Score: 0.2566
# Total METEOR Score (normalized): 0.2004
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a complaint filed against Alia Bhatt and Mahesh Bhatt for the Sadak 2 poster?'
# Best METEOR Score: 0.0862
# Generated Question 2: What is the complaint filed against Alia Bhatt and Mahesh Bhatt about the Sadak 2 poster?'
# Best METEOR Score: 0.1587
# Generated Question 3: How did the Sadak 2 poster allegedly hurt Hindu sentiments?'
# Best METEOR Score: 0.2748
# Total METEOR Score (normalized): 0.1732
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What is the name of the new scheme launched by the MP government?'
# Best METEOR Score: 0.1220
# Generated Question 2: Who is eligible for the new 100-day employment scheme in MP?'
# Best METEOR Score: 0.0893
# Generated Question 3: Does the new scheme only apply to EWS youth?'
# Best METEOR Score: 0.2148
# Total METEOR Score (normalized): 0.1187
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did RJD MLAs behave inappropriately with a woman during their study tour?'
# Best METEOR Score: 0.1579
# Generated Question 2: What was the nature of RJD MLAs interaction with the woman on their study tour?'
# Best METEOR Score: 0.1200
# Generated Question 3: How did RJD MLAs conduct themselves with the woman during their study tour?'
# Best METEOR Score: 0.3288
# Total METEOR Score (normalized): 0.1643
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What is the ranking of the BJP's income among national parties?
# Best METEOR Score: 0.1653
# Generated Question 2: How does the BJP's income compare to other national parties?
# Best METEOR Score: 0.2630
# Generated Question 3: Is it true that the BJP's income is the 23rd highest among national parties?
# Best METEOR Score: 0.1210
# Total METEOR Score (normalized): 0.1346
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did PM Narendra Modi, President Droupadi Murmu, Uttar Pradesh CM Yogi Adityanath, and Maharashtra CM Eknath Shinde know each other in their youth?'
# Best METEOR Score: 0.0917
# Generated Question 2: What are some anecdotes about the youth of PM Narendra Modi, President Droupadi Murmu, Uttar Pradesh CM Yogi Adityanath, and Maharashtra CM Eknath Shinde?'
# Best METEOR Score: 0.1460
# Generated Question 3: How did PM Narendra Modi, President Droupadi Murmu, Uttar Pradesh CM Yogi Adityanath, and Maharashtra CM Eknath Shinde spend their youth?'
# Best METEOR Score: 0.2388
# Total METEOR Score (normalized): 0.1545
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Will the Enforcement Directorate register a fresh case in the Sushant Singh Rajput case?'
# Best METEOR Score: 0.0870
# Generated Question 2: What are the findings of the NCB that may lead to a fresh case in the Sushant Singh Rajput case?'
# Best METEOR Score: 0.1154
# Generated Question 3: Which aspects of the Sushant Singh Rajput case are likely to be investigated in the fresh case?'
# Best METEOR Score: 0.0847
# Total METEOR Score (normalized): 0.0841
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: How many Indian soldiers were released by China from their custody?
# Best METEOR Score: 0.1075
# Generated Question 2: What is the current status of the Galwan valley dispute?
# Best METEOR Score: 0.1261
# Generated Question 3: Did China release any Indian soldiers as a gesture of goodwill?
# Best METEOR Score: 0.1075
# Total METEOR Score (normalized): 0.1079
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Which state did the chief secretary testing positive for covid-19 belong to?'
# Best METEOR Score: 0.1230
# Generated Question 2: What was the test result of Maharashtra’s chief secretary?
# Best METEOR Score: 0.1250
# Generated Question 3: Did Maharashtra’s chief secretary test positive for covid-19?
# Best METEOR Score: 0.1087
# Total METEOR Score (normalized): 0.1072
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who was killed in Bengaluru according to the claim?'
# Best METEOR Score: 0.1364
# Generated Question 2: What did the man do in Kolkata according to the claim?
# Best METEOR Score: 0.1250
# Generated Question 3: Did the man kill himself according to the claim?
# Best METEOR Score: 0.1099
# Total METEOR Score (normalized): 0.1238
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Which girls of Kerala’s pancharatnam quintuplets got married on the same day?'
# Best METEOR Score: 0.0806
# Generated Question 2: What details does the report provide about the quintuplets' wedding?
# Best METEOR Score: 0.2500
# Generated Question 3: Did all five sisters of the pancharatnam quintuplets get married on the same day?
# Best METEOR Score: 0.1042
# Total METEOR Score (normalized): 0.1325
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who was responsible for setting the fighter jet on fire at the Mianwali air base?'
# Best METEOR Score: 0.0862
# Generated Question 2: What evidence exists to suggest that the fire at the Mianwali air base was caused by arson?
# Best METEOR Score: 0.1190
# Generated Question 3: Is there any indication that the fire at the Mianwali air base was the result of a deliberate attack?
# Best METEOR Score: 0.2652
# Total METEOR Score (normalized): 0.1451
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are COVID-19 tests conducted for free in other countries?'
# Best METEOR Score: 0.0909
# Generated Question 2: What are the charges for COVID-19 tests in India?'
# Best METEOR Score: 0.1261
# Generated Question 3: How do the costs of COVID-19 tests in India compare to those in other countries?'
# Best METEOR Score: 0.1020
# Total METEOR Score (normalized): 0.1063
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: What is the allowance increase that has been approved for MPs by the Union Cabinet?
# Best METEOR Score: 0.1210
# Generated Question 2: Can you summarize the recent decision made by the Union Cabinet regarding MPs' allowances?
# Best METEOR Score: 0.0806
# Generated Question 3: Has the Union Cabinet decided to decrease the allowances for MPs?
# Best METEOR Score: 0.0833
# Total METEOR Score (normalized): 0.0727
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Who is the Kerala health official accused of raping a woman?'
# Best METEOR Score: 0.0826
# Generated Question 2: What is the allegation against the Kerala health official?'
# Best METEOR Score: 0.1261
# Generated Question 3: Has the Kerala health official been arrested?'
# Best METEOR Score: 0.0855
# Total METEOR Score (normalized): 0.0754
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
#
# Average METEOR Score: 0.1557
