# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.18.0

# %%
# @title Default title text
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
# Initialize Groq API client
client = Groq(api_key="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")


import re

def convert_to_json(llm_response):
    responseQuestions = []
    questions_llm = re.findall(r'\{(.*?)\}', llm_response, re.DOTALL)

    for question in questions_llm:
        question_json = {}

        q = re.findall(r'[\"\']question[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip()
        else:
            continue

        a = re.findall(r'[\"\']answer[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if a:
            question_json['answer'] = a[0].strip()

        at = re.findall(r'[\"\']answerType[\"\']:\s*[\"\']?(.*?)[\"\']', question, re.DOTALL)
        if at:
            question_json['answerType'] = at[0].strip()

        responseQuestions.append(question_json)

    return responseQuestions



def get_response_llm(claim, questions):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions and answer pairs in a single list json. Do not leave question and answer pair empty"

  try:
      response = client.chat.completions.create(
          messages=[
              {
                  "role": "user",
                  "content": prompt,
              }
          ],
          model="llama3-70b-8192",
          max_tokens=4000,
      )
      response = response.choices[0].message.content.strip()
      response_json = convert_to_json(response)
      return response_json
  except Exception as e:
      print(f"Error processing claim '{claim}': {e}, {response}")
      print("-*"*50)
      return ""

# %%
new_data = []

for data in combined_claims[:5010]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    q['answer'] = answer['answer']
    q['answerType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
print(len([1 for n in new_data if n['generatedQuestions'] == []]))
new_data
# Out:
# 0
# [{'claim': 'UP muslim community gives rs 6 lakh for damages during anti-caa protests',
#   'generatedQuestions': [{'question': 'Did the UP Muslim community contribute funds for damages during anti-CAA protests?',
#     'answerType': 'Boolean'},
#    {'question': "What was the purpose of the UP Muslim community's financial contribution?",
#     'answer': 'The UP Muslim community contributed to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'What amount did the UP Muslim community contribute for damages during anti-CAA protests?',
#     'answer': 'Rs 6 lakh',
#     'answerType': 'Extractive'},
#    {'question': 'Did the UP Muslim community take financial responsibility for anti-CAA protest damages?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community contribute a significant amount for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much financial compensation did the UP Muslim community provide for anti-CAA protest damages?',
#     'answer': 'Rs 6 lakh',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'PM Modi was watching the live broadcast of the meeting between Imran Khan and Donald Trump.',
#   'generatedQuestions': [{'question': 'Was PM Modi watching the live broadcast of the meeting between Imran Khan and Donald Trump?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was PM Modi watching the live broadcast of the meeting between Imran Khan and Donald Trump?',
#     'answer': 'The reason behind PM Modi watching the live broadcast of the meeting between Imran Khan and Donald Trump is not specified.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was PM Modi doing during the meeting between Imran Khan and Donald Trump?',
#     'answer': 'PM Modi was watching the live broadcast of the meeting between Imran Khan and Donald Trump.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Punjab CM Bhagwant Mann spoke about an imaginary museum in the parliament during a speech.',
#   'generatedQuestions': [{'question': 'Did Punjab CM Bhagwant Mann speak about a non-existent museum in parliament?',
#     'answerType': 'Boolean'},
#    {'question': 'What did Punjab CM Bhagwant Mann talk about in his parliament speech that was inaccurate?',
#     'answer': 'Punjab CM Bhagwant Mann spoke about an imaginary museum in the parliament during a speech.',
#     'answerType': 'Abstractive'},
#    {'question': 'What false information did Punjab CM Bhagwant Mann share in his parliament speech?',
#     'answer': 'He spoke about an imaginary museum.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'This dilapidated structure with the roof missing is a government school in Gujarat.',
#   'generatedQuestions': [{'question': 'Is the dilapidated structure shown a government school in Gujarat?',
#     'answerType': 'Boolean'},
#    {'question': 'What kind of structure is shown in the image?',
#     'answer': 'The image shows a dilapidated government school in Gujarat.',
#     'answerType': 'Abstractive'},
#    {'question': 'Where is the dilapidated government school located?',
#     'answer': 'The dilapidated government school is located in Gujarat.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Shiv sena leader sanjay raut hospitalised for chest pain.',
#   'generatedQuestions': [{'question': 'Was Shiv Sena leader Sanjay Raut hospitalized due to chest pain?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was Shiv Sena leader Sanjay Raut hospitalized?',
#     'answer': 'Shiv Sena leader Sanjay Raut was hospitalized due to chest pain.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the reason behind Shiv Sena leader Sanjay Raut being hospitalized?',
#     'answer': 'Chest pain',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Demonstrating support for Israel, Azerbaijan illuminated the Flame Towers in its capital Baku with the Israeli flag.',
#   'generatedQuestions': [{'question': 'Did Azerbaijan illuminate the Flame Towers in its capital Baku with the Israeli flag?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Azerbaijan illuminate the Flame Towers with the Israeli flag?',
#     'answer': 'Azerbaijan illuminated the Flame Towers in its capital Baku with the Israeli flag as a demonstration of support for Israel.',
#     'answerType': 'Abstractive'},
#    {'question': "What was displayed on the Flame Towers in Azerbaijan\\'s capital Baku?",
#     'answer': 'The Israeli flag.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'devendra fadnavis resigns as maharashtra cm, terms maha vikas aghadi as desperation of power.',
#   'generatedQuestions': [{'question': 'Did Devendra Fadnavis resign as Maharashtra CM?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Devendra Fadnavis resign as Maharashtra CM?',
#     'answer': 'Devendra Fadnavis resigned as Maharashtra CM, terming the Maha Vikas Aghadi as desperation of power.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did Devendra Fadnavis call the Maha Vikas Aghadi while resigning as Maharashtra CM?',
#     'answer': 'Desperation of power',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': " FEMA violation case: punjab cm's son seeks adjournment from ed.",
#   'generatedQuestions': [{'question': "Did Punjab CM\\'s son seek adjournment from ED in a FEMA violation case?",
#     'answerType': 'Boolean'},
#    {'question': "Why did Punjab CM\\'s son seek adjournment from ED?",
#     'answer': "Punjab CM\\'s son sought adjournment from ED in a FEMA violation case.",
#     'answerType': 'Abstractive'},
#    {'question': "In which case did Punjab CM\\'s son seek adjournment from ED?",
#     'answer': "Punjab CM\\'s son sought adjournment from ED in a FEMA violation case.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Centre hails haryana's fast-paced implementation of jal jeevan mission.",
#   'generatedQuestions': [{'question': 'Did the Centre praise Haryana for its fast implementation of Jal Jeevan Mission?',
#     'answerType': 'Boolean'},
#    {'question': "What did the Centre do regarding Haryana's implementation of Jal Jeevan Mission?",
#     'answer': 'The Centre hailed Haryana for its fast-paced implementation of Jal Jeevan Mission.',
#     'answerType': 'Abstractive'},
#    {'question': 'What achievement of Haryana did the Centre acknowledge?',
#     'answer': "The Centre hailed Haryana\\'s fast-paced implementation of Jal Jeevan Mission.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Commandant of delhi itbp unit with high covid-19 cases posted out immediately.',
#   'generatedQuestions': [{'question': 'Was the Commandant of Delhi ITBP unit with high COVID-19 cases posted out?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was the Commandant of Delhi ITBP unit posted out?',
#     'answer': 'The Commandant of Delhi ITBP unit was posted out due to high COVID-19 cases in the unit.',
#     'answerType': 'Abstractive'},
#    {'question': 'What happened to the Commandant of Delhi ITBP unit with high COVID-19 cases?',
#     'answer': 'The Commandant was posted out immediately.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'India’s covid-19 cases approaches close to 64-lakh while death toll nears 1-lakh mark.',
#   'generatedQuestions': [{'question': 'Has India’s covid-19 cases approached close to 64-lakh?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the current status of covid-19 cases in India?',
#     'answer': 'India’s covid-19 cases approaches close to 64-lakh while death toll nears 1-lakh mark.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many covid-19 cases have been reported in India?',
#     'answer': 'India’s covid-19 cases approaches close to 64-lakh.',
#     'answerType': 'Extractive'},
#    {'question': 'What is the current death toll due to covid-19 in India?',
#     'answer': 'The death toll due to covid-19 in India nears 1-lakh mark.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A Tamil Nadu police constable was attacked by a Muslim mob for trying to stop three inebriated Muslim men from abusing women.',
#   'generatedQuestions': [{'question': 'Was a Tamil Nadu police constable attacked by a Muslim mob?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was a Tamil Nadu police constable attacked by a Muslim mob?',
#     'answer': 'A Tamil Nadu police constable was attacked by a Muslim mob for trying to stop three inebriated Muslim men from abusing women.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the police constable trying to do when he was attacked by a Muslim mob?',
#     'answer': 'The police constable was trying to stop three inebriated Muslim men from abusing women.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Former RBI governor Raghuram Rajan has been appointed as the governor of the Bank of England.',
#   'generatedQuestions': [{'question': 'Is Raghuram Rajan the new governor of the Bank of England?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was Raghuram Rajan appointed as the governor of the Bank of England?',
#     'answer': 'Raghuram Rajan has not been appointed as the governor of the Bank of England.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is the current governor of the Bank of England?',
#     'answer': 'The current governor of the Bank of England is not Raghuram Rajan.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Former IPS officer Kiran Bedi has been appointed as the governor of Jammu & Kashmir.',
#   'generatedQuestions': [{'question': 'Was Kiran Bedi appointed as the governor of Jammu & Kashmir?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Kiran Bedi become the governor of Jammu & Kashmir?',
#     'answer': 'Kiran Bedi did not become the governor of Jammu & Kashmir.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is the governor of Jammu & Kashmir appointed instead of Kiran Bedi?',
#     'answer': 'The claim does not specify who is the actual governor of Jammu & Kashmir.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Covid situation in delhi under control, rise in cases due to increase in number of tests',
#   'generatedQuestions': [{'question': 'Is the Covid situation in Delhi under control?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the rise in Covid cases in Delhi?',
#     'answer': 'The rise in Covid cases in Delhi is due to an increase in the number of tests.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the main factor contributing to the rise in Covid cases in Delhi?',
#     'answer': 'The increase in the number of tests.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Defence minister rajnath singh discusses bilateral ties, regional security with iranian counterpart.',
#   'generatedQuestions': [{'question': 'Did Defence Minister Rajnath Singh discuss bilateral ties with his Iranian counterpart?',
#     'answerType': 'Boolean'},
#    {'question': 'What did Defence Minister Rajnath Singh discuss with his Iranian counterpart?',
#     'answer': 'Defence Minister Rajnath Singh discussed bilateral ties and regional security with his Iranian counterpart.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who did Defence Minister Rajnath Singh discuss bilateral ties and regional security with?',
#     'answer': 'Defence Minister Rajnath Singh discussed bilateral ties and regional security with his Iranian counterpart.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'On November 20, Elon Musk tweeted that he will buy the social media platform Snapchat and then delete all its filters.',
#   'generatedQuestions': [{'question': 'Did Elon Musk tweet that he will buy Snapchat and delete its filters?',
#     'answerType': 'Boolean'},
#    {'question': 'What did Elon Musk reportedly tweet about Snapchat?',
#     'answer': 'Elon Musk did not tweet about buying Snapchat or deleting its filters.',
#     'answerType': 'Abstractive'},
#    {'question': "What was the content of Elon Musk\\'s tweet about Snapchat on November 20?",
#     'answer': 'There was no such tweet from Elon Musk on November 20.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'centre angry with me for denying use of delhi stadiums as jails for farmers, says kejriwal.',
#   'generatedQuestions': [{'question': 'Is Kejriwal angry with the centre?',
#     'answerType': 'Boolean'},
#    {'question': 'Why is the centre angry with Kejriwal?',
#     'answer': 'The centre is angry with Kejriwal for denying use of Delhi stadiums as jails for farmers.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did Kejriwal deny to the centre that made them angry?',
#     'answer': 'Kejriwal denied the use of Delhi stadiums as jails for farmers.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Sonia gandhi asks pm to extend free food grain scheme by three more months',
#   'generatedQuestions': [{'question': 'Did Sonia Gandhi ask the PM to extend the free food grain scheme?',
#     'answerType': 'Boolean'},
#    {'question': 'What did Sonia Gandhi request the PM to do?',
#     'answer': 'Sonia Gandhi asked the PM to extend the free food grain scheme by three more months.',
#     'answerType': 'Abstractive'},
#    {'question': 'How long did Sonia Gandhi ask the PM to extend the free food grain scheme?',
#     'answer': 'Sonia Gandhi asked the PM to extend the free food grain scheme by three more months.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Pm modi greets people on eid-ul-fitr.',
#   'generatedQuestions': [{'question': 'Did PM Modi greet people on Eid-ul-Fitr?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did PM Modi greet people on Eid-ul-Fitr?',
#     'answer': 'PM Modi greeted people on Eid-ul-Fitr as a gesture of goodwill and respect for the Muslim community.',
#     'answerType': 'Abstractive'},
#    {'question': 'On which occasion did PM Modi extend his greetings to the people?',
#     'answer': 'PM Modi extended his greetings to the people on Eid-ul-Fitr.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Delhi asks pm for 1,000 icu beds, says schools may be shut till there is vaccine.',
#   'generatedQuestions': [{'question': 'Did Delhi ask PM for 1,000 ICU beds?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Delhi ask PM for 1,000 ICU beds?',
#     'answer': 'Delhi asked PM for 1,000 ICU beds as a precautionary measure.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many ICU beds did Delhi ask PM for?',
#     'answer': 'Delhi asked PM for 1,000 ICU beds.',
#     'answerType': 'Extractive'},
#    {'question': 'Are schools in Delhi likely to be shut till there is a vaccine?',
#     'answerType': 'Boolean'},
#    {'question': 'Why may schools in Delhi be shut?',
#     'answer': 'Schools in Delhi may be shut till there is a vaccine as a safety measure.',
#     'answerType': 'Abstractive'},
#    {'question': 'Until when may schools in Delhi be shut?',
#     'answer': 'Schools in Delhi may be shut till there is a vaccine.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Vandalism has begun after the withdrawal of farm laws was announced.',
#   'generatedQuestions': [{'question': 'Did vandalism start after the announcement of the withdrawal of farm laws?',
#     'answerType': 'Boolean'},
#    {'question': 'What happened after the announcement of the withdrawal of farm laws?',
#     'answer': 'Vandalism started after the announcement of the withdrawal of farm laws.',
#     'answerType': 'Abstractive'},
#    {'question': 'When did vandalism begin?',
#     'answer': 'Vandalism began after the withdrawal of farm laws was announced.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'SC panel will continue work, whether farmers take up govt offer or not, says member.',
#   'generatedQuestions': [{'question': 'Will the SC panel continue its work if farmers reject the govt offer?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did the SC panel member say they will continue their work?',
#     'answer': 'The SC panel member said they will continue their work regardless of whether the farmers accept or reject the govt offer.',
#     'answerType': 'Abstractive'},
#    {'question': "What is the SC panel's stance on continuing their work amid the farmers protests?",
#     'answer': 'The SC panel will continue its work whether the farmers take up the govt offer or not.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Trump stopped his motorcade to take pictures with young black men who waved at him.',
#   'generatedQuestions': [{'question': 'Did Trump stop his motorcade to take pictures with young black men?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Trump stop his motorcade during the event?',
#     'answer': 'Trump stopped his motorcade to take pictures with young black men who waved at him.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did Trump do when young black men waved at him?',
#     'answer': 'Trump stopped his motorcade to take pictures with them.',
#     'answerType': 'Extractive'},
#    {'question': 'Who did Trump take pictures with during the motorcade stop?',
#     'answer': 'young black men',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Young couple lying on the road and kissing was taken during protests over George Floyd’s death in the US.',
#   'generatedQuestions': [{'question': 'Was the photo of a young couple lying on the road and kissing taken during protests over George Floyd’s death in the US?',
#     'answerType': 'Boolean'},
#    {'question': 'What was the context of the photo of a young couple lying on the road and kissing?',
#     'answer': 'The photo of a young couple lying on the road and kissing was not taken during protests over George Floyd’s death in the US.',
#     'answerType': 'Abstractive'},
#    {'question': 'Where was the photo of a young couple lying on the road and kissing actually taken?',
#     'answer': 'The information about the actual context of the photo is not specified in the claim.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Reliance Jio is offering a prize money of Rs. 999 on its seventh anniversary.',
#   'generatedQuestions': [{'question': 'Is Reliance Jio offering a prize money of Rs. 999 on its seventh anniversary?',
#     'answerType': 'Boolean'},
#    {'question': 'Why is Reliance Jio offering a prize money of Rs. 999 on its seventh anniversary?',
#     'answer': 'There is no such offer from Reliance Jio. The claim is false.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much prize money is Reliance Jio offering on its seventh anniversary?',
#     'answer': 'There is no such offer from Reliance Jio. The claim is false.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'gujarat hc gives clean chit to bjp mla in 2014 bypoll bribery case.',
#   'generatedQuestions': [{'question': 'Did the Gujarat HC give a clean chit to a BJP MLA in a 2014 bypoll bribery case?',
#     'answerType': 'Boolean'},
#    {'question': 'What was the outcome of the 2014 bypoll bribery case against a BJP MLA in Gujarat?',
#     'answer': 'The Gujarat High Court gave a clean chit to the BJP MLA.',
#     'answerType': 'Abstractive'},
#    {'question': 'In what year was a bribery case filed against a BJP MLA, which was later cleared by the Gujarat HC?',
#     'answer': '2014',
#     'answerType': 'Extractive'},
#    {'question': 'Which court gave a clean chit to a BJP MLA in a 2014 bypoll bribery case?',
#     'answer': 'Gujarat High Court',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Govt doctors from yavatmal protest 'ill treatment', present list of demands to district collector",
#   'generatedQuestions': [{'question': 'Did Govt doctors from Yavatmal protest ill treatment?',
#     'answerType': 'Boolean'},
#    {'question': 'What did Govt doctors from Yavatmal protest against?',
#     'answer': 'Govt doctors from Yavatmal protested against ill treatment.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did Govt doctors from Yavatmal present to the district collector?',
#     'answer': 'A list of demands',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Bjp's haryana sweep leaves legacy of the 3 formidable lals in tatters.",
#   'generatedQuestions': [{'question': 'Did the BJP win the Haryana election?',
#     'answerType': 'Boolean'},
#    {'question': "What impact did the BJP's Haryana win have on the legacy of the 3 formidable Lals?",
#     'answer': "The BJP\\'s Haryana sweep left the legacy of the 3 formidable Lals in tatters.",
#     'answerType': 'Abstractive'},
#    {'question': "What was the result of the BJP\\'s performance in the Haryana election?",
#     'answer': 'The BJP won the Haryana election, leaving the legacy of the 3 formidable Lals in tatters.',
#     'answerType': 'Extractive'},
#    {'question': "What is the status of the legacy of the 3 formidable Lals after the BJP\\'s Haryana win?",
#     'answer': 'The legacy of the 3 formidable Lals is in tatters.',
#     'answerType': 'Extractive'},
#    {'question': "How did the BJP\\'s Haryana win affect the Lals\\' legacy?",
#     'answer': 'It left their legacy in tatters.',
#     'answerType': 'Extractive'},
#    {'question': "What does the BJP\\'s Haryana win signify for the 3 formidable Lals?",
#     'answer': 'Their legacy is in tatters.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'US President Joe Biden touching her granddaughter in an inappropriate manner.',
#   'generatedQuestions': [{'question': 'Did US President Joe Biden touch his granddaughter in an inappropriate manner?',
#     'answerType': 'Boolean'},
#    {'question': 'Why is there an allegation against US President Joe Biden of touching his granddaughter in an inappropriate manner?',
#     'answer': 'There is no credible evidence to support the claim that US President Joe Biden touched his granddaughter in an inappropriate manner.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the controversy surrounding US President Joe Biden and his granddaughter?',
#     'answer': 'There is no controversy surrounding US President Joe Biden and his granddaughter related to inappropriate touching.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Bihar voters fatigued by nitish but he'll be helped by goodwill for modi, bjp assessment says.",
#   'generatedQuestions': [{'question': 'Will Nitish be helped by goodwill for Modi in the Bihar elections?',
#     'answerType': 'Boolean'},
#    {'question': "What is the BJP assessment of Nitish's chances in the Bihar elections?",
#     'answer': 'The BJP assessment says Nitish will be helped by goodwill for Modi.',
#     'answerType': 'Abstractive'},
#    {'question': "What is the reason behind BJP's optimism about Nitish in the Bihar elections?",
#     'answer': 'Goodwill for Modi.',
#     'answerType': 'Extractive'},
#    {'question': 'Is there voter fatigue with Nitish in Bihar?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the sentiment of Bihar voters towards Nitish according to BJP assessment?',
#     'answer': 'The Bihar voters are fatigued with Nitish.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the factor that will help Nitish despite voter fatigue in Bihar?',
#     'answer': 'Goodwill for Modi.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Special celebrations for elephants at hyderabad zoo including 82-year-old rani.',
#   'generatedQuestions': [{'question': 'Did the Hyderabad zoo have special celebrations for elephants including an 82-year-old elephant named Rani?',
#     'answerType': 'Boolean'},
#    {'question': 'What was special about the celebration at the Hyderabad zoo?',
#     'answer': 'The celebration at the Hyderabad zoo was special because it included an 82-year-old elephant named Rani.',
#     'answerType': 'Abstractive'},
#    {'question': 'How old was the elephant named Rani at the Hyderabad zoo celebration?',
#     'answer': 'The elephant named Rani was 82 years old at the Hyderabad zoo celebration.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Saudi colonel killed for khashoggi murder',
#   'generatedQuestions': [{'question': 'Was a Saudi colonel killed for the Khashoggi murder?',
#     'answerType': 'Boolean'},
#    {'question': 'Why was a Saudi colonel killed?',
#     'answer': 'A Saudi colonel was killed as punishment for the murder of Khashoggi.',
#     'answerType': 'Abstractive'},
#    {'question': "What was the punishment for the Saudi colonel involved in Khashoggi\\'s murder?",
#     'answer': 'The Saudi colonel was killed.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Captain Deepak Sathe, who died in the Air India Express plane crash in Kerala, singing an iconic Bollywood song.',
#   'generatedQuestions': [{'question': 'Did Captain Deepak Sathe sing an iconic Bollywood song?',
#     'answerType': 'Boolean'},
#    {'question': 'What was Captain Deepak Sathe doing before he died in the Air India Express plane crash in Kerala?',
#     'answer': 'Captain Deepak Sathe was singing an iconic Bollywood song.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was Captain Deepak Sathe known for doing before the Air India Express plane crash in Kerala?',
#     'answer': 'Singing an iconic Bollywood song',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Tablighi jamaat event caused coronavirus to spread to 'many persons': MHA.",
#   'generatedQuestions': [{'question': 'Did the Tablighi Jamaat event cause COVID-19 to spread to many people?',
#     'answerType': 'Boolean'},
#    {'question': 'What was the consequence of the Tablighi Jamaat event according to the MHA?',
#     'answer': 'The Tablighi Jamaat event caused coronavirus to spread to many persons.',
#     'answerType': 'Abstractive'},
#    {'question': 'According to the MHA, what was the impact of the Tablighi Jamaat event on the spread of coronavirus?',
#     'answer': 'The event caused the coronavirus to spread to many persons.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'a Muslim man in France pinning down two French men who tried to attack him. The clip is shared following the beheading of a teacher in Paris over the prophet cartoon.',
# ...
#     'answerType': 'Boolean'},
#    {'question': 'Why does Abhijit plan to convert a floor of his home?',
#     'answer': 'Abhijit plans to convert a floor of his home into a museum-cum-library in memory of Pranab Mukherjee.',
#     'answerType': 'Abstractive'},
#    {'question': "What is Abhijit's plan to honor Pranab Mukherjee's memory?",
#     'answer': "Abhijit will convert a floor of his home into a museum-cum-library in Pranab Mukherjee's memory.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'praising modi misreports irritate him, says shashi tharoor.',
#   'generatedQuestions': [{'question': 'Did Shashi Tharoor say that misreporting praises about Modi irritate him?',
#     'answerType': 'Boolean'},
#    {'question': 'What does Shashi Tharoor think about misreporting praises about Modi?',
#     'answer': 'Shashi Tharoor thinks that misreporting praises about Modi irritate him.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did Shashi Tharoor say happens when praises about Modi are misreported?',
#     'answer': 'Shashi Tharoor said that misreported praises about Modi irritate him.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A man celebrating T raja singh’s victory in the recent telangana assembly elections.',
#   'generatedQuestions': [{'question': "Was a man celebrating T Raja Singh's victory in the recent Telangana assembly elections?",
#     'answerType': 'Boolean'},
#    {'question': 'What was the man doing during the recent Telangana assembly elections?',
#     'answer': "The man was celebrating T Raja Singh\\'s victory.",
#     'answerType': 'Abstractive'},
#    {'question': 'Whose victory was the man celebrating in the recent Telangana assembly elections?',
#     'answer': "T Raja Singh\\'s",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Session of rancour ends prematurely, battle over farm bills set to continue.',
#   'generatedQuestions': [{'question': 'Did the session of parliament end prematurely?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did the battle over farm bills continue after the parliamentary session ended?',
#     'answer': 'The battle over farm bills continued after the parliamentary session ended prematurely due to rancour.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the current status of the battle over farm bills after the parliamentary session?',
#     'answer': 'The battle over farm bills is set to continue after the parliamentary session ended prematurely.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Taliban has refused to sponsor the Afghan cricket team for the T20 World Cup. Captain Mohammad Nabi is bearing the team's entire expenses.",
#   'generatedQuestions': [{'question': 'Has the Taliban refused to sponsor the Afghan cricket team for the T20 World Cup?',
#     'answerType': 'Boolean'},
#    {'question': "Why is Captain Mohammad Nabi bearing the team\\'s entire expenses?",
#     'answer': 'Because the Taliban has refused to sponsor the Afghan cricket team for the T20 World Cup.',
#     'answerType': 'Abstractive'},
#    {'question': "Who is bearing the Afghan cricket team\\'s entire expenses for the T20 World Cup?",
#     'answer': 'Captain Mohammad Nabi',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Amid border row with china, india says australia will join malabar exercise.',
#   'generatedQuestions': [{'question': 'Will Australia join the Malabar exercise with India amid the border row with China?',
#     'answerType': 'Boolean'},
#    {'question': 'What significant development has occurred in the context of the border row between India and China?',
#     'answer': 'Australia has agreed to join the Malabar exercise with India.',
#     'answerType': 'Abstractive'},
#    {'question': 'Which country is set to participate in the Malabar exercise with India amid the border tensions with China?',
#     'answer': 'Australia',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'campaign ends for the first phase of bihar assembly election.',
#   'generatedQuestions': [{'question': 'Did the campaign end for the first phase of Bihar assembly election?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the current status of the campaign for the first phase of Bihar assembly election?',
#     'answer': 'The campaign for the first phase of Bihar assembly election has ended.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the update on the campaign for the Bihar assembly election?',
#     'answer': 'The campaign has ended for the first phase.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': "SC rejects activist rehana's anticipatory bail plea",
#   'generatedQuestions': [{'question': "Did the SC reject activist Rehana's anticipatory bail plea?",
#     'answerType': 'Boolean'},
#    {'question': "What happened to activist Rehana's anticipatory bail plea in the SC?",
#     'answer': "The SC rejected activist Rehana\\'s anticipatory bail plea.",
#     'answerType': 'Abstractive'},
#    {'question': "What was the SC\\'s decision on activist Rehana\\'s anticipatory bail plea?",
#     'answer': 'The SC rejected it.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'C-grade actor Poonam Pandey, who has often insulted Hindu gods, is now in hospital after marrying Shamshad Ali alias Sam Bombay to prove her secularism.',
#   'generatedQuestions': [{'question': 'Did Poonam Pandey marry Shamshad Ali alias Sam Bombay to prove her secularism?',
#     'answerType': 'Boolean'},
#    {'question': 'Why did Poonam Pandey marry Shamshad Ali alias Sam Bombay?',
#     'answer': 'Poonam Pandey married Shamshad Ali alias Sam Bombay to prove her secularism.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who did Poonam Pandey marry to prove her secularism?',
#     'answer': 'Shamshad Ali alias Sam Bombay',
#     'answerType': 'Extractive'},
#    {'question': "What is Poonam Pandey's husband's alias?",
#     'answer': 'Sam Bombay',
#     'answerType': 'Extractive'},
#    {'question': 'Is Poonam Pandey a C-grade actor?', 'answerType': 'Boolean'},
#    {'question': 'What is the reason behind Poonam Pandey being in hospital?',
#     'answer': 'Marriage to Shamshad Ali alias Sam Bombay to prove her secularism.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Ctet december 2019 online registration to begin today at ctet.nic.in, examination on december 8.',
#   'generatedQuestions': [{'question': 'Will the CTET December 2019 online registration begin on the given date?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the purpose of the online registration starting today at ctet.nic.in?',
#     'answer': 'The purpose is to register for the CTET December 2019 examination.',
#     'answerType': 'Abstractive'},
#    {'question': 'When is the CTET December 2019 examination scheduled to take place?',
#     'answer': 'The examination is scheduled to take place on December 8.',
#     'answerType': 'Extractive'},
#    {'question': 'What is the website where the CTET December 2019 online registration will begin?',
#     'answer': 'The website is ctet.nic.in.',
#     'answerType': 'Extractive'},
#    {'question': 'Will the online registration for CTET December 2019 examination start today?',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Ease of doing business in up better, law and order behind the leap, say police.',
#   'generatedQuestions': [{'question': 'Is law and order a factor behind improved ease of doing business in UP?',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the improvement in ease of doing business in UP, according to the police?',
#     'answer': 'The police attribute the improvement in ease of doing business in UP to better law and order.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who credits improved law and order for the ease of doing business in UP?',
#     'answer': 'The police',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Aiadmk puts up show of strength at jaya’s memorial',
#   'generatedQuestions': [{'question': "Did the AIADMK party hold a show of strength at Jaya's memorial?",
#     'answerType': 'Boolean'},
#    {'question': "Why did the AIADMK party organize a show of strength at Jaya's memorial?",
#     'answer': "The AIADMK party organized a show of strength at Jaya's memorial to demonstrate their power.",
#     'answerType': 'Abstractive'},
#    {'question': 'Where did the AIADMK party hold a show of strength?',
#     'answer': "The AIADMK party held a show of strength at Jaya's memorial.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did the UP Muslim community contribute Rs 6 lakh for damages during the anti-CAA protests?',
#     'answer': True,
#     'answerType': 'Boolean'},
#    {'question': 'Why did the UP Muslim community give Rs 6 lakh for damages?',
#     'answer': 'The UP Muslim community contributed Rs 6 lakh to compensate for the damages incurred during the anti-CAA protests.',
#     'answerType': 'Abstractive'},
#    {'question': 'How much did the UP Muslim community contribute for damages during the anti-CAA protests?',
#     'answer': 'The UP Muslim community contributed over Rs 6 lakh.',
#     'answerType': 'Extractive'}]},
#  ...]

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences
    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))

for data in new_data:
  generated_sequences = [question['question']+'\n'+question.get('answer', "") for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question']+'\n'+str(question['answer']) for question in data['goldQuestions']] # Convert answer to string here
  if not generated_sequences or not reference_sequences:
    continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------
# Generated Question 1: Did Punjab farm outfits decide to end dharnas outside dealer-run petrol pumps?
#
# Best METEOR Score: 0.0602
# Generated Question 2: Why did Punjab farm outfits decide to end dharnas outside dealer-run petrol pumps?
# Punjab farm outfits decided to end dharnas outside dealer-run petrol pumps as part of their protests.
# Best METEOR Score: 0.1602
# Generated Question 3: How many railway platforms were vacated as a result of Punjab farm outfits ending their protests?
# 29 railway platforms were vacated.
# Best METEOR Score: 0.1273
# Generated Question 4: What was the location of the dharnas that Punjab farm outfits decided to end?
# The dharnas that Punjab farm outfits decided to end were outside dealer-run petrol pumps.
# Best METEOR Score: 0.1459
# Total METEOR Score (normalized): 0.1375
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has NEET UG 2020 been postponed again?
#
# Best METEOR Score: 0.0311
# Generated Question 2: Why has the date of NEET UG 2020 been changed?
# The date of NEET UG 2020 has been changed to August.
# Best METEOR Score: 0.1273
# Generated Question 3: When is NEET UG 2020 scheduled to take place?
# NEET UG 2020 is scheduled to take place in August.
# Best METEOR Score: 0.0485
# Total METEOR Score (normalized): 0.0690
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the WHO classify the COVID-19 vaccine provided by Russia to Pakistan as part of Phase III trials?
#
# Best METEOR Score: 0.1835
# Generated Question 2: What was the purpose of the 1 million doses of COVID-19 vaccine provided by Russia to Pakistan?
# The 1 million doses of COVID-19 vaccine provided by Russia to Pakistan were part of Phase III trials, as classified by the WHO.
# Best METEOR Score: 0.1057
# Generated Question 3: How many doses of COVID-19 vaccine did Russia provide to Pakistan?
# Russia provided 1 million doses of the COVID-19 vaccine to Pakistan.
# Best METEOR Score: 0.1004
# Total METEOR Score (normalized): 0.1299
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a rally with green flags and loud music pass by a temple in Khargone, MP on Ram Navami?
#
# Best METEOR Score: 0.0575
# Generated Question 2: Why was a rally allowed to pass by a temple in Khargone, MP on Ram Navami with green flags and loud music?
# A rally bearing green flags and playing loud music was allowed to pass by a temple in Khargone, MP on the same day and at the same place where communal violence broke out on Ram Navami.
# Best METEOR Score: 0.1143
# Generated Question 3: What was notable about the rally that passed by a temple in Khargone, MP on Ram Navami?
# The rally was notable for bearing green flags and playing loud music while passing by a temple in Khargone, MP on Ram Navami.
# Best METEOR Score: 0.1383
# Generated Question 4: Where did a rally with green flags and loud music pass by a temple on Ram Navami?
# The rally passed by a temple in Khargone, MP on Ram Navami.
# Best METEOR Score: 0.1228
# Total METEOR Score (normalized): 0.1129
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was Environment minister Gopal Rai discharged from hospital?
#
# Best METEOR Score: 0.0309
# Generated Question 2: What happened to Environment minister Gopal Rai recently?
# Environment minister Gopal Rai was discharged from hospital.
# Best METEOR Score: 0.0490
# Generated Question 3: What is the current status of Environment minister Gopal Rai with respect to hospitalization?
# He was discharged from hospital.
# Best METEOR Score: 0.0647
# Total METEOR Score (normalized): 0.0470
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are 41 teams prepositioned for Orissa and West Bengal for Amphan NDRF?
#
# Best METEOR Score: 0.0602
# Generated Question 2: Why are 41 teams prepositioned for Orissa and West Bengal?
# The 41 teams are prepositioned for Orissa and West Bengal as they are likely to be hit by Amphan NDRF.
# Best METEOR Score: 0.1228
# Generated Question 3: How many teams are prepositioned for Orissa and West Bengal for Amphan NDRF?
# 41 teams are prepositioned for Orissa and West Bengal for Amphan NDRF.
# Best METEOR Score: 0.0794
# Total METEOR Score (normalized): 0.0830
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Have the results of the dusu polls been announced?
#
# Best METEOR Score: 0.0920
# Generated Question 2: What is the current status of the dusu polls?
# The counting of votes has begun, with results expected by afternoon.
# Best METEOR Score: 0.1500
# Generated Question 3: When are the results of the dusu polls expected to be announced?
# The results are expected to be announced by afternoon.
# Best METEOR Score: 0.1500
# Total METEOR Score (normalized): 0.1128
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did L.K. Advani call Sushma Swaraj a role model for women politicians?
#
# Best METEOR Score: 0.0898
# Generated Question 2: Why did L.K. Advani remember Sushma Swaraj as a role model for women politicians?
# L.K. Advani remembered Sushma Swaraj as a role model for women politicians because of her remarkable work and achievements.
# Best METEOR Score: 0.1312
# Generated Question 3: Who did L.K. Advani remember as a role model for women politicians?
# L.K. Advani remembered Sushma Swaraj as a role model for women politicians.
# Best METEOR Score: 0.0829
# Total METEOR Score (normalized): 0.1000
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was Ilhan Omar at an Al-Qaeda training camp in Somalia?
#
# Best METEOR Score: 0.0305
# Generated Question 2: What is the evidence that Ilhan Omar attended an Al-Qaeda training camp?
# There is no credible evidence to suggest that Ilhan Omar attended an Al-Qaeda training camp.
# Best METEOR Score: 0.0631
# Generated Question 3: Where did Ilhan Omar grow up?
# Ilhan Omar grew up in a refugee camp in Kenya, not in Somalia.
# Best METEOR Score: 0.1012
# Generated Question 4: Is there any truth to the claim that Ilhan Omar was at an Al-Qaeda training camp?
# No, there is no truth to this claim.
# Best METEOR Score: 0.0635
# Generated Question 5: What is the origin of the rumor about Ilhan Omar and the Al-Qaeda training camp?
# The origin of the rumor is unclear, but it has been widely debunked as false.
# Best METEOR Score: 0.0969
# Total METEOR Score (normalized): 0.0834
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a former Pakistani diplomat admit on TV that over 300 terrorists were killed in the Balakot airstrike and Pakistan's response was weak?
#
# Best METEOR Score: 0.0843
# Generated Question 2: What did a former Pakistani diplomat admit on TV about the Balakot airstrike?
# A former Pakistani diplomat, Zafar, admitted on TV that over 300 terrorists were killed in the Balakot airstrike and Pakistan's response was weak.
# Best METEOR Score: 0.1128
# Generated Question 3: How many terrorists did a former Pakistani diplomat admit were killed in the Balakot airstrike on TV?
# Over 300 terrorists.
# Best METEOR Score: 0.1215
# Total METEOR Score (normalized): 0.0939
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Does the Congress party now oppose NOTA in RS elections after 20 different elections?
#
# Best METEOR Score: 0.0893
# Generated Question 2: Why does the Congress party oppose NOTA in RS elections?
# The Congress party opposes NOTA in RS elections because it has lost 20 different elections.
# Best METEOR Score: 0.1476
# Generated Question 3: How many elections did the Congress party lose before opposing NOTA in RS elections?
# The Congress party lost 20 different elections before opposing NOTA in RS elections.
# Best METEOR Score: 0.2044
# Total METEOR Score (normalized): 0.1338
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Has the novel coronavirus been detected in broiler chickens?
#
# Best METEOR Score: 0.0613
# Generated Question 2: What is the significance of detecting the novel coronavirus in broiler chickens?
# The detection of the novel coronavirus in broiler chickens raises concerns about the potential for transmission to humans or other animals.
# Best METEOR Score: 0.1647
# Generated Question 3: In which type of chickens has the novel coronavirus been detected?
# The novel coronavirus has been detected in broiler chickens.
# Best METEOR Score: 0.1278
# Total METEOR Score (normalized): 0.1179
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did PM Modi highlight India's low COVID-19 deaths?
#
# Best METEOR Score: 0.0613
# Generated Question 2: What did PM Modi emphasize about India's COVID-19 situation?
# PM Modi underlined India\'s low COVID-19 deaths.
# Best METEOR Score: 0.0612
# Generated Question 3: What aspect of India's COVID-19 situation did PM Modi draw attention to?
# India's low COVID-19 deaths.
# Best METEOR Score: 0.0649
# Generated Question 4: What did PM Modi suggest was necessary for the current COVID-19 situation?
# a fresh mindset
# Best METEOR Score: 0.1183
# Total METEOR Score (normalized): 0.0815
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was Gurudas Kamat a Congress MP?
#
# Best METEOR Score: 0.0312
# Generated Question 2: What kind of personality did Gurudas Kamat have?
# Gurudas Kamat was impulsive.
# Best METEOR Score: 0.0662
# Generated Question 3: How many times was Gurudas Kamat elected as a Congress MP?
# Gurudas Kamat was elected as a Congress MP five times.
# Best METEOR Score: 0.0605
# Total METEOR Score (normalized): 0.0527
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Pope Francis cancel the Bible?
#
# Best METEOR Score: 0.0938
# Generated Question 2: What is the truth behind Pope Francis canceling the Bible and creating a new book?
# There is no truth to this claim. Pope Francis did not cancel the Bible and propose to create a new book.
# Best METEOR Score: 0.1136
# Generated Question 3: What action did Pope Francis take regarding the Bible?
# Pope Francis did not cancel the Bible or propose to create a new book. This claim is false.
# Best METEOR Score: 0.1093
# Total METEOR Score (normalized): 0.1006
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Were individuals booked for offering namaz in a UP temple?
#
# Best METEOR Score: 0.0915
# Generated Question 2: What happened to those who offered namaz in a UP temple?
# Four individuals were booked for offering namaz in a UP temple.
# Best METEOR Score: 0.1004
# Generated Question 3: How many individuals were booked for offering namaz in a UP temple?
# Four individuals were booked.
# Best METEOR Score: 0.1029
# Total METEOR Score (normalized): 0.0968
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Centre send a countrywide advisory for Bharat Bandh?
#
# Best METEOR Score: 0.1220
# Generated Question 2: What was the purpose of the advisory sent by the Centre for Bharat Bandh?
# The advisory was sent to ask states to tighten security and ensure peace.
# Best METEOR Score: 0.1679
# Generated Question 3: What did the Centre ask states to do in preparation for Bharat Bandh?
# The Centre asked states to tighten security and ensure peace.
# Best METEOR Score: 0.2090
# Total METEOR Score (normalized): 0.1479
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was a terrorist caught by the police at Hubli bus stand in Karnataka?
#
# Best METEOR Score: 0.0599
# Generated Question 2: What happened at the Hubli bus stand in Karnataka?
# A terrorist was nabbed by the police at Hubli bus stand in Karnataka and the entire action was caught on camera.
# Best METEOR Score: 0.0973
# Generated Question 3: Where was the terrorist caught by the police?
# The terrorist was caught at the Hubli bus stand in Karnataka.
# Best METEOR Score: 0.1016
# Total METEOR Score (normalized): 0.0847
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Pakistan recently open its border for Afghan refugees fleeing the Taliban?
#
# Best METEOR Score: 0.1205
# Generated Question 2: Why did Pakistan open its border for Afghan refugees?
# Pakistan opened its border for Afghan refugees fleeing the Taliban.
# Best METEOR Score: 0.1722
# Generated Question 3: What is the current situation of Afghan refugees in relation to Pakistan?
# Thousands of Afghans are rushing to Pakistan.
# Best METEOR Score: 0.0647
# Generated Question 4: What is the reason for Afghan refugees fleeing to Pakistan?
# The refugees are fleeing the Taliban.
# Best METEOR Score: 0.1235
# Total METEOR Score (normalized): 0.1387
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it true that Pragyan's wheel left an imprint of India’s national emblem and ISRO’s logo on the lunar surface?
#
# Best METEOR Score: 0.0838
# Generated Question 2: What did Pragyan's wheel leave on the lunar surface?
# An imprint of India’s national emblem and ISRO’s logo.
# Best METEOR Score: 0.0843
# Generated Question 3: What mark did Pragyan's wheel leave on the lunar surface?
# An imprint of India’s national emblem and ISRO’s logo.
# Best METEOR Score: 0.0838
# Total METEOR Score (normalized): 0.0758
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Will Suvendu Adhikari join BJP according to Mukul Roy?
#
# Best METEOR Score: 0.0336
# Generated Question 2: What does Mukul Roy predict about Suvendu Adhikari?
# Mukul Roy expects Suvendu Adhikari to join BJP.
# Best METEOR Score: 0.0490
# Generated Question 3: How soon does Mukul Roy expect a final decision from Suvendu Adhikari?
# A final decision is expected in a day or two.
# Best METEOR Score: 0.0602
# Total METEOR Score (normalized): 0.0466
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Nagpur civic chief test positive for COVID-19?
#
# Best METEOR Score: 0.1227
# Generated Question 2: What was the outcome of the COVID-19 test for the Nagpur civic chief?
# The Nagpur civic chief tested positive for COVID-19.
# Best METEOR Score: 0.1719
# Generated Question 3: What milestone did the Nagpur district COVID-19 toll cross?
# The Nagpur district COVID-19 toll crossed 800.
# Best METEOR Score: 0.1846
# Total METEOR Score (normalized): 0.1412
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did the BJP win 30 seats by a margin of less than 500 votes?
#
# Best METEOR Score: 0.0893
# Generated Question 2: Why does the investigation of the 130 seats matter?
# The investigation of the 130 seats matters because it could reveal potential manipulation in the results.
# Best METEOR Score: 0.1523
# Generated Question 3: How many seats did the BJP win by a margin of less than 1,000 votes?
# The BJP won more than 100 seats by a margin of less than 1,000 votes.
# Best METEOR Score: 0.1706
# Generated Question 4: What is the total number of seats that should be investigated for manipulation?
# The results of 130 seats should be investigated for manipulation.
# Best METEOR Score: 0.1488
# Generated Question 5: Did the BJP win more than 100 seats by a margin of less than 1,000 votes?
#
# Best METEOR Score: 0.0882
# Total METEOR Score (normalized): 0.1572
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did hundreds of students test positive for coronavirus after AP schools reopened?
#
# Best METEOR Score: 0.0904
# Generated Question 2: What happened to students after AP schools reopened?
# Hundreds of students tested positive for coronavirus after AP schools reopened.
# Best METEOR Score: 0.0647
# Generated Question 3: How many students tested positive for coronavirus after AP schools reopened in AP?
# Hundreds of students tested positive.
# Best METEOR Score: 0.0816
# Total METEOR Score (normalized): 0.0789
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Delhi police halt an ambulance to let the convoy of BJP MP Manoj Tiwari pass?
#
# Best METEOR Score: 0.1846
# Generated Question 2: What was the consequence of the Delhi police halting an ambulance to let the convoy of BJP MP Manoj Tiwari pass?
# As a result of which a little girl died.
# Best METEOR Score: 0.1094
# Generated Question 3: What happened to the little girl after the Delhi police halted the ambulance to let the convoy of BJP MP Manoj Tiwari pass?
# The little girl died.
# Best METEOR Score: 0.1465
# Total METEOR Score (normalized): 0.1468
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the SCBA president recuse himself from the EC meet?
#
# Best METEOR Score: 0.1925
# Generated Question 2: Why did the SCBA president recuse himself from the EC meet?
# The SCBA president recused himself from the EC meet because of a resolution condemning the AP CM\'s letter to the CJI.
# Best METEOR Score: 0.1808
# Generated Question 3: What was the reason for the SCBA president recusing himself from the EC meet?
# The SCBA president recused himself from the EC meet due to a resolution condemning the AP CM\'s letter to the CJI.
# Best METEOR Score: 0.1227
# Total METEOR Score (normalized): 0.1624
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it true that penguin urine makes up nearly three per cent of Antarctic glaciers ice?
#
# Best METEOR Score: 0.0882
# Generated Question 2: What percentage of Antarctic glaciers ice is made up of penguin urine?
# There is no evidence to suggest that penguin urine makes up a significant percentage of Antarctic glaciers ice.
# Best METEOR Score: 0.0938
# Generated Question 3: How much of Antarctic glaciers ice is composed of penguin urine?
# There is no credible source suggesting penguin urine is a significant component of Antarctic glaciers ice.
# Best METEOR Score: 0.1243
# Total METEOR Score (normalized): 0.1021
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a man swept away by a river in Andhra Pradesh while trying to get coconuts from a tree?
#
# Best METEOR Score: 0.0487
# Generated Question 2: What happened to the man who tried to get coconuts from a tree in Andhra Pradesh?
# The man was swept away by the river as the ground gave way and the coconut tree with the man was lost in the waters.
# Best METEOR Score: 0.1360
# Generated Question 3: How did the man trying to get coconuts from a tree in Andhra Pradesh get swept away?
# The ground gave away and the coconut tree with the man was lost in the waters.
# Best METEOR Score: 0.1548
# Total METEOR Score (normalized): 0.0998
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is there a contradiction in lockdown updates between Aajtak and India Today news channels?
#
# Best METEOR Score: 0.0298
# Generated Question 2: Why do Aajtak and India Today news channels show different lockdown updates?
# Aajtak news channel shows lockdown is withdrawn at a few places while India Today news channel shows it is extended till May 4.
# Best METEOR Score: 0.0462
# Generated Question 3: What are the conflicting lockdown updates shown by Aajtak and India Today news channels?
# Aajtak shows lockdown is withdrawn at a few places, while India Today shows it is extended till May 4.
# Best METEOR Score: 0.0575
# Total METEOR Score (normalized): 0.0445
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a tsunami hit Turkey after the devastating February 6 earthquake?
#
# Best METEOR Score: 0.1212
# Generated Question 2: What happened in Turkey after the devastating February 6 earthquake?
# There was no tsunami in Turkey after the devastating February 6 earthquake.
# Best METEOR Score: 0.1130
# Generated Question 3: What natural disaster hit Turkey after the February 6 earthquake?
# No tsunami hit Turkey after the February 6 earthquake.
# Best METEOR Score: 0.1149
# Total METEOR Score (normalized): 0.1063
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the NIA arrest a key operative of the Handwara narcoterror module?
#
# Best METEOR Score: 0.1901
# Generated Question 2: What did the NIA do to the key operative of the Handwara narcoterror module?
# The NIA arrested the key operative of the Handwara narcoterror module.
# Best METEOR Score: 0.1689
# Generated Question 3: What action was taken by the NIA against the key operative of the Handwara narcoterror module?
# The NIA arrested the key operative.
# Best METEOR Score: 0.1004
# Total METEOR Score (normalized): 0.1531
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Amit Shah begin his political journey in an abandoned school in Ahmedabad?
#
# Best METEOR Score: 0.0599
# Generated Question 2: Where did Amit Shah start his political career?
# Amit Shah started his political career at an abandoned school in Ahmedabad.
# Best METEOR Score: 0.0607
# Generated Question 3: In what location did Amit Shah begin his political journey?
# An abandoned school in Ahmedabad
# Best METEOR Score: 0.0592
# Total METEOR Score (normalized): 0.0512
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the Supreme Court ask the Centre to clarify doubts on the Citizenship Amendment Act?
#
# Best METEOR Score: 0.1544
# Generated Question 2: What did the Supreme Court ask the Centre to do regarding the Citizenship Amendment Act?
# The Supreme Court asked the Centre to root out doubts on the Citizenship Amendment Act.
# Best METEOR Score: 0.1663
# Generated Question 3: What action did the Supreme Court instruct the Centre to take on the Citizenship Amendment Act?
# The Centre was asked to root out doubts on the Act.
# Best METEOR Score: 0.1262
# Generated Question 4: Who asked the Centre to address doubts on the Citizenship Amendment Act?
# The Supreme Court asked the Centre to address doubts on the Act.
# Best METEOR Score: 0.1527
# Generated Question 5: What does the Supreme Court want the Centre to do about doubts surrounding the Citizenship Amendment Act?
# The Supreme Court wants the Centre to root out doubts on the Act.
# Best METEOR Score: 0.1499
# Total METEOR Score (normalized): 0.1435
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Are electoral bonds 10 times the contributions received by electoral trusts?
#
# Best METEOR Score: 0.0909
# Generated Question 2: Why are electoral bonds 10 times the contributions received by electoral trusts?
# Electoral bonds have exceeded electoral trusts in contributions by a factor of 10, indicating a significant shift in political donations.
# Best METEOR Score: 0.0962
# Generated Question 3: How many times more are electoral bonds compared to electoral trusts?
# Electoral bonds are 10 times the contributions received by electoral trusts.
# Best METEOR Score: 0.1004
# Total METEOR Score (normalized): 0.0947
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Owaisi take up Amit Shah's challenge on CAA?
#
# Best METEOR Score: 0.0915
# Generated Question 2: Why did Owaisi take up Amit Shah's challenge on CAA?
# Owaisi took up Amit Shah's challenge on CAA as a response to the debate challenge.
# Best METEOR Score: 0.1678
# Generated Question 3: Who took up Amit Shah's challenge on CAA?
# Owaisi took up Amit Shah's challenge on CAA.
# Best METEOR Score: 0.0816
# Generated Question 4: What was the challenge that Owaisi took up from Amit Shah?
# The challenge was on CAA.
# Best METEOR Score: 0.1531
# Generated Question 5: Did Amit Shah challenge Owaisi on CAA?
#
# Best METEOR Score: 0.0621
# Generated Question 6: Who challenged Owaisi on CAA?
# Amit Shah challenged Owaisi on CAA.
# Best METEOR Score: 0.0420
# Total METEOR Score (normalized): 0.1375
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did an 86-year-old Muslim man sexually assault a 7-year-old girl in an agricultural field?
#
# Best METEOR Score: 0.0893
# Generated Question 2: What is the nature of the allegation against the 86-year-old Muslim man?
# The 86-year-old Muslim man allegedly sexually assaulted a 7-year-old girl in an agricultural field.
# Best METEOR Score: 0.1896
# Generated Question 3: How old was the girl who was allegedly sexually assaulted by the 86-year-old Muslim man?
# The girl was 7 years old.
# Best METEOR Score: 0.1934
# Generated Question 4: Where did the alleged sexual assault of the 7-year-old girl by the 86-year-old Muslim man occur?
# The alleged sexual assault occurred in an agricultural field.
# Best METEOR Score: 0.1903
# Generated Question 5: How old was the Muslim man who allegedly sexually assaulted a girl in an agricultural field?
# The Muslim man was 86 years old.
# Best METEOR Score: 0.1918
# Total METEOR Score (normalized): 0.1582
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did the Congress spokesperson praise Narendra Modi as a hero in a TV debate?
#
# Best METEOR Score: 0.0893
# Generated Question 2: What did the Congress spokesperson say about Narendra Modi in a TV debate?
# The Congress spokesperson praised Narendra Modi as a hero and acknowledged that it is very difficult for Rahul Gandhi to compete with him.
# Best METEOR Score: 0.1948
# Generated Question 3: What compliment did the Congress spokesperson give to Narendra Modi in a TV debate?
# The Congress spokesperson called Narendra Modi a hero.
# Best METEOR Score: 0.1783
# Total METEOR Score (normalized): 0.1312
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a school teacher in WB host a blood donation camp and distribute books on their wedding eve?
#
# Best METEOR Score: 0.0581
# Generated Question 2: Why did the school teacher in WB organize a blood donation camp on their wedding eve?
# The school teacher in WB hosted a blood donation camp and distributed books on their wedding eve as a unique way to celebrate their special day.
# Best METEOR Score: 0.1602
# Generated Question 3: What did the school teacher in WB do on their wedding eve?
# The school teacher in WB hosted a blood donation camp and distributed books.
# Best METEOR Score: 0.1753
# Total METEOR Score (normalized): 0.1203
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was there a total blackout in Kerala on August 5 to prevent people from watching the Ram Janmabhoomi Pujan?
#
# Best METEOR Score: 0.0578
# Generated Question 2: Why was there a blackout in Kerala on August 5?
# There was no total blackout in Kerala on August 5 to prevent people from watching the Ram Janmabhoomi Pujan. This claim is false.
# Best METEOR Score: 0.0772
# Generated Question 3: What was the reason behind the blackout in Kerala on August 5?
# There was no blackout in Kerala on August 5.
# Best METEOR Score: 0.0852
# Total METEOR Score (normalized): 0.0719
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Modi government still searching for a solution to the farm protests?
#
# Best METEOR Score: 0.2228
# Generated Question 2: Why is the Modi government back in a huddle?
# The Modi government is back in a huddle to find a middle path to resolve the farm protests.
# Best METEOR Score: 0.1842
# Generated Question 3: What is the Modi government trying to find for the farm protests?
# The Modi government is trying to find a middle path to resolve the farm protests.
# Best METEOR Score: 0.2005
# Generated Question 4: What is the current status of the Modi government in regards to the farm protests?
# The Modi government is still searching for a solution to the farm protests.
# Best METEOR Score: 0.1836
# Total METEOR Score (normalized): 0.1868
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a congress leader make controversial pro-militancy remarks ahead of the upcoming assembly elections in Jammu and Kashmir?
#
# Best METEOR Score: 0.0872
# Generated Question 2: What was the context in which the congress leader made controversial remarks?
# The congress leader made controversial pro-militancy remarks ahead of the upcoming assembly elections in Jammu and Kashmir.
# Best METEOR Score: 0.1097
# Generated Question 3: What type of remarks did the congress leader make ahead of the upcoming assembly elections in Jammu and Kashmir?
# The congress leader made pro-militancy remarks.
# Best METEOR Score: 0.2028
# Total METEOR Score (normalized): 0.1332
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a 12-year-old Swedish boy beaten up by a Muslim immigrant?
#
# Best METEOR Score: 0.0909
# Generated Question 2: What was the reason for the alleged beating of the 12-year-old Swedish boy by a Muslim immigrant?
# There is no credible evidence to support this claim, and it is likely a fabrication.
# Best METEOR Score: 0.1647
# Generated Question 3: What distinctive feature did the 12-year-old Swedish boy have that allegedly led to his beating by a Muslim immigrant?
# The claim states that the boy had blue eyes.
# Best METEOR Score: 0.1881
# Total METEOR Score (normalized): 0.1479
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a Ballia resident arrested for setting a train on fire during the Agnipath scheme protests?
#
# Best METEOR Score: 0.2624
# Generated Question 2: Why was a Ballia resident arrested during the Agnipath scheme protests?
# A Ballia resident was arrested for setting a train on fire while protesting against the union government’s Agnipath scheme.
# Best METEOR Score: 0.2280
# Generated Question 3: What was the reason behind the arrest of a Ballia resident during the Agnipath scheme protests?
# The Ballia resident was arrested for setting a train on fire.
# Best METEOR Score: 0.2765
# Total METEOR Score (normalized): 0.2210
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did an Iranian missile malfunction and hit its own launcher?
#
# Best METEOR Score: 0.0610
# Generated Question 2: What happened when an Iranian missile malfunctioned?
# The Iranian missile malfunctioned and made a U-turn to hit the launcher instead of the target.
# Best METEOR Score: 0.1532
# Generated Question 3: What was the result of an Iranian missile malfunction?
# The missile hit its own launcher instead of the target.
# Best METEOR Score: 0.1016
# Total METEOR Score (normalized): 0.1053
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Mark Zuckerberg say that the six-hour global outage of Facebook, Instagram, and WhatsApp was planned?
#
# Best METEOR Score: 0.0872
# Generated Question 2: Why did Mark Zuckerberg say that the six-hour global outage of Facebook, Instagram, and WhatsApp happened?
# There is no evidence to suggest that Mark Zuckerberg said the downtime was planned to enter the cryptocurrency business.
# Best METEOR Score: 0.1627
# Generated Question 3: What was the reason behind the six-hour global outage of Facebook, Instagram, and WhatsApp according to Mark Zuckerberg?
# There is no statement from Mark Zuckerberg suggesting that the downtime was planned.
# Best METEOR Score: 0.0962
# Total METEOR Score (normalized): 0.1154
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Capt's son Rawat question the timing of the ED summons?
#
# Best METEOR Score: 0.1205
# Generated Question 2: Why did Capt's son Rawat question the ED summons?
# Capt\'s son Rawat questioned the ED summons due to the timing.
# Best METEOR Score: 0.1705
# Generated Question 3: What did Capt\'s son Rawat do in response to the ED summons?
# Capt\'s son Rawat questioned the timing of the ED summons.
# Best METEOR Score: 0.1195
# Total METEOR Score (normalized): 0.1368
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did China approach the United Nations regarding India?
#
# Best METEOR Score: 0.0926
# Generated Question 2: Why did China approach the United Nations about India?
# China approached the United Nations, pleading that India is misusing its power.
# Best METEOR Score: 0.1367
# Generated Question 3: What is the reason behind China approaching the United Nations about India?
# China approached the United Nations pleading that India is misusing its power.
# Best METEOR Score: 0.0996
# Total METEOR Score (normalized): 0.1096
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a Gaza man mourn Yahya Sinwar's death?
#
# Best METEOR Score: 0.0613
# Generated Question 2: Why did the Gaza man mourn?
# There is no evidence that a Gaza man mourned Yahya Sinwar\'s death.
# Best METEOR Score: 0.1204
# Generated Question 3: What happened to Yahya Sinwar?
# There is no report of Yahya Sinwar\'s death.
# Best METEOR Score: 0.0493
# Total METEOR Score (normalized): 0.0744
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will the Ambani family provide Rs 200 crore to Kangana Ranaut to build a new studio?
#
# Best METEOR Score: 0.0882
# Generated Question 2: Why did Nita Ambani offer to help Kangana Ranaut with Rs 200 crore?
# There is no evidence to suggest that Nita Ambani offered to help Kangana Ranaut with Rs 200 crore to build a new studio.
# Best METEOR Score: 0.1471
# Generated Question 3: How much money did Nita Ambani offer to Kangana Ranaut to construct a new studio?
# There is no evidence to suggest that Nita Ambani offered any money to Kangana Ranaut to construct a new studio.
# Best METEOR Score: 0.1420
# Total METEOR Score (normalized): 0.1258
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Congress first list for Haryana elections a new phenomenon?
#
# Best METEOR Score: 0.0909
# Generated Question 2: What is the significance of the Congress first list for Haryana elections?
# The Congress first list for Haryana elections is a repeat of the old practice of giving tickets to old-timers and leaders\' kin.
# Best METEOR Score: 0.1538
# Generated Question 3: What is notable about the Congress first list for Haryana elections?
# The list features old-timers and leaders\' kin.
# Best METEOR Score: 0.1512
# Total METEOR Score (normalized): 0.1320
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will Biden help India get a UN Security Council permanent seat if elected?
#
# Best METEOR Score: 0.0331
# Generated Question 2: What did Biden's aide say about India's UN Security Council permanent seat?
# According to Biden\'s aide, if elected, Biden will help India get a UN Security Council permanent seat.
# Best METEOR Score: 0.0772
# Generated Question 3: What did Biden's aide say about Biden's role in India getting a UN Security Council permanent seat?
# Biden\'s aide said that if elected, Biden will help India get a UN Security Council permanent seat.
# Best METEOR Score: 0.0610
# Total METEOR Score (normalized): 0.0546
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was the Canadian wildfires started by a fire-raining helicopter?
#
# Best METEOR Score: 0.0613
# Generated Question 2: What is the real explanation behind the Canadian wildfires?
# There is no credible evidence to suggest that a fire-raining helicopter started the Canadian wildfires. The actual cause of the wildfires is usually due to factors like lightning, human activities, or climate change.
# Best METEOR Score: 0.1045
# Generated Question 3: What is known about the starting of the Canadian wildfires?
# The Canadian wildfires were not started by a fire-raining helicopter, as there is no such evidence. Instead, wildfires are often caused by natural or human factors.
# Best METEOR Score: 0.1603
# Total METEOR Score (normalized): 0.1087
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Were chapters on democratic rights, secularism, citizenship, and 5-year plans removed from CBSE syllabi for higher classes?
#
# Best METEOR Score: 0.0575
# Generated Question 2: What changes were made to the CBSE syllabi for higher classes?
# Chapters on democratic rights, secularism, citizenship, and 5-year plans were dropped from the CBSE syllabi for higher classes.
# Best METEOR Score: 0.1242
# Generated Question 3: What topics were removed from the CBSE syllabus?
# Democratic rights, secularism, citizenship, and 5-year plans
# Best METEOR Score: 0.0581
# Total METEOR Score (normalized): 0.0743
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was the Indian flag waved in PoK's Rawalkot during an anti-government protest?
#
# Best METEOR Score: 0.1890
# Generated Question 2: What was the significance of the Indian flag being waved in PoK's Rawalkot?
# The Indian flag was waved in PoK's Rawalkot as a symbol of defiance during an anti-government protest.
# Best METEOR Score: 0.1852
# Generated Question 3: Where was the Indian flag waved during an anti-government protest?
# The Indian flag was waved in PoK's Rawalkot.
# Best METEOR Score: 0.2138
# Total METEOR Score (normalized): 0.1819
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a man seen sleeping on a mattress while floating on muddy water in flood-hit Assam?
#
# Best METEOR Score: 0.0294
# Generated Question 2: What was a man in flood-hit Assam seen doing while floating on muddy water?
# A man in flood-hit Assam was seen sleeping on a mattress while floating on muddy water.
# Best METEOR Score: 0.0389
# Generated Question 3: How was a man in flood-hit Assam seen floating on the water?
# A man in flood-hit Assam was seen sleeping on a mattress while floating on muddy water.
# Best METEOR Score: 0.0784
# Total METEOR Score (normalized): 0.0464
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# ...
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the world's largest hydroelectric project burst due to heavy floods?
#
# Best METEOR Score: 0.0904
# Generated Question 2: What was the reason behind the burst of the world's largest hydroelectric project?
# The world's largest hydroelectric project burst due to heavy floods.
# Best METEOR Score: 0.1476
# Generated Question 3: What event caused damage to the world's largest hydroelectric project?
# Heavy floods caused damage to the world's largest hydroelectric project.
# Best METEOR Score: 0.1130
# Total METEOR Score (normalized): 0.1167
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a truck ram into a bus stop in Ramat Hasharon?
#
# Best METEOR Score: 0.0606
# Generated Question 2: What was the location of the truck accident?
# The truck accident occurred in Ramat Hasharon near Tel Aviv.
# Best METEOR Score: 0.1518
# Generated Question 3: What did a truck ram into in Ramat Hasharon?
# A truck rammed into a bus stop in Ramat Hasharon near Tel Aviv.
# Best METEOR Score: 0.0602
# Total METEOR Score (normalized): 0.0868
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is Neena Gupta the first Indian to win the Ramanujan Prize?
#
# Best METEOR Score: 0.0909
# Generated Question 2: What achievement did Neena Gupta attain in the field of mathematics?
# Neena Gupta became the first Indian to win the Ramanujan Prize for young mathematicians.
# Best METEOR Score: 0.1389
# Generated Question 3: What award did Neena Gupta win, becoming the first Indian to do so?
# Neena Gupta won the Ramanujan Prize.
# Best METEOR Score: 0.1143
# Total METEOR Score (normalized): 0.1089
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are the farm laws well-received, with protests limited to Punjab, according to Prakash Javadekar?
#
# Best METEOR Score: 0.0882
# Generated Question 2: What is Prakash Javadekar's view on the response to the farm laws?
# According to Prakash Javadekar, the farm laws have received a good response, with protests limited to Punjab.
# Best METEOR Score: 0.1242
# Generated Question 3: Where are the protests against the farm laws happening, according to Prakash Javadekar?
# Protests against the farm laws are happening only in Punjab, according to Prakash Javadekar.
# Best METEOR Score: 0.1172
# Generated Question 4: How widespread are the protests against the farm laws, as per Prakash Javadekar?
# Protests against the farm laws are limited to Punjab, as per Prakash Javadekar.
# Best METEOR Score: 0.1373
# Total METEOR Score (normalized): 0.1234
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Kashmiri boy viral on social media due to his resemblance to Shah Rukh Khan?
#
# Best METEOR Score: 0.0588
# Generated Question 2: Why is the Kashmiri boy viral on social media?
# The Kashmiri boy has gone viral on social media because of his close resemblance to Shah Rukh Khan.
# Best METEOR Score: 0.1243
# Generated Question 3: What is the reason behind the Kashmiri boy going viral on social media?
# His close resemblance to Shah Rukh Khan.
# Best METEOR Score: 0.0857
# Total METEOR Score (normalized): 0.0879
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a woman lose respect for her father after being defeated in Ludo?
#
# Best METEOR Score: 0.0898
# Generated Question 2: What was the reason for the woman to lose respect for her father?
# The woman lost respect for her father after being defeated in Ludo.
# Best METEOR Score: 0.1692
# Generated Question 3: Where did the woman go after losing respect for her father?
# The woman reached the Bhopal Family Court.
# Best METEOR Score: 0.1958
# Total METEOR Score (normalized): 0.1375
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Rohit Sharma seen holding a copy of the Bhagavad Gita?
#
# Best METEOR Score: 0.0606
# Generated Question 2: What is Rohit Sharma seen holding in the picture?
# Rohit Sharma is seen holding a copy of the Bhagavad Gita.
# Best METEOR Score: 0.0857
# Generated Question 3: What book is Rohit Sharma holding?
# The Bhagavad Gita
# Best METEOR Score: 0.0798
# Total METEOR Score (normalized): 0.0737
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the J&K police chief deny reports of violence?
#
# Best METEOR Score: 0.0909
# Generated Question 2: What did the J&K police chief say about the reports of violence?
# The J&K police chief rebuted reports of violence, stating that not a single bullet was fired in 6 days.
# Best METEOR Score: 0.2177
# Generated Question 3: How many days did the J&K police chief claim there was no violence?
# The J&K police chief claimed there was no violence for 6 days.
# Best METEOR Score: 0.2317
# Generated Question 4: What was the J&K police chief's stance on the reports of violence?
# The J&K police chief rebuted reports of violence.
# Best METEOR Score: 0.1476
# Generated Question 5: Did the J&K police chief report any firing incidents in the 6-day period?
# No
# Best METEOR Score: 0.1857
# Total METEOR Score (normalized): 0.1763
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Were Indians trying to climb up an escalator moving down?
#
# Best METEOR Score: 0.0610
# Generated Question 2: What were Indians trying to do on an escalator moving down?
# Indians were trying to climb up an escalator that was moving down.
# Best METEOR Score: 0.0639
# Generated Question 3: What was the situation with Indians and an escalator?
# Indians were trying to climb up an escalator that was moving down.
# Best METEOR Score: 0.0852
# Total METEOR Score (normalized): 0.0685
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is terrorism considered the biggest challenge faced by the region according to India at SCO?
#
# Best METEOR Score: 0.0888
# Generated Question 2: What did India say is the biggest challenge faced by the region at the SCO meeting?
# India stated that terrorism is the biggest challenge faced by the region at the SCO meeting.
# Best METEOR Score: 0.1158
# Generated Question 3: What challenge did India identify as the biggest at the SCO meeting?
# Terrorism is the biggest challenge faced by the region, according to India at the SCO meeting.
# Best METEOR Score: 0.1254
# Total METEOR Score (normalized): 0.1100
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Punjab CM Bhagwant Mann take a photo with Goldy Brar, the man who claimed responsibility for the assassination of Sidhu Moose Wala?
#
# Best METEOR Score: 0.1404
# Generated Question 2: What is the significance of the photo taken by Punjab CM Bhagwant Mann?
# There is no evidence to suggest that Punjab CM Bhagwant Mann took a photo with Goldy Brar, the man who claimed responsibility for the assassination of Sidhu Moose Wala.
# Best METEOR Score: 0.1201
# Generated Question 3: Who did Punjab CM Bhagwant Mann allegedly take a photo with?
# There is no evidence to suggest that Punjab CM Bhagwant Mann took a photo with Goldy Brar.
# Best METEOR Score: 0.0629
# Total METEOR Score (normalized): 0.1065
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Raebareli MLA Aditi Singh openly defy the Congress line?
#
# Best METEOR Score: 0.0915
# Generated Question 2: Why did Raebareli MLA Aditi Singh defy the Congress line?
# Raebareli MLA Aditi Singh defied the Congress line, fuelling rumors that she will quit.
# Best METEOR Score: 0.1354
# Generated Question 3: What did Raebareli MLA Aditi Singh do that went against the Congress line?
# Raebareli MLA Aditi Singh openly defied the Congress line.
# Best METEOR Score: 0.1130
# Generated Question 4: Is it true that Raebareli MLA Aditi Singh defied the Congress line?
#
# Best METEOR Score: 0.0904
# Generated Question 5: What rumors did Raebareli MLA Aditi Singh's action fuel?
# Raebareli MLA Aditi Singh's action fueled rumors that she will quit the Congress.
# Best METEOR Score: 0.0838
# Generated Question 6: Who is the MLA who defied the Congress line?
# Raebareli MLA Aditi Singh
# Best METEOR Score: 0.0898
# Total METEOR Score (normalized): 0.1093
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was there a landslide in Naina Peak due to heavy snowfall in Uttarakhand\'s Nainital?
#
# Best METEOR Score: 0.0329
# Generated Question 2: What was the impact of heavy snowfall in Uttarakhand\'s Nainital?
# Heavy snowfall in Uttarakhand\'s Nainital triggered a landslide in Naina Peak.
# Best METEOR Score: 0.0600
# Generated Question 3: What happened in Naina Peak due to heavy snowfall in Uttarakhand\'s Nainital?
# A landslide was triggered.
# Best METEOR Score: 0.0489
# Total METEOR Score (normalized): 0.0461
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is it true that Sanjoy Rabidas, a cobbler in West Bengal, scored 93% in the West Bengal board exams?
#
# Best METEOR Score: 0.0852
# Generated Question 2: What is notable about Sanjoy Rabidas, a cobbler in West Bengal, in relation to the West Bengal board exams?
# Sanjoy Rabidas, a cobbler in West Bengal, scored 93% in the West Bengal board exams and is also an RSS member.
# Best METEOR Score: 0.0750
# Generated Question 3: What percentage did Sanjoy Rabidas, a cobbler in West Bengal, score in the West Bengal board exams?
# 93%
# Best METEOR Score: 0.0857
# Total METEOR Score (normalized): 0.0735
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Rahul Gandhi's new adviser a former JNU student?
#
# Best METEOR Score: 0.0305
# Generated Question 2: What did Rahul Gandhi's new adviser do during Manmohan Singh's event?
# Rahul Gandhi's new adviser waved black flags at Manmohan Singh.
# Best METEOR Score: 0.0838
# Generated Question 3: What is notable about Rahul Gandhi's new adviser?
# Rahul Gandhi's new adviser is a former JNU student who waved black flags at Manmohan Singh.
# Best METEOR Score: 0.0395
# Generated Question 4: Was Rahul Gandhi's new adviser involved in a protest against Manmohan Singh?
#
# Best METEOR Score: 0.0599
# Generated Question 5: What is the background of Rahul Gandhi's new adviser?
# Rahul Gandhi's new adviser is a former JNU student.
# Best METEOR Score: 0.0607
# Generated Question 6: Who waved black flags at Manmohan Singh?
# Rahul Gandhi's new adviser.
# Best METEOR Score: 0.0418
# Total METEOR Score (normalized): 0.0626
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did former civil servants urge the EC to stall the release of the Modi biopic until the election results?
#
# Best METEOR Score: 0.1156
# Generated Question 2: Why did former civil servants urge the EC to stall the release of the Modi biopic?
# Former civil servants urged the EC to stall the release of the Modi biopic until the election results to maintain the electoral integrity.
# Best METEOR Score: 0.1775
# Generated Question 3: What was the request of former civil servants to the EC regarding the Modi biopic?
# The request was to stall the release of the Modi biopic until the election results.
# Best METEOR Score: 0.1094
# Total METEOR Score (normalized): 0.1301
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was BJP legislator Shankar Lal Sharma chased and beaten up by a crowd in Rajasthan's Dausa?
#
# Best METEOR Score: 0.0585
# Generated Question 2: What happened to BJP legislator Shankar Lal Sharma in Rajasthan's Dausa?
# BJP legislator Shankar Lal Sharma was chased and beaten up by a crowd.
# Best METEOR Score: 0.0635
# Generated Question 3: Where was BJP legislator Shankar Lal Sharma chased and beaten up by a crowd?
# In Rajasthan's Dausa
# Best METEOR Score: 0.0581
# Total METEOR Score (normalized): 0.0543
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Shaheen Bagh dadi Bilkis Bano in jail?
#
# Best METEOR Score: 0.0309
# Generated Question 2: Why is Shaheen Bagh dadi Bilkis Bano in jail?
# Shaheen Bagh dadi Bilkis Bano has been in jail since December 1 after reaching Singhu border to join the farmers’ protest.
# Best METEOR Score: 0.1494
# Generated Question 3: When did Shaheen Bagh dadi Bilkis Bano go to jail?
# Shaheen Bagh dadi Bilkis Bano has been in jail since December 1.
# Best METEOR Score: 0.0641
# Total METEOR Score (normalized): 0.0802
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
#
# Average METEOR Score: 0.1013
