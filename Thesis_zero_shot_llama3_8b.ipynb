# %%
# Clone the BARTScore repository
# !git clone https://github.com/neulab/BARTScore.git
# Out:
# Cloning into 'BARTScore'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 220 (delta 18), reused 14 (delta 14), pack-reused 194 (from 1)
# Receiving objects: 100% (220/220), 101.98 MiB | 14.15 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (192/192), done.

# %%
# %cd /content/BARTScore
# Out:
# /content/BARTScore

# %%
# Import libraries
from bart_score import BARTScorer
import torch

# %%
# Install necessary libraries
# !pip install --upgrade pip  # ensures that pip is current
# !pip install tensorflow tensorflow_hub transformers
# !pip install git+https://github.com/google-research/bleurt.git
# !pip install pandas
# !pip install groq
# !pip install scikit-learn
# !pip install matplotlib
# !pip install nltk
# !pip install rouge
# !pip install sacrebleu
# !pip install bert-score
# !pip install rouge
# Navigate to the repository directory
# %cd /content/BARTScore

# Download and unzip BLEURT checkpoint
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# !unzip BLEURT-20.zip


# Import libraries
from bart_score import BARTScorer
import torch

# Initialize BART-Scorer
bart_scorer = BARTScorer(device='cuda:0' if torch.cuda.is_available() else 'cpu',
                         checkpoint='facebook/bart-large-cnn')
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.2 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (2.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-vcqp_zsk
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-vcqp_zsk
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=b655de5ab9ac62e9e085c40373c2646100afd5742234696128d0a7e7db284fa3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-49xqtri_/wheels/64/f4/2c/509a6c31b8ebde891a81029fd94f199b1b92f0e7cfc20d417a
# Successfully built BLEURT
# Installing collected packages: BLEURT
# Successfully installed BLEURT-0.0.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting groq
#   Downloading groq-0.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Downloading groq-0.15.0-py3-none-any.whl (109 kB)
# Installing collected packages: groq
# Successfully installed groq-0.15.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# /content/BARTScore
# --2025-01-15 07:44:35--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.207, 64.233.170.207, 142.251.175.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G  22.1MB/s    in 94s
#
# 2025-01-15 07:46:11 (21.6 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]
#
# Archive:  BLEURT-20.zip
#    creating: BLEURT-20/
#   inflating: BLEURT-20/bert_config.json
#   inflating: BLEURT-20/saved_model.pb
#    creating: BLEURT-20/variables/
#   inflating: BLEURT-20/variables/variables.index
#   inflating: BLEURT-20/variables/variables.data-00000-of-00001
#   inflating: BLEURT-20/sent_piece.vocab
#   inflating: BLEURT-20/bleurt_config.json
#   inflating: BLEURT-20/sent_piece.model
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from sacrebleu.metrics import CHRF, TER
from bert_score import score
from bleurt import score as bleurt_score
import json
import pandas as pd
import random
import warnings
from groq import Groq
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
from nltk.translate.meteor_score import meteor_score
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Suppress specific warning messages
import logging
logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)

# Function to read JSON file and extract claims
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/last_fake_claims.json'
claims_file_2 = '/content/Modified_true_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# Extract relevant information and convert to DataFrame
claims_list = []
for claim in combined_claims:
    claims_list.append({
        'Text': claim['claim'],
        'classification_label': claim['label'],
        'justification': claim['justification']
    })

claims_df = pd.DataFrame(claims_list)

# Process only the first 10 claims
claims_df = claims_df.head(5006)

# Initialize Groq API client
client = Groq(api_key="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")

# Initialize label map
label_map = {'true': 'true', 'fake': 'fake', "correct": "true", "false": "fake", "incorrect": "fake", "not true": "fake","true:" : "true","fake:": "fake"}

# Define the function to get predictions
def get_claim_predictions(claim):
    prompt = f"Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: {claim}"

    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="llama3-8b-8192",
            max_tokens=4000,
        )

        predicted_result = response.choices[0].message.content.strip().splitlines()
        print(predicted_result)
        predicted_label_justification = predicted_result[0].strip(' .,*').lower()
        if ':' in predicted_label_justification:
            predicted_label, predicted_justification = predicted_label_justification.split(':', 1)
            predicted_label = predicted_label.strip()
            predicted_justification = predicted_justification.strip()
        else:
            predicted_label = predicted_label_justification
            predicted_justification = " ".join(predicted_result[1:]).strip().lower()

        if predicted_label in label_map:
            predicted_label = label_map[predicted_label]
        else:
            # Handle cases where the label is not clear
            predicted_label = "unknown"
            predicted_justification = " ".join(predicted_result).strip().lower()
    except Exception as e:
        print(f"Error processing claim '{claim}': {e}")
        return ("", "", "")

    return (prompt, predicted_label, predicted_justification)

# Evaluate claims
results = []
actual_labels = []
predicted_labels = []
predicted_justifications = []
actual_justifications = []

correct_predictions = 0
total_processed_claims = 0

for index, row in claims_df.iterrows():
    claim = row['Text']
    actual_label = str(row['classification_label'].strip().lower())
    actual_justification = str(row['justification'].strip().lower())

    prompt, predicted_label, predicted_justification = get_claim_predictions(claim)

    total_processed_claims += 1

    if (predicted_label, predicted_justification) == ("", ""):
        continue

    actual_labels.append(actual_label)
    actual_justifications.append(actual_justification)
    predicted_labels.append(predicted_label)
    predicted_justifications.append(predicted_justification)

    if predicted_label == actual_label:
        correct_predictions += 1
    print(f"Claim #{total_processed_claims}")
    print(f"Prompt: {prompt}")
    print(f"Claim: {claim}")
    print(f"Predicted Label: {predicted_label}")
    print(f"Actual Label: {actual_label}")
    print(f"Predicted Justification: {predicted_justification}")
    print(f"Actual Justification: {actual_justification}")
    print('-' * 50)

# Metrics initialization
rouge = Rouge()
smoothing_function = SmoothingFunction().method4
chrf = CHRF()
ter = TER()
bleurt_scorer = bleurt_score.BleurtScorer("BLEURT-20")

# Filter out empty justifications
filtered_justifications = [
    (actual, predicted)
    for actual, predicted in zip(actual_justifications, predicted_justifications)
    if predicted.strip()
]

# Calculate metrics
def calculate_metrics_extended(justifications):
    bleu_scores = []
    rouge_scores = []
    meteor_scores = []
    chrf_scores = []
    ter_scores = []
    bert_scores = []
    bleurt_scores = []
    bart_scores = []

    for ref, pred in justifications:
        # BLEU score
        bleu = sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothing_function)
        bleu_scores.append(bleu)

        # ROUGE score
        rouge_score = rouge.get_scores(pred, ref, avg=True)
        rouge_scores.append(rouge_score)

        # METEOR score
        meteor = meteor_score([ref.split()], pred.split())
        meteor_scores.append(meteor)

        # ChrF
        chrf_scores.append(chrf.corpus_score([pred], [[ref]]).score)

        # TER
        ter_scores.append(ter.corpus_score([pred], [[ref]]).score)

        # BERTScore
        P, R, F1 = score([pred], [ref], lang="en")
        bert_scores.append(F1.mean().item())

        # BLEURT
        bleurt_scores.append(bleurt_scorer.score(references=[ref], candidates=[pred])[0])

        # BARTScore
        bart_scores.append(bart_scorer.score([pred], [ref])[0])

    return bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores

# Calculate metrics
bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores = calculate_metrics_extended(filtered_justifications)

# Summarize and print results
avg_rouge_1 = sum([score['rouge-1']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_2 = sum([score['rouge-2']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_l = sum([score['rouge-l']['f'] for score in rouge_scores]) / len(rouge_scores)

print(f"Average BLEU Score: {sum(bleu_scores) / len(bleu_scores):.4f}")
print(f"Average METEOR Score: {sum(meteor_scores) / len(meteor_scores):.4f}")
print(f"Average ChrF Score: {sum(chrf_scores) / len(chrf_scores):.4f}")
print(f"Average TER Score: {sum(ter_scores) / len(ter_scores):.4f}")
print(f"Average BERTScore F1: {sum(bert_scores) / len(bert_scores):.4f}")
print(f"Average BLEURT Score: {sum(bleurt_scores) / len(bleurt_scores):.4f}")
print(f"Average BARTScore: {sum(bart_scores) / len(bart_scores):.4f}")
print(f"Average ROUGE-1 F1 Score: {avg_rouge_1:.4f}")
print(f"Average ROUGE-2 F1 Score: {avg_rouge_2:.4f}")
print(f"Average ROUGE-L F1 Score: {avg_rouge_l:.4f}")

# Calculate accuracy
accuracy = (correct_predictions / total_processed_claims) * 100 if total_processed_claims > 0 else 0
print(f"Model Accuracy: {accuracy:.2f}%")

# Calculate the F1 score
f1 = f1_score(actual_labels, predicted_labels, average='weighted', labels=["true", "fake"])
print(f"F1 Score Average: {f1}")

# Confusion matrix
cm = confusion_matrix(actual_labels, predicted_labels, labels=["true", "fake"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["true", "fake"])
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is valid because according to multiple news sources, including hindustan times, the hindu, and india today, the indian government has indeed announced plans to induct around 2,000 retired army personnel, including those under the age of 50, into the central industrial security force (cisf) as part of a rehabilitation program. this initiative aims to provide employment opportunities to these veterans and enable their smooth transition into civilian life.
# Actual Justification: the article reports that the government is planning to induct 2,000 ex-armymen under the age of 50 into the cisf as part of a rehabilitation initiative.
# --------------------------------------------------
# ['FAKE', '', 'There is no evidence to support this claim. Celebratory firing is a common phenomenon in some parts of the world, particularly in South Asia, where firearms are discharged in the air to celebrate joyful occasions such as weddings, religious festivals, and even the recovery of a loved one from illness. However, without specific details, names, dates, or sources supporting this claim, it cannot be verified as true.']
# Claim #4452
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Muslim leader in pakistan had returned home after recovering from coronavirus, but was killed in celebratory firing.
# Claim: Muslim leader in pakistan had returned home after recovering from coronavirus, but was killed in celebratory firing.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is based on a news article stating that the chief minister of karnataka, siddaramaiah, has said that the congress government will seek the disqualification of mlas who have resigned from the state assembly. this statement has been reported by multiple news sources and is a direct quote from the chief minister himself, making it a credible claim.
# Actual Justification: congress leader siddaramaiah stated that the party would pursue the disqualification of rebel karnataka mlas who submitted their resignations, citing anti-defection laws. he emphasized that the resignations were politically motivated and intended to destabilize the government.
# --------------------------------------------------
# ['TRUE', '', "This claim is true because truck overturning accidents can and do occur, and it's possible for such an accident to result in fatalities. However, without more context or specific information about the incident, it's unclear whether an actual truck overturning accident occurred, and if so, whether it indeed resulted in eight fatalities."]
# Claim #4457
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Truck overturns in up, eight killed
# Claim: Truck overturns in up, eight killed
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this claim is true because truck overturning accidents can and do occur, and it's possible for such an accident to result in fatalities. however, without more context or specific information about the incident, it's unclear whether an actual truck overturning accident occurred, and if so, whether it indeed resulted in eight fatalities.
# Actual Justification: the claim that eight people were killed when a truck overturned in uttar pradesh is true. according to india today, the incident occurred in hardoi district when a sand-laden truck overturned on people sleeping outside their house. the victims were buried alive under the sand, and despite efforts to rescue them, eight members of a family were killed.
# --------------------------------------------------
# ['FAKE', "This claim is likely fabricated as there is no credible evidence or records of such an incident happening. The Central Industrial Security Force (CISF) is responsible for securing sensitive installations and protecting the country's critical infrastructure, but it has no jurisdiction over the Reserve Bank of India (RBI) or its officials. Any allegations or corruption cases involving RBI officials would be investigated and prosecuted by the Central Bureau of Investigation (CBI) or other designated agencies, not CISF."]
# Claim #4458
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: CISF police personnel recovering cash from the deputy director of RBI.
# Claim: CISF police personnel recovering cash from the deputy director of RBI.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: this claim is likely fabricated as there is no credible evidence or records of such an incident happening. the central industrial security force (cisf) is responsible for securing sensitive installations and protecting the country's critical infrastructure, but it has no jurisdiction over the reserve bank of india (rbi) or its officials. any allegations or corruption cases involving rbi officials would be investigated and prosecuted by the central bureau of investigation (cbi) or other designated agencies, not cisf.
# Actual Justification: the claim is misleading. the officer in the video is not the deputy director of rbi. the video shows cisf police personnel recovering cash from a deputy control officer in the bank note press (bnp) at dewas, madhya pradesh. the bnp is a unit of the security printing and minting corporation of india ltd (spmcil) and is not under the control of the rbi.
# --------------------------------------------------
# ['TRUE', 'According to various news reports, on August 14, 2023, a priest at the Imlitala temple in Vrindavan, Mathura, was brutally assaulted, and police suspect that some Bangladeshis might be involved in the attack.']
# Claim #4459
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A priest at Vrindavan’s Imlitala temple was brutally assaulted; Bangladeshis suspected to be among the attackers.
# Claim: A priest at Vrindavan’s Imlitala temple was brutally assaulted; Bangladeshis suspected to be among the attackers.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: according to various news reports, on august 14, 2023, a priest at the imlitala temple in vrindavan, mathura, was brutally assaulted, and police suspect that some bangladeshis might be involved in the attack.
# Actual Justification: the claim is false. the incident at imlitala temple in vrindavan was related to a feud within a local religious sect, not a communal attack. there is no credible evidence to suggest that bangladeshis were involved.
# --------------------------------------------------
# ['FAKE', '', 'On January 20, 2022, multiple news outlets reported that several Indian ministers, including Minister of State for External Affairs V Muraleedharan, Minister of State for Defence Ajay Bhatt, and Minister of State for Jal Shakti Ratan Lal Kataria, were scheduled to attend the World Economic Forum (WEF) Annual Meeting in Davos, Switzerland. The meeting, held from January 17-22, 2022, aimed to discuss global economic issues and bring together leaders from various sectors.']
# Claim #4460
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Modi ministers skip davos meet due to pressing matters ahead of lok sabha polls
# Claim: Modi ministers skip davos meet due to pressing matters ahead of lok sabha polls
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: on january 20, 2022, multiple news outlets reported that several indian ministers, including minister of state for external affairs v muraleedharan, minister of state for defence ajay bhatt, and minister of state for jal shakti ratan lal kataria, were scheduled to attend the world economic forum (wef) annual meeting in davos, switzerland. the meeting, held from january 17-22, 2022, aimed to discuss global economic issues and bring together leaders from various sectors.
# Actual Justification: the claim is supported by a report from *the print*, which mentions that modi ministers skipped the davos meet because of pressing matters related to the upcoming lok sabha elections.
# --------------------------------------------------
# ['TRUE', '', "The claim is verified to be true. The four accused in the Hyderabad vet's rape and murder case were indeed identified as Mohammad Pasha, Mohammad Iqbal, Mohammad Arif, and Jollu Shiva, not Mohammad Akram. The case gained widespread attention in India and the accused were subsequently arrested and charged for committing the heinous crime."]
# Claim #4461
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: The four accused in the Hyderabad vet’s rape and murder were Mohammad Pasha, Mohammad Iqbal, Mohammad Rahim, and Mohammad Akram.
# Claim: The four accused in the Hyderabad vet’s rape and murder were Mohammad Pasha, Mohammad Iqbal, Mohammad Rahim, and Mohammad Akram.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the claim is verified to be true. the four accused in the hyderabad vet's rape and murder case were indeed identified as mohammad pasha, mohammad iqbal, mohammad arif, and jollu shiva, not mohammad akram. the case gained widespread attention in india and the accused were subsequently arrested and charged for committing the heinous crime.
# Actual Justification: the names of the accused mentioned in the claim are fake and part of a viral misinformation campaign with a communal twist. the real identities of the accused do not match these names.
# --------------------------------------------------
# ['TRUE', 'There is evidence of a legitimate news article or report that confirms the claim of a drug haul in Pune, citing specific numbers and details, such as the amount of drugs seized (Rs 20 crore) and the number of individuals arrested (nine).']
# Claim #4462
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Nine more arrested in Rs 20 crore drug haul in pune.
# Claim: Nine more arrested in Rs 20 crore drug haul in pune.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: there is evidence of a legitimate news article or report that confirms the claim of a drug haul in pune, citing specific numbers and details, such as the amount of drugs seized (rs 20 crore) and the number of individuals arrested (nine).
# Actual Justification: the article confirms the arrest of nine more individuals in connection with a rs 20 crore drug haul in pune.
# --------------------------------------------------
# ['FAKE', '', 'The claim cannot be verified, as a search of official sources and news articles did not find any evidence of a "Rs Secretariat" launching an employee welfare scheme named after Arun Jaitley.']
# Claim #4463
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Rs secretariat launches employee welfare scheme named after arun jaitley
# Claim: Rs secretariat launches employee welfare scheme named after arun jaitley
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim cannot be verified, as a search of official sources and news articles did not find any evidence of a "rs secretariat" launching an employee welfare scheme named after arun jaitley.
# Actual Justification: the rajya sabha secretariat has launched an employee welfare scheme in honor of arun jaitley, the former finance minister of india.
# --------------------------------------------------
# ['FAKE', 'There is no such place as "moldo" where army commanders would meet. It is possible that you may be thinking of a different place, such as a NATO codename like "Moldavia" which is a historical name for Romania, but without more context, it is impossible to determine the validity of the claim.']
# Claim #4464
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Army commanders meet at moldo.
# Claim: Army commanders meet at moldo.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim is not supported by any credible sources or official announcements, and interstate travel restrictions due to covid-19 have been lifted in various countries.
# Actual Justification: the government has extended restrictions till may 31, with states authorized to implement their own measures. interstate travel and activities will be regulated until the new guidelines are in place.
# --------------------------------------------------
# ['TRUE', 'There is no evidence to support this claim, and it appears to be a baseless and insensitive accusation. The show\'s format typically involves randomly pairing contestants together for challenges and interactions, and the pairing of a Kashmiri Muslim man with a Brahmin woman would not necessarily be a deliberate attempt to promote "love jihad" or any other ideology. The show aims to promote socializing and understanding among people from diverse backgrounds, not to perpetuate harmful stereotypes or biases.']
# Claim #4473
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A Kashmiri Muslim man has been invited to Bigg Boss season 13, and the show deliberately partnered him with a Brahmin woman to encourage 'love jihad'.
# Claim: A Kashmiri Muslim man has been invited to Bigg Boss season 13, and the show deliberately partnered him with a Brahmin woman to encourage 'love jihad'.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: there is no evidence to support this claim, and it appears to be a baseless and insensitive accusation. the show's format typically involves randomly pairing contestants together for challenges and interactions, and the pairing of a kashmiri muslim man with a brahmin woman would not necessarily be a deliberate attempt to promote "love jihad" or any other ideology. the show aims to promote socializing and understanding among people from diverse backgrounds, not to perpetuate harmful stereotypes or biases.
# Actual Justification: the claim is false. there is no evidence to support the claim that bigg boss season 13 was deliberately trying to promote 'love jihad' by pairing a muslim man with a brahmin woman. the show is based on the participants' interactions, and the intimate image that was circulated was unrelated to any such agenda. the claim is a misinterpretation of the situation and based on misinformation.
# --------------------------------------------------
# ['FAKE', '', "The claim is false as the film 'Brahmastra' was not originally titled 'Dragon'. According to various sources, including interviews with the film's director Ayan Mukerji, the title 'Brahmastra' was chosen to reflect the film's mythological theme and connection to ancient Hindu mythology. The film was in production for several years before the 2019 Pulwama suicide bombing, and there is no evidence to suggest that the title was changed in response to the event."]
# Claim #4474
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: ‘Brahmastra’ was renamed from ‘Dragon’ after the 2019 Pulwama suicide bombing to appease a wider Hindu audience.
# Claim: ‘Brahmastra’ was renamed from ‘Dragon’ after the 2019 Pulwama suicide bombing to appease a wider Hindu audience.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is false as the film 'brahmastra' was not originally titled 'dragon'. according to various sources, including interviews with the film's director ayan mukerji, the title 'brahmastra' was chosen to reflect the film's mythological theme and connection to ancient hindu mythology. the film was in production for several years before the 2019 pulwama suicide bombing, and there is no evidence to suggest that the title was changed in response to the event.
# Actual Justification: the claim that ‘brahmastra’ was renamed from ‘dragon’ after the 2019 pulwama suicide bombing to appease a wider hindu audience is false. ‘brahmastra’ was always the intended title of the film. the confusion around the name change likely stems from the film's earlier working title, 'dragon', which was never officially used in marketing or promotion. the renaming had no connection to the pulwama attack.
# --------------------------------------------------
# ['TRUE', '', 'Umar Khalid, a former Jawaharlal Nehru University (JNU) student, was indeed arrested by the Delhi Police Special Cell in September 2020 under the Unlawful Activities (Prevention) Act (UAPA) in connection with the Delhi riots that took place in February 2020.']
# Claim #4475
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Former jnu student umar khalid arrested under uapa in connection with delhi riots.
# Claim: Former jnu student umar khalid arrested under uapa in connection with delhi riots.
# Predicted Label: true
# Actual Label: true
# Predicted Justification
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: 4 telugu desam party members of rajya sabha join bjp
# Claim: 4 telugu desam party members of rajya sabha join bjp
# Predicted Label: true
# Actual Label: true
# Predicted Justification: on september 11, 2021, four telugu desam party (tdp) members of the rajya sabha, including its spokesperson and former union minister y.s. chowdary, joined the bharatiya janata party (bjp). a statement released by the bjp confirmed the development, citing the four mps' decision to join the party.
# Actual Justification: the article confirms that four rajya sabha members from the telugu desam party (tdp) joined the bharatiya janata party (bjp).
# --------------------------------------------------
# ['FAKE', '', 'The claim is fake because Joshimath is not commonly referred to as the "sinking city of Uttarakhand". Joshimath is a town in the Chamoli district of Uttarakhand, India, but it is not known for sinking. Also, a quick search did not turn up any evidence of a verified sighting of a cloud formation resembling folded hands in Joshimath or anywhere else.']
# Claim #4480
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A strange cloud formation that looks like folded hands, spotted in Joshimath, the sinking city of Uttarakhand.
# Claim: A strange cloud formation that looks like folded hands, spotted in Joshimath, the sinking city of Uttarakhand.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is fake because joshimath is not commonly referred to as the "sinking city of uttarakhand". joshimath is a town in the chamoli district of uttarakhand, india, but it is not known for sinking. also, a quick search did not turn up any evidence of a verified sighting of a cloud formation resembling folded hands in joshimath or anywhere else.
# Actual Justification: the video in question shows a cloud formation that appears to resemble folded hands, but it is computer-generated imagery (cgi), not a real cloud formation. the claim about the cloud being spotted in joshimath is misleading.
# --------------------------------------------------
# ['FAKE', '', 'Fadnavis, the former Chief Minister of Maharashtra, was known for his opposition to the Shiv Sena, and although he had previously ruled out an alliance with the party, he eventually formed an alliance with them after the 2019 Maharashtra state assembly election.']
# Claim #4481
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: No intention of joining hands with shiv sena: fadnavis
# Claim: No intention of joining hands with shiv sena: fadnavis
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: fadnavis, the former chief minister of maharashtra, was known for his opposition to the shiv sena, and although he had previously ruled out an alliance with the party, he eventually formed an alliance with them after the 2019 maharashtra state assembly election.
# Actual Justification: devendra fadnavis, the leader of the bharatiya janata party (bjp), stated that there was no intention of forming an alliance with shiv sena. this statement came amid political developments in maharashtra, where the bjp and shiv sena were facing a rift after the state assembly elections.
# --------------------------------------------------
# ['FAKE', 'This claim is likely misleading or taken out of context. While it\'s true that India\'s economy has been attempting to recover from the COVID-19 pandemic and subsequent lockdowns, there is no evidence to suggest that the Prime Minister, Narendra Modi, has specifically mentioned "green shoots emerging" in the economy. It\'s possible that the quote has been misreported or is a fictional representation of the PM\'s remarks.']
# Claim #4482
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Green shoots emerging in economy: pm modi.
# Claim: Green shoots emerging in economy: pm modi.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this claim is likely misleading or taken out of context. while it's true that india's economy has been attempting to recover from the covid-19 pandemic and subsequent lockdowns, there is no evidence to suggest that the prime minister, narendra modi, has specifically mentioned "green shoots emerging" in the economy. it's possible that the quote has been misreported or is a fictional representation of the pm's remarks.
# Actual Justification: the article confirms that pm modi stated that the indian economy is seeing 'green shoots' of recovery, signaling early signs of economic improvement.
# --------------------------------------------------
# ['TRUE', 'According to news reports, the opposition parties did indeed send 23 notices to the government, including 10 to Prime Minister Narendra Modi and 13 to Home Minister Amit Shah, seeking a discussion and holding the Centre responsible for the recent violence in North-East Delhi.']
# Claim #4483
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line:
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: chants of 'India-India' were raised as Donald trump’s running mate JD vance arrived at the RNC with his indian wife usha chilukuri.
# Claim: chants of 'India-India' were raised as Donald trump’s running mate JD vance arrived at the RNC with his indian wife usha chilukuri.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no evidence to suggest that jd vance, the author and venture capitalist, was ever donald trump's running mate, nor does it appear that he was invited to the republican national convention (rnc) with his wife. jd vance did not become a prominent figure in the trump administration, and there is no record of him being trump's running mate.
# Actual Justification: the claim that chants of 'india-india' were raised as donald trump’s running mate jd vance arrived at the rnc with his indian wife usha chilukuri is false. according to telugu post, the video was edited to add the chants. in the original video, a country band could be heard performing, and no such chants were raised at the event.
# --------------------------------------------------
# ['FAKE', '', 'This claim is a well-known example of a "deep fake" or a completely fabricated story that is designed to go viral and generate shock or outrage. There is no evidence to support the claim, and it is likely that such a gruesome and absurd event did not occur. The story may have originated as a fictional news article or social media post and was then spread and shared without verification.']
# Claim #5001
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Uttar pradesh man kills his wife for serving tea with less sugar.
# Claim: Uttar pradesh man kills his wife for serving tea with less sugar.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: this claim is a well-known example of a "deep fake" or a completely fabricated story that is designed to go viral and generate shock or outrage. there is no evidence to support the claim, and it is likely that such a gruesome and absurd event did not occur. the story may have originated as a fictional news article or social media post and was then spread and shared without verification.
# Actual Justification: the claim is accurate as the article reports that a man in uttar pradesh killed his pregnant wife after she served him tea with less sugar.
# --------------------------------------------------
# ['TRUE', 'The claim is based on a real news article that quotes Karnataka Chief Minister Yediyurappa announcing that the government will ban the use of firecrackers during Deepavali celebrations to reduce air pollution and noise pollution.']
# Claim #5002
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Karnataka will ban the use of firecrackers during deepavali: cm yediyurappa.
# Claim: Karnataka will ban the use of firecrackers during deepavali: cm yediyurappa.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is based on a real news article that quotes karnataka chief minister yediyurappa announcing that the government will ban the use of firecrackers during deepavali celebrations to reduce air pollution and noise pollution.
# Actual Justification: the article confirms that karnataka chief minister bs yediyurappa announced a ban on the use of firecrackers during deepavali due to concerns over air pollution and covid-19.
# --------------------------------------------------
# ['TRUE', '', "There is no credible evidence to support the claim that Mahatma Gandhi had a romantic affair with a married, progressive woman in Lahore. Gandhi's personal life has been extensively documented, and there is no record of such an affair in his biography or in the accounts of his contemporaries. While Gandhi did have relationships with women, including a romantic interest in a woman named Kasturba, who later became his wife, there is no evidence to suggest that he had an affair with a married woman in Lahore."]
# Claim #5003
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: mahatma gandhi's little-known love affair with a married, progressive woman in lahore.
# Claim: mahatma gandhi's little-known love affair with a married, progressive woman in lahore.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: there is no credible evidence to support the claim that mahatma gandhi had a romantic affair with a married, progressive woman in lahore. gandhi's personal life has been extensively documented, and there is no record of such an affair in his biography or in the accounts of his contemporaries. while gandhi did have relationships with women, including a romantic interest in a woman named kasturba, who later became his wife, there is no evidence to suggest that he had an affair with a married woman in lahore.
# Actual Justification: the article discusses mahatma gandhi's lesser-known romantic relationship with a married, progressive woman in lahore, detailing how this affair was a part of his complex personal life.
# --------------------------------------------------
# ['FAKE', '', 'The reason I labeled this claim as \'FAKE\' is that there is no credible evidence to support the existence of an "old woman, a first-year BA student, protesting against the fee hike at JNU". The Jawaharlal Nehru University (JNU) has faced several fee hike protests, but there is no record of an old woman, a first-year BA student, being taken into custody for protesting against the fee hike.']
# Claim #5004
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: An old woman, a first-year BA student, was taken into custody for protesting against the fee hike at JNU.
# Claim: An old woman, a first-year BA student, was taken into custody for protesting against the fee hike at JNU.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the reason i labeled this claim as 'fake' is that there is no credible evidence to support the existence of an "old woman, a first-year ba student, protesting against the fee hike at jnu". the jawaharlal nehru university (jnu) has faced several fee hike protests, but there is no record of an old woman, a first-year ba student, being taken into custody for protesting against the fee hike.
# Actual Justification: the claim is misleading. the woman in the picture is not a first-year ba student from jnu. she is an elderly woman who was detained during a protest in delhi, but she is not associated with jnu or the fee hike protests.
# --------------------------------------------------
# ['**TRUE**', '', 'The World Health Organization (WHO) has issued guidelines and advisories on food safety during the COVID-19 pandemic, including the importance of proper food handling and preparation to prevent contamination. While there is no specific advisory asking people not to consume bakery items, the WHO does recommend taking precautions when consuming food and drinks to prevent the spread of the virus. These precautions include washing hands frequently, using a mask, and avoiding close contact with others. Furthermore, the WHO also recommends that food handlers and processors take measures to prevent contamination, including proper cleaning and sanitizing of equipment, surfaces, and food contact items.']
# Claim #5005
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: WHO advisory asks people not to consume bakery items as they get contaminated by coronavirus easily.
# Claim: WHO advisory asks people not to consume bakery items as they get contaminated by coronavirus easily.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the world health organization (who) has issued guidelines and advisories on food safety during the covid-19 pandemic, including the importance of proper food handling and preparation to prevent contamination. while there is no specific advisory asking people not to consume bakery items, the who does recommend taking precautions when consuming food and drinks to prevent the spread of the virus. these precautions include washing hands frequently, using a mask, and avoiding close contact with others. furthermore, the who also recommends that food handlers and processors take measures to prevent contamination, including proper cleaning and sanitizing of equipment, surfaces, and food contact items.
# Actual Justification: the world health organization (who) has not issued any such advisory about avoiding bakery items due to coronavirus contamination. the claim is false and misleading.
# --------------------------------------------------
# ['FALSE', '', 'There is no credible evidence to support the claim that journalist Rana Ayyub was forcefully taken away by the police amid a public protest. Rana Ayyub is an Indian investigative journalist known for her work on issues like corruption and politics, and there is no record of such an incident occurring.']
# Claim #5006
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Journalist Rana Ayyub was forcefully taken away by the police amid a public protest.
# Claim: Journalist Rana Ayyub was forcefully taken away by the police amid a public protest.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence to support the claim that journalist rana ayyub was forcefully taken away by the police amid a public protest. rana ayyub is an indian investigative journalist known for her work on issues like corruption and politics, and there is no record of such an incident occurring.
# Actual Justification: the claim is false. the woman in the photo being circulated is not rana ayyub, but a kerala student leader. the video showing her being taken away by the police was misattributed to rana ayyub.
# --------------------------------------------------
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Average BLEU Score: 0.0691
# Average METEOR Score: 0.2943
# Average ChrF Score: 39.8631
# Average TER Score: 159.4482
# Average BERTScore F1: 0.8822
# Average BLEURT Score: 0.4944
# Average BARTScore: -2.9468
# Average ROUGE-1 F1 Score: 0.3322
# Average ROUGE-2 F1 Score: 0.1264
# Average ROUGE-L F1 Score: 0.2895
# Model Accuracy: 56.79%
# F1 Score Average: 0.5622781139391192
