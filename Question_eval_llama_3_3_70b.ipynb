# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)

# %%
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
import time

# %%
import re


# Initialize Groq API client
client = Groq(api_key="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")



def convert_to_json(llm_response):
    responseQuestions = []
    pattern = r'\[(.*?)\]'
    matches = re.findall(pattern, llm_response, re.DOTALL)

    if not matches:
        return responseQuestions  # Return an empty list if no matches are found

    json_str = matches[0]
    questions_llm = re.findall(r'\{(.*?)\}', json_str, re.DOTALL)

    for question in questions_llm:
        question_json = {}
        q = re.findall(r'.?question.?:\s*.?(.*),[\s\n]+.?questionType', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip().strip('"')
        qt = re.findall(r'.?questionType.?:\s*.?(.*)[\'\"]', question, re.DOTALL)
        if qt:
            question_json['questionType'] = qt[0].strip().strip('"')
        responseQuestions.append(question_json)

    return responseQuestions


def get_response_llm(claim, questions, max_retries=3, retry_delay=2):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions."
  response = None
  for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="llama-3.3-70b-versatile",
            max_tokens=4000,
        )
        response_content = response.choices[0].message.content.strip()
        if response_content:
            response_json = convert_to_json(response_content)
            return response_json
        else:
             print(f"Empty response on attempt {attempt + 1} for claim: '{claim}'")

    except Exception as e:
        if response and response.choices and response.choices[0].message:
            print(f"Error on attempt {attempt + 1} for claim '{claim}': {e}, {response.choices[0].message.content}")
        else:
            print(f"Error on attempt {attempt + 1} for claim '{claim}': {e}, Response not available")
        if attempt < max_retries - 1:
            time.sleep(retry_delay) # Wait before retrying
        continue # Try again
  print(f"Failed to get response after {max_retries} attempts for claim: '{claim}'")
  return [] # Return empty list if all retries fail

# %%
new_data = []

for data in combined_claims[:5008]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    #q['answer'] = answer['answer']
    q['questionType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
new_data
# Out:
# [{'claim': '12 BSF jawans died in a bus accident in Meghalaya on February 19, 2022.',
#   'generatedQuestions': [{'question': "Did the bus accident in Meghalaya on February 19, 2022, result in 12 fatalities among BSF jawans?'",
#     'questionType': 'Boolean'},
#    {'question': "Can you describe the circumstances surrounding the image of BSF jawans involved in the alleged bus accident in Meghalaya on February 19, 2022?'",
#     'questionType': 'Abstractive'},
#    {'question': "What facts are known about the bus accident in Meghalaya on February 19, 2022, involving BSF jawans that can confirm or deny the claim of 12 deaths?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Muslims calling for the boycott of Hindu businesses in Bangalore.',
#   'generatedQuestions': [{'question': "Are Muslims calling for the boycott of Hindu businesses in Bangalore?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the claim of Muslims calling for the boycott of Hindu businesses in Bangalore on social media?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports or refutes the claim that Muslims are calling for the boycott of Hindu businesses in Bangalore?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Bodies of children being retrieved from the debris following an airstrike in Yemen’s Saada on January 21.',
#   'generatedQuestions': [{'question': "Did an airstrike in Yemen\\'s Saada occur on January 21?'",
#     'questionType': 'Boolean'},
#    {'question': "Was the image shared on social media from the January 2022 airstrike in Yemen\\'s Saada?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the truth about the image showing retrieval of bodies from the debris in Yemen\\'s Saada?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Palestinian president mahmoud abbas called Indian prime minister narendra modi a ‘zionist slave’.',
#   'generatedQuestions': [{'question': "Did Palestinian President Mahmoud Abbas call Indian Prime Minister Narendra Modi a Zionist slave?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the statement where Palestinian President Mahmoud Abbas allegedly called Indian Prime Minister Narendra Modi a Zionist slave?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the factual basis for the claim that Palestinian President Mahmoud Abbas referred to Indian Prime Minister Narendra Modi as a Zionist slave?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Time magazine cover has the image of Prime Minister Narendra Modi and 'Delete Fascism' written on it.",
#   'generatedQuestions': [{'question': 'Is the Time magazine cover with Prime Minister Narendra Modi and "Delete Fascism" real?\'',
#     'questionType': 'Boolean'},
#    {'question': 'What is the context behind the Time magazine cover with Prime Minister Narendra Modi and "Delete Fascism" that is being shared on social media?\'',
#     'questionType': 'Abstractive'},
#    {'question': 'What are the facts about the Time magazine cover with the image of Prime Minister Narendra Modi and the phrase "Delete Fascism"?\'',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Actor Salman Khan dedicated his song ‘Bhai Bhai’ - where he talks about unity and syncretic harmony - to the Congress party’s Bharat Jodo Yatra.',
#   'generatedQuestions': [{'question': "Did Salman Khan dedicate his song “Bhai Bhai” to the Bharat Jodo Yatra?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind Salman Khan dedicating his song to the Bharat Jodo Yatra, as shared on social media?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts about Salman Khan’s song “Bhai Bhai” and its relation to the Bharat Jodo Yatra?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Citizenship act protest: tough security measures continue at amu',
#   'generatedQuestions': [{'question': "Are tough security measures in place at AMU due to Citizenship Act protests?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the tough security measures being implemented at AMU as shown in the image or video?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information can be extracted about the current security situation at AMU in relation to the Citizenship Act protests?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Russian President Vladimir Putin reading a book by former Pakistani Prime Minister Imran Khan.',
#   'generatedQuestions': [{'question': "Is the claim that Russian President Vladimir Putin is reading a book by former Pakistani Prime Minister Imran Khan true?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image showing Russian President Vladimir Putin with a book by former Pakistani Prime Minister Imran Khan?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available about the book allegedly being read by Russian President Vladimir Putin that was written by former Pakistani Prime Minister Imran Khan?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Pm approves rs 2 lakh for kin of migrants run over by goods train, rs 50k for injured.',
#   'generatedQuestions': [{'question': "Did the PM approve Rs 2 lakh for the kin of migrants run over by a goods train?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the amount approved by the PM for the kin of migrants who were run over by a goods train?'",
#     'questionType': 'Abstractive'},
#    {'question': "What financial assistance has the PM approved for migrants injured by a goods train and their kin?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'UP police beat up a muslim man for mocking a street cow.',
#   'generatedQuestions': [{'question': "Did the UP police beat up a Muslim man for mocking a street cow?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video shared on social media showing a Muslim man being beaten by UP police for allegedly mocking a street cow?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the factual basis for the claim that a Muslim man was beaten by UP police for mocking a street cow?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'According to a CNN report, Taliban has banned the use of sanitary napkins in Afghanistan saying it is against Sharia.',
#   'generatedQuestions': [{'question': "Has the Taliban banned the use of sanitary napkins in Afghanistan?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the Taliban allegedly banning sanitary napkins in Afghanistan, as reported by CNN?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports the claim that the Taliban has prohibited the use of sanitary napkins in Afghanistan citing Sharia law?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Palestinian influencer Saleh Al-Jafarawi abandoned Gaza for a luxurious life in Qatar.',
#   'generatedQuestions': [{'question': "Did Palestinian influencer Saleh Al-Jafarawi leave Gaza for Qatar?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video of Saleh Al-Jafarawi in Qatar that is being shared on social media?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports or refutes the claim that Saleh Al-Jafarawi abandoned Gaza for a luxurious life in Qatar?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Nandi idol in the Kashi Vishwanath Temple in Varanasi faces the Gyanvapi mosque.',
#   'generatedQuestions': [{'question': "Does the Nandi idol in the Kashi Vishwanath Temple face the Gyanvapi mosque?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the significance of the Nandi idol in the Kashi Vishwanath Temple in relation to the Gyanvapi mosque?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the architectural alignment between the Nandi idol in the Kashi Vishwanath Temple and the Gyanvapi mosque?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'An american ship that was set on fire by the houthi militant group.',
#   'generatedQuestions': [{'question': "Was an American ship set on fire by the Houthi militant group?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image shared on social media showing an American ship on fire, allegedly attacked by the Houthi militant group?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the incident of the American ship being set on fire, supposedly by the Houthi militant group?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Police arresting Priyadarshini Narayan, who was seen thrashing a cab driver at a traffic signal in Lucknow.',
#   'generatedQuestions': [{'question': "Was Priyadarshini Narayan arrested by the police for thrashing a cab driver in Lucknow?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video shared on social media showing Priyadarshini Narayan thrashing a cab driver at a traffic signal?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the incident of Priyadarshini Narayan allegedly assaulting a cab driver in Lucknow?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "A burqa-clad Muslim man who was caught taking recordings from the women's washroom.",
#   'generatedQuestions': [{'question': "Was a burqa-clad Muslim man caught taking recordings from the women\\'s washroom?'",
#     'questionType': 'Boolean'},
#    {'question': "Can you describe the incident involving the burqa-clad Muslim man and the recordings from the women\\'s washroom as shared on social media?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts about the claim of a burqa-clad Muslim man taking recordings from the women\\'s washroom?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Facelift of kerala's public schools",
#   'generatedQuestions': [{'question': "Is the Kerala government investing in the renovation of public schools?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the key features of the facelift plan for Kerala\\'s public schools as shared on social media?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts about the renovation and upgrade of Kerala\\'s public schools under the new initiative?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Kareena Kapoor Khan appealed to people not to watch her upcoming film 'Laal Singh Chaddha'.",
#   'generatedQuestions': [{'question': "Did Kareena Kapoor Khan appeal to people not to watch her upcoming film Laal Singh Chaddha?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind Kareena Kapoor Khan allegedly asking people not to watch Laal Singh Chaddha?'",
#     'questionType': 'Abstractive'},
#    {'question': "Is there any evidence to support the claim that Kareena Kapoor Khan asked people to boycott her film Laal Singh Chaddha?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'IED expert among 3 terrorists killed in kulgam encounter',
#   'generatedQuestions': [{'question': "Were 3 terrorists killed in the Kulgam encounter?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the Kulgam encounter where an IED expert was among those killed?'",
#     'questionType': 'Abstractive'},
#    {'question': "Who were the terrorists killed in the Kulgam encounter and what were their areas of expertise?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Indian army shot down a Kashmiri student.',
#   'generatedQuestions': [{'question': "Did the Indian army shoot down a Kashmiri student?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the incident where the Indian army allegedly shot down a Kashmiri student?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the incident involving the Indian army and a Kashmiri student?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Monks who came to attend the Ayodhya Ram temple Bhoomi Pujan ceremony violated COVID-19 protocols.',
#   'generatedQuestions': [{'question': "Did monks attending the Ayodhya Ram temple Bhoomi Pujan ceremony violate COVID-19 protocols?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video showing monks at the Ayodhya Ram temple Bhoomi Pujan ceremony in relation to COVID-19 protocols?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence is there to support the claim that monks at the Ayodhya Ram temple Bhoomi Pujan ceremony did not follow COVID-19 protocols?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Metoo: m.j. akbar deliberately, mischievously misread her article, ramani tells court.',
#   'generatedQuestions': [{'question': "Did M.J. Akbar misread the article deliberately?'",
#     'questionType': 'Boolean'},
#    {'question': "What was the context of the article that led to M.J. Akbar misreading it, according to Ramani?'",
#     'questionType': 'Abstractive'},
#    {'question': "What did Ramani tell the court about M.J. Akbar\\'s reading of her article?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Large gathering with saffron flags violating covid-19 protocol on the day of Ram Mandir groundbreaking ceremony.',
#   'generatedQuestions': [{'question': "Did a large gathering with saffron flags take place on the day of Ram Mandir groundbreaking ceremony?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image showing a large gathering with saffron flags on the day of Ram Mandir groundbreaking ceremony?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information can be extracted from the image about covid-19 protocol violation during Ram Mandir groundbreaking ceremony?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Ratan Tata is endorsing an online get-rich-quick betting game called ‘Aviator’.',
#   'generatedQuestions': [],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Mumbai’s popular Wibs Bread company has been sealed after its workers tested positive for coronavirus. People should not consume their bread.',
#   'generatedQuestions': [{'question': "Has Wibs Bread company been sealed due to workers testing positive for coronavirus?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the origin of the claim that Wibs Bread company was sealed because its workers tested positive for coronavirus, and is the claim authentic?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available regarding the claim about Wibs Bread company workers testing positive for coronavirus and the consequent action taken?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "In the backdrop of farmers' protests, former US president Barack Obama tweeted an image with Narendra Modi saying he now feels ashamed of shaking hands with him.",
#   'generatedQuestions': [{'question': "Did Barack Obama tweet an image expressing shame over shaking hands with Narendra Modi?'",
#     'questionType': 'Boolean'},
#    {'question': "What was the context of the image shared by Barack Obama regarding Narendra Modi?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the truth about Barack Obama tweeting an image with a statement about Narendra Modi?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'President kovind gives assent to 3 contentious farm bills.',
#   'generatedQuestions': [{'question': "Did President Kovind give assent to the 3 farm bills?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the significance of President Kovind giving assent to the 3 contentious farm bills?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the 3 farm bills that President Kovind gave assent to?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "'Khalistan Zindabad' slogans being raised during Modi’s visit to Punjab on January 5. The PM’s convoy was stopped due to protests some distance away from his scheduled public meeting in Ferozepur.",
#   'generatedQuestions': [{'question': "Were Khalistan Zindabad slogans raised during PM Modis visit to Punjab on January 5?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video showing Khalistan Zindabad slogans during PM Modis visit to Punjab?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the factual basis of the claim that Khalistan Zindabad slogans were raised during PM Modis visit to Punjab on January 5?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Dna special: Adulterated vegetables are affecting our health and wellbeing.',
#   'generatedQuestions': [{'question': "Is it true that adulterated vegetables are affecting our health and wellbeing?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the potential health risks associated with consuming adulterated vegetables as reported in the DNA special?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports the claim that adulterated vegetables are impacting our health and wellbeing as stated in the DNA special?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'India will now start levying GST on school books.',
#   'generatedQuestions': [{'question': "Is it true that GST will be levied on school books in India?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the claim that India will start levying GST on school books?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts regarding the imposition of GST on school books in India?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Gujarat is the only state to have reduced fines under the amended Motor Vehicles Act, 2019.',
#   'generatedQuestions': [{'question': "Is Gujarat the only state to have reduced fines under the amended Motor Vehicles Act, 2019?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the key points about the reduction of fines under the amended Motor Vehicles Act, 2019 in Gujarat as compared to other states?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available about the states that have reduced fines under the amended Motor Vehicles Act, 2019, and where does Gujarat stand?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Schools, colleges in sikkim to reopen on june 15.',
#   'generatedQuestions': [{'question': "Will schools and colleges in Sikkim reopen on June 15?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the source of the information about schools and colleges in Sikkim reopening on June 15?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the official announcement regarding the reopening of schools and colleges in Sikkim?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'BJP flags abandoned in a public waste container in poll-bound Uttar Pradesh.',
#   'generatedQuestions': [{'question': "Were BJP flags found abandoned in a public waste container in poll-bound Uttar Pradesh?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image showing BJP flags in a waste container in Uttar Pradesh?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the truth about the image of BJP flags discarded in a public waste container?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Behind bhagat singh chants at farmers' protest, a century-old left tradition in punjab.",
#   'generatedQuestions': [{'question': 'Is the "Bhagat Singh" chant at the farmers\\\' protest in Punjab a century-old left tradition?\'',
#     'questionType': 'Boolean'},
#    {'question': "What is the historical context of the left tradition in Punjab that is associated with Bhagat Singh and the farmers\\' protest?'",
#     'questionType': 'Abstractive'},
#    {'question': "What role does Bhagat Singh\\'s legacy play in the farmers\\' protest in Punjab and its connection to the left tradition?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Colonel was decorated twice for gallantry.',
#   'generatedQuestions': [{'question': "Was the Colonel decorated twice for gallantry?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the details of the Colonel being decorated twice for gallantry?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports the claim that the Colonel was decorated twice for gallantry?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'The flipkart big billion days sale has 99 per cent discounts on apple watches, refrigerators, smartphones, and more.',
#   'generatedQuestions': [{'question': "Does the Flipkart Big Billion Days sale offer 99 percent discounts on all products?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the authenticity of the claim about 99 percent discounts on Apple watches and other items during the Flipkart Big Billion Days sale?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the actual discounts being offered by Flipkart on products like Apple watches, refrigerators, and smartphones during the Big Billion Days sale?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Due to the ongoing lockdown in Kashmir, a 90-year-old man has not been able to bury the body of his son for two days.',
#   'generatedQuestions': [{'question': "Is the claim about a 90-year-old man unable to bury his son due to the Kashmir lockdown true?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or story about the 90-year-old man and his son in relation to the Kashmir lockdown?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the story of a 90-year-old man being unable to bury his son because of the lockdown in Kashmir?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Pakistan politician Haroon Bilour insulted the tricolour by wrapping it around his shoe. He was later blown away in an explosion by terrorists.',
#   'generatedQuestions': [{'question': "Did Haroon Bilour wrap the Indian tricolour around his shoe?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the image or video of Haroon Bilour allegedly disrespecting the Indian flag?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the fact about the incident involving Haroon Bilour and the Indian tricolour?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'A hamas leader caught in a compromising position with a sex worker in a hotel amid the ongoing conflict in gaza.',
#   'generatedQuestions': [{'question': "Was a Hamas leader caught with a sex worker in a hotel during the Gaza conflict?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video allegedly showing a Hamas leader with a sex worker in a hotel?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence is there to support the claim that a Hamas leader was found in a compromising position with a sex worker in a hotel?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Litmus test for hm amit shah, cm yogi adityanath: congress demands inquiry by sc judge in vikas dubey killing.',
#   'generatedQuestions': [{'question': "Did the Congress demand an inquiry by an SC judge into the Vikas Dubey killing?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the Congress demanding an inquiry into the Vikas Dubey killing, and what roles do Amit Shah and Yogi Adityanath play in this?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the truth about the claim that the Vikas Dubey killing is a litmus test for Amit Shah and Yogi Adityanath?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Brahmins in UP's Bundelkhand region cut off the tongue of a class 8 girl and offered it as sacrifice to Lord Shiva to save their village from coronavirus.",
#   'generatedQuestions': [{'question': "Did Brahmins in UP\\'s Bundelkhand region cut off the tongue of a class 8 girl as a sacrifice to Lord Shiva?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the origin of the claim that a class 8 girl was subjected to an inhumane act to save a village from coronavirus in UP\\'s Bundelkhand region?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the factual basis for the claim of a horrific incident involving a class 8 girl in UP\\'s Bundelkhand region in relation to coronavirus?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Social activist Teesta Setalvad spitting at cops.',
#   'generatedQuestions': [{'question': "Is the video of Teesta Setalvad spitting at cops authentic?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the video shared on social media showing Teesta Setalvad spitting at cops?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the claim that Teesta Setalvad spat at police officers?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Haryana redesignates body for microirrigation projects.',
#   'generatedQuestions': [{'question': "Did Haryana redesignate a body for microirrigation projects?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the purpose of the body redesignated by Haryana for microirrigation projects?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available about Haryana redesignating a body for microirrigation projects?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Tension along the Assam-Bangladesh border. Massive protests by Hindus of Assam against the anti-minority violence in Bangladesh. Red alert issued in Muslim-majority areas of Assam.',
#   'generatedQuestions': [{'question': "Is there a red alert issued in Muslim-majority areas of Assam due to protests?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the massive protests by Hindus of Assam against anti-minority violence in Bangladesh?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts regarding the tension along the Assam-Bangladesh border and the alleged anti-minority violence in Bangladesh?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'The Chinese laboratory in Wuhan where coronavirus emerged is owned by GlaxoSmithKline (GSK). The same GSK also owns Pfizer, the pharma company that produces the vaccine for the virus.',
#   'generatedQuestions': [{'question': "Is the Wuhan laboratory where coronavirus emerged owned by GlaxoSmithKline?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the implications of GlaxoSmithKline owning the Wuhan laboratory and its connection to Pfizer vaccine production?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports or refutes the claim that GlaxoSmithKline owns the Wuhan laboratory and Pfizer?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Parliament house bans washing of utensils, lunch boxes.',
#   'generatedQuestions': [{'question': "Is it true that the Parliament house has banned washing of utensils and lunch boxes?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind the alleged ban on washing utensils and lunch boxes in the Parliament house?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts regarding the Parliament house\\'s policy on washing utensils and lunch boxes?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Kerala hc serves notice to actor mohanlal in possession of ivory case.',
#   'generatedQuestions': [{'question': "Did the Kerala High Court serve a notice to actor Mohanlal in an ivory possession case?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or report about Mohanlal being served a notice by the Kerala High Court in the ivory possession case?'",
#     'questionType': 'Abstractive'},
# ...
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Kolkata's fd block durga puja organisers smell conspiracy after pandal gutted in fire.",
#   'generatedQuestions': [{'question': "Was a Durga Puja pandal in Kolkata\\'s FD Block gutted in a fire?",
#     'questionType': 'Boolean'},
#    {'question': "What is the nature of the fire incident at the FD Block Durga Puja pandal in Kolkata as claimed by the organisers?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence do the organisers of the FD Block Durga Puja in Kolkata have to claim a conspiracy behind the fire incident?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'People using an oxygen concentrator should keep doors and windows open as it extracts oxygen from open air. It is harmful to shut the room and turn on AC while using a concentrator.',
#   'generatedQuestions': [{'question': "Is it necessary to keep doors and windows open while using an oxygen concentrator?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the recommended usage guidelines for an oxygen concentrator in a closed room with air conditioning?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the potential risks or consequences of using an oxygen concentrator in a sealed room with the air conditioner turned on?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Mumbai cop dies of coronavirus, 9th death in city police force.',
#   'generatedQuestions': [{'question': "Did a Mumbai cop die from coronavirus?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image shared about a Mumbai cop dying from coronavirus?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available about the death of a Mumbai cop due to coronavirus?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'TMC mp nusrat jahan gets death threats for posing as goddess durga, seeks security for uk trip',
#   'generatedQuestions': [{'question': "Did TMC MP Nusrat Jahan receive death threats for posing as Goddess Durga?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context behind TMC MP Nusrat Jahan seeking security for her UK trip?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the details about the death threats received by TMC MP Nusrat Jahan for posing as Goddess Durga?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Stubble fires surge in punjab, haryana; delhi feels the choke',
#   'generatedQuestions': [{'question': "Are stubble fires in Punjab and Haryana the primary cause of air pollution in Delhi?'",
#     'questionType': 'Boolean'},
#    {'question': "What are the effects of stubble fires in Punjab and Haryana on the air quality in Delhi, as seen in recent reports?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence is there to support the claim that stubble fires in Punjab and Haryana are contributing to air pollution in Delhi?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'The discovery of this strange looking mummy only strengthens the belief that aliens visited ancient Egypt. Scientists cannot explain anything about this mummy which was uncovered by Dr. Victor Lubeck, a retired professor from the University of Pennsylvania.',
#   'generatedQuestions': [{'question': "Is the mummy discovered by Dr. Victor Lubeck evidence of alien visitation in ancient Egypt?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the significance of the mummy uncovered by Dr. Victor Lubeck in relation to the theory of alien visits to ancient Egypt?'",
#     'questionType': 'Abstractive'},
#    {'question': "What facts are known about the strange-looking mummy discovered by Dr. Victor Lubeck that support or refute the claim of alien visitation in ancient Egypt?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Gujarat: five covid-19 patients killed in fire at rajkot hospital, cm rupani orders probe',
#   'generatedQuestions': [{'question': "Did five COVID-19 patients die in a fire at a hospital in Rajkot, Gujarat?'",
#     'questionType': 'Boolean'},
#    {'question': "What were the circumstances surrounding the fire at the Rajkot hospital that resulted in the deaths of COVID-19 patients?'",
#     'questionType': 'Abstractive'},
#    {'question': "What information is available about the fire incident at the hospital in Rajkot where COVID-19 patients lost their lives?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Four booked for offering namaz in UP temple.',
#   'generatedQuestions': [{'question': "Were four people booked for offering namaz in a UP temple?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or video shared on social media about people being booked for offering namaz in a UP temple?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the incident of people being booked for offering namaz in a UP temple?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Dmk mla says he opened fire in self-defense.',
#   'generatedQuestions': [{'question': "Did the DMK MLA open fire in self-defense?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the DMK MLA claiming to have opened fire in self-defense?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the DMK MLA opening fire, was it indeed in self-defense?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "'modi-modi' chants were raised during donald trump’s victory speech.",
#   'generatedQuestions': [{'question': 'Were "modi-modi" chants raised during Donald Trump’s victory speech?\'',
#     'questionType': 'Boolean'},
#    {'question': 'What was the context of the "modi-modi" chants during Donald Trump’s victory speech as seen on social media?\'',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the "modi-modi" chants during Donald Trump’s victory speech?\'',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'Queen Elizabeth II flinging food at children in one of Africa’s British colonies.',
#   'generatedQuestions': [{'question': "Is the claim that Queen Elizabeth II flinging food at children in one of Africa’s British colonies true?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the origin of the image or video showing Queen Elizabeth II interacting with children in a British colony in Africa?'",
#     'questionType': 'Abstractive'},
#    {'question': "What evidence supports or refutes the claim that Queen Elizabeth II was involved in an incident of flinging food at children in a British colony in Africa?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Chinese President Xi Jinping, US President-elect Joe Biden, and US Vice-President-elect Kamala Harris have been named Time magazine's 'Person of the Year' for 2020.",
#   'generatedQuestions': [{'question': 'Was Joe Biden named Time magazine\\\'s "Person of the Year" for 2020?\'',
#     'questionType': 'Boolean'},
#    {'question': 'What was the reason behind Time magazine naming Joe Biden, Kamala Harris, and Xi Jinping as "Person of the Year" in 2020?\'',
#     'questionType': 'Abstractive'},
#    {'question': 'Who were the individuals named Time magazine\\\'s "Person of the Year" for 2020, and what were their achievements?\'',
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'An 86-year-old muslim man sexually assaulting a seven-year-old girl in an agricultural field.',
#   'generatedQuestions': [{'question': "Did an 86-year-old Muslim man sexually assault a 7-year-old girl in an agricultural field?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the image or report shared on social media about an 86-year-old man and a 7-year-old girl in an agricultural field?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the facts surrounding the alleged incident of an 86-year-old man sexually assaulting a minor in a field?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': "Khap panchayat in UP ordered Dalit sisters to be raped and paraded naked around the village under Yogi Adityanath's rule.",
#   'generatedQuestions': [{'question': "Did a Khap panchayat in UP order Dalit sisters to be raped under Yogi Adityanath\\'s rule?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the origin of the image or report shared on social media about the Khap panchayat ordering Dalit sisters to be raped and paraded naked in UP?'",
#     'questionType': 'Abstractive'},
#    {'question': "What is the factual basis of the claim regarding the Khap panchayat\\'s alleged order to rape and parade Dalit sisters naked in a village in UP during Yogi Adityanath\\'s rule?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  {'claim': 'SC rejects plea of former IAF officer seeking bail in spying case',
#   'generatedQuestions': [{'question': "Did the Supreme Court reject the bail plea of a former IAF officer in a spying case?'",
#     'questionType': 'Boolean'},
#    {'question': "What is the context of the Supreme Court rejecting the bail plea of a former IAF officer in the spying case?'",
#     'questionType': 'Abstractive'},
#    {'question': "What are the key facts about the Supreme Court decision on the bail plea of the former IAF officer accused of spying?'",
#     'questionType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Did 12 BSF jawans die in a bus accident in Meghalaya on February 19, 2022?',
#     'questionType': 'Boolean'},
#    {'question': 'Was the image shared on social media from the February 2022 Meghalaya bus accident involving BSF jawans?',
#     'questionType': 'Abstractive'},
#    {'question': 'What is the truth about the image showing BSF jawans injured in a bus accident?',
#     'questionType': 'Extractive'}]},
#  ...]

# %%
import numpy as np

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences

    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    try:
      row_ind, col_ind = linear_sum_assignment(cost_matrix)
    except ValueError as e:
      print(f"ravi,{generated_sequences},{reference_sequences},{scores}")
    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))


for data in new_data:
  generated_sequences = [question['question'] for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question'] for question in data['goldQuestions']]
  if not generated_sequences or not reference_sequences:
      continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Total METEOR Score (normalized): 0.1313
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the image of a woman donating bundles of cash in Ayodhya\'s Ram Mandir real?'
# Best METEOR Score: 0.2632
# Generated Question 2: What is the context of the image shared on social media showing a woman donating bundles of cash in Ayodhya\'s Ram Mandir?'
# Best METEOR Score: 0.4536
# Generated Question 3: What is the fact about the image of the woman donating cash in Ayodhya\'s Ram Mandir?'
# Best METEOR Score: 0.3264
# Total METEOR Score (normalized): 0.2717
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was Salman Khan a background dancer at the Nita Mukesh Ambani Cultural Centre launch event?'
# Best METEOR Score: 0.0932
# Generated Question 2: What is the context of the video or image showing Salman Khan dancing at the Nita Mukesh Ambani Cultural Centre launch event?'
# Best METEOR Score: 0.3407
# Generated Question 3: What is the fact about Salman Khan being seen dancing as a background dancer at the Nita Mukesh Ambani Cultural Centre launch event?'
# Best METEOR Score: 0.3387
# Total METEOR Score (normalized): 0.1684
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a Covid patient jump to death from a hospital in Rajasthan?'
# Best METEOR Score: 0.1198
# Generated Question 2: Was the incident of a Covid patient jumping to death from a Rajasthan hospital reported in the news?'
# Best METEOR Score: 0.2044
# Generated Question 3: What are the facts surrounding the incident of a Covid patient jumping to death from a hospital in Rajasthan?'
# Best METEOR Score: 0.1818
# Total METEOR Score (normalized): 0.1687
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are there heavy floods in the Palestinian city of Jericho?'
# Best METEOR Score: 0.0962
# Generated Question 2: What is the origin of the image shared on social media showing heavy floods in Jericho?'
# Best METEOR Score: 0.4335
# Generated Question 3: What is the current situation regarding flooding in the Palestinian city of Jericho?'
# Best METEOR Score: 0.3215
# Total METEOR Score (normalized): 0.2662
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Phoolka post about Paswan providing refuge to a Sikh man during the 1984 riots?'
# Best METEOR Score: 0.1242
# Generated Question 2: What is the context of Phoolka sharing information about Paswan’s efforts during the 1984 riots on social media?'
# Best METEOR Score: 0.3111
# Generated Question 3: What information did Phoolka share about Paswan’s role in helping a Sikh man during the 1984 riots?'
# Best METEOR Score: 0.1818
# Total METEOR Score (normalized): 0.1937
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Sanjay Raut claim that chickens fed herbal food produce vegetarian Ayurvedic eggs?'
# Best METEOR Score: 0.0595
# Generated Question 2: What is the context of Sanjay Raut saying chickens who eat herbal food produce vegetarian Ayurvedic eggs?'
# Best METEOR Score: 0.1936
# Generated Question 3: What is the truth behind Sanjay Raut\'s statement about herbal food producing vegetarian Ayurvedic eggs in chickens?'
# Best METEOR Score: 0.2924
# Total METEOR Score (normalized): 0.1357
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a crab catcher killed in a tiger attack in Bengal\'s Sundarbans?'
# Best METEOR Score: 0.1879
# Generated Question 2: What is the context of the image shared on social media about a crab catcher being killed by a tiger in Bengal\'s Sundarbans?'
# Best METEOR Score: 0.4510
# Generated Question 3: What are the facts about the incident of a crab catcher being killed in a tiger attack in Bengal\'s Sundarbans?'
# Best METEOR Score: 0.2872
# Total METEOR Score (normalized): 0.2913
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim that US President Joe Biden touched his granddaughter in an inappropriate manner true?'
# Best METEOR Score: 0.1235
# Generated Question 2: What is the context of the image or video showing US President Joe Biden with his granddaughter that is being shared on social media?
# Best METEOR Score: 0.3756
# Generated Question 3: What evidence is there to support or refute the claim that US President Joe Biden touched his granddaughter inappropriately?'
# Best METEOR Score: 0.1212
# Total METEOR Score (normalized): 0.1851
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did India record the highest single-day spike in COVID-19 cases worldwide?'
# Best METEOR Score: 0.1274
# Generated Question 2: What is the context of the image shared on social media regarding India recording the highest single-day spike in COVID-19 cases?'
# Best METEOR Score: 0.4210
# Generated Question 3: What is the actual number of COVID-19 cases in India when it recorded the highest single-day spike?'
# Best METEOR Score: 0.3512
# Total METEOR Score (normalized): 0.2875
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are the images of fishes inside a flooded house in Hyderabad genuine?'
# Best METEOR Score: 0.2354
# Generated Question 2: What is the context of the image showing fishes inside a flooded house in Hyderabad?'
# Best METEOR Score: 0.5111
# Generated Question 3: What is the fact about the image of fishes inside a house during Hyderabad rains?'
# Best METEOR Score: 0.4658
# Total METEOR Score (normalized): 0.2375
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did an IED blast occur at a Kalyan Jewelers showroom in Bellary, Karnataka?'
# Best METEOR Score: 0.1479
# Generated Question 2: What is the context of the image shared on social media related to the Kalyan Jewelers showroom incident in Bellary, Karnataka?'
# Best METEOR Score: 0.4188
# Generated Question 3: What are the facts about the reported IED blast at the Kalyan Jewelers showroom in Bellary, Karnataka?'
# Best METEOR Score: 0.1829
# Total METEOR Score (normalized): 0.2499
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it true that most of the names inscribed on India Gate are of Muslim freedom fighters?'
# Best METEOR Score: 0.1227
# Generated Question 2: What is the significance of the number of Muslim names inscribed on India Gate in the context of India\'s freedom struggle?'
# Best METEOR Score: 0.2538
# Generated Question 3: What percentage of the names on India Gate are of Muslim freedom fighters according to the given claim?'
# Best METEOR Score: 0.1220
# Total METEOR Score (normalized): 0.1406
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the RBI keep the repo rate unchanged?'
# Best METEOR Score: 0.0974
# Generated Question 2: What is the significance of the RBI maintaining an accommodative stance and keeping the repo rate unchanged?'
# Best METEOR Score: 0.2282
# Generated Question 3: What are the key takeaways from the RBI decision to maintain the repo rate and reverse repo rate at their current levels?'
# Best METEOR Score: 0.1190
# Total METEOR Score (normalized): 0.1324
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Donald Trump ever meet or shake hands with Osama bin Laden?'
# Best METEOR Score: 0.0599
# Generated Question 2: What is the origin of the image allegedly showing Donald Trump shaking hands with Osama bin Laden?'
# Best METEOR Score: 0.3894
# Generated Question 3: Is there any credible evidence to support the claim that Donald Trump praised Osama bin Laden as a great man?'
# Best METEOR Score: 0.1205
# Total METEOR Score (normalized): 0.1679
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the Afghanistan cricket team chant "Vande Mataram" after qualifying for the T20 World Cup semifinals?'
# Best METEOR Score: 0.0915
# Generated Question 2: What is the origin of the image or video showing the Afghanistan cricket team chanting "Vande Mataram" after qualifying for the T20 World Cup semifinals?'
# Best METEOR Score: 0.2772
# Generated Question 3: What is the fact about the Afghanistan cricket team chanting "Vande Mataram" after their T20 World Cup semifinals qualification?'
# Best METEOR Score: 0.3368
# Total METEOR Score (normalized): 0.1664
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Supreme Court reject a plea against the Justice Chauhan inquiry commission in the Vikas Dubey encounter case?'
# Best METEOR Score: 0.1515
# Generated Question 2: What are the implications of the Supreme Court rejecting the plea against the Justice Chauhan inquiry commission in the Vikas Dubey encounter case?'
# Best METEOR Score: 0.1479
# Generated Question 3: What details did the Supreme Court provide while rejecting the plea against the Justice Chauhan inquiry commission in the Vikas Dubey encounter case?'
# Best METEOR Score: 0.1479
# Total METEOR Score (normalized): 0.1144
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is JD(U) concerned that the BJP will repeat its Maharashtra strategy after the 2020 Bihar polls?'
# Best METEOR Score: 0.1212
# Generated Question 2: What is the context behind JD(U) worrying about BJP repeating its actions in Maharashtra after the Bihar polls in 2020?'
# Best METEOR Score: 0.3387
# Generated Question 3: What evidence is there to support the claim that JD(U) is fretting about BJP repeating the Maharashtra drama after the 2020 Bihar polls?'
# Best METEOR Score: 0.1744
# Total METEOR Score (normalized): 0.1494
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Sonia Gandhi lead a Congress protest against Maharashtra government formation in parliament?'
# Best METEOR Score: 0.1190
# Generated Question 2: What was the context of the image or video of Sonia Gandhi protesting against Maharashtra government formation in parliament that is being shared on social media?'
# Best METEOR Score: 0.4331
# Generated Question 3: What are the facts about Sonia Gandhi and the Congress party\'s stance on the Maharashtra government formation, and what was her role in the protest in parliament?'
# Best METEOR Score: 0.1714
# Total METEOR Score (normalized): 0.2412
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has unsold beer in Australia been converted into renewable energy during the coronavirus lockdown?'
# Best METEOR Score: 0.0938
# Generated Question 2: What is the story behind the unsold beer in Australia being turned into renewable energy during the lockdown?'
# Best METEOR Score: 0.2600
# Generated Question 3: What is the process by which unsold beer in Australia is being transformed into renewable energy?'
# Best METEOR Score: 0.1543
# Total METEOR Score (normalized): 0.1249
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did JP Nadda return without attending an event in Bengal's Jhargram?'
# Best METEOR Score: 0.0898
# Generated Question 2: What was the reason behind JP Nadda not attending the event in Jhargram, Bengal as shared on social media?'
# Best METEOR Score: 0.4076
# Generated Question 3: What is the truth about JP Nadda returning from Bengal's Jhargram without attending the scheduled event?'
# Best METEOR Score: 0.4125
# Total METEOR Score (normalized): 0.3033
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Sadhguru\'s event in March lead to over 1,000 corona cases in Tamil Nadu?'
# Best METEOR Score: 0.1176
# Generated Question 2: Is the image shared on social media of foreigners attending Sadhguru\'s event in March, which supposedly caused a surge in corona cases, genuine?'
# Best METEOR Score: 0.3539
# Generated Question 3: What is the actual number of corona cases in Tamil Nadu that can be attributed to Sadhguru\'s event in March?'
# Best METEOR Score: 0.2228
# Total METEOR Score (normalized): 0.2314
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a tiger carcass found in a Goa forest?'
# Best METEOR Score: 0.1649
# Generated Question 2: What is the context of the tiger carcass discovery in the Goa forest as shared on social media?'
# Best METEOR Score: 0.3487
# Generated Question 3: What information is available about the discovery of a tiger carcass in a Goa forest?'
# Best METEOR Score: 0.3556
# Total METEOR Score (normalized): 0.2653
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Do AAP leaders change their attire based on the region they are campaigning in?'
# Best METEOR Score: 0.0938
# Generated Question 2: What is the significance of AAP leaders wearing saffron scarves in UP and observing Muslim rituals in Delhi during elections?'
# Best METEOR Score: 0.2241
# Generated Question 3: What is the truth behind the claim that AAP leaders adapt their rituals and attire to suit the local electorate during elections?'
# Best METEOR Score: 0.2538
# Total METEOR Score (normalized): 0.1413
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did China seek Supreme Court approval to euthanize coronavirus patients?'
# Best METEOR Score: 0.0606
# Generated Question 2: What is the origin of the claim that China sought to euthanize 20,000 coronavirus patients, and is the image or report shared on social media related to this claim?'
# Best METEOR Score: 0.3620
# Generated Question 3: What is the factual basis for the claim that China sought approval to euthanize 20,000 coronavirus patients, and what evidence supports or refutes this claim?'
# Best METEOR Score: 0.2163
# Total METEOR Score (normalized): 0.2130
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Indian government arrange a flight for 354 stranded migrant workers from Bengaluru to Chhattisgarh?'
# Best METEOR Score: 0.0926
# Generated Question 2: What is the context of the report about 354 migrant workers being flown from Bengaluru to Chhattisgarh?'
# Best METEOR Score: 0.3136
# Generated Question 3: What are the key details about the flight arranged for migrant workers from Bengaluru to Chhattisgarh?'
# Best METEOR Score: 0.2296
# Total METEOR Score (normalized): 0.1708
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Yogi Adityanath’s UP government shower flower petals on Hindu devotees from a helicopter during the 2022 Hindu New Year celebration?'
# Best METEOR Score: 0.1404
# Generated Question 2: What is the context of the image or video showing a helicopter showering flower petals on Hindu devotees during the 2022 Hindu New Year celebration?'
# Best METEOR Score: 0.3111
# Generated Question 3: What is the truth behind the claim that Yogi Adityanath’s UP government used a helicopter to shower flower petals on Hindu devotees during the 2022 Hindu New Year celebration?'
# Best METEOR Score: 0.2710
# Total METEOR Score (normalized): 0.2123
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim about a young child in Gaza narrating the difficulty of life amid the Israel-Hamas war true?'
# Best METEOR Score: 0.2121
# Generated Question 2: What is the context of the image or video of a young child in Gaza discussing the challenges of life during the Israel-Hamas war?'
# Best METEOR Score: 0.3130
# Generated Question 3: What information can be verified about the young child in Gaza who shared their experience of living through the Israel-Hamas conflict?'
# Best METEOR Score: 0.1796
# Total METEOR Score (normalized): 0.1691
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did UPJEE 2019 online registration for direct admissions start on the given date?'
# Best METEOR Score: 0.0893
# Generated Question 2: What is the process to apply for UPJEE 2019 online registration for direct admissions as per the given information?'
# Best METEOR Score: 0.3098
# Generated Question 3: What are the key details about the UPJEE 2019 online registration for direct admissions, including the deadline and website?'
# Best METEOR Score: 0.1506
# Total METEOR Score (normalized): 0.1602
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did CDS Gen. Bipin Rawat recommend the removal of Gen. MM Naravane as Army Chief in a letter to PM Modi?'
# Best METEOR Score: 0.1890
# Generated Question 2: What are the details of the letter supposedly written by Defence Minister Rajnath Singh to PM Modi regarding Gen. MM Naravane?'
# Best METEOR Score: 0.1198
# Generated Question 3: What is the truth behind the claim that Gen. MM Naravane is being considered for removal as Army Chief over the Ladakh crisis?'
# Best METEOR Score: 0.2071
# Total METEOR Score (normalized): 0.1339
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the image of people jostling to enter a cinema hall in Saudi Arabia related to the inauguration by Crown Prince Mohammed bin Salman?'
# Best METEOR Score: 0.2821
# Generated Question 2: What is the context of the image showing people jostling to enter a cinema hall in Saudi Arabia, particularly in relation to the movie being shown?'
# Best METEOR Score: 0.3978
# Generated Question 3: What is the truth about the movie being shown at the cinema hall in Saudi Arabia where people are jostling to enter, specifically regarding its origin?'
# Best METEOR Score: 0.3978
# Total METEOR Score (normalized): 0.2344
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did BSP supremo Mayawati urge voters to vote for the BJP in the UP assembly polls?'
# Best METEOR Score: 0.1235
# Generated Question 2: What is the context behind BSP supremo Mayawati allegedly asking voters to not elect radical Muslims and instead vote for the BJP?'
# Best METEOR Score: 0.2655
# Generated Question 3: What are the facts about BSP supremo Mayawati statement on voting for the BJP in the UP assembly polls?'
# Best METEOR Score: 0.1818
# Total METEOR Score (normalized): 0.1542
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did PM Modi receive a gold chain from a sheikh during the Nupur Sharma controversy?'
# Best METEOR Score: 0.0932
# Generated Question 2: What is the context behind the image of PM Modi receiving a gold chain from a sheikh that is being shared on social media?'
# Best METEOR Score: 0.4078
# Generated Question 3: What are the facts surrounding the claim that PM Modi was gifted a gold chain by a sheikh amidst the Nupur Sharma controversy?'
# Best METEOR Score: 0.1479
# Total METEOR Score (normalized): 0.2147
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Nitish Kumar abandon Bihari workers during the coronavirus pandemic?'
# Best METEOR Score: 0.0641
# Generated Question 2: What is the context behind the criticism of Nitish Kumar by the opposition regarding his response to the coronavirus pandemic in Bihar?'
# Best METEOR Score: 0.2538
# Generated Question 3: What are the facts behind the claim that Nitish Kumar dumped Bihari workers and his allies during the COVID-19 crisis?'
# Best METEOR Score: 0.1205
# Total METEOR Score (normalized): 0.1320
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a man from Gujarat kill his live-in partner and daughter with a stick?'
# Best METEOR Score: 0.0888
# Generated Question 2: What is the context of the image shared on social media about a Gujarat man allegedly murdering his live-in partner and daughter?'
# Best METEOR Score: 0.4181
# Generated Question 3: What are the facts about the incident where a Gujarat man allegedly hacked his live-in partner and daughter to death?'
# Best METEOR Score: 0.2569
# Total METEOR Score (normalized): 0.2496
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the road in PM Modi’s parliamentary constituency, Varanasi, filled with sewage water?'
# Best METEOR Score: 0.1227
# Generated Question 2: What is the current condition of the roads in Varanasi, recently awarded the cleanest Ganga town?'
# Best METEOR Score: 0.2616
# Generated Question 3: What is the truth behind the image of a dug-up road filled with sewage water in Varanasi?'
# Best METEOR Score: 0.5048
# Total METEOR Score (normalized): 0.2250
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the CPM promise to scrap the sedition law in their election manifesto?'
# Best METEOR Score: 0.1258
# Generated Question 2: What are the key highlights of the CPM election manifesto, including their stance on unemployment allowance and sedition law?'
# Best METEOR Score: 0.1205
# Generated Question 3: What specific measures has the CPM proposed in their election manifesto to address unemployment and reform laws like sedition?'
# Best METEOR Score: 0.1212
# Total METEOR Score (normalized): 0.1064
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it mandatory to link voter ID with Aadhaar to avoid deletion from the voter list?'
# Best METEOR Score: 0.1420
# Generated Question 2: What are the implications of not linking voter ID with Aadhaar on the voter list status, as shared on social media?'
# Best METEOR Score: 0.3412
# Generated Question 3: What is the official information regarding the requirement to link voter ID with Aadhaar to retain voter list enrollment?'
# Best METEOR Score: 0.2703
# Total METEOR Score (normalized): 0.2136
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a tiger in Maharashtra claim its 8th human victim?'
# Best METEOR Score: 0.1212
# Generated Question 2: How does the recent tiger attack in Maharashtra compare to the Avni case in terms of challenges faced by the forest department?'
# Best METEOR Score: 0.1190
# Generated Question 3: What are the key similarities between the recent Maharashtra tiger attacks and the Avni case that pose a challenge to the forest department?'
# Best METEOR Score: 0.1479
# Total METEOR Score (normalized): 0.1166
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the government distribute 35,000 crore LED bulbs in the country as claimed by Nirmala Sitharaman?'
# Best METEOR Score: 0.1543
# Generated Question 2: Is the image shared on social media related to the distribution of 35,000 crore LED bulbs by the government as claimed by Nirmala Sitharaman?'
# Best METEOR Score: 0.3989
# Generated Question 3: What is the factual accuracy of Nirmala Sitharaman\'s claim about distributing 35,000 crore LED bulbs in the country?'
# Best METEOR Score: 0.3469
# Total METEOR Score (normalized): 0.2876
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did NASA predict a strong earthquake in Delhi-NCR between April 7-15, 2020?'
# Best METEOR Score: 0.1488
# Generated Question 2: What is the origin of the claim about NASA predicting an earthquake in Delhi-NCR in April 2020?'
# Best METEOR Score: 0.3512
# Generated Question 3: What is the factual basis for the claim that NASA issued an earthquake prediction for Delhi-NCR in 2020?'
# Best METEOR Score: 0.3117
# Total METEOR Score (normalized): 0.1941
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Tariq Anwar join the Congress party after leaving the Nationalist Congress Party?'
# Best METEOR Score: 0.0943
# Generated Question 2: What is the significance of Tariq Anwar switching from the Nationalist Congress Party to the Congress party?'
# Best METEOR Score: 0.2282
# Generated Question 3: What is the background and context behind Tariq Anwar leaving the Nationalist Congress Party to join the Congress party?'
# Best METEOR Score: 0.2255
# Total METEOR Score (normalized): 0.1318
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will heavy to very heavy rains occur over western coast and central India from August 3-5, 2022?'
# Best METEOR Score: 0.1702
# Generated Question 2: What is the forecast for the western coast and central India from August 3-5, 2022, according to the IMD?'
# Best METEOR Score: 0.2228
# Generated Question 3: What specific dates are mentioned in the IMD forecast for heavy to very heavy rains over western coast and central India?'
# Best METEOR Score: 0.1198
# Total METEOR Score (normalized): 0.1490
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Will the GDP contract by 9.6% as predicted?'
# Best METEOR Score: 0.0968
# Generated Question 2: What are the implications of a 9.6% contraction in GDP as stated by the World Bank?'
# Best METEOR Score: 0.1840
# Generated Question 3: What is the World Bank's forecast for the GDP contraction rate?'
# Best METEOR Score: 0.2823
# Total METEOR Score (normalized): 0.1424
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it true that covid cases per day have dropped in Gujarat?'
# Best METEOR Score: 0.0949
# Generated Question 2: What is the current trend of covid cases in Gujarat, as per the latest reports?'
# Best METEOR Score: 0.3534
# Generated Question 3: What are the key factors contributing to the decline in daily covid cases in Gujarat?'
# Best METEOR Score: 0.1553
# Total METEOR Score (normalized): 0.1657
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the UP government handling the Hathras case in an unethical manner?'
# Best METEOR Score: 0.2354
# Generated Question 2: How have Congress leaders Rahul and Priyanka Gandhi responded to the UP government\'s handling of the Hathras case?'
# Best METEOR Score: 0.0909
# Generated Question 3: What are the specific allegations made by Rahul and Priyanka Gandhi against the UP government regarding the Hathras case?'
# Best METEOR Score: 0.1212
# Total METEOR Score (normalized): 0.1154
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is it true that Uttar Pradesh and Bihar were the worst in COVID-19 reporting across India according to a Stanford study?'
# Best METEOR Score: 0.1497
# Generated Question 2: What does the Stanford study reveal about the COVID-19 reporting in Uttar Pradesh and Bihar compared to other states in India?'
# Best METEOR Score: 0.2553
# Generated Question 3: What are the key findings of the Stanford study regarding COVID-19 reporting in Uttar Pradesh and Bihar?'
# Best METEOR Score: 0.1534
# Total METEOR Score (normalized): 0.1411
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Was a cyclist attacked by a tiger on the Rishikesh-Dehradun road?'
# Best METEOR Score: 0.1143
# Generated Question 2: Can you describe the incident where a cyclist was allegedly attacked by a tiger on the Rishikesh-Dehradun road?'
# Best METEOR Score: 0.1374
# Generated Question 3: What are the facts about the reported tiger attack on a cyclist on the Rishikesh-Dehradun road?'
# Best METEOR Score: 0.1852
# Total METEOR Score (normalized): 0.1376
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did BJP workers vandalize their own party office over oxygen shortage?'
# Best METEOR Score: 0.0602
# Generated Question 2: Is the image shared on social media of BJP workers vandalising their party office due to oxygen shortage authentic?'
# Best METEOR Score: 0.3675
# Generated Question 3: What is the fact about the incident where BJP workers allegedly vandalized their own party office?'
# Best METEOR Score: 0.3472
# Total METEOR Score (normalized): 0.2583
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did 77 people die in flash floods and heavy rains in Pakistan\'s Baluchistan province?'
# Best METEOR Score: 0.2188
# Generated Question 2: Is the image shared on social media of a flooded river in Pakistan\'s Baluchistan province where 77 people died in flash floods?'
# Best METEOR Score: 0.3596
# Generated Question 3: What is the truth about the claim of 77 deaths in flash floods and heavy rains in Pakistan\'s Baluchistan province?'
# Best METEOR Score: 0.4664
# Total METEOR Score (normalized): 0.3483
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Kangana Ranaut celebrating Vijay Diwas with BSF jawans this year?'
# Best METEOR Score: 0.2010
# Generated Question 2: What is the context of the image of Kangana Ranaut with BSF jawans on social media?'
# Best METEOR Score: 0.4630
# Generated Question 3: What is the reality behind the claim of Kangana Ranaut celebrating Vijay Diwas with BSF jawans?'
# Best METEOR Score: 0.3918
# Total METEOR Score (normalized): 0.3239
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the autopsy report of West Bengal MLA Debendra Nath Ray confirm death by hanging?'
# Best METEOR Score: 0.0621
# Generated Question 2: What are the findings of the autopsy report on the cause of death of West Bengal MLA Debendra Nath Ray?'
# Best METEOR Score: 0.1205
# Generated Question 3: What does the autopsy report reveal about the circumstances surrounding the death of West Bengal MLA Debendra Nath Ray?'
# Best METEOR Score: 0.1515
# Total METEOR Score (normalized): 0.1063
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did 20,000 bikers in Germany rally to cheer up a six-year-old cancer patient?'
# Best METEOR Score: 0.1190
# Generated Question 2: What is the context of the image shared on social media about the German bikers rallying for a cancer patient?'
# Best METEOR Score: 0.4233
# Generated Question 3: What are the facts about the German bikers rally for the six-year-old cancer patient?'
# Best METEOR Score: 0.1562
# Total METEOR Score (normalized): 0.2329
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the United States of America recently pass a bill recognizing the Hindu New Year?'
# Best METEOR Score: 0.1242
# Generated Question 2: What is the context behind the claim that the United States of America passed a bill recognizing the Hindu New Year?'
# Best METEOR Score: 0.2553
# Generated Question 3: What are the facts about the bill passed by the United States of America regarding the recognition of the Hindu New Year?'
# Best METEOR Score: 0.1488
# Total METEOR Score (normalized): 0.1512
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did people protest naked in Manipur following the incident of nude women being paraded?'
# Best METEOR Score: 0.0938
# Generated Question 2: What is the context of the image or video showing people protesting naked in Manipur?'
# Best METEOR Score: 0.4362
# Generated Question 3: What is the fact about the protest in Manipur where people allegedly protested naked?'
# Best METEOR Score: 0.3967
# Total METEOR Score (normalized): 0.2031
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are the soldiers in the image Russian soldiers checking dead Ukrainian soldiers?'
# Best METEOR Score: 0.2354
# Generated Question 2: What is the context of the image showing soldiers checking dead bodies?'
# Best METEOR Score: 0.4256
# Generated Question 3: What is the origin of the image showing soldiers inspecting dead bodies?'
# Best METEOR Score: 0.4256
# Total METEOR Score (normalized): 0.1997
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Hima Das win a gold medal in the women\'s 400-metre race at the Commonwealth Games 2022?'
# Best METEOR Score: 0.2150
# Generated Question 2: What is the context of Hima Das winning a gold medal in the women\'s 400-metre race at the Commonwealth Games 2022 as shared on social media?'
# Best METEOR Score: 0.3677
# Generated Question 3: What is the factual information about Hima Das winning a gold medal in the women\'s 400-metre race at the Commonwealth Games 2022?'
# Best METEOR Score: 0.3148
# Total METEOR Score (normalized): 0.2992
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are there 24 fake universities listed by the UGC?'
# Best METEOR Score: 0.0645
# Generated Question 2: What is the significance of UGC listing 24 fake universities, particularly in UP and Delhi, on the educational landscape?'
# Best METEOR Score: 0.3061
# Generated Question 3: How many fake universities are there in UP and Delhi according to the UGC list?'
# Best METEOR Score: 0.0932
# Total METEOR Score (normalized): 0.1409
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Are BJP workers protesting outside the residences of Delhi government ministers?'
# Best METEOR Score: 0.0637
# Generated Question 2: What is the context of the BJP workers protest outside the residences of Delhi government ministers?'
# Best METEOR Score: 0.2296
# Generated Question 3: What is the issue that led to BJP workers protesting outside the residences of Delhi government ministers?'
# Best METEOR Score: 0.2736
# Total METEOR Score (normalized): 0.1290
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Tulsi Gabbard running for the US presidency?'
# Best METEOR Score: 0.0974
# Generated Question 2: What are Tulsi Gabbard\'s views on gay sex and abortion that are relevant to her presidential campaign?'
# Best METEOR Score: 0.0610
# Generated Question 3: What are the key issues, including gay sex and abortion, that define Tulsi Gabbard\'s stance in the US presidential race?'
# Best METEOR Score: 0.1479
# Total METEOR Score (normalized): 0.0880
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was Israel\'s ambassador to the United Nations, Gilad Erdan, kicked out of the General Assembly?'
# Best METEOR Score: 0.1099
# Generated Question 2: What is the context of the incident where Israel\'s ambassador to the United Nations, Gilad Erdan, was allegedly kicked out of the General Assembly?'
# Best METEOR Score: 0.2150
# Generated Question 3: What is the evidence that Israel\'s ambassador to the United Nations, Gilad Erdan, was removed from the General Assembly during the conflict with Hamas?'
# Best METEOR Score: 0.2150
# Total METEOR Score (normalized): 0.1346
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Haryana report 1,295 new cases and 12 deaths?'
# Best METEOR Score: 0.0915
# Generated Question 2: What is the context of the report of 1,295 new cases and 12 deaths in Haryana?'
# Best METEOR Score: 0.3155
# Generated Question 3: What are the details of the 1,295 new cases and 12 deaths reported in Haryana?'
# Best METEOR Score: 0.1553
# Total METEOR Score (normalized): 0.1636
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are Malaysian Muslims protesting against PM Modi?'
# Best METEOR Score: 0.0327
# Generated Question 2: What is the context of the image of Malaysian Muslims protesting against PM Modi?'
# Best METEOR Score: 0.3516
# Generated Question 3: What is the truth behind the claim of Malaysian Muslims protesting against PM Modi over the alleged persecution of Indian Muslims?'
# Best METEOR Score: 0.2553
# Total METEOR Score (normalized): 0.1545
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Was a Muslim man in UP\'s Deoband crushed and killed by a truck carrying Kanwariya pilgrims on July 20?'
# Best METEOR Score: 0.1143
# Generated Question 2: What is the context of the image or report shared on social media about a Muslim man killed in UP\'s Deoband by a truck carrying Kanwariya pilgrims?'
# Best METEOR Score: 0.4406
# Generated Question 3: What are the facts about the incident in Deoband where a Muslim man was allegedly killed by a truck carrying Kanwariya pilgrims?'
# Best METEOR Score: 0.2855
# Total METEOR Score (normalized): 0.2552
# Optimal Matching from Hungarian Algorithm:
# ...
# Best METEOR Score: 0.2282
# Generated Question 3: What are the specific guidelines issued by the Supreme Court regarding the treatment of the Shivalingam at the Ujjain temple?'
# Best METEOR Score: 0.1205
# Total METEOR Score (normalized): 0.1227
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did netizens celebrate Rabindranath Tagore's 159th birth anniversary with online performances?'
# Best METEOR Score: 0.0599
# Generated Question 2: How are netizens commemorating the 159th birth anniversary of Rabindranath Tagore during the coronavirus lockdown?'
# Best METEOR Score: 0.0932
# Generated Question 3: What is the context behind netizens celebrating Rabindranath Tagore's birth anniversary online?'
# Best METEOR Score: 0.1985
# Total METEOR Score (normalized): 0.1141
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will the lockdown in Maharashtra continue after June 30?'
# Best METEOR Score: 0.0968
# Generated Question 2: What are the implications of the lockdown extension in Maharashtra as announced by Uddhav?'
# Best METEOR Score: 0.1875
# Generated Question 3: What did Uddhav say about the lockdown in Maharashtra and its proposed end date?'
# Best METEOR Score: 0.2325
# Total METEOR Score (normalized): 0.1264
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the RJD opposing the new farm laws?'
# Best METEOR Score: 0.2050
# Generated Question 2: What is the context of RJD’s Manoj Jha moving the SC over the new farm laws?'
# Best METEOR Score: 0.2268
# Generated Question 3: What are the key points of the petition filed by RJD’s Manoj Jha regarding the new farm laws?'
# Best METEOR Score: 0.1506
# Total METEOR Score (normalized): 0.1142
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did a massive rally take place in support of Muslims in Tripura?'
# Best METEOR Score: 0.1497
# Generated Question 2: What was the context of the massive rally held in support of Muslims in Tripura?'
# Best METEOR Score: 0.1763
# Generated Question 3: What information is available about the recent violence faced by Muslims in Tripura that led to a rally in their support?'
# Best METEOR Score: 0.2872
# Total METEOR Score (normalized): 0.2044
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the image of Donald Trump kissing Jeffrey Epstein authentic?'
# Best METEOR Score: 0.2023
# Generated Question 2: What is the origin of the image shared on social media showing Donald Trump and Jeffrey Epstein in a car?'
# Best METEOR Score: 0.4957
# Generated Question 3: What is the fact-checking result of the photo allegedly showing Donald Trump kissing Jeffrey Epstein?'
# Best METEOR Score: 0.3175
# Total METEOR Score (normalized): 0.2518
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Hima Das win a gold medal last month?'
# Best METEOR Score: 0.0915
# Generated Question 2: What are the details of the clip showing Hima Das family reacting to her recent gold medal win?'
# Best METEOR Score: 0.1524
# Generated Question 3: What is the context of the video clip of Hima Das family reacting to her gold medal victory?'
# Best METEOR Score: 0.2720
# Total METEOR Score (normalized): 0.1486
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the fountain image used to discredit the alleged Shivling discovery at Gyanvapi Masjid from a Kolkata mosque?'
# Best METEOR Score: 0.2600
# Generated Question 2: What is the origin of the fountain image being used in relation to the Gyanvapi Masjid and Kolkata mosque controversy?'
# Best METEOR Score: 0.2889
# Generated Question 3: What are the facts surrounding the image of the fountain and its connection to the Gyanvapi Masjid and Kolkata mosque?'
# Best METEOR Score: 0.1506
# Total METEOR Score (normalized): 0.1518
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did children die in Palestine due to Israel\'s siege of Gaza?'
# Best METEOR Score: 0.1198
# Generated Question 2: What is the origin of the image shared on social media showing children killed in Palestine?'
# Best METEOR Score: 0.4335
# Generated Question 3: What is the factual context surrounding the Claim of children killed in Palestine following Israel’s siege of Gaza?'
# Best METEOR Score: 0.3079
# Total METEOR Score (normalized): 0.2814
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Gujarat government unable to provide details about the Aatmanirbhar scheme?'
# Best METEOR Score: 0.2823
# Generated Question 2: What is the reason given by the Gujarat government for not disclosing details about the Aatmanirbhar scheme?'
# Best METEOR Score: 0.3136
# Generated Question 3: What information can be extracted about the Gujarat government\'s stance on providing details about the Aatmanirbhar scheme?'
# Best METEOR Score: 0.2268
# Total METEOR Score (normalized): 0.1522
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did an Islamic terrorist accidentally blow himself up after falling off a hoverboard?'
# Best METEOR Score: 0.0893
# Generated Question 2: What is the context of the image or video allegedly showing an Islamic terrorist blowing himself up after falling off a hoverboard?'
# Best METEOR Score: 0.4181
# Generated Question 3: What are the facts surrounding the claim of an Islamic terrorist accidentally detonating an explosive while riding a hoverboard?'
# Best METEOR Score: 0.1515
# Total METEOR Score (normalized): 0.1964
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Has the CPM decided to have friends in Bengal and foes in Kerala for its congress line?'
# Best METEOR Score: 0.0920
# Generated Question 2: What is the significance of the CPM deciding its congress line in terms of alliances in Bengal and Kerala?'
# Best METEOR Score: 0.3098
# Generated Question 3: What are the key points of the CPM congress line decision regarding its stance in Bengal and Kerala?'
# Best METEOR Score: 0.1829
# Total METEOR Score (normalized): 0.1598
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Will PM Modi inaugurate multistorey flats for MPs on Monday?'
# Best METEOR Score: 0.0606
# Generated Question 2: What is the purpose of the event where PM Modi will be inaugurating multistorey flats for MPs on Monday?'
# Best METEOR Score: 0.2703
# Generated Question 3: What are the details about the multistorey flats for MPs that PM Modi is set to inaugurate on Monday?'
# Best METEOR Score: 0.2584
# Total METEOR Score (normalized): 0.1467
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the 8th round of corps commander talks between India and China expected to happen this week?'
# Best METEOR Score: 0.0920
# Generated Question 2: What is the significance of the upcoming 8th round of corps commander talks in the context of the Lac row?'
# Best METEOR Score: 0.2569
# Generated Question 3: What are the key issues that will be discussed during the 8th round of corps commander talks?'
# Best METEOR Score: 0.1227
# Total METEOR Score (normalized): 0.1229
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is British Prime Minister Boris Johnson dead?'
# Best METEOR Score: 0.0654
# Generated Question 2: What is the source of the information that British Prime Minister Boris Johnson has died, and is the image or news report shared on social media related to this claim?'
# Best METEOR Score: 0.3602
# Generated Question 3: What is the factual information regarding the claim that British Prime Minister Boris Johnson has passed away?'
# Best METEOR Score: 0.2736
# Total METEOR Score (normalized): 0.2216
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Prime Minister Narendra Modi pay homage at the tomb of Mughal emperor Aurangzeb?'
# Best METEOR Score: 0.0625
# Generated Question 2: Is the image shared on social media of Prime Minister Narendra Modi paying homage at the tomb of Aurangzeb authentic?'
# Best METEOR Score: 0.4233
# Generated Question 3: What is the fact about the visit of Prime Minister Narendra Modi to the tomb of Mughal emperor Aurangzeb?'
# Best METEOR Score: 0.2584
# Total METEOR Score (normalized): 0.2470
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was UP CM Yogi Adityanath present at the forced cremation of the Hathras case victim?'
# Best METEOR Score: 0.1242
# Generated Question 2: What is the context of the image or video showing UP CM Yogi Adityanath in relation to the Hathras case victim\'s cremation?'
# Best METEOR Score: 0.3148
# Generated Question 3: What is the factual information regarding UP CM Yogi Adityanath watching the forced cremation of the Hathras case victim?'
# Best METEOR Score: 0.2255
# Total METEOR Score (normalized): 0.1518
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Were CRPF jawans attacked by terrorists in J-K’s Sopore?'
# Best METEOR Score: 0.0955
# Generated Question 2: What was the nature of the incident in J-K’s Sopore involving CRPF jawans?'
# Best METEOR Score: 0.2855
# Generated Question 3: How many CRPF jawans were killed and injured in the terrorist attack in J-K’s Sopore?'
# Best METEOR Score: 0.1534
# Total METEOR Score (normalized): 0.1764
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Edappadi Palaniswami the AIADMK chief ministerial candidate for the 2021 election?'
# Best METEOR Score: 0.1266
# Generated Question 2: What is the context of Edappadi Palaniswami being announced as the AIADMK chief ministerial candidate for the 2021 election?'
# Best METEOR Score: 0.2584
# Generated Question 3: What are the facts about Edappadi Palaniswami being AIADMK’s chief ministerial candidate for the 2021 election?'
# Best METEOR Score: 0.1524
# Total METEOR Score (normalized): 0.1242
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was a Hindu woman killed by a Muslim man in Haryana’s Gurugram?'
# Best METEOR Score: 0.0938
# Generated Question 2: What is the context of the image shared on social media showing a Hindu woman being killed by a Muslim man in Haryana’s Gurugram?'
# Best METEOR Score: 0.4457
# Generated Question 3: What are the facts about the incident involving a Hindu woman and a Muslim man in Haryana’s Gurugram?'
# Best METEOR Score: 0.2889
# Total METEOR Score (normalized): 0.2575
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has Varun Gandhi removed BJP from his Twitter bio?'
# Best METEOR Score: 0.0578
# Generated Question 2: What could be the implications of Varun Gandhi removing BJP from his Twitter bio?'
# Best METEOR Score: 0.0938
# Generated Question 3: What does Varun Gandhi\'s Twitter bio currently indicate about his affiliation with the BJP?'
# Best METEOR Score: 0.1242
# Total METEOR Score (normalized): 0.0797
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a Muslim mob vandalize a railway station in West Bengal because a train horn interrupted namaz?'
# Best METEOR Score: 0.1163
# Generated Question 2: What is the context of the image or video shared on social media showing a mob vandalizing a railway station in West Bengal?'
# Best METEOR Score: 0.4536
# Generated Question 3: What is the factual basis for the claim that a Muslim mob vandalized a railway station in West Bengal due to a train horn interrupting namaz?'
# Best METEOR Score: 0.3328
# Total METEOR Score (normalized): 0.2749
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
#
# Average METEOR Score: 0.1738
