# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.18.0

# %%
# @title Default title text
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
# Initialize Groq API client
client = Groq(api_key="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")


import re

def convert_to_json(llm_response):
    responseQuestions = []
    questions_llm = re.findall(r'\{(.*?)\}', llm_response, re.DOTALL)

    for question in questions_llm:
        question_json = {}

        q = re.findall(r'[\"\']question[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip()
        else:
            continue

        a = re.findall(r'[\"\']answer[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if a:
            question_json['answer'] = a[0].strip()

        at = re.findall(r'[\"\']answerType[\"\']:\s*[\"\']?(.*?)[\"\']', question, re.DOTALL)
        if at:
            question_json['answerType'] = at[0].strip()

        responseQuestions.append(question_json)

    return responseQuestions



def get_response_llm(claim, questions):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions and answer pairs in a single list json. Do not leave question and answer pair empty"

  try:
      response = client.chat.completions.create(
          messages=[
              {
                  "role": "user",
                  "content": prompt,
              }
          ],
          model="llama-3.3-70b-versatile",
          max_tokens=4000,
      )
      response = response.choices[0].message.content.strip()
      response_json = convert_to_json(response)
      return response_json
  except Exception as e:
      print(f"Error processing claim '{claim}': {e}, {response}")
      print("-*"*50)
      return ""

# %%
new_data = []

for data in combined_claims[:5010]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    q['answer'] = answer['answer']
    q['answerType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
print(len([1 for n in new_data if n['generatedQuestions'] == []]))
new_data
# Out:
# 0
# [{'claim': 'Pasighat in Arunachal Pradesh, the only village where it never rains as it is situated at an altitude higher than the clouds.',
#   'generatedQuestions': [{'question': 'Is Pasighat the only village where it never rains due to its high altitude?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Does the claim that Pasighat in Arunachal Pradesh never experiences rain due to its altitude hold true?',
#     'answer': 'No, the claim is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested.',
#     'answerType': 'Abstractive'},
#    {'question': 'Is it true that Pasighat in Arunachal Pradesh is situated above the clouds and never experiences rainfall?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it is situated above the clouds and never rains is false.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Bhagat Singh  publicly flogged by the British.',
#   'generatedQuestions': [{'question': 'Was Bhagat Singh publicly flogged by the British?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the historical account of Bhagat Singh being flogged by the British?',
#     'answer': 'Bhagat Singh was indeed publicly flogged by the British during his imprisonment in 1929 for his involvement in the Indian independence movement. The flogging was a form of punishment and an attempt to break his spirit.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Bhagat Singh face any physical punishment from the British?',
#     'answer': "Yes, Bhagat Singh was publicly flogged by the British as a form of punishment for his revolutionary activities, showcasing the British colonial regime\\'s brutal treatment of Indian freedom fighters.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Tesla CEO Elon Musk has said his daughter can never marry a person who does not have the ability to create wealth.',
#   'generatedQuestions': [{'question': 'Has Elon Musk stated that his daughter can only marry someone who can create wealth?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': "Is it true that Elon Musk has set a condition for his daughter\\'s marriage based on the ability to create wealth?",
#     'answer': "There is no credible information available to suggest that Elon Musk has made such a statement about his daughter\\'s marriage. The claim appears to be unfounded and lacks evidence to support it.",
#     'answerType': 'Abstractive'},
#    {'question': 'Did Elon Musk specify that his daughter must marry someone with the ability to generate wealth?',
#     'answer': "No, there is no reliable source indicating that Elon Musk has ever made such a statement regarding his daughter\\'s potential spouse. The claim is likely fabricated and not based on factual information.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'In Maharashtra, Hindus in a residential society are heard chanting slogans in support of Lord Ram.',
#   'generatedQuestions': [{'question': 'Are Hindus in a residential society in Maharashtra chanting slogans in support of Lord Ram?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that Hindus in a residential society in Maharashtra are chanting slogans in support of Lord Ram accurate?',
#     'answer': 'There is no evidence to support the claim that Hindus in a residential society in Maharashtra are chanting slogans in support of Lord Ram. Without further context or information, it is impossible to verify the authenticity of this claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does the claim about Hindus chanting slogans in support of Lord Ram in a Maharashtra residential society have any basis in fact?',
#     'answer': 'No, the claim that Hindus in a residential society in Maharashtra are chanting slogans in support of Lord Ram does not appear to be supported by any credible evidence. As such, it should be treated with skepticism.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Covid-19 schools in delhi to remain closed till october 31',
#   'generatedQuestions': [{'question': 'Are schools in Delhi closed until October 31 due to Covid-19?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that schools in Delhi will remain closed till October 31 due to Covid-19 accurate?',
#     'answer': 'No, the claim is inaccurate as the decision to close schools is subject to change based on the Covid-19 situation and government directives. Schools in Delhi may reopen earlier or later than October 31, depending on the circumstances.',
#     'answerType': 'Abstractive'},
#    {'question': 'Will schools in Delhi remain closed until October 31 because of the Covid-19 pandemic?',
#     'answer': 'No, the closure of schools in Delhi is not permanently set until October 31. The duration of school closures can vary based on the Covid-19 situation and guidelines issued by the government.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Aajtak tweets about Smriti Irani saying that polling booths should not be in Delhi government schools.',
#   'generatedQuestions': [{'question': 'Did Smriti Irani suggest that polling booths should not be in Delhi government schools?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that Smriti Irani said polling booths should not be in Delhi government schools accurate?',
#     'answer': 'No, the claim is inaccurate. There is no evidence to suggest Smriti Irani made such a statement. Aajtak tweets may have been misinterpreted or misrepresented.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Smriti Irani oppose the use of Delhi government schools as polling booths?',
#     'answer': 'No, there is no evidence to suggest Smriti Irani opposes the use of Delhi government schools as polling booths. The claim appears to be false and may have been spread through misinformation.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Mario Balotelli said he would like to win two Ballon d'Ors for two clubs like Ronaldo and unlike Messi.",
#   'generatedQuestions': [{'question': "Did Mario Balotelli express a desire to win two Ballon d\\'Ors?",
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': "Is the statement about Mario Balotelli wanting to win two Ballon d\\'Ors for two different clubs like Ronaldo and unlike Messi accurate?",
#     'answer': 'There is no evidence to suggest that Mario Balotelli made such a statement. The claim appears to be false and lacks credible sources to support it.',
#     'answerType': 'Abstractive'},
#    {'question': "Is it true that Mario Balotelli aims to replicate Ronaldo\\'s achievement of winning Ballon d\\'Ors with different clubs?",
#     'answer': 'No, there is no reliable source indicating that Mario Balotelli has expressed such an ambition. The claim seems to be unfounded and not supported by factual evidence.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Woman burned her hands while putting on the stove due to high alcohol content in hand sanitiser.',
#   'generatedQuestions': [{'question': 'Can hand sanitiser with high alcohol content cause burns if it comes into contact with an open flame?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the risk of using hand sanitiser with high alcohol content near an open flame?',
#     'answer': 'The risk is that the alcohol in the hand sanitiser can ignite and cause burns, as seen in the claim of a woman burning her hands while putting on the stove.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does the high alcohol content in hand sanitiser pose a fire hazard if not used properly?',
#     'answer': 'Yes, the high alcohol content in hand sanitiser can pose a fire hazard if it comes into contact with an open flame or spark, such as when putting on the stove.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'The recent Istanbul blast on November 13 that caused at least six deaths and injured dozens of people.',
#   'generatedQuestions': [{'question': "Was the Istanbul blast on November 13 the deadliest bombing in the city\\'s history?",
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that the recent Istanbul blast occurred on November 13 accurate?',
#     'answer': 'The claim that the recent Istanbul blast occurred on November 13 and caused at least six deaths and injured dozens of people may be accurate, but the details of the blast, including the number of casualties and the circumstances surrounding it, require verification.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the Istanbul blast on November 13 result in at least six deaths and injure dozens of people?',
#     'answer': 'The Istanbul blast on November 13 did cause casualties, but the exact number of deaths and injuries may vary depending on the source. However, it is confirmed that the blast resulted in multiple deaths and injuries.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Indian fans expressing anger against the Indian cricket team after the World Cup final.',
#   'generatedQuestions': [{'question': 'Is the Indian cricket team facing backlash from fans after the World Cup final?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reaction of Indian fans towards the Indian cricket team after the World Cup final?',
#     'answer': 'The reaction is one of anger and disappointment, with fans expressing their frustration on social media and other platforms.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are Indian fans upset with the Indian cricket team due to their performance in the World Cup final?',
#     'answer': 'Yes, Indian fans are expressing anger and disappointment towards the team due to their performance in the final match.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Congress President Rahul Gandhi was seen waving a BJP flag.',
#   'generatedQuestions': [{'question': 'Is Rahul Gandhi a member of the BJP?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Was Rahul Gandhi seen waving a BJP flag at a public event?',
#     'answer': 'No, the claim that Rahul Gandhi was seen waving a BJP flag is inaccurate. There is no credible evidence to support this claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Rahul Gandhi wave a BJP flag in support of the party?',
#     'answer': 'No, Rahul Gandhi is the President of the Indian National Congress and has not been known to wave a BJP flag in support of the party. The claim appears to be false.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'crpf gets over 40k bulletproof jackets, 170 armoured vehicles for kashmir, lwe theatres.',
#   'generatedQuestions': [{'question': 'Did CRPF receive over 40k bulletproof jackets for Kashmir and LWE theatres?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the significance of CRPF receiving over 40k bulletproof jackets and 170 armoured vehicles?',
#     'answer': 'The CRPF receiving over 40k bulletproof jackets and 170 armoured vehicles is significant as it will enhance their operational capabilities in high-risk areas such as Kashmir and LWE theatres, providing better protection for the personnel.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many armoured vehicles did CRPF receive for Kashmir and LWE theatres?',
#     'answer': 'CRPF received 170 armoured vehicles for Kashmir and LWE theatres.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Eluru mystery disease may be caused by anti-mosquito fogging.',
#   'generatedQuestions': [{'question': 'Is the Eluru mystery disease caused by anti-mosquito fogging?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What is the likely cause of the Eluru mystery disease in relation to anti-mosquito fogging?',
#     'answer': 'The claim that anti-mosquito fogging is the cause of the Eluru mystery disease is inaccurate. The actual cause is still under investigation and research.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does anti-mosquito fogging have any connection to the outbreak of the Eluru mystery disease?',
#     'answer': 'No, there is no conclusive evidence to prove that anti-mosquito fogging is the cause of the Eluru mystery disease. Further research is needed to determine the actual cause.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Rajasthan crisis: where things stand for bjp.',
#   'generatedQuestions': [{'question': 'Is the Rajasthan crisis benefiting the BJP?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What is the current situation of the Rajasthan crisis and its impact on the BJP?',
#     'answer': 'The Rajasthan crisis is a complex situation with various political implications for the BJP. The party is navigating the situation carefully to minimize potential damage and maximize political gains.',
#     'answerType': 'Abstractive'},
#    {'question': "Does the Rajasthan crisis pose a significant threat to the BJP\\'s political standing?",
#     'answer': "Yes, the Rajasthan crisis has the potential to impact the BJP\\'s political standing, and the party is taking steps to mitigate the risks and capitalize on opportunities.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Girish chandra murmu takes oath as first lt. governor of jammu and kashmir.',
#   'generatedQuestions': [{'question': 'Is Girish Chandra Murmu the first Lt. Governor of Jammu and Kashmir?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Who took oath as the first Lt. Governor of Jammu and Kashmir?',
#     'answer': 'Girish Chandra Murmu took oath as the first Lt. Governor of Jammu and Kashmir, marking a new chapter in the administrative history of the region.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Girish Chandra Murmu assume the role of Lt. Governor of Jammu and Kashmir?',
#     'answer': 'Yes, Girish Chandra Murmu took oath as the first Lt. Governor of Jammu and Kashmir, assuming the role and responsibilities that come with it.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Those in need of 2-DG anti-covid drug can place the order with Dr. Reddy's Lab through the mail ID: deepaksapra@drreddys.com and mallikarjunard@drreddys.com.",
#   'generatedQuestions': [{'question': "Can people order 2-DG anti-covid drug from Dr. Reddy\\'s Lab through the provided email IDs?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What is the process to order 2-DG anti-covid drug from Dr. Reddy\\'s Lab for those in need?",
#     'answer': "Those in need of 2-DG anti-covid drug can place the order with Dr. Reddy\\'s Lab through the given mail IDs.",
#     'answerType': 'Abstractive'},
#    {'question': "How can individuals obtain the 2-DG anti-covid drug from Dr. Reddy\\'s Lab?",
#     'answer': 'Individuals can obtain the 2-DG anti-covid drug by placing an order through the provided email IDs: deepaksapra@drreddys.com and mallikarjunard@drreddys.com.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Sonia Gandhi said she was the daughter-in-law of Indira Gandhi after the ED summoned the Congress president recently.',
#   'generatedQuestions': [{'question': 'Is Sonia Gandhi the daughter-in-law of Indira Gandhi?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the relationship between Sonia Gandhi and Indira Gandhi?',
#     'answer': 'Sonia Gandhi is the wife of Rajiv Gandhi, who is the son of Indira Gandhi, making her the daughter-in-law of Indira Gandhi.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Sonia Gandhi claim to be the daughter-in-law of Indira Gandhi after being summoned by the ED?',
#     'answer': 'The claim that Sonia Gandhi said she was the daughter-in-law of Indira Gandhi after the ED summoned her is true, as she is indeed the daughter-in-law of Indira Gandhi by marriage to Rajiv Gandhi.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': "China's actions show complete failure of india's foreign policy under modi govt, rahul gandhi.",
#   'generatedQuestions': [{'question': "Has India's foreign policy under the Modi government been a complete failure?",
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': "What is Rahul Gandhi's opinion on the Modi government's foreign policy, particularly concerning China?",
#     'answer': "Rahul Gandhi has been critical of the Modi government\\'s foreign policy, especially with regards to China, stating that their actions demonstrate a complete failure of India\\'s foreign policy.",
#     'answerType': 'Abstractive'},
#    {'question': "Is Rahul Gandhi correct in stating that China's actions are a result of the failure of India's foreign policy under the Modi government?",
#     'answer': "No, the situation is more complex, and while China\\'s actions are a concern, they do not solely reflect a complete failure of India\\'s foreign policy under the Modi government.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Andrew Tye quit the ongoing IPL season and said, 'I do not understand how Indian companies and government are spending huge money for IPL when people actually need hospitals.'",
#   'generatedQuestions': [{'question': 'Did Andrew Tye quit the IPL season due to concerns over funding priorities?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the reason behind Andrew Tye quitting the ongoing IPL season?',
#     'answer': 'Andrew Tye quit the IPL season because he was concerned about the large amount of money spent by Indian companies and the government on the tournament when people were in need of hospitals.',
#     'answerType': 'Abstractive'},
#    {'question': 'What comment did Andrew Tye make when he quit the IPL season?',
#     'answer': 'Andrew Tye said that he did not understand how Indian companies and the government were spending huge amounts of money on the IPL when people actually needed hospitals.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara.',
#   'generatedQuestions': [{'question': 'Is the claim that Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara true?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What is the accuracy of the statement that Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara?',
#     'answer': 'The claim is inaccurate. There is no evidence to support that Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Pakistan actually paint its national flag on the rooftop of Kartarpur Gurudwara?',
#     'answer': 'No, there is no credible evidence to suggest that Pakistan painted its national flag on the rooftop of Kartarpur Gurudwara. The claim appears to be false.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Modi govt could send notices to 3 ips officers and bengal govt over deputation tug-of-war.',
#   'generatedQuestions': [{'question': 'Will the Modi government send notices to 3 IPS officers?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the Modi government sending notices to IPS officers and Bengal government?',
#     'answer': 'The reason behind the Modi government sending notices to IPS officers and Bengal government is due to a deputation tug-of-war.',
#     'answerType': 'Abstractive'},
#    {'question': 'Is the deputation tug-of-war between the Modi government and Bengal government related to IPS officers?',
#     'answer': 'Yes, the deputation tug-of-war is related to 3 IPS officers.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Bubonic plague detected in China can trigger a severe epidemic. According to the US Centers for Disease Control (CDC), bubonic plague is airborne and can be spread through cough droplets.',
#   'generatedQuestions': [{'question': 'Is bubonic plague airborne?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Can bubonic plague be spread through cough droplets?',
#     'answer': 'No, the plague is typically spread through the bites of infected fleas or direct contact with infected animals, not through cough droplets.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does the US Centers for Disease Control (CDC) classify bubonic plague as an airborne disease?',
#     'answer': 'No, according to the CDC, bubonic plague is primarily spread through the bites of infected fleas or direct contact with infected animals, not through the air.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Voting on in 94 bihar assembly constituencies, modi urges people to participate in large numbers',
#   'generatedQuestions': [{'question': 'Is voting currently taking place in 94 Bihar assembly constituencies?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What is the current status of voting in the Bihar assembly constituencies and what is Modi\\'s message to the people?",
#     'answer': 'Voting is taking place in 94 Bihar assembly constituencies, and Modi is urging people to participate in large numbers.',
#     'answerType': 'Abstractive'},
#    {'question': "How many Bihar assembly constituencies are currently undergoing voting and what is Modi\\'s appeal to the voters?",
#     'answer': '94 Bihar assembly constituencies are currently undergoing voting, and Modi is appealing to the voters to participate in large numbers.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'NIA raids residence of gujarat man, who provided rs 5k to pak spy',
#   'generatedQuestions': [{'question': 'Was the Gujarat man involved in providing funds to a Pakistani spy?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the amount of money provided by the Gujarat man to the Pakistani spy?',
#     'answer': 'The Gujarat man provided Rs 5,000 to the Pakistani spy.',
#     'answerType': 'Extractive'},
#    {'question': 'Why did the NIA raid the residence of the Gujarat man?',
#     'answer': 'The NIA raided the residence of the Gujarat man because he was suspected of providing financial support to a Pakistani spy, with an amount of Rs 5,000 being transferred.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the NIA conduct a raid at the residence of the Gujarat man?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was the reason behind the NIA raiding the Gujarat man\\'s residence?",
#     'answer': "The NIA raided the Gujarat man\\'s residence due to his alleged involvement in providing Rs 5,000 to a Pakistani spy.",
#     'answerType': 'Extractive'},
#    {'question': 'Is it true that the NIA raided the residence of a Gujarat man who provided funds to a Pakistani spy?',
#     'answer': 'Yes, the claim is true. The NIA did raid the residence of a Gujarat man who was suspected of providing Rs 5,000 to a Pakistani spy.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Maharashtra assembly polls: shiv sena-bjp alliance face rift over seat-sharing.',
#   'generatedQuestions': [{'question': 'Is the Shiv Sena-BJP alliance facing a rift over seat-sharing for the Maharashtra assembly polls?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the current status of the Shiv Sena-BJP alliance regarding seat-sharing for the Maharashtra assembly polls?',
#     'answer': 'The Shiv Sena-BJP alliance is facing a rift due to disagreements over seat-sharing for the upcoming Maharashtra assembly polls.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are the Shiv Sena and BJP experiencing disagreements over seat allocation for the Maharashtra assembly elections?',
#     'answer': 'Yes, the Shiv Sena and BJP are experiencing disagreements over seat allocation, which is causing a rift in their alliance.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A chariot made of gold reached the shores of Srikakulam in Andhra Pradesh because of Cyclone Asani.',
#   'generatedQuestions': [{'question': 'Is a gold chariot reaching the shores of Srikakulam in Andhra Pradesh due to Cyclone Asani factually correct?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Did Cyclone Asani bring a chariot made of gold to the shores of Srikakulam in Andhra Pradesh?',
#     'answer': 'No, there is no evidence to support the claim that Cyclone Asani brought a gold chariot to the shores of Srikakulam in Andhra Pradesh. The claim appears to be entirely fictional.',
#     'answerType': 'Abstractive'},
#    {'question': 'Can a cyclone like Asani transport a chariot made of gold to a different location?',
#     'answer': 'No, it is highly unlikely and not scientifically possible for a cyclone to transport a chariot made of gold to a different location like the shores of Srikakulam in Andhra Pradesh.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Without uniform civil code in India, large Muslim families like this one will reap all the benefits of taxpayers' money.",
#   'generatedQuestions': [{'question': 'Does the presence of a uniform civil code in India prevent large Muslim families from receiving government benefits?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': "Is it true that large Muslim families in India reap all the benefits of taxpayers\\' money due to the absence of a uniform civil code?",
#     'answer': 'No, the claim is inaccurate. The presence or absence of a uniform civil code does not directly determine the eligibility of families to receive government benefits. Benefits are typically determined by specific laws and policies related to social welfare, taxation, and other areas.',
#     'answerType': 'Abstractive'},
# ...
#     'answer': 'The Union Cabinet has approved an increase in the allowances for Members of Parliament (MPs).',
#     'answerType': 'Abstractive'},
#    {'question': 'Are the allowances for Members of Parliament (MPs) increased as per the Union Cabinet decision?',
#     'answer': 'Yes, the Union Cabinet has approved an increase in the allowances for Members of Parliament (MPs).',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'After his daughter K Kavitha was charged in the Delhi liquor scam case, Telangana CM KCR praised Modi and claimed he was the PM’s “best friend”.',
#   'generatedQuestions': [{'question': 'Is Telangana CM KCR the best friend of PM Modi?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Did Telangana CM KCR claim to be the best friend of PM Modi after his daughter was charged in the Delhi liquor scam case?',
#     'answer': 'The claim that Telangana CM KCR praised Modi and claimed to be his best friend after his daughter K Kavitha was charged in the Delhi liquor scam case is inaccurate. There is no evidence to suggest that KCR made such a statement.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does the statement that Telangana CM KCR is the best friend of PM Modi have any basis in fact?',
#     'answer': 'No, the statement that Telangana CM KCR is the best friend of PM Modi does not have any basis in fact. The claim that he praised Modi and claimed to be his best friend after his daughter was charged in the Delhi liquor scam case is unfounded and lacks evidence.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Prime Minister Narendra Modi was booed by the people of Varanasi during his recent trip, which the media never showed. People shouted anti-Modi slogans while he was walking down the streets with Yogi Adityanath.',
#   'generatedQuestions': [{'question': 'Was Prime Minister Narendra Modi booed by the people of Varanasi during his recent trip?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that Prime Minister Narendra Modi was booed by the people of Varanasi during his recent trip accurate?',
#     'answer': 'No, the claim is inaccurate. There is no evidence to suggest that Prime Minister Narendra Modi was booed by the people of Varanasi during his recent trip.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the media fail to show Prime Minister Narendra Modi being booed by the people of Varanasi during his recent trip?',
#     'answer': 'No, there is no evidence to suggest that the media failed to show Prime Minister Narendra Modi being booed by the people of Varanasi. The claim appears to be false.',
#     'answerType': 'Extractive'},
#    {'question': 'Did people shout anti-Modi slogans while he was walking down the streets with Yogi Adityanath in Varanasi?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is it true that Prime Minister Narendra Modi faced protest from the people of Varanasi during his visit?',
#     'answer': 'No, there is no credible evidence to support the claim that Prime Minister Narendra Modi faced protest from the people of Varanasi during his visit.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does the video or any report show Prime Minister Narendra Modi being booed by the people of Varanasi?',
#     'answer': 'No, there is no video or report that shows Prime Minister Narendra Modi being booed by the people of Varanasi. The claim is likely fabricated.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Edappadi palaniswami is aiadmk’s chief ministerial candidate for 2021 election',
#   'generatedQuestions': [{'question': 'Is Edappadi Palaniswami the AIADMK chief ministerial candidate for the 2021 election?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Who is the AIADMK chief ministerial candidate for the 2021 election?',
#     'answer': 'Edappadi Palaniswami is the AIADMK chief ministerial candidate for the 2021 election. This was announced by the party as part of their election strategy.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did AIADMK announce Edappadi Palaniswami as their chief ministerial candidate for 2021?',
#     'answer': "Yes, AIADMK did announce Edappadi Palaniswami as their chief ministerial candidate for the 2021 election, as per the party\\'s official statements and election preparations.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Waterlogged mumbai streets following heavy rainfall.',
#   'generatedQuestions': [{'question': 'Is Mumbai prone to waterlogging due to heavy rainfall?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind waterlogged Mumbai streets?',
#     'answer': 'The reason behind waterlogged Mumbai streets is heavy rainfall, which causes flooding and water accumulation on the streets.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does heavy rainfall cause waterlogging in Mumbai?',
#     'answer': "Yes, heavy rainfall is a significant cause of waterlogging in Mumbai, as the city\\'s drainage system often struggles to handle large amounts of rainwater.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Terrorists killed in an air strike by the Indian air force on a jaish-e-mohammed training camp in balakot, pakistan.',
#   'generatedQuestions': [{'question': 'Was the Indian air force involved in an air strike on a Jaish-e-Mohammed training camp in Balakot, Pakistan?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the target of the air strike by the Indian air force in Pakistan?',
#     'answer': 'The target of the air strike was a Jaish-e-Mohammed training camp in Balakot, Pakistan.',
#     'answerType': 'Abstractive'},
#    {'question': 'Where did the Indian air force conduct an air strike on a Jaish-e-Mohammed training camp?',
#     'answer': 'The Indian air force conducted an air strike on a Jaish-e-Mohammed training camp in Balakot, Pakistan.',
#     'answerType': 'Extractive'},
#    {'question': 'Did the Indian air force carry out an air strike on a terrorist camp in Pakistan?',
#     'answer': 'Yes, the Indian air force carried out an air strike on a Jaish-e-Mohammed training camp in Balakot, Pakistan.',
#     'answerType': 'Boolean'},
#    {'question': 'What was the outcome of the air strike by the Indian air force on the Jaish-e-Mohammed training camp?',
#     'answer': 'The air strike resulted in the killing of terrorists at the Jaish-e-Mohammed training camp in Balakot, Pakistan.',
#     'answerType': 'Abstractive'},
#    {'question': 'In which city was the Jaish-e-Mohammed training camp located that was targeted by the Indian air force?',
#     'answer': 'The Jaish-e-Mohammed training camp targeted by the Indian air force was located in Balakot, Pakistan.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Patidar leader hardik patel missing for 20 days, claims wife, accuses gujarat govt of targeting him',
#   'generatedQuestions': [{'question': 'Is Hardik Patel missing for 20 days?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What is the current status of Hardik Patel?',
#     'answer': 'The claim that Hardik Patel is missing for 20 days is inaccurate. There is no credible information to suggest that he has been missing for such an extended period.',
#     'answerType': 'Abstractive'},
#    {'question': 'Is the Gujarat government targeting Hardik Patel?',
#     'answer': 'No, there is no concrete evidence to suggest that the Gujarat government is targeting Hardik Patel. The claim made by his wife appears to be unsubstantiated.',
#     'answerType': 'Extractive'},
#    {'question': 'Has Hardik Patel been missing due to government action?',
#     'answer': 'No, there is no reliable source indicating that Hardik Patel has been missing due to any government action. The claim seems to be speculative and lacks concrete evidence.',
#     'answerType': 'Extractive'},
#    {'question': 'Is the claim about Hardik Patel made by his wife accurate?',
#     'answer': "No, the claim made by Hardik Patel\\'s wife appears to be inaccurate. There is no substantial proof to support the statement that he has been missing for 20 days.",
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'When Delhi CM Arvind Kejriwal asked Gujaratis if they needed free electricity, they said no.',
#   'generatedQuestions': [{'question': 'Did Gujaratis refuse free electricity when asked by Delhi CM Arvind Kejriwal?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim that Gujaratis declined free electricity offered by Delhi CM Arvind Kejriwal accurate?',
#     'answer': 'No, the claim is inaccurate. There is no evidence to suggest that Delhi CM Arvind Kejriwal asked Gujaratis if they needed free electricity and they refused it.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Delhi CM Arvind Kejriwal actually ask Gujaratis if they needed free electricity and got a negative response?',
#     'answer': 'No, there is no credible source to confirm that such an incident occurred. The claim appears to be fabricated.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Is Pasighat in Arunachal Pradesh the only village where it never rains because it is situated above the clouds?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Is the video showing Pasighat in Arunachal Pradesh?',
#     'answer': 'No, the video does not show Pasighat in Arunachal Pradesh. The claim that it does is inaccurate. Pasighat does experience rainfall and is not situated above the clouds as suggested in the claim.',
#     'answerType': 'Abstractive'},
#    {'question': 'Does Pasighat never experience rainfall due to its altitude?',
#     'answer': 'No, Pasighat does experience rainfall. The claim that it never rains there due to its altitude is inaccurate. Pasighat, located in Arunachal Pradesh, receives regular rainfall and is not situated above the clouds.',
#     'answerType': 'Extractive'}]},
#  ...]

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences
    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))

for data in new_data:
  generated_sequences = [question['question']+'\n'+question.get('answer', "") for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question']+'\n'+question['answer'] for question in data['goldQuestions']]
  if not generated_sequences or not reference_sequences:
    continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# No, the campaign has ended for the first phase of Bihar assembly election.
# Best METEOR Score: 0.1706
# Total METEOR Score (normalized): 0.0979
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the claim of an angry mob destroying EVMs found in a BJP leader\'s car during Karnataka election 2023 true?
# No
# Best METEOR Score: 0.1755
# Generated Question 2: What is the accuracy of the claim that an angry mob destroyed EVMs found in a BJP leader\'s car during Karnataka election 2023?
# The claim is inaccurate. There is no evidence to support the claim that an angry mob destroyed EVMs found in a BJP leader\'s car during the Karnataka election 2023.
# Best METEOR Score: 0.2923
# Generated Question 3: Did an angry mob destroy EVMs found in a BJP leader\'s car during Karnataka election 2023?
# No, there is no credible evidence to suggest that an angry mob destroyed EVMs found in a BJP leader\'s car during the Karnataka election 2023.
# Best METEOR Score: 0.1087
# Total METEOR Score (normalized): 0.1901
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Can an Iranian missile make a u-turn to hit the launcher instead of the target if it malfunctions?
# No
# Best METEOR Score: 0.1780
# Generated Question 2: Is the claim of an Iranian missile making a u-turn to hit the launcher instead of the target accurate?
# No, the claim that an Iranian missile can malfunction and make a u-turn to hit the launcher is inaccurate and likely an exaggeration or misinformation. Missiles are designed with complex guidance systems and safety features to prevent such incidents.
# Best METEOR Score: 0.2345
# Generated Question 3: Does a malfunctioning Iranian missile have the capability to change its trajectory and hit the launcher?
# No, a malfunctioning Iranian missile does not have the capability to make a deliberate u-turn and hit the launcher. While missiles can malfunction, the claim of intentionally changing trajectory to hit the launcher is not supported by evidence and is unlikely.
# Best METEOR Score: 0.2562
# Total METEOR Score (normalized): 0.2223
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will Kejriwal implement L-G\'s order to keep hospitals in Delhi open for non-residents?
# Yes
# Best METEOR Score: 0.0488
# Generated Question 2: What is Kejriwal\'s stance on L-G\'s order to keep hospitals in Delhi open for non-residents?
# Kejriwal will implement L-G\'s order to keep hospitals in Delhi open for non-residents as per the given claim.
# Best METEOR Score: 0.1177
# Generated Question 3: Is it true that Kejriwal will not implement L-G\'s order to keep hospitals in Delhi open for non-residents?
# No, the claim states that Kejriwal will implement L-G\'s order to keep hospitals in Delhi open for non-residents.
# Best METEOR Score: 0.2081
# Total METEOR Score (normalized): 0.1135
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the teenager involved in the Pune Porsche accident bragging about the incident in a rap song?
# No
# Best METEOR Score: 0.2050
# Generated Question 2: What is the context of the teenager accused in the Pune Porsche accident making a rap song about the incident?
# The claim that the teenager is bragging about the incident in a profane rap song is unverified and lacks context. There is no evidence to support the claim that the teenager made a rap song about the incident, and the details of the incident are not provided.
# Best METEOR Score: 0.2062
# Generated Question 3: Does the rap song made by the teenager accused in the Pune Porsche accident contain profanity?
# There is no evidence to suggest that the teenager accused in the Pune Porsche accident made a rap song about the incident, let alone one that contains profanity. The claim appears to be unverified and lacks credible sources.
# Best METEOR Score: 0.2207
# Total METEOR Score (normalized): 0.2032
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a man from Bihar kill people in Telangana to hide a murder?
# Yes
# Best METEOR Score: 0.0490
# Generated Question 2: What was the motive behind the man from Bihar killing people in Telangana?
# The man from Bihar killed people in Telangana to hide the murder of his lover, according to the police.
# Best METEOR Score: 0.1114
# Generated Question 3: How many people were killed by the man from Bihar in Telangana?
# 9 people were killed by the man from Bihar in Telangana by being tossed into a well.
# Best METEOR Score: 0.0909
# Generated Question 4: Where did the man from Bihar kill the people to hide his crime?
# Telangana
# Best METEOR Score: 0.0980
# Generated Question 5: What method did the man from Bihar use to kill the people in Telangana?
# The man from Bihar tossed the people into a well to kill them and hide his crime.
# Best METEOR Score: 0.0901
# Generated Question 6: Was the man from Bihar successful in hiding the murder by killing people in Telangana?
# No, the police discovered the crime and the motive behind it.
# Best METEOR Score: 0.2046
# Total METEOR Score (normalized): 0.1304
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did a US C-130 military aircraft crash in Afghanistan\'s Farah province?
# No
# Best METEOR Score: 0.1259
# Generated Question 2: Is the claim that a United States C-130 military aircraft crashed in Afghanistan’s Farah province, killing and injuring hundreds of civilians and soldiers true?
# No, the claim is inaccurate. There is no evidence to suggest a US C-130 military aircraft crashed in Afghanistan’s Farah province, resulting in hundreds of casualties.
# Best METEOR Score: 0.3022
# Generated Question 3: Was the US C-130 military aircraft en route from Kabul to Qatar when it crashed in Farah province?
# No, there is no evidence to confirm the plane was going from Kabul to Qatar when it crashed. In fact, there is no evidence of the crash itself.
# Best METEOR Score: 0.1875
# Total METEOR Score (normalized): 0.1969
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Dr. Li Wenliang a Chinese doctor who endorsed tea as a cure for Covid-19?
# No
# Best METEOR Score: 0.1241
# Generated Question 2: Did Dr. Li Wenliang recommend tea as a treatment for Covid-19?
# There is no evidence to suggest Dr. Li Wenliang recommended tea as a cure for Covid-19. Dr. Li Wenliang was a Chinese doctor who warned about the Covid-19 outbreak, but his recommendations were based on medical treatments, not alternative remedies like tea.
# Best METEOR Score: 0.1102
# Generated Question 3: Does the claim that Dr. Li Wenliang recommended tea as a cure for Covid-19 have any scientific basis?
# No, the claim that Dr. Li Wenliang recommended tea as a cure for Covid-19 is unfounded. Dr. Li Wenliang was a medical professional who emphasized the importance of evidence-based medicine, and there is no record of him recommending tea as a treatment for Covid-19.
# Best METEOR Score: 0.2061
# Total METEOR Score (normalized): 0.1468
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are Muslims in India producing counterfeit hand sanitisers?
# No
# Best METEOR Score: 0.1284
# Generated Question 2: Is the claim that Muslims in India are manufacturing fake hand sanitisers accurate?
# No, the claim is inaccurate and lacks credible evidence. There is no reliable source to support the notion that Muslims in India are specifically involved in the production of counterfeit hand sanitisers.
# Best METEOR Score: 0.2745
# Generated Question 3: Do Muslims in India have a significant role in creating fake hand sanitisers?
# No, there is no substantial evidence to suggest that Muslims in India are predominantly involved in the manufacture of fake hand sanitisers. The production of counterfeit products is often linked to organized crime and is not specific to any particular community.
# Best METEOR Score: 0.2365
# Total METEOR Score (normalized): 0.2054
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Priyanka Gandhi protest at India Gate against the police action on Jamia students and the Citizenship Act?
# Yes
# Best METEOR Score: 0.0718
# Generated Question 2: What was the reason behind Priyanka Gandhi protesting at India Gate?
# Priyanka Gandhi protested at India Gate against the police action on Jamia students and the Citizenship Act, showing her support for the students and opposition to the Act.
# Best METEOR Score: 0.1096
# Generated Question 3: Where did Priyanka Gandhi protest against the police action on students and the Citizenship Act?
# India Gate. Priyanka Gandhi protested at India Gate in opposition to the police action on Jamia students and the Citizenship Act.
# Best METEOR Score: 0.1096
# Total METEOR Score (normalized): 0.0883
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Ireland expel its Israeli ambassador?
# No
# Best METEOR Score: 0.1297
# Generated Question 2: Is the claim that Ireland took Israel to the International Criminal Court accurate?
# No, the claim that Ireland took Israel to the International Criminal Court is inaccurate. There is no evidence to support this claim.
# Best METEOR Score: 0.2787
# Generated Question 3: Has Ireland taken any official action against Israel, including expelling its ambassador or taking it to the International Criminal Court?
# No, there is no evidence to suggest that Ireland has taken such actions against Israel. The claim appears to be untrue.
# Best METEOR Score: 0.1715
# Total METEOR Score (normalized): 0.1909
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Vladimir Putin participating in traditional Epiphany ice-bathing this year?
# No
# Best METEOR Score: 0.1570
# Generated Question 2: Is the claim that Russian President Vladimir Putin participated in traditional Epiphany ice-bathing this year accurate?
# There is no evidence to suggest that the claim about Russian President Vladimir Putin participating in traditional Epiphany ice-bathing this year is accurate. The claim may be misinformation or unverified.
# Best METEOR Score: 0.2032
# Generated Question 3: Did Russian President Vladimir Putin participate in traditional Epiphany ice-bathing this year amid rumors of cancer?
# There is no credible evidence to support the claim that Russian President Vladimir Putin participated in traditional Epiphany ice-bathing this year. The rumors about his health, including cancer, are unsubstantiated and unverified.
# Best METEOR Score: 0.2048
# Total METEOR Score (normalized): 0.1883
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the boy in the video performing namaz in the middle of a busy road in Pakistan?
# No
# Best METEOR Score: 0.2050
# Generated Question 2: Is the claim of a young boy performing namaz in the middle of a busy road in Pakistan accurate?
# No, the claim is inaccurate and the video does not show a young boy performing namaz in the middle of a busy road in Pakistan.
# Best METEOR Score: 0.2980
# Generated Question 3: Does the video show a boy performing namaz on a busy road in Pakistan?
# No, the video does not show a boy performing namaz on a busy road in Pakistan. The claim is false and there is no evidence to support it.
# Best METEOR Score: 0.2986
# Total METEOR Score (normalized): 0.2293
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the gigantic castle cake served only at Anant Ambani and Radhika Merchant\'s pre-wedding celebrations?
# No
# Best METEOR Score: 0.1797
# Generated Question 2: What is the significance of the gigantic castle cake at Anant Ambani and Radhika Merchant\'s pre-wedding celebrations?
# The claim about the gigantic castle cake being served at Anant Ambani and Radhika Merchant\'s pre-wedding celebrations is likely exaggerated or inaccurate. Without more information, it is difficult to determine the significance of the cake.
# Best METEOR Score: 0.1993
# Generated Question 3: Was the gigantic castle cake actually served at Anant Ambani and Radhika Merchant\'s pre-wedding celebrations?
# There is no evidence to confirm that a gigantic castle cake was served at Anant Ambani and Radhika Merchant\'s pre-wedding celebrations. The claim appears to be unsubstantiated.
# Best METEOR Score: 0.1379
# Total METEOR Score (normalized): 0.1707
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Will the SC review the verdict on the Aadhaar scheme on June 9?
# Yes
# Best METEOR Score: 0.0735
# Generated Question 2: What is the significance of the SC taking up pleas on the Aadhaar scheme on June 9?
# The SC taking up pleas on the Aadhaar scheme on June 9 is significant as it will review the verdict upholding the validity of the scheme, which may have implications for the future of the program.
# Best METEOR Score: 0.1489
# Generated Question 3: On what date will the SC take up pleas seeking review of the verdict on the Aadhaar scheme?
# June 9
# Best METEOR Score: 0.0714
# Total METEOR Score (normalized): 0.0886
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a New Delhi qazi threaten to make things harder for Hindus?
# No
# Best METEOR Score: 0.0924
# Generated Question 2: Is the claim about a New Delhi qazi threatening Hindus accurate?
# The claim about a New Delhi qazi threatening to make things harder for Hindus is not supported by evidence and appears to be unfounded. There is no credible source to confirm this claim, and it may be a baseless allegation.
# Best METEOR Score: 0.1613
# Generated Question 3: Does the claim about a New Delhi qazi threatening Hindus have any basis in fact?
# No, the claim that a New Delhi qazi threatened to make things harder for Hindus does not have any basis in fact. There is no record of such a threat being made, and the claim appears to be entirely fabricated.
# Best METEOR Score: 0.2573
# Total METEOR Score (normalized): 0.1703
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the rally of TDP chief Chandrababu Naidu at Kuppam in Andhra Pradesh witnessing a large crowd?
# Yes
# Best METEOR Score: 0.1202
# Generated Question 2: What is the scene like at the TDP chief Chandrababu Naidu’s rally at Kuppam, Andhra Pradesh?
# The scene at the TDP chief Chandrababu Naidu’s rally at Kuppam, Andhra Pradesh is one of large public gathering, with many people thronging to attend and show their support.
# Best METEOR Score: 0.1685
# Generated Question 3: Is the public attending the TDP chief Chandrababu Naidu’s rally at Kuppam, Andhra Pradesh in large numbers?
# Yes, the public is attending the rally in large numbers, indicating a significant level of support and interest in the event.
# Best METEOR Score: 0.1939
# Total METEOR Score (normalized): 0.1451
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim that a police officer pressed wrestler Sakshi Malik\'s face to the ground with his boot true?
# No
# Best METEOR Score: 0.1763
# Generated Question 2: Does the video show the Phogat sisters smiling while being detained by the police?
# No, the video does not show the Phogat sisters smiling while being detained. The claim that it does is inaccurate.
# Best METEOR Score: 0.3869
# Generated Question 3: Did a police officer really press Sakshi Malik\'s face to the ground with his boot during her detention?
# No, there is no evidence to suggest that a police officer pressed Sakshi Malik\'s face to the ground with his boot. The claim appears to be false.
# Best METEOR Score: 0.1587
# Total METEOR Score (normalized): 0.2318
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did MS Dhoni visit a gurudwara during the ongoing farmers\' protests?
# No
# Best METEOR Score: 0.1259
# Generated Question 2: Is the claim that MS Dhoni visited a gurudwara during the farmers\' protests accurate?
# There is no evidence to suggest that MS Dhoni visited a gurudwara during the farmers\' protests. The claim appears to be false and lacks credible sources to support it.
# Best METEOR Score: 0.2036
# Generated Question 3: Is there any truth to the claim that MS Dhoni visited a gurudwara during the ongoing farmers\' protests?
# No, there is no truth to the claim. MS Dhoni did not visit a gurudwara during the farmers\' protests. The claim is inaccurate and lacks credible sources to support it.
# Best METEOR Score: 0.2819
# Total METEOR Score (normalized): 0.1871
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the Delhi HC granting bail to the rape accused based solely on the tattoo of his name on the woman\'s arm?
# No
# Best METEOR Score: 0.1738
# Generated Question 2: What is the reasoning behind the Delhi HC granting bail to the rape accused in this specific case?
# The Delhi HC granted bail to the rape accused considering various factors, not solely because of the tattoo of his name on the woman\'s arm. The claim may be misleading, as the court takes into account multiple aspects before making such decisions.
# Best METEOR Score: 0.1563
# Generated Question 3: Does the presence of the accused\'s name tattooed on the woman\'s arm necessarily imply consent or a legitimate reason for granting bail in a rape case?
# No, the presence of a tattoo of the accused\'s name on the woman\'s arm does not necessarily imply consent or serve as a legitimate reason for granting bail in a rape case. The court considers various evidence and circumstances before making a decision.
# Best METEOR Score: 0.2495
# Total METEOR Score (normalized): 0.1930
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are 7 Punjab AAP MLAs rebelling against the party leadership?
# Yes
# Best METEOR Score: 0.0498
# Generated Question 2: What is the significance of 7 Punjab AAP MLAs declaring the state unit free from Delhi\'s control?
# The move indicates a power struggle within the party, with the MLAs likely seeking more autonomy and decision-making authority at the state level, potentially weakening the central leadership\'s grip on the state unit.
# Best METEOR Score: 0.1064
# Generated Question 3: Does the revolt by 7 Punjab AAP MLAs mean they are breaking away from the party?
# No, the revolt by 7 Punjab AAP MLAs does not necessarily mean they are breaking away from the party, but rather seeking to assert their independence and decision-making authority within the state unit, free from Delhi\'s control.
# Best METEOR Score: 0.1812
# Total METEOR Score (normalized): 0.1125
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did England win the 2022 Men\'s T20 World Cup semi-final by foul play?
# No
# Best METEOR Score: 0.1247
# Generated Question 2: Is the claim that PM Modi demanded a rematch of the 2022 Men\'s T20 World Cup semi-final due to England\'s alleged foul play accurate?
# No, the claim is inaccurate. There is no evidence to suggest that PM Modi made such a demand to the ICC.
# Best METEOR Score: 0.2400
# Generated Question 3: Was the 2022 Men\'s T20 World Cup semi-final replayed due to England\'s alleged foul play as demanded by PM Modi?
# No, the match was not replayed. The claim that England won by foul play and PM Modi demanded a rematch is false.
# Best METEOR Score: 0.2295
# Total METEOR Score (normalized): 0.1974
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Was the Rajiv Gandhi Foundation transformed into the PM CARES Fund by the Narendra Modi-led government?
# No
# Best METEOR Score: 0.1525
# Generated Question 2: What is the relationship between the Rajiv Gandhi Foundation and the PM CARES Fund?
# The claim that the Rajiv Gandhi Foundation was transformed into the PM CARES Fund by the Narendra Modi-led government is inaccurate. The PM CARES Fund is a separate entity established by the government, and it is not a transformation of the Rajiv Gandhi Foundation.
# Best METEOR Score: 0.2562
# Generated Question 3: Did the Narendra Modi-led government convert the Rajiv Gandhi Foundation into the PM CARES Fund?
# No, the Narendra Modi-led government did not convert the Rajiv Gandhi Foundation into the PM CARES Fund. The PM CARES Fund is a new entity that was established during the COVID-19 pandemic to provide relief and support to those affected.
# Best METEOR Score: 0.2139
# Total METEOR Score (normalized): 0.1924
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did US President Joe Biden insult PM Modi at the Quad Summit?
# No
# Best METEOR Score: 0.1259
# Generated Question 2: Is it true that US President Joe Biden snubbed PM Modi at the Quad Summit to talk to the new Australian PM Anthony Albanese?
# No, there is no evidence to suggest that US President Joe Biden insulted or snubbed PM Modi at the Quad Summit. The claim appears to be inaccurate and misleading.
# Best METEOR Score: 0.2105
# Generated Question 3: Was PM Modi snubbed by US President Joe Biden at the Quad Summit in favor of the Australian PM?
# No, there is no credible evidence to support the claim that US President Joe Biden insulted or snubbed PM Modi at the Quad Summit. The interaction between the leaders was likely a normal diplomatic exchange.
# Best METEOR Score: 0.1581
# Total METEOR Score (normalized): 0.1648
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the cut-out of Lionel Messi erected underwater by Argentina fans from Kerala to celebrate the team?
# No
# Best METEOR Score: 0.1788
# Generated Question 2: Did Argentina fans from Kerala erect a cut-out of Lionel Messi underwater to celebrate the team?
# There is no evidence to suggest that Argentina fans from Kerala erected a cut-out of Lionel Messi underwater. The claim appears to be inaccurate and may be a work of fiction or a misleading report.
# Best METEOR Score: 0.1577
# Generated Question 3: Are there any reports of Argentina fans from Kerala erecting a cut-out of Lionel Messi underwater to celebrate the team?
# No, there are no credible reports or evidence to suggest that Argentina fans from Kerala erected a cut-out of Lionel Messi underwater to celebrate the team. The claim is likely a fabrication or an exaggeration.
# Best METEOR Score: 0.1560
# Total METEOR Score (normalized): 0.1588
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the Ministry of Finance providing financial aid worth Rs. 30,628 to all Indian citizens?
# No
# Best METEOR Score: 0.1525
# Generated Question 2: Does the claim that the Ministry of Finance is providing financial aid worth Rs. 30,628 to all Indian citizens hold any truth?
# The claim that the Ministry of Finance is providing financial aid worth Rs. 30,628 to all Indian citizens is inaccurate and has no basis in reality. There is no evidence to support this claim, and it is likely a false rumor.
# Best METEOR Score: 0.2470
# Generated Question 3: Will every Indian citizen receive financial aid of Rs. 30,628 from the Ministry of Finance?
# No, the Ministry of Finance is not providing financial aid of Rs. 30,628 to every Indian citizen. This claim is false and lacks credible sources to support it.
# Best METEOR Score: 0.2072
# Total METEOR Score (normalized): 0.2006
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Fire and Fury Corps of the Indian Army based in Leh?
# Yes
# Best METEOR Score: 0.1225
# Generated Question 2: What is the significance of the Fire and Fury Corps in the Indian Army?
# The Fire and Fury Corps is a significant unit of the Indian Army, playing a crucial role in the country\'s defense, particularly in the Ladakh region. The new head of the corps will be responsible for overseeing its operations and strategy.
# Best METEOR Score: 0.1684
# Generated Question 3: Who is the new head of the Fire and Fury Corps of the Indian Army?
# The claim does not provide the name of the new head, however, it is stated that the Leh-based Fire and Fury Corps of the army has got a new head.
# Best METEOR Score: 0.1792
# Total METEOR Score (normalized): 0.1446
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was the earthquake that hit Ojai, California on August 20 a 5.5 magnitude earthquake?
# No
# Best METEOR Score: 0.1241
# Generated Question 2: Is the information about the 5.5 magnitude earthquake that hit Ojai, California on August 20 accurate?
# There is no record of a 5.5 magnitude earthquake hitting Ojai, California on August 20. The claim appears to be inaccurate and requires verification.
# Best METEOR Score: 0.1939
# Generated Question 3: Did a 5.5 magnitude earthquake occur in Ojai, California on August 20?
# No, there is no evidence to confirm that a 5.5 magnitude earthquake hit Ojai, California on August 20. The claim is likely incorrect and needs further investigation.
# Best METEOR Score: 0.1646
# Total METEOR Score (normalized): 0.1609
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Vladimir Putin announce a death sentence for burning the Quran in Russia?
# No
# Best METEOR Score: 0.1547
# Generated Question 2: Is it true that Vladimir Putin said burning a copy of the Quran in Russia would result in a death sentence?
# There is no evidence to suggest that Vladimir Putin made such a statement. The claim appears to be inaccurate and may be misinformation.
# Best METEOR Score: 0.2041
# Generated Question 3: Does Russian law, as stated by Vladimir Putin, prescribe a death sentence for desecrating the Quran?
# No, there is no record of Vladimir Putin making such a statement or implementing such a law in Russia. The claim is likely false and does not reflect the actual legal stance of Russia on the matter.
# Best METEOR Score: 0.2008
# Total METEOR Score (normalized): 0.1796
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was an Iftar party organised at Presidency University, Kolkata, on April 5?
# Yes
# Best METEOR Score: 0.0328
# Generated Question 2: What happened at Presidency University, Kolkata, on April 5, and how does it relate to the university\'s earlier decision on Saraswati Puja?
# An Iftar party was organised at Presidency University, Kolkata, on April 5, which is notable because the university had earlier denied permission for Saraswati Puja inside the campus, sparking controversy and debate over allegations of religious bias.
# Best METEOR Score: 0.1176
# Generated Question 3: Did Presidency University, Kolkata, allow an Iftar party on campus after denying permission for Saraswati Puja?
# Yes, Presidency University, Kolkata, allowed an Iftar party on campus on April 5, despite having earlier denied permission for Saraswati Puja, highlighting the university\'s stance on religious events and potential accusations of partiality.
# Best METEOR Score: 0.0700
# Total METEOR Score (normalized): 0.0698
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Mamata Banerjee promise to quit politics if she lost the Nandigram election?
# Yes
# Best METEOR Score: 0.0490
# Generated Question 2: Is the claim that Mamata Banerjee lost the Nandigram election and will quit politics accurate?
# No, the claim is partially inaccurate. While Mamata Banerjee did lose the Nandigram election, there is no evidence to suggest she has quit or will quit politics.
# Best METEOR Score: 0.2533
# Generated Question 3: Will Mamata Banerjee step down from politics after her defeat in Nandigram by 1,622 votes?
# No, there is no confirmation that Mamata Banerjee will quit politics due to her defeat in Nandigram. Despite the initial claim, her actual actions after the defeat do not align with quitting politics.
# Best METEOR Score: 0.1904
# Total METEOR Score (normalized): 0.1643
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Delhi state cancer institute shut due to coronavirus?
# Yes
# Best METEOR Score: 0.0821
# Generated Question 2: What is the reason behind the shutdown of the Delhi state cancer institute?
# The Delhi state cancer institute was shut after 18 staff members tested positive for coronavirus.
# Best METEOR Score: 0.0913
# Generated Question 3: How many staff members at the Delhi state cancer institute tested positive for coronavirus?
# 18 staff members at the Delhi state cancer institute tested positive for coronavirus, leading to its shutdown.
# Best METEOR Score: 0.1010
# Total METEOR Score (normalized): 0.0848
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are Indians still widely supporting the demonetisation policy?
# No
# Best METEOR Score: 0.1284
# Generated Question 2: Is the claim that Indians are still celebrating demonetisation accurate?
# No, the claim is inaccurate. Many Indians have expressed dissatisfaction and criticism towards the demonetisation policy, and it is not a widely celebrated event.
# Best METEOR Score: 0.3523
# Generated Question 3: Does the Indian population still view demonetisation as a positive move?
# No, many Indians do not view demonetisation as a positive move, citing its negative impacts on the economy and their personal livelihoods. The claim that they are still celebrating it is misleading.
# Best METEOR Score: 0.2415
# Total METEOR Score (normalized): 0.2328
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a Pakistani fighter recently captured in Panjshir, Afghanistan?
# No
# Best METEOR Score: 0.1271
# Generated Question 2: Is the claim that a Pakistani fighter was captured in Panjshir, Afghanistan accurate?
# There is no evidence to support the claim that a Pakistani fighter was recently captured in Panjshir, Afghanistan. The claim appears to be inaccurate and lacks credible sources.
# Best METEOR Score: 0.2426
# Generated Question 3: Is it true that a Pakistani fighter was captured in Panjshir, Afghanistan?
# No, there is no credible information or evidence to confirm that a Pakistani fighter was recently captured in Panjshir, Afghanistan. The claim is likely false.
# Best METEOR Score: 0.1837
# Total METEOR Score (normalized): 0.1784
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Coronavirus kill 1,12,000 people in China?
# No
# Best METEOR Score: 0.1586
# Generated Question 2: Is the claim that Coronavirus killed 1,12,000 people and infected 28 lakh in China accurate?
# No, the claim is inaccurate. According to official reports, the actual number of deaths and infections in China was different.
# Best METEOR Score: 0.2907
# Generated Question 3: Does the claim that Coronavirus infected 28 lakh people in China match the official numbers?
# No, the claim does not match the official numbers. Official reports show a different number of infections in China.
# Best METEOR Score: 0.2830
# Total METEOR Score (normalized): 0.2283
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did thousands of Russian army soldiers parachute into Ukraine?
# No
# Best METEOR Score: 0.0938
# Generated Question 2: Is the claim that thousands of Russian army soldiers parachuted into Ukraine accurate?
# No, the claim that thousands of Russian army soldiers parachuted into Ukraine is inaccurate. There is no evidence to support this claim, and it is likely a work of fiction or misinformation.
# Best METEOR Score: 0.2293
# Generated Question 3: Can it be confirmed that Russian army soldiers parachuted into Ukraine in large numbers?
# No, it cannot be confirmed that Russian army soldiers parachuted into Ukraine in large numbers. This claim appears to be unsubstantiated and lacks credible evidence to support it.
# Best METEOR Score: 0.1850
# Total METEOR Score (normalized): 0.1685
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the ruling on state consent for CBI probe aligned with the federal structure of India?
# Yes
# Best METEOR Score: 0.0966
# Generated Question 2: How does the ruling on state consent for CBI probe reflect the federal character of the Indian constitution?
# The ruling is in tune with the federal character of the Indian constitution as it respects the autonomy of states and requires their consent for CBI investigations, thereby balancing the power between the center and the states.
# Best METEOR Score: 0.1483
# Generated Question 3: What is the significance of state consent in CBI probes in relation to India\'s federal character?
# The requirement of state consent for CBI probes signifies that the ruling is consistent with the principles of federalism, which emphasizes the importance of cooperation and consent between the central government and state governments.
# Best METEOR Score: 0.1496
# Total METEOR Score (normalized): 0.1187
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Mohammad Sharief Niaz a 3-time Congress MLA from Jammu who passed away?
# Yes
# Best METEOR Score: 0.0490
# Generated Question 2: What happened to the 3-time Congress MLA Mohammad Sharief Niaz from Jammu?
# Mohammad Sharief Niaz, a 3-time Congress MLA from Jammu, passed away.
# Best METEOR Score: 0.0641
# Generated Question 3: Did Mohammad Sharief Niaz, a 3-time Congress MLA from Jammu, pass away?
# Yes, Mohammad Sharief Niaz, a 3-time Congress MLA from Jammu, passed away.
# Best METEOR Score: 0.0530
# Total METEOR Score (normalized): 0.0491
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Saleh Al-Jafarawi a Palestinian influencer who left Gaza for Qatar?
# No
# Best METEOR Score: 0.1265
# Generated Question 2: Did Saleh Al-Jafarawi really abandon Gaza for a life of luxury in Qatar?
# There is no evidence to confirm that Saleh Al-Jafarawi left Gaza for a luxurious life in Qatar. This claim appears to be unverified and potentially inaccurate.
# Best METEOR Score: 0.1346
# Generated Question 3: Is it true that Saleh Al-Jafarawi gave up his life in Gaza to live a luxurious life in Qatar?
# No, there is no credible information to support the claim that Saleh Al-Jafarawi abandoned Gaza for a luxurious life in Qatar. The details of his life and movements are not publicly known to confirm this statement.
# Best METEOR Score: 0.2336
# Total METEOR Score (normalized): 0.1602
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Enforcement Directorate (ED) involved in the case against Rhea Chakraborty?
# Yes
# Best METEOR Score: 0.1220
# Generated Question 2: What is the reason for the ED asking for case details in the FIR against Rhea Chakraborty from Bihar police?
# The ED is investigating the financial aspects of the case and needs the case details to proceed with their inquiry.
# Best METEOR Score: 0.1299
# Generated Question 3: Has the ED requested case details from the Bihar police in the case against Rhea Chakraborty?
# Yes, the ED has asked the Bihar police for case details in the FIR against Rhea Chakraborty.
# Best METEOR Score: 0.1412
# Total METEOR Score (normalized): 0.1188
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is West Bengal experiencing a surge in terrorist activities similar to Kashmir?
# No
# Best METEOR Score: 0.1555
# Generated Question 2: What is the current situation in West Bengal regarding terrorism and daily arrests?
# The claim that West Bengal has become a second Kashmir with terrorists being arrested daily is an exaggeration. While there may be some instances of terrorism, it is not comparable to the situation in Kashmir. The statement made by the state BJP chief is likely a political statement and not entirely factual.
# Best METEOR Score: 0.2273
# Generated Question 3: Are terrorists being arrested daily in West Bengal, making it similar to Kashmir?
# No, the situation in West Bengal is not similar to Kashmir in terms of terrorist activities and daily arrests. The claim made by the state BJP chief is an exaggeration and not entirely accurate. West Bengal does experience some instances of terrorism, but it is not comparable to the situation in Kashmir.
# Best METEOR Score: 0.3509
# Total METEOR Score (normalized): 0.2368
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Will all COVID-19 vaccinated individuals die within two years as stated by Luc Montagnier?
# No
# Best METEOR Score: 0.0915
# Generated Question 2: Is the claim that Nobel laureate Luc Montagnier said all COVID-19 vaccinated people will die within two years accurate?
# No, the claim is inaccurate. There is no scientific evidence to support the statement that all COVID-19 vaccinated individuals will die within two years. Luc Montagnier did make some controversial statements, but this specific claim has been debunked.
# Best METEOR Score: 0.1972
# Generated Question 3: Does the statement from Luc Montagnier about COVID-19 vaccinated individuals dying within two years have a scientific basis?
# No, the statement has been discredited and lacks scientific evidence. Luc Montagnier, a Nobel laureate, has made some unverified claims, but reputable health organizations and scientific communities have not supported this specific assertion.
# Best METEOR Score: 0.1581
# Total METEOR Score (normalized): 0.1489
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Beijing adhering to the pullback deal?
# No
# Best METEOR Score: 0.1594
# Generated Question 2: What is the current status of the talks between the parties involved in the pullback deal?
# The talks have hit a bump due to Beijing\'s hesitation in honoring the agreement.
# Best METEOR Score: 0.1126
# Generated Question 3: Has the pullback deal been successfully implemented?
# No, the deal has not been fully implemented as Beijing is dithering on honoring the agreement, causing a setback in the talks.
# Best METEOR Score: 0.1921
# Total METEOR Score (normalized): 0.1541
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim of a civilian thrashing a policeman during lockdown true?
# No
# Best METEOR Score: 0.1555
# Generated Question 2: What is the context of the claim about a civilian thrashing a policeman during lockdown?
# The claim about a civilian thrashing a policeman during lockdown is likely a misleading or exaggerated representation of an incident, and its context is not entirely accurate.
# Best METEOR Score: 0.2090
# Generated Question 3: Does the claim of a civilian thrashing a policeman during lockdown represent an isolated incident or a broader trend?
# The claim does not represent a broader trend, and such incidents are not commonly associated with lockdowns. The claim may be an isolated incident that has been blown out of proportion.
# Best METEOR Score: 0.1902
# Total METEOR Score (normalized): 0.1623
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Were Muslims responsible for attacking policemen in Bihar\'s Motihari?
# No
# Best METEOR Score: 0.1271
# Generated Question 2: Is the claim that Muslims attacked policemen in Bihar\'s Motihari when they tried to arrest an accused in a kidnapping case accurate?
# The claim that Muslims attacked policemen in Bihar\'s Motihari is inaccurate and lacks specific evidence to support it. There is no concrete information available to confirm the involvement of Muslims in the attack.
# Best METEOR Score: 0.2681
# Generated Question 3: Did Muslims attack policemen in Motihari, Bihar, during the arrest of a kidnapping accused?
# ...
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Hindus in Rajasthan face attacks from Muslims?
# No
# Best METEOR Score: 0.1284
# Generated Question 2: Is the claim about Hindus being attacked by Muslims in Rajasthan accurate?
# There is no evidence to support the claim that Hindus were attacked by Muslims in Rajasthan and the police did not help them. The claim appears to be a fabrication with no basis in fact.
# Best METEOR Score: 0.2757
# Generated Question 3: Were Hindus in Rajasthan attacked by Muslims and ignored by the police?
# No, there is no credible evidence to suggest that Hindus in Rajasthan were attacked by Muslims and ignored by the police. The claim is likely an exaggeration or a false narrative.
# Best METEOR Score: 0.2041
# Total METEOR Score (normalized): 0.1859
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the government distribute 35,000 crore LED bulbs in the country?
# No
# Best METEOR Score: 0.1842
# Generated Question 2: Is the claim about the government distributing 35,000 crore LED bulbs in the country accurate?
# No, the claim that the government distributed 35,000 crore LED bulbs is inaccurate. The actual number of LED bulbs distributed is different.
# Best METEOR Score: 0.3025
# Generated Question 3: Is it true that 35,000 crore LED bulbs were distributed by the government?
# No, the claim is false. The government did not distribute 35,000 crore LED bulbs. The correct figure is not available, but this claim is an exaggeration.
# Best METEOR Score: 0.2657
# Total METEOR Score (normalized): 0.2316
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did India condemn Turkey for supporting Pakistan over Kashmir?
# Yes
# Best METEOR Score: 0.0250
# Generated Question 2: What is India\'s stance on Turkey\'s support for Pakistan over the Kashmir issue?
# India has expressed strong opposition to Turkey\'s support for Pakistan\'s stance on Kashmir, with the Indian government criticizing President Erdogan\'s comments on the matter.
# Best METEOR Score: 0.0871
# Generated Question 3: Has India criticized Turkey for backing Pakistan\'s stand on Kashmir?
# Yes, India has criticized Turkey for supporting Pakistan\'s stance on Kashmir, with the Indian government viewing Turkey\'s actions as an interference in its internal affairs.
# Best METEOR Score: 0.0866
# Total METEOR Score (normalized): 0.0616
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the rally in Delhi against NPR and NRC organized by Muslims?
# No
# Best METEOR Score: 0.1833
# Generated Question 2: What is the nature of the rally in Delhi regarding NPR and NRC?
# The rally in Delhi against NPR and NRC is not exclusively organized by Muslims, the claim is inaccurate as people from different communities have participated in protests against NPR and NRC.
# Best METEOR Score: 0.2260
# Generated Question 3: Are Muslims the only community participating in the rally against NPR and NRC in Delhi?
# No, people from various communities are participating in the rally against NPR and NRC in Delhi, not just Muslims.
# Best METEOR Score: 0.1878
# Total METEOR Score (normalized): 0.1806
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Mukherjee walk barefoot to school in monsoon?
# No
# Best METEOR Score: 0.1284
# Generated Question 2: Is the claim that Mukherjee wore a gamcha and walked 2 km barefoot to school in monsoon true?
# There is no credible source to confirm that Mukherjee wore a gamcha and walked 2 km barefoot to school in monsoon. This claim appears to be anecdotal and lacks verification.
# Best METEOR Score: 0.1423
# Generated Question 3: Is it true that Mukherjee had to walk 2 km barefoot to school during monsoon due to lack of transportation?
# There is no evidence to suggest that Mukherjee had to walk 2 km barefoot to school during monsoon. The claim that he did so is unverified and lacks credible sources.
# Best METEOR Score: 0.1802
# Total METEOR Score (normalized): 0.1495
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has the Arvind Kejriwal government imposed any lockdown in Delhi until March 31?
# Yes
# Best METEOR Score: 0.0735
# Generated Question 2: Is the claim that the Arvind Kejriwal government has not imposed any lockdown in Delhi until March 31 accurate?
# No, the claim is inaccurate. The Arvind Kejriwal government has indeed imposed lockdown-like restrictions in Delhi due to the COVID-19 pandemic.
# Best METEOR Score: 0.3128
# Generated Question 3: Did the Arvind Kejriwal government impose lockdown in Delhi before March 31?
# Yes, the government imposed lockdown-like restrictions in Delhi before March 31 to curb the spread of COVID-19.
# Best METEOR Score: 0.0905
# Total METEOR Score (normalized): 0.1534
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has Rajinikanth announced his retirement from politics due to health concerns?
# Yes
# Best METEOR Score: 0.0563
# Generated Question 2: What is the reason behind Rajinikanth not joining politics as stated by him?
# Rajinikanth has stated that he won\'t be joining politics due to his frail health, which makes him unfit to handle the physical demands of a career in politics.
# Best METEOR Score: 0.1237
# Generated Question 3: Is Rajinikanth joining politics?
# No, Rajinikanth has stated that he won\'t join politics, citing his frail health as the main reason for this decision.
# Best METEOR Score: 0.1454
# Total METEOR Score (normalized): 0.1036
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Were the 14 arrested during anti-CAA protests in UP\'s Muzaffarnagar granted bail by the court?
# Yes
# Best METEOR Score: 0.0966
# Generated Question 2: What was the outcome for the 14 individuals arrested during the anti-CAA protests in Muzaffarnagar, UP?
# The court granted bail to the 14 individuals who were arrested during the anti-CAA protests in Muzaffarnagar, UP.
# Best METEOR Score: 0.1106
# Generated Question 3: What happened to the 14 people arrested during the anti-CAA protests in Muzaffarnagar, UP?
# The 14 individuals arrested during the anti-CAA protests in Muzaffarnagar, UP, were granted bail by the court.
# Best METEOR Score: 0.1111
# Total METEOR Score (normalized): 0.1005
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was an egg thrown at French President Emmanuel Macron?
# Yes
# Best METEOR Score: 0.0250
# Generated Question 2: What happened to French President Emmanuel Macron after his comments on Islam?
# An egg was thrown at him as a form of protest against his controversial comments on Islam.
# Best METEOR Score: 0.0337
# Generated Question 3: What was thrown at French President Emmanuel Macron after his comments on Islam?
# An egg was thrown at him, reportedly in response to the controversy surrounding his comments on Islam.
# Best METEOR Score: 0.0676
# Total METEOR Score (normalized): 0.0407
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Supreme Court giving a 15-day deadline for migrant movement?
# No
# Best METEOR Score: 0.1562
# Generated Question 2: Is the claim that the Supreme Court wants all migrants moved in 15 days accurate?
# No, the claim is inaccurate and lacks evidence. There is no such order from the Supreme Court regarding migrant movement within a specific timeframe.
# Best METEOR Score: 0.2556
# Generated Question 3: Does the Supreme Court have a policy to relocate migrants within a 15-day period?
# No, there is no such policy or order from the Supreme Court that mandates the relocation of migrants within a 15-day period. The claim is misleading and does not reflect any real directive from the court.
# Best METEOR Score: 0.2003
# Total METEOR Score (normalized): 0.2040
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the video showing a genuine incident of a cop beating women in a queue for ration in Noida?
# No
# Best METEOR Score: 0.1771
# Generated Question 2: What is the context of the video showing a cop beating women in a queue for ration in Noida?
# The video does not show a genuine incident of a cop beating women in a queue for ration in Noida. The claim that it does is inaccurate and likely misinformation.
# Best METEOR Score: 0.3425
# Generated Question 3: Did the incident of a cop beating women in a queue for ration in Noida actually occur?
# No, there is no evidence to suggest that the incident actually occurred. The video is likely staged or taken out of context.
# Best METEOR Score: 0.1751
# Total METEOR Score (normalized): 0.2214
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Karnataka speaker ask 8 MLAs to resign to buy time for the Congress-JDS?
# Yes
# Best METEOR Score: 0.0728
# Generated Question 2: What is the significance of the Karnataka speaker asking 8 MLAs to resign again?
# The Karnataka speaker asking 8 MLAs to resign again is a move to buy time for the Congress-JDS, potentially delaying the formation of a new government.
# Best METEOR Score: 0.1094
# Generated Question 3: How does the Karnataka speaker's request for 8 MLAs to resign impact the Congress-JDS coalition?
# The Karnataka speaker\'s request for 8 MLAs to resign gives the Congress-JDS coalition more time to regroup and potentially save their government from collapse.
# Best METEOR Score: 0.0875
# Total METEOR Score (normalized): 0.0883
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the Maharashtra tiger responsible for 8 deaths?
# Yes
# Best METEOR Score: 0.0754
# Generated Question 2: What are the challenges faced by the forest department in the Maharashtra tiger case?
# The forest department faces challenges similar to the Avni case, including containing the tiger and preventing further human-wildlife conflicts.
# Best METEOR Score: 0.1111
# Generated Question 3: How many victims has the Maharashtra tiger claimed?
# The Maharashtra tiger has claimed 8 victims.
# Best METEOR Score: 0.0728
# Total METEOR Score (normalized): 0.0804
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Dr. Reddy\'s, Bharat Biotech, and Bio E have to revise their proposals for human trials of Covid-19 vaccine candidates?
# Yes
# Best METEOR Score: 0.0536
# Generated Question 2: What happened to the proposals for human trials of Covid-19 vaccine candidates submitted by Dr. Reddy\'s, Bharat Biotech, and Bio E?
# The proposals for human trials of Covid-19 vaccine candidates submitted by Dr. Reddy\'s, Bharat Biotech, and Bio E were told to be revised.
# Best METEOR Score: 0.1014
# Generated Question 3: Why did Dr. Reddy\'s, Bharat Biotech, and Bio E have to revise their proposals for human trials of Covid-19 vaccine candidates?
# Dr. Reddy\'s, Bharat Biotech, and Bio E were told to revise their proposals for human trials of Covid-19 vaccine candidates due to the need for further clarification or modification to meet regulatory requirements.
# Best METEOR Score: 0.0994
# Total METEOR Score (normalized): 0.0653
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the video clip tweeted by Nitesh Rane accurate in depicting the former Chief Minister calling Aurangzeb his brother and a martyr?
# No
# Best METEOR Score: 0.2002
# Generated Question 2: Does the video clip show the former Chief Minister referring to Aurangzeb as his brother and a martyr?
# The video does not accurately represent the former Chief Minister\'s statement about Aurangzeb. The claim made in the tweet is misleading and lacks context.
# Best METEOR Score: 0.2651
# Generated Question 3: Did Nitesh Rane tweet a video clip showing the former Chief Minister talking about Aurangzeb as his brother and a martyr?
# No, the video clip tweeted by Nitesh Rane does not accurately represent the former Chief Minister\'s statement about Aurangzeb. The claim is misleading and lacks context.
# Best METEOR Score: 0.2745
# Generated Question 4: Is the claim made by Nitesh Rane about the video clip showing the former Chief Minister talking about Aurangzeb accurate?
# No
# Best METEOR Score: 0.1763
# Generated Question 5: Does the video clip tweeted by Nitesh Rane provide evidence of the former Chief Minister calling Aurangzeb his brother and a martyr?
# The video clip does not provide sufficient evidence to support the claim made by Nitesh Rane. The claim is inaccurate and lacks context.
# Best METEOR Score: 0.2528
# Generated Question 6: Did the former Chief Minister refer to Aurangzeb as his brother and a martyr in the video clip tweeted by Nitesh Rane?
# No, the former Chief Minister did not refer to Aurangzeb as his brother and a martyr in the video clip. The claim made in the tweet is misleading.
# Best METEOR Score: 0.3372
# Total METEOR Score (normalized): 0.2331
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 2
# --------------------------------------------------
#
# Average METEOR Score: 0.1402
