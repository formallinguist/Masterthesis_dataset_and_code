# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)

# %%
# @title Default title text
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
# Initialize Groq API client
client = Groq(api_key="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")


import re

def convert_to_json(llm_response):
    responseQuestions = []
    questions_llm = re.findall(r'\{(.*?)\}', llm_response, re.DOTALL)

    for question in questions_llm:
        question_json = {}

        q = re.findall(r'[\"\']question[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip()
        else:
            continue

        a = re.findall(r'[\"\']answer[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if a:
            question_json['answer'] = a[0].strip()

        at = re.findall(r'[\"\']answerType[\"\']:\s*[\"\']?(.*?)[\"\']', question, re.DOTALL)
        if at:
            question_json['answerType'] = at[0].strip()

        responseQuestions.append(question_json)

    return responseQuestions



def get_response_llm(claim, questions):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions and answer pairs in a single list json. Do not leave question and answer pair empty"

  try:
      response = client.chat.completions.create(
          messages=[
              {
                  "role": "user",
                  "content": prompt,
              }
          ],
          model="llama3-8b-8192",
          max_tokens=4000,
      )
      response = response.choices[0].message.content.strip()
      response_json = convert_to_json(response)
      return response_json
  except Exception as e:
      print(f"Error processing claim '{claim}': {e}, {response}")
      print("-*"*50)
      return ""

# %%
new_data = []

for data in combined_claims[:5010]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    q['answer'] = answer['answer']
    q['answerType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
print(len([1 for n in new_data if n['generatedQuestions'] == []]))
new_data
# Out:
# 20
# [{'claim': 'Kanpur: 22-year-old man beaten to death due to water splatter',
#   'generatedQuestions': [{'question': 'Was the incident a result of senseless violence?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What led to the altercation?',
#     'answer': 'Accidental water splatter',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the police take any actions against the perpetrators?',
#     'answer': 'Four people were arrested, and an investigation is ongoing',
#     'answerType': 'Extractive'},
#    {'question': 'Was the victim a victim of a hate crime?',
#     'answer': 'No information available',
#     'answerType': 'Boolean'},
#    {'question': 'What happened when the victim accidentally stepped on the water pouch?',
#     'answer': 'Water splashed on Faiz Mohammad and his associates, leading to a clash',
#     'answerType': 'Abstractive'},
#    {'question': 'Are the perpetrators still at large?',
#     'answer': 'The police are still searching for others involved',
#     'answerType': 'Boolean'},
#    {'question': 'Did the incident receive widespread media attention?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the age of the victim?',
#     'answer': '22 years old',
#     'answerType': 'Extractive'},
#    {'question': 'Where did the incident occur?',
#     'answer': 'Kanpur',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Gujarat groundnut production estimated to be higher this kharif season.',
#   'generatedQuestions': [{'question': 'Is the production of groundnuts higher in Gujarat this kharif season?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the expected outcome of groundnut production in Gujarat this kharif season?',
#     'answer': 'Higher',
#     'answerType': 'Boolean'},
#    {'question': 'What is the primary reason behind the expected increase in groundnut production in Gujarat this kharif season?',
#     'answer': 'Estimates suggest that the favorable weather conditions and optimal soil moisture are contributing factors.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions do farmers in Gujarat need to take to ensure maximum yield of groundnuts during this kharif season?',
#     'answer': 'Farmers need to ensure timely planting, proper irrigation, and pest management to maximize their crop yield.',
#     'answerType': 'Abstractive'},
#    {'question': 'How has the Indian Meteorological Department (IMD) been monitoring the weather conditions in Gujarat to determine the expected groundnut production?',
#     'answer': 'The IMD has been closely monitoring the weather conditions and aggregating data from nearby weather stations to make accurate predictions about groundnut production.',
#     'answerType': 'Extractive'},
#    {'question': 'In what ways is the Gujarat government supporting groundnut farmers to boost their yield this kharif season?',
#     'answer': 'The government is providing subsidies for agricultural inputs, training farmers on best practices, and promoting research and development in groundnut cultivation.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'After his daughter K Kavitha was charged in the Delhi liquor scam case, Telangana CM KCR praised Modi and claimed he was the PM’s “best friend”.',
#   'generatedQuestions': [{'question': 'Is Telangana CM KCR the one who praised Modi after K Kavitha was charged in the Delhi liquor scam case?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What did Telangana CM KCR say about Modi after K Kavitha was charged in the Delhi liquor scam case?',
#     'answer': 'He called him his “best friend”',
#     'answerType': 'Abstractive'},
#    {'question': 'Why did Telangana CM KCR praise Modi after K Kavitha was charged in the Delhi liquor scam case?',
#     'answer': "The reason behind KCR's praise for Modi remains unclear, but some speculate it could be due to political alliance or personal friendship.",
#     'answerType': 'Abstractive'},
#    {'question': 'Who was Telangana CM KCR praising when he called Modi his “best friend”?',
#     'answer': 'Prime Minister Narendra Modi',
#     'answerType': 'Extractive'},
#    {'question': 'What event or occasion led to Telangana CM KCR praising Modi as his “best friend”?',
#     'answer': 'When K Kavitha was charged in the Delhi liquor scam case',
#     'answerType': 'Extractive'},
#    {'question': "Did Telangana CM KCR's praise for Modi have any significant implications on their political relationship or Telangana-Indian politics?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Has Telangana CM KCR clarified or justified his praise for Modi after receiving criticism or backlash?',
#     'answer': 'Unknown',
#     'answerType': 'Boolean'},
#    {'question': "Are there any plausible explanations or interpretations for Telangana CM KCR's sudden praise for Modi after K Kavitha's charging of Delhi liquor scam case?",
#     'answer': "Some speculate it could be due to political survival, while others think it could be a sign of genuine admiration for Modi\\'s leadership.",
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "Dilip saikia's appointment as general secy shows bjp now wants to reward its own in assam",
#   'generatedQuestions': [{'question': 'Is Dilip Saikia a member of BJP?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What is the significance of Dilip Saikia's appointment as general secretary in Assam?",
#     'answer': "It indicates the BJP's desire to reward its own members in the state.",
#     'answerType': 'Abstractive'},
#    {'question': 'Why did the BJP appoint Dilip Saikia as general secretary in Assam?',
#     'answer': 'The party wishes to acknowledge his loyalty and faithful service as a member.',
#     'answerType': 'Abstractive'},
#    {'question': "What can be inferred about BJP's political stance in Assam from this appointment?",
#     'answer': 'The party seems to be focusing on internal growth and rewards rather than external influences.',
#     'answerType': 'Extractive'},
#    {'question': "What might be the underlying motive behind the BJP's decision to appoint Dilip Saikia?",
#     'answer': 'To demonstrate their commitment to internal loyalty and patronage within the party.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Police washing blood stains off the street after lathicharge against protesting farmers in Haryana’s Karnal on August 28.',
#   'generatedQuestions': [{'question': 'Were police involved in a violent crackdown on protesters in Karnal, Haryana?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the nature of the violence perpetrated by the police against the protesters?',
#     'answer': 'The police used a lathicharge and washed blood stains off the street.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the date of the incident in which the police used violence against the farmers?',
#     'answer': 'August 28',
#     'answerType': 'Extractive'},
#    {'question': 'Who were the victims of the police violence?',
#     'answer': 'Farmers',
#     'answerType': 'Extractive'},
#    {'question': 'What location was the site of the violent police crackdown on farmers?',
#     'answer': 'Karnal, Haryana',
#     'answerType': 'Extractive'},
#    {'question': 'Was the police action against the farmers justified?',
#     'answer': 'Undetermined',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'nia chargesheets 16 operatives of pro-khalistan group promoting secession in kashmir.',
#   'generatedQuestions': [{'question': 'Has NIA chargesheeted 16 operatives of a pro-Khalistan group?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the primary reason behind the chargesheeting of the 16 operatives?',
#     'answer': 'Promoting secession in Kashmir',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the group associated with the secessionist activities in Kashmir?',
#     'answer': 'Pro-Khalistan group',
#     'answerType': 'Extractive'},
#    {'question': 'What action did the NIA take against the 16 operatives?',
#     'answer': 'Chargesheeted them',
#     'answerType': 'Extractive'},
#    {'question': 'Who are the 16 operatives responsible for promoting secession in Kashmir?',
#     'answer': 'Operatives of the pro-Khalistan group',
#     'answerType': 'Extractive'},
#    {'question': 'Is the chargesheet a result of investigations by the NIA?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the significance of the chargesheet in the context of Kashmir?',
#     'answer': 'It highlights the efforts of the pro-Khalistan group to promote secession in Kashmir',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'A man performing namaz in the aisle and kicking windows in an Indian aircraft during flight.',
#   'generatedQuestions': [{'question': 'Was a man performing a religious ritual on an Indian aircraft during a flight?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the man doing on the aircraft that caused concern among passengers and crew?',
#     'answer': 'He was performing namaz in the aisle.',
#     'answerType': 'Abstractive'},
#    {'question': "Did the man's behavior cause any damage to the aircraft during the incident?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was the man's behavior described as by those who witnessed the incident?",
#     'answer': 'Kicking windows',
#     'answerType': 'Abstractive'},
#    {'question': 'Were any passengers or crew members injured during the incident?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What actions did the authorities take in response to the incident?',
#     'answer': 'Unclear',
#     'answerType': 'Abstractive'},
#    {'question': 'Was the man removed from the aircraft after the incident?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Did the incident cause any disruption to the flight?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Julian Assange said the goal of the Ukraine-Russia conflict was to launder money from the United States and Europe through Ukraine.',
#   'generatedQuestions': [{'question': 'Did Julian Assange link the Ukraine-Russia conflict to financial laundering?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the alleged goal of the Ukraine-Russia conflict according to Julian Assange?',
#     'answer': 'To launder money from the United States and Europe through Ukraine',
#     'answerType': 'Abstractive'},
#    {'question': 'Is the Ukrainian government involved in this alleged money laundering scheme, according to Julian Assange?',
#     'answer': 'Not explicitly stated',
#     'answerType': 'Boolean'},
#    {'question': 'What other entities or organizations, according to Julian Assange, are also involved in the alleged money laundering scheme?',
#     'answer': 'United States and Europe',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Julian Assange provide evidence to support his claim of financial laundering through the Ukraine-Russia conflict?',
#     'answer': 'Unknown',
#     'answerType': 'Boolean'},
#    {'question': "Are there any other reports or sources corroborating Julian Assange\\'s claims about the Ukraine-Russia conflict?",
#     'answer': 'Not provided',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "A crowd gathered to welcome Bhim Army chief Chandrashekhar Azad in Rajasthan's Jalore where a nine-year-old Dalit boy died after allegedly being assaulted by his teacher.",
#   'generatedQuestions': [{'question': 'Did a nine-year-old Dalit boy die after an alleged assault by his teacher?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the occasion when the crowd gathered in Jalore, Rajasthan?',
#     'answer': 'It was a welcome event for Bhim Army chief Chandrashekhar Azad',
#     'answerType': 'Abstractive'},
#    {'question': 'Who was the victim of the alleged assault?',
#     'answer': 'A nine-year-old Dalit boy',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is accused of assaulting the boy?',
#     'answer': "The boy\\'s teacher",
#     'answerType': 'Abstractive'},
#    {'question': 'What was the outcome of the alleged assault?',
#     'answer': 'The boy died',
#     'answerType': 'Abstractive'},
#    {'question': 'Were there any arrests or police action in response to the incident?',
#     'answer': 'It is unclear from the provided information',
#     'answerType': 'Abstractive'},
#    {'question': 'Where did the incident occur?',
#     'answer': 'In Jalore, Rajasthan',
#     'answerType': 'Abstractive'},
#    {'question': 'How old was the victim of the alleged assault?',
#     'answer': 'Nine years old',
#     'answerType': 'Extractive'},
#    {'question': 'Who was the leader being welcomed in Jalore?',
#     'answer': 'Chandrashekhar Azad',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'A wedding procession did not stop because of heavy rains caused by Cyclone Biparjoy.',
#   'generatedQuestions': [{'question': 'Was a wedding procession delayed due to Cyclone Biparjoy?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What weather condition was not responsible for delaying a wedding procession according to the claim?',
#     'answer': 'Heavy rains caused by Cyclone Biparjoy',
#     'answerType': 'Abstractive'},
#    {'question': 'Why was the wedding procession not delayed, according to the claim?',
#     'answer': 'Because of unknown reasons (Please note: The claim does not provide specific reasons)',
#     'answerType': 'Abstractive'},
#    {'question': 'What did not cause a delay in the wedding procession, according to the claim?',
#     'answer': 'Heavy rains caused by Cyclone Biparjoy',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Cannabis found at home, comedian bharti arrested.',
#   'generatedQuestions': [{'question': "Was cannabis found in Bharti\\'s home?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was found in Bharti\\'s home?",
#     'answer': 'Cannabis',
#     'answerType': 'Abstractive'},
#    {'question': "What did the police find at Bharti\\'s residence?",
#     'answer': 'Cannabis',
#     'answerType': 'Extractive'},
#    {'question': 'Who was arrested in connection with the discovery of cannabis at home?',
#     'answer': 'Bharti',
#     'answerType': 'Abstractive'},
#    {'question': 'What happened to Bharti as a result of the discovery of cannabis at home?',
#     'answer': 'Bharti was arrested',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "20 years later, four up cops among 6 booked for 'framing' man in drug case",
#   'generatedQuestions': [{'question': 'Did the four police officers have any previous involvement in a drug case?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'How many people were booked in connection with the drug case?',
#     'answer': '6',
#     'answerType': 'Extractive'},
#    {'question': 'What allegations were made against the four police officers in the drug case?',
#     'answer': 'That they "framed" Pintu Nishad, 22, in the drug case, 20 years after his death in the Kanpur clash.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is the person who allegedly was framed by the four police officers?',
#     'answer': 'Pintu Nishad',
#     'answerType': 'Extractive'},
#    {'question': 'What was the alleged motive behind the four police officers framing Pintu Nishad in the drug case?',
#     'answer': 'There was no stated motive, but the incident highlights the alleged lapses in the 1999 case.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Ram temple construction on rss annual meet agenda as sc order fuels anger against bjp.',
#   'generatedQuestions': [{'question': 'Is the Ram temple construction a contentious issue in India?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the anger towards the BJP following the SC order?',
#     'answer': "The Supreme Court\\'s decision to favour the Hindus in the Ayodhya dispute led to widespread anger and protests across the country.",
#     'answerType': 'Abstractive'},
#    {'question': 'What was the key topic discussed at the RSS annual meet following the SC order?',
#     'answer': 'The construction of the Ram temple was a key topic of discussion at the RSS annual meet.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the current status of the Ram temple construction?',
#     'answer': "The construction of the Ram temple has yet to begin despite the Supreme Court\\'s verdict in favour of the Hindus.",
#     'answerType': 'Extractive'},
#    {'question': 'Is the RSS involved in the efforts to construct the Ram temple?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the significance of the SC order in the controversy surrounding the Ram temple construction?',
#     'answer': 'The SC order has escalated tensions and polarized the nation, making the construction of the Ram temple a highly controversial issue.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is currently involved in the controversy surrounding the Ram temple construction?',
#     'answer': 'The dispute has pitted Hindus and Muslims against each other, with the BJP and RSS supporting the construction of the temple and the Opposition and religious leaders opposing it.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the timeline for the construction of the Ram temple?',
#     'answer': 'The exact timeline for the construction of the Ram temple has not been announced, but it is expected to begin soon.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'A man walking on water.',
#   'generatedQuestions': [{'question': 'Can a person walk on water in reality?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What is the scientific explanation for a person being unable to walk on water?',
#     'answer': 'The surface tension of water is not strong enough to support the weight of a person, and the density of water is greater than that of air, making it difficult to walk on it.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are there any recorded instances of a person walking on water in history or mythology?',
#     'answer': 'Yes, there are biblical accounts of Jesus Christ walking on water, and there are also mythological stories of gods and goddesses walking on water.',
#     'answerType': 'Abstractive'},
#    {'question': 'Can any skill or training enable a person to walk on water?',
#     'answer': 'No, without external assistance or supernatural intervention, it is not physically possible for a person to walk on water.',
#     'answerType': 'Boolean'},
#    {'question': 'What would happen if a person tried to walk on water without any flotation device or support?',
#     'answer': 'They would likely drown or struggle to stay afloat due to the density of water being greater than that of air.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'The mha stated to the supreme court that it has allowed university exams in the academic interest of students.',
#   'generatedQuestions': [{'question': 'Did the MHA issue a statement regarding university exams to the Supreme Court?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was the main reason for the MHA's decision to allow university exams, as stated in the statement?",
#     'answer': 'Academic interest of students',
#     'answerType': 'Abstractive'},
#    {'question': 'Has the MHA clarified the current situation regarding university exams in its statement to the Supreme Court?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What is the primary objective of the MHA's decision to allow university exams, according to its statement?",
#     'answer': 'To benefit students academically',
#     'answerType': 'Abstractive'},
#    {'question': 'Who did the MHA address its statement regarding university exams to, as mentioned in the report?',
#     'answer': 'The Supreme Court',
#     'answerType': 'Extractive'},
#    {'question': "Is the MHA's decision to allow university exams conditional on any specific criteria, according to its statement?",
#     'answer': 'Not mentioned',
#     'answerType': 'Boolean'},
#    {'question': "Was the MHA's decision to allow university exams influenced by the academic calendar, as stated in its statement?",
#     'answer': 'Not specified',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'The dead bodies of 72 people who died in the January 15 Nepal plane crash.',
#   'generatedQuestions': [{'question': 'Were there no survivors of the January 15 Nepal plane crash?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the cause of the crash that led to the deaths of 72 people?',
#     'answer': '',
#     'answerType': 'Abstractive'},
#    {'question': 'Who were the authorities informed about the plane crash and its aftermath?',
#     'answer': 'The crash was reported to the aviation authorities and the Nepalese government.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the response of the emergency services to the crash?',
#     'answer': 'Emergency services were immediately dispatched to the scene to provide assistance and evacuate the survivors.',
#     'answerType': 'Abstractive'},
#    {'question': 'Have any investigations or inquires been conducted into the cause of the crash?',
#     'answer': 'Yes, several investigations and inquiries have been conducted, but the exact cause of the crash is still under investigation.',
#     'answerType': 'Extractive'},
#    {'question': 'Are there any controversies or disputes surrounding the crash and its aftermath?',
#     'answer': 'Yes, there have been reports of disagreements over the handling of the crash and the allocation of resources for the relief effort.',
#     'answerType': 'Extractive'},
#    {'question': 'Did the international community offer assistance and support to Nepal after the crash?',
#     'answer': 'Yes, several countries and organizations offered assistance and support to Nepal in the aftermath of the crash.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many aircraft were affected by the crash, and what was the composition of the passengers and crew?',
#     'answer': '',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Man suffered a heart attack and died at work, co-workers clicked selfie thinking he’d fallen asleep.',
#   'generatedQuestions': [{'question': 'Did the man die at his workplace?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the initial impression of his colleagues about his condition?',
#     'answer': 'They thought he had fallen asleep.',
#     'answerType': 'Abstractive'},
#    {'question': "What were his colleagues' reactions immediately after assuming he was asleep?",
#     'answer': 'They clicked a selfie.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the man have any underlying health condition that contributed to his death?',
#     'answer': 'Yes, a heart attack.',
#     'answerType': 'Abstractive'},
#    {'question': "What was the cause of the man's death, according to the available information?",
#     'answer': 'Heart attack at work.',
#     'answerType': 'Extractive'},
#    {'question': 'Did his colleagues realize something was wrong with him later on?',
#     'answer': 'Yes, after taking the selfie.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "Won't dismantle encroachment without decision taken jointly with urban development ministry, delhi govt, railways",
#   'generatedQuestions': [{'question': 'Is the Delhi Government refusing to dismantle encroachment without a joint decision with the Urban Development Ministry and Railways?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the condition for the Delhi Government to dismantle encroachment as per the claim?',
#     'answer': 'The condition is a joint decision with the Urban Development Ministry and Railways.',
#     'answerType': 'Abstractive'},
#    {'question': 'Has the Delhi Government or Railways made any comments on dismantling encroachment according to the claim?',
#     'answer': 'No comment has been made by the Delhi Government or Railways, and the claim refers to their refusal to dismantle encroachment.',
#     'answerType': 'Abstractive'},
#    {'question': 'What would the Delhi Government need to do to dismantle encroachment according to the claim?',
#     'answer': 'The Delhi Government would need to make a joint decision with the Urban Development Ministry and Railways to dismantle the encroachment.',
#     'answerType': 'Extractive'},
#    {'question': 'Are there any alternatives to dismantling encroachment without a joint decision with the Urban Development Ministry and Railways, according to the claim?',
#     'answer': "The claim does not provide any information on alternatives, and it refers to the Delhi Government's refusal to dismantle encroachment without a joint decision.",
#     'answerType': 'Abstractive'},
#    {'question': 'What consequences may arise if the Delhi Government does not comply with the condition to dismantle encroachment, according to the claim?',
#     'answer': 'The claim does not provide any information on consequences, and it focuses on the condition required for dismantling encroachment.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Police evicting people from their homes in Assam after NRC.',
#   'generatedQuestions': [{'question': 'Are people being removed from their residences in Assam following the National Register of Citizens (NRC) update?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reported action taken by the police in Assam against individuals not included in the NRC?',
#     'answer': 'The police are allegedly evicting people from their homes in Assam.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are there reports of people being forcibly removed from their homes and properties in Assam after the NRC update?',
#     'answer': 'Yes, according to reports, many have been displaced and made homeless.',
#     'answerType': 'Abstractive'},
#    {'question': 'What has been the response of the Assam government and law enforcement agencies to allegations of forced evictions?',
#     'answer': 'The government claims to be taking necessary steps to ensure the safety and security of all citizens, but critics alleges that police are involvement in forced eviction of Muslim minorities.',
#     'answerType': 'Abstractive'},
#    {'question': 'Have there been any documented cases of police involvement in evictions and human rights abuses in Assam?',
#     'answer': 'Yes, numerous reports have surfaced of police brutality, extortion, and forced evictions, highlighting concerns over human rights violations.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "A lady constable speaks about the 'love jihad' conspiracy and how Hindu women are lured into marriage by Muslim men.",
#   'generatedQuestions': [{'question': 'Was the lady constable referring to a specific incident or phenomenon when discussing "love jihad"?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What did the lady constable claim was happening to Hindu women in the context of "love jihad"?',
#     'answer': 'They were being lured into marriage by Muslim men.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the term "love jihad" typically defined as?',
#     'answer': 'The phenomenon of Muslim men converting Hindu women to Islam by feigning romantic interest and marrying them.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the lady constable\'s stance on the issue of "love jihad"?',
#     'answer': 'She expressed concern and said it is a conspiracy.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are "love jihad" cases typically reported to the police?',
#     'answer': 'Not always.',
#     'answerType': 'Boolean'},
#    {'question': 'Is "love jihad" considered a hate crime or a form of terrorism by many groups?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'UP police ‘rescued’ Vaishali Yadav from Ukraine. Vaishali, the daughter of a Samajwadi Party leader from UP’s Hardoi, tried to defame the image of India and PM Modi.',
#   'generatedQuestions': [{'question': 'Is the claim about UP police rescuing Vaishali Yadav from Ukraine true?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What did Vaishali Yadav reportedly try to do to the image of India and PM Modi?',
#     'answer': 'defame',
#     'answerType': 'Abstractive'},
#    {'question': 'Who is the father of Vaishali Yadav?',
#     'answer': "a Samajwadi Party leader from UP's Hardoi",
#     'answerType': 'Abstractive'},
#    {'question': "What is the occupation of Vaishali Yadav's father?",
#     'answer': 'Samajwadi Party leader',
#     'answerType': 'Extractive'},
#    {'question': "What is the location of Vaishali Yadav's father's party affiliation?",
#     'answer': "UP's Hardoi",
#     'answerType': 'Extractive'},
#    {'question': "What was the reason behind Vaishali Yadav's action to defame India's image?",
#     'answer': 'not provided',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "Deepika Padukone appeared before NCB for questioning wearing a t-shirt that said 'I stand with Indian farmers'.",
#   'generatedQuestions': [{'question': "Did Deepika Padukone wear a t-shirt that said 'I stand with Indian farmers'?",
#     'answer': 'True',
#     'answerType': 'Boolean'},
#    {'question': 'What did the t-shirt worn by Deepika Padukone during her NCB appearance say?',
#     'answer': "'I stand with Indian farmers'",
#     'answerType': 'Abstractive'},
#    {'question': 'Why did Deepika Padukone wear the t-shirt during her NCB appearance?',
#     'answer': 'It was a show of solidarity with Indian farmers',
#     'answerType': 'Abstractive'},
#    {'question': 'Has Deepika Padukone been involved in any other controversies surrounding her fashion choices?',
#     'answer': 'No further information available',
#     'answerType': 'Extractive'},
#    {'question': 'Has Deepika Padukone spoken publicly about her support for Indian farmers?',
#     'answer': 'No specific information available',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Three maoists killed in bihar encounter',
#   'generatedQuestions': [{'question': 'Was an encounter between security forces and Maoists occurred in Bihar?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What happened to three Maoists as a result of the encounter in Bihar?',
#     'answer': 'They were killed.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who was involved in the encounter that resulted in the death of the three Maoists?',
#     'answer': 'Security forces and Maoists were involved in the encounter.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many Maoists were killed in the Bihar encounter?',
#     'answer': 'Three',
#     'answerType': 'Extractive'},
#    {'question': 'Where did the deadly encounter between security forces and Maoists take place?',
#     'answer': 'Bihar',
#     'answerType': 'Extractive'},
#    {'question': 'Were any arrests made by the police following the encounter that killed the three Maoists?',
#     'answer': 'Unknown',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Massacre in Kashmir after India revoked Article 370.',
#   'generatedQuestions': [{'question': 'Was there a massacre in Kashmir after India revoked Article 370?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the main consequence of the revocation of Article 370 in Kashmir?',
#     'answer': 'The Jammu and Kashmir region was downgraded from a state to a union territory, and India took direct administrative control.',
#     'answerType': 'Abstractive'},
#    {'question': 'What did the protests in Kashmir look like in the aftermath of Article 370 being revoked?',
#     'answer': 'Protesters clashed with security forces, and there were reports of fatalities, injuries, and widespread violence.',
#     'answerType': 'Extractive'},
#    {'question': 'Did several political leaders, including Omar Abdullah and Mehbooba Mufti, get arrested after Article 370 was revoked?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was the international response to India\\'s decision to revoke Article 370 in Kashmir?",
#     'answer': 'Several countries, including the US, UK, and European Union, expressed concerns about the situation in Kashmir and the potential human rights implications.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the official response of the Indian government to the allegations of human rights abuses in Kashmir after Article 370 was revoked?',
#     'answer': 'The Indian government denied allegations of human rights abuses and said that it was working to maintain law and order in the region.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
# ...
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What led to the Vizag-type tragedy and how do the NDMA guidelines aim to prevent such incidents?',
#     'answer': 'The tragedy was caused by a gas leak into the sea, resulting in the deaths of 12 people. The NDMA guidelines aim to prevent similar incidents by ensuring proper safety measures are in place during industrial activities.',
#     'answerType': 'Abstractive'},
#    {'question': 'What specific measures does the NDMA recommend for restarting industrial activities to prevent a Vizag-type tragedy?',
#     'answer': 'The NDMA guidelines recommend measures such as regular safety inspections, emergency response plans, and environmental monitoring to prevent accidents and minimize damage in case of an incident.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the NDMA provide a timeline for implementing the new guidelines for restarting industrial activities ?',
#     'answer': 'Yes, the NDMA provided a timeline for implementation of the guidelines.',
#     'answerType': 'Boolean'},
#    {'question': 'What are the consequences if the guidelines are not implemented for restarting industrial activities?',
#     'answer': 'The consequences of not implementing the guidelines could be disastrous, resulting in loss of life and damage to the environment.',
#     'answerType': 'Extractive'},
#    {'question': 'Did the NDMA collaborate with other agencies to develop the guidelines for restarting industrial activities?',
#     'answer': 'Yes, the NDMA collaborated with other agencies to develop the guidelines.',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'A journalist asking a question from the election commissioner, who skipped it.',
#   'generatedQuestions': [{'question': "Did the election commissioner skip a journalist\\'s question during a public gathering?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the nature of the question the journalist asked the election commissioner?',
#     'answer': 'The journalist asked a question related to an ongoing issue or scandal.',
#     'answerType': 'Abstractive'},
#    {'question': "Why do you think the election commissioner avoided answering the journalist\\'s question?",
#     'answer': 'Potential reasons include the commissioner not having an adequate response, being uncomfortable with the topic, or avoiding controversy.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the journalist take after being silenced by the election commissioner?',
#     'answer': 'The journalist may have filed a complaint, spoken to other officials, or reported the incident to the public.',
#     'answerType': 'Abstractive'},
#    {'question': 'Can you recall similar instances where public officials avoided questions from journalists?',
#     'answer': 'Yes, there have been instances where public officials have skipped questions or been evasive in their answers.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'RBI may extend moratorium on loans by 3 months report',
#   'generatedQuestions': [{'question': 'Will RBI impose additional fees on borrowers during the extended moratorium?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'What would be the likely impact of the 3-month moratorium extension on the economy?',
#     'answer': 'A potential setback for economic recovery',
#     'answerType': 'Abstractive'},
#    {'question': 'Can banks foreclose on properties during the extended moratorium period?',
#     'answer': 'No, under current rules',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the current interest rate offered by RBI on loans during the existing moratorium?',
#     'answer': 'The rate remains same as of now',
#     'answerType': 'Extractive'},
#    {'question': 'Will RBI consider re-amortizing loan payments during the extended moratorium?',
#     'answer': 'Yes, a possibility',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'ugc lists 24 fake universities, most in up and delhi.',
#   'generatedQuestions': [{'question': 'Did UGC identify 24 fake universities?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Which states have the most number of fake universities listed by UGC?',
#     'answer': 'Uttar Pradesh and Delhi',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the total number of fake universities listed by UGC?',
#     'answer': '24',
#     'answerType': 'Extractive'},
#    {'question': 'Is this a recent development?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What prompted the UGC to take action against fake universities?',
#     'answer': 'The UGC received complaints about the fake universities and conducted an investigation to verify their authenticity.',
#     'answerType': 'Abstractive'},
#    {'question': 'What measures are being taken by the UGC to tackle the issue of fake universities?',
#     'answer': 'The UGC is working with the police and other authorities to take action against the fake universities and ensure that students are protected from fake education.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "RBI's dollar mopping spree could slow down as us puts india on currency watchlist",
#   'generatedQuestions': [{'question': "Is RBI's dollar mopping spree already slow?",
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': "What is the rumor about RBI\\'s dollar mopping spree?",
#     'answer': "RBI\\'s dollar mopping spree could slow down.",
#     'answerType': 'Abstractive'},
#    {'question': "Why could RBI\\'s dollar mopping spree slow down?",
#     'answer': "The United States put India on its currency watchlist., which could affect RBI\\'s dollar mopping spree.",
#     'answerType': 'Abstractive'},
#    {'question': 'What action is the United States likely to take after putting India on its currency watchlist?',
#     'answer': "The United States may scrutinize India\\'s currency moves and potentially impose restrictions, slowing down RBI\\'s dollar mopping spree.",
#     'answerType': 'Abstractive'},
#    {'question': "Has RBI\\'s dollar mopping spree affected India\\'s economy before?",
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "Why would RBI\\'s dollar mopping spree slowing down be a concern for India\\'s economy?",
#     'answer': "Slowing down RBI\\'s dollar mopping spree could lead to economic instability and potentially affect India\\'s currency reserves.",
#     'answerType': 'Abstractive'},
#    {'question': "What negative consequence could RBI\\'s dollar mopping spree slowing down have on India\\'s economy?",
#     'answer': "It could lead to a depreciation in the value of the rupee and affect India\\'s ability to import goods and services.",
#     'answerType': 'Abstractive'},
#    {'question': 'What could RBI do if the dollar mopping spree slows down due to the currency watchlist?',
#     'answer': 'The RBI could optimize its foreign exchange reserves management strategies or consider alternative options to stabilize the rupee.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'A grand palace built by Chola emperor Rajaraja I for his wife in Gujarat’s Patan village.',
#   'generatedQuestions': [{'question': 'Was a grand palace built by a Chola emperor for his wife in Gujarat?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Which Chola emperor built a grand palace for his wife in Gujarat?',
#     'answer': 'Rajaraja I',
#     'answerType': 'Extractive'},
#    {'question': 'What was the purpose of the grand palace built by Chola emperor Rajaraja I in Gujarat?',
#     'answer': 'For his wife',
#     'answerType': 'Abstractive'},
#    {'question': 'In which village was the grand palace built by Chola emperor Rajaraja I for his wife?',
#     'answer': 'Patan',
#     'answerType': 'Extractive'},
#    {'question': 'Did the grand palace built by Chola emperor Rajaraja I for his wife still exist today?',
#     'answer': 'No',
#     'answerType': 'Boolean'},
#    {'question': 'Was the grand palace built by Chola emperor Rajaraja I for his wife a rare architectural feat in Gujarat?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the architectural style of the grand palace built by Chola emperor Rajaraja I for his wife?',
#     'answer': 'Unknown',
#     'answerType': 'Extractive'},
#    {'question': 'Who might have designed the grand palace built by Chola emperor Rajaraja I for his wife?',
#     'answer': 'Unknown',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': 'Bjp-trs tussle ahead of telangana bypoll has more to do with congress',
#   'generatedQuestions': [{'question': 'Is Congress a key player in the BJP-TRS tussle?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the primary reason behind the BJP-TRS tussle ahead of the Telangana bypoll?',
#     'answer': "The Congress party's involvement in the bypoll is the main cause of the tussle.",
#     'answerType': 'Abstractive'},
#    {'question': "How does the Congress party's role affect the relationship between BJP and TRS?",
#     'answer': "The Congress party's involvement has created a rift between the BJP and TRS, leading to a more competitive scenario in the bypoll.",
#     'answerType': 'Extractive'},
#    {'question': 'Has the Congress party benefited from the BJP-TRS tussle?',
#     'answer': 'Yes, the Congress party appears to be gaining traction from the rift between the BJP and TRS.',
#     'answerType': 'Abstractive'},
#    {'question': "Can the BJP-TRS tussle be resolved without Congress's involvement?",
#     'answer': "No, the Congress party's role in the bypoll has complicated the situation, making it more difficult to resolve the tussle.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  {'claim': "Temple priest, burnt alive over land dispute in rajasthan's karauli",
#   'generatedQuestions': [{'question': 'Was a temple priest killed in a land dispute in Rajasthan?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What was the main cause of the priest's death in Karauli, Rajasthan?",
#     'answer': 'A land dispute',
#     'answerType': 'Abstractive'},
#    {'question': 'In what circumstances was the temple priest from Rajasthan, India',
#     'answer': 'Burnt alive',
#     'answerType': 'Abstractive'},
#    {'question': "What was the outcome of the land dispute in Karauli, Rajasthan that led to the priest\\'s death?",
#     'answer': 'The priest was killed',
#     'answerType': 'Extractive'},
#    {'question': 'Who was the victim in the land dispute turned violent incident in Karauli, Rajasthan?',
#     'answer': 'A temple priest',
#     'answerType': 'Extractive'},
#    {'question': "Where did the land dispute turned violent incident occur that led to the priest\\'s death?",
#     'answer': 'Karauli, Rajasthan',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Was a 22-year-old man beaten to death due to water splatter in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What led to the clash that resulted in the man's death?",
#     'answer': 'The clash started when the victim, Pintu Nishad, accidentally stepped on a water pouch, causing water to splash on Faiz Mohammad and his associates.',
#     'answerType': 'Abstractive'},
#    {'question': 'What actions did the police take in response to the incident?',
#     'answer': 'The police arrested four people and are searching for others involved in the incident.',
#     'answerType': 'Abstractive'}]},
#  ...]

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences
    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))

for data in new_data:
  generated_sequences = [question['question']+'\n'+question.get('answer', "") for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question']+'\n'+question['answer'] for question in data['goldQuestions']]
  if not generated_sequences or not reference_sequences:
    continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generated Question 7: Is the landslide related to heavy snowfall confirmed in any official report?
# Yes
# Best METEOR Score: 0.2118
# Total METEOR Score (normalized): 0.3917
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 7 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Chinese Premier Xi Jinping officially endorse Rahul Gandhi\'s Bharat Jodo Nyay Yatra?
# No
# Best METEOR Score: 0.0386
# Generated Question 2: What is the likely reason behind Xi Jinping\'s alleged endorsement of Rahul Gandhi\'s yatra?
# To respect China\'s territorial sovereignty by omitting Arunachal Pradesh.
# Best METEOR Score: 0.0923
# Generated Question 3: What is Rahul Gandhi\'s Bharat Jodo Nyay Yatra about?
# It\'s a 3,500-kilometer march across India to reclaim the country\'s lost economic, social, and political ground, focusing on issues like inflation, unemployment, and inequality.
# Best METEOR Score: 0.1456
# Generated Question 4: Is Arunachal Pradesh\'s sovereignty a disputed territory between China and India?
# Yes
# Best METEOR Score: 0.1715
# Generated Question 5: What is the current relationship between China and India, specifically with regards to their borders?
# The border dispute between China and India is ongoing, with both countries having claimed sovereignty over the disputed territories.
# Best METEOR Score: 0.2078
# Generated Question 6: What did Rahul Gandhi\'s yatra aim to achieve by omitting Arunachal Pradesh?
# By omitting Arunachal Pradesh, Rahul Gandhi aimed to appease China and maintain a cordial relationship.
# Best METEOR Score: 0.1277
# Generated Question 7: Who is Rahul Gandhi and what is his role in Indian Politics?
# Rahul Gandhi is the leader of the Indian National Congress party and the son of the former Prime Minister of India, Rajiv Gandhi.
# Best METEOR Score: 0.1779
# Total METEOR Score (normalized): 0.1750
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Imran Khan attend an event with Israeli counterpart?
# Yes
# Best METEOR Score: 0.1284
# Generated Question 2: What was Imran Khan\'s reaction when he met the Israeli counterpart at the event?
# He refused to stand up and greet him.
# Best METEOR Score: 0.1306
# Generated Question 3: Did all world leaders stand up and greet their counterparts at the event?
# Yes, except Imran Khan.
# Best METEOR Score: 0.1649
# Generated Question 4: Which event did Imran Khan meet his Israeli counterpart at?
# The event details were not specified, but it was alleged to be an international meeting.
# Best METEOR Score: 0.0923
# Generated Question 5: Was this incident widely reported in the media?
# Yes, it was widely reported and sparked controversy.
# Best METEOR Score: 0.2050
# Generated Question 6: What was the reaction of the international community to Imran Khan\'s refusal to greet the Israeli counterpart?
# The reaction was mixed, with some criticizing his stance and others defending it.
# Best METEOR Score: 0.1805
# Generated Question 7: Has Imran Khan ever spoken about his actions at the event?
# Yes, he justified his actions by saying that it was a personal decision.
# Best METEOR Score: 0.2315
# Total METEOR Score (normalized): 0.1852
# Optimal Matching from Hungarian Algorithm:
# Generated Question 5 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 2
# Generated Question 7 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did JD(U) express concerns about the BJP
# Yes
# Best METEOR Score: 0.0394
# Generated Question 2: What party did JD(U) express concerns about repeating a "Maharashtra-like" drama?
# BJP
# Best METEOR Score: 0.0654
# Generated Question 3: What event did JD(U) associate with the party they expressed concerns about?
# The 2019 Maharashtra Assembly elections
# Best METEOR Score: 0.0947
# Generated Question 4: What happened in the 2020 Bihar polls that made JD(U) concerned about the BJP?
# JD(U) is referring to the NDA\'s poor performance in the polls
# Best METEOR Score: 0.2303
# Generated Question 5: What action did JD(U) take in response to their concerns about the BJP?
# Expressed concerns
# Best METEOR Score: 0.2926
# Generated Question 6: Is JD(U) part of the NDA?
# Yes
# Best METEOR Score: 0.1284
# Total METEOR Score (normalized): 0.1818
# Optimal Matching from Hungarian Algorithm:
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the poster held by Mamata Banerjee
# No
# Best METEOR Score: 0.0398
# Generated Question 2: Who is pictured with Mamata Banerjee on the poster?
# Amit Shah
# Best METEOR Score: 0.0394
# Generated Question 3: What is written on the poster held by Mamata Banerjee and Amit Shah?
# 'Jai Shri Ram'
# Best METEOR Score: 0.0958
# Generated Question 4: Why is this news significant or controversial?
# Mamata Banerjee, a prominent politician in the opposition party, being seen holding a poster with Amit Shah, the leader of the ruling party, might be seen as an appeasement or a sign of softening of stance by Mamata Banerjee.
# Best METEOR Score: 0.1510
# Generated Question 5: What might be the reactions or responses to this news?
# This news might elicit strong reactions from both supporters and detractors of Mamata Banerjee, with some perceiving it as a cynical attempt to gain political advantage and others seeing it as a genuine attempt to bridge divides.
# Best METEOR Score: 0.1365
# Generated Question 6: Has Mamata Banerjee denied or confirmed holding the poster?
#
# Best METEOR Score: 0.0593
# Generated Question 7: Who has the power to verify the authenticity of the poster?
# Mamata Banerjee, Amit Shah, or their respective parties/public relations teams could verify the authenticity of the poster.
# Best METEOR Score: 0.1273
# Generated Question 8: In what context or event might Mamata Banerjee have held the poster?
# The poster could have been held during a joint event, a press conference, or a visit to a common location.
# Best METEOR Score: 0.1613
# Total METEOR Score (normalized): 0.1401
# Optimal Matching from Hungarian Algorithm:
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# Generated Question 8 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Malaysian Muslims protest against PM Modi recently?
# Yes
# Best METEOR Score: 0.1293
# Generated Question 2: What was the main issue that led Malaysian Muslims to protest against PM Modi?
# The alleged persecution of Indian Muslims in recent times
# Best METEOR Score: 0.1311
# Generated Question 3: Have there been any previous protests or incidents involving Malaysian Muslims and Indian Muslims?
# Yes, there were reports of clashes and violence between Indian and Malaysian Muslims in Kanpur, Uttar Pradesh
# Best METEOR Score: 0.2219
# Generated Question 4: What did the Malaysian Muslims demand from the government during the protest?
# They demanded an end to the alleged persecution of Indian Muslims in India
# Best METEOR Score: 0.2362
# Generated Question 5: Were there any arrests or charges filed against the Malaysian Muslims who protested against PM Modi?
# No, there were no reports of arrests or charges filed against the protesters
# Best METEOR Score: 0.0730
# Generated Question 6: How many Malaysian Muslims were involved in the protest against PM Modi?
# Cannot be determined, but it was reported as a large gathering
# Best METEOR Score: 0.1394
# Generated Question 7: Did the Malaysian government officially condemn or support the protest against PM Modi?
# Yes, the government condemned the protest and appealed for calm
# Best METEOR Score: 0.1985
# Generated Question 8: Were there any international reactions or responses to the protest against PM Modi by Malaysian Muslims?
# Yes, several international organizations and countries condemned the alleged persecution of Indian Muslims in India and urged both sides to remain peaceful
# Best METEOR Score: 0.2126
# Total METEOR Score (normalized): 0.1866
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are incentives a prerequisite for a successful vehicle scrapping plan?
# Yes
# Best METEOR Score: 0.1738
# Generated Question 2: What are the primary obstacles to implementing the Modi government\'s vehicle scrapping plan?
# Lack of incentives and infrastructure
# Best METEOR Score: 0.1331
# Generated Question 3: Which two factors are hindering the Modi government\'s vehicle scrapping plan?
# Lack of incentives and lack of infrastructure
# Best METEOR Score: 0.0760
# Generated Question 4: Does the Modi government\'s vehicle scrapping plan rely on infrastructure for its success?
# Yes
# Best METEOR Score: 0.1242
# Generated Question 5: What infrastructure do authorities need to provide for the Modi government\'s vehicle scrapping plan to be effective?
# Proper infrastructure including recycling facilities and adequate disposal methods
# Best METEOR Score: 0.1292
# Generated Question 6: Are there any specific incentives that the Modi government\'s plan needs to offer to make it successful?
# Yes, incentives such as rebates and discounts on new vehicles
# Best METEOR Score: 0.2255
# Generated Question 7: Is the lack of infrastructure a major challenge for the Modi government\'s vehicle scrapping plan?
# Yes
# Best METEOR Score: 0.1670
# Generated Question 8: What would improve the chances of success for the Modi government\'s vehicle scrapping plan?
# Providing adequate incentives and infrastructure
# Best METEOR Score: 0.1136
# Total METEOR Score (normalized): 0.1531
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Dr. Tasuku Honjo claim that the coronavirus was manufactured by China?
# Yes
# Best METEOR Score: 0.1715
# Generated Question 2: What did Dr. Tasuku Honjo allegedly claim about the origin of the coronavirus?
# Dr. Tasuku Honjo allegedly claimed that China manufactured the coronavirus.
# Best METEOR Score: 0.1493
# Generated Question 3: What is the implication of Dr. Tasuku Honjo\'s claim about the coronavirus\'s origins?
# Dr. Tasuku Honjo\'s claim implies that the coronavirus was created by China, which could have significant political and scientific implications.
# Best METEOR Score: 0.1418
# Generated Question 4: Is Dr. Tasuku Honjo\'s claim about the coronavirus\'s origin supported by scientific evidence?
# The credibility and accuracy of Dr. Tasuku Honjo\'s claim have been disputed by the scientific community and experts, citing lack of reliable evidence.
# Best METEOR Score: 0.1683
# Generated Question 5: Have any official institutions or organizations corroborated Dr. Tasuku Honjo\'s claim about the coronavirus\'s origin?
# No, official institutions and organizations, including the World Health Organization and the Centers for Disease Control and Prevention, have not corroborated Dr. Tasuku Honjo\'s claim, and instead, have stated that the origin of the coronavirus is still under investigation.
# Best METEOR Score: 0.1501
# Total METEOR Score (normalized): 0.1633
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did India hold the presidency of the United Nations Security Council for the first time?
# Yes
# Best METEOR Score: 0.1346
# Generated Question 2: What is the significance of India holding the presidency of the United Nations Security Council for the first time?
# It marked a historic milestone for India's international relations and global diplomacy efforts.
# Best METEOR Score: 0.1799
# Generated Question 3: How did India's presidency of the United Nations Security Council impact its global relations?
# India's presidency showcased its growing influence and diplomatic prowess, strengthening its relationships with other countries and international organizations.
# Best METEOR Score: 0.1071
# Generated Question 4: What are the implications of India holding the presidency of the United Nations Security Council for the first time?
# The development is likely to give India a stronger voice on global issues, such as counter-terrorism, non-proliferation, and sustainable development.
# Best METEOR Score: 0.2091
# Generated Question 5: Who were some of the key players involved in India's presidency of the United Nations Security Council?
# Indian diplomats, along with representatives from other council member countries, played critical roles in shaping the council's agenda and making key decisions.
# Best METEOR Score: 0.1910
# Generated Question 6: What were some of the key issues addressed by India during its presidency of the United Nations Security Council?
# India focused on topics such as climate change, disarmament, and human rights, using its presidency to advance its priorities and promote international cooperation.
# Best METEOR Score: 0.1562
# Total METEOR Score (normalized): 0.1653
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was the journalist arrested under the Official Secrets Act (OSA) in Delhi?
# Yes
# Best METEOR Score: 0.2090
# Generated Question 2: What act was the journalist arrested under?
# The Official Secrets Act (OSA)
# Best METEOR Score: 0.0969
# Generated Question 3: What was the outcome of the journalist's bail plea in the Delhi court?
# The bail plea was rejected
# Best METEOR Score: 0.1331
# Generated Question 4: In which court was the journalist's bail plea rejected?
# Delhi court
# Best METEOR Score: 0.1014
# Generated Question 5: What was the journalist arrested for under the OSA?
# Unknown (not mentioned in the claim)
# Best METEOR Score: 0.2237
# Total METEOR Score (normalized): 0.1785
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was an autorickshaw driver beaten to death in Tenkasi, Tamil Nadu?
# Yes
# Best METEOR Score: 0.3219
# Generated Question 2: What was the alleged reason for the autorickshaw driver's death?
# Police assault
# Best METEOR Score: 0.1334
# Generated Question 3: Was the autorickshaw driver involved in any incident or altercation before his death?
# Unknown
# Best METEOR Score: 0.1442
# Generated Question 4: Did the police take immediate action after receiving reports of the incident?
# No
# Best METEOR Score: 0.2456
# Generated Question 5: What was the current condition of the autorickshaw driver before the alleged police assault?
# Unharmed
# Best METEOR Score: 0.1158
# Generated Question 6: Were there any eyewitnesses to the alleged police assault?
# Not disclosed
# Best METEOR Score: 0.0784
# Generated Question 7: Has the police department issued any statement regarding the incident?
# No confirmation
# Best METEOR Score: 0.1742
# Generated Question 8: Were any injuries or bruises found on the autorickshaw driver's body after the alleged police assault?
# Yes
# Best METEOR Score: 0.1218
# Generated Question 9: Were any weapons used during the alleged police assault?
# No
# Best METEOR Score: 0.0591
# Generated Question 10: Did the autorickshaw driver file a complaint before his death?
# No
# Best METEOR Score: 0.1020
# Total METEOR Score (normalized): 0.2336
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a Haryana policeman attacked by individuals with tractors?
# Yes
# Best METEOR Score: 0.2568
# Generated Question 2: What mode of transportation were used to attack the policeman?
# Tractors
# Best METEOR Score: 0.0784
# Generated Question 3: How far was the policeman's body dragged after being attacked?
# 50 metres
# Best METEOR Score: 0.0671
# Generated Question 4: Were the attackers identified or apprehended by the authorities?
# The police arrested four people and are searching for others involved in the incident.
# Best METEOR Score: 0.6701
# Generated Question 5: Were the attackers affiliated with Khalistanis?
# True
# Best METEOR Score: 0.0398
# Generated Question 6: What type of attack was this, as described in the claim?
# Physical attack
# Best METEOR Score: 0.1442
# Generated Question 7: Who was the victim of the attack, according to the claim?
# A Haryana policeman
# Best METEOR Score: 0.1325
# Total METEOR Score (normalized): 0.3436
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 7 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did VP Venkaiah Naidu attend the Kartarpur Corridor event?
# Yes
# Best METEOR Score: 0.1284
# Generated Question 2: What topic did VP Venkaiah Naidu discuss at the Kartarpur Corridor event?
# Peace
# Best METEOR Score: 0.0778
# Generated Question 3: Who also spoke at the Kartarpur Corridor event and issued a warning to Pakistan?
# Amarinder Singh
# Best METEOR Score: 0.0987
# Generated Question 4: What did Amarinder Singh warn Pakistan about at the Kartarpur Corridor event?
# None mentioned
# Best METEOR Score: 0.0775
# Generated Question 5: What is the Kartarpur Corridor used for?
# A border crossing between India and Pakistan
# Best METEOR Score: 0.0969
# Generated Question 6: Are there any reports of any violence or clashes during the Kartarpur Corridor event?
# No
# Best METEOR Score: 0.0579
# Total METEOR Score (normalized): 0.1010
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was the alleged rape attempt successful?
# No
# Best METEOR Score: 0.0699
# Generated Question 2: What was the reported disturbance that led to the intervention of the Muslim men in Lucknow?
# Unknown from the claim, but it mentions that the woman resisted the rape attempt.
# Best METEOR Score: 0.1812
# Generated Question 3: Were any official actions reported by the police in response to the alleged incident in Lucknow?
# Not mentioned in the claim, but it only makes the claim without providing any further details.
# Best METEOR Score: 0.3450
# Generated Question 4: Who were the alleged attackers in the alleged rape attempt in Lucknow?
# According to the claim, few Muslim men.
# Best METEOR Score: 0.1698
# Generated Question 5: Was the woman injured in the alleged incident in Lucknow?
# Not mentioned in the claim.
# Best METEOR Score: 0.2246
# Generated Question 6: Did the alleged incident in Lucknow result in any arrests?
# Not mentioned in the claim.
# Best METEOR Score: 0.2444
# Total METEOR Score (normalized): 0.2114
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the claim about a woman constable in Gujarat?
# Yes
# Best METEOR Score: 0.2162
# Generated Question 2: What was the woman constable transferred for?
# Arresting the minister's son and his friends over curfew violations
# Best METEOR Score: 0.1336
# Generated Question 3: What is the specific action that the woman constable is being transferred for?
# Arresting the minister's son and his friends
# Best METEOR Score: 0.1698
# Generated Question 4: Is this incident related to a law enforcement matter?
# Yes
# Best METEOR Score: 0.2162
# Generated Question 5: What was the minister's son and his friends alleged to have done?
# Violated a curfew
# Best METEOR Score: 0.1378
# Generated Question 6: Who took the action against the minister's son and his friends?
# A woman constable
# Best METEOR Score: 0.1246
# Generated Question 7: What is the result of the woman constable's actions?
# She is being transferred
# Best METEOR Score: 0.0969
# Total METEOR Score (normalized): 0.1746
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did an aide of President Biden make a statement on India getting a permanent seat in the UN Security Council?
# Yes
# Best METEOR Score: 0.2010
# Generated Question 2: What was the statement made by the aide of President Biden regarding India and the UN Security Council?
# He claimed that if elected, President Biden will help India get a permanent seat in the UN Security Council.
# Best METEOR Score: 0.2427
# Generated Question 3: What does the aide of President Biden attribute to his boss in helping India get a permanent seat in the UN Security Council?
# If elected, he will take action to help India get a permanent seat in the UN Security Council.
# Best METEOR Score: 0.2571
# Generated Question 4: What action has the aide of President Biden promised to take regarding India and the UN Security Council?
# According to the aide, President Biden will help India get a permanent seat in the UN Security Council if elected.
# Best METEOR Score: 0.3191
# Generated Question 5: Is President Biden's election expected to lead to India getting a permanent seat in the UN Security Council?
# According to the aide, yes, President Biden will take action to help India get a permanent seat in the UN Security Council if elected.
# Best METEOR Score: 0.2368
# Generated Question 6: What implication does the statement by the aide of President Biden have on India\'s bid for a permanent seat in the UN Security Council?
# It indicates that President Biden will support India\'s bid for a permanent seat in the UN Security Council if elected.
# Best METEOR Score: 0.2360
# Generated Question 7: What does the aide of President Biden hope to achieve in terms of the UN Security Council with President Biden\'s election?
# He hopes to help India get a permanent seat in the UN Security Council.
# Best METEOR Score: 0.2262
# Total METEOR Score (normalized): 0.2295
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is Mumbai experiencing its first cyclone in over 100 years?
# Yes
# Best METEOR Score: 0.1738
# Generated Question 2: What is the name of the cyclone that is expected to hit Mumbai?
# Nisarga
# Best METEOR Score: 0.0969
# Generated Question 3: Which other state is also bracing for the impact of cyclone Nisarga?
# Gujarat
# Best METEOR Score: 0.0778
# Generated Question 4: What is PM Modi doing to assess the situation?
# Reviewing the situation
# Best METEOR Score: 0.0977
# Generated Question 5: How many years has it been since Mumbai experienced a cyclone?
# Over 100 years
# Best METEOR Score: 0.0667
# Generated Question 6: What states are most likely to be affected by cyclone Nisarga?
# Maharashtra and Gujarat
# Best METEOR Score: 0.0969
# Generated Question 7: Has the government taken any measures to prepare for the cyclone?
# The police are searching for those involved in a recent incident and reviewing the situation.
# Best METEOR Score: 0.4945
# Total METEOR Score (normalized): 0.2488
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 7 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the police firing result in the death of hundreds of sadhus and gau rakshaks?
# Yes
# Best METEOR Score: 0.2202
# Generated Question 2: What were the sadhus and gau rakshaks protesting against when they were fired upon by the police?
# Anti-cow slaughter agitation
# Best METEOR Score: 0.1136
# Generated Question 3: What was the alleged instigation behind the police firing?
# Indira Gandhi government
# Best METEOR Score: 0.0977
# Generated Question 4: Were there any reports of violence or unrest during the anti-cow slaughter agitation?
#
# Best METEOR Score: 0.0389
# Generated Question 5: What was the outcome of the police firing on the sadhus and gau rakshaks?
# Hundreds of deaths
# Best METEOR Score: 0.1838
# Generated Question 6: Did the event occur on a specific date?
# November 7, 1966
# Best METEOR Score: 0.0785
# Generated Question 7: Who were the protest leaders among the sadhus and gau rakshaks?
#
# Best METEOR Score: 0.0784
# Generated Question 8: Were there any arrests or investigations following the police firing?
#
# Best METEOR Score: 0.0787
# Generated Question 9: What was the overall atmosphere or situation in Delhi during the time of the incident?
#
# Best METEOR Score: 0.1852
# Generated Question 10: Were there any reports of property damage or looting during the anti-cow slaughter agitation?
#
# Best METEOR Score: 0.0388
# Total METEOR Score (normalized): 0.1654
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# Generated Question 9 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did reports of cannibalism emerge in Haiti?
# Yes
# Best METEOR Score: 0.1775
# Generated Question 2: What sparked the rumors of cannibalism in Haiti?
# A social media post claiming to show a video of people eating human flesh sparked the rumors.
# Best METEOR Score: 0.1667
# Generated Question 3: What was the response of Haitian authorities to the allegations of cannibalism?
# Haiti\'s government and police have denied the claims of cannibalism and launched an investigation into the source of the rumors.
# Best METEOR Score: 0.2158
# Generated Question 4: Were any arrests made in connection to the cannibalism allegations?
# Three people were arrested in connection with the rumors, but they were later released without charge.
# Best METEOR Score: 0.2336
# Generated Question 5: Was cannibalism confirmed to have taken place in Haiti?
# No
# Best METEOR Score: 0.1370
# Total METEOR Score (normalized): 0.1783
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Were Israeli football fans involved in a violent attack in Amsterdam?
# Yes
# Best METEOR Score: 0.2133
# Generated Question 2: What happened to the Israeli football fans in Amsterdam?
# They were attacked by a group of violent individuals.
# Best METEOR Score: 0.1290
# Generated Question 3: What measures did the police take to address the incident?
# The police arrested several individuals and are investigating the incident.
# Best METEOR Score: 0.6274
# Generated Question 4: Who was responsible for the attack on Israeli football fans in Amsterdam?
# The police are searching for the perpetrators and investigating the motives behind the attack. A suspect was identified as a 30-year-old man.
# Best METEOR Score: 0.3236
# Total METEOR Score (normalized): 0.3254
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Were RSS workers involved in a violent incident involving a Christian couple?
# Yes
# Best METEOR Score: 0.2118
# Generated Question 2: What was the reason behind the violent incident involving the Christian couple?
# They resisted land grabbing by the RSS workers
# Best METEOR Score: 0.1515
# Generated Question 3: What was the outcome of the violent incident involving the Christian couple?
# The Christian couple was set ablaze
# Best METEOR Score: 0.1527
# Generated Question 4: Did the police take any action against the RSS workers involved in the incident?
# Unknown
# Best METEOR Score: 0.3430
# Generated Question 5: Who were the perpetrators of the violence against the Christian couple?
# RSS workers
# Best METEOR Score: 0.0778
# Generated Question 6: What did the Christian couple do to provoke the violent incident?
# They resisted land grabbing
# Best METEOR Score: 0.1351
# Generated Question 7: Were there any casualties in the violent incident involving the Christian couple?
# Yes
# Best METEOR Score: 0.1715
# Generated Question 8: What was the motive behind the RSS workers' actions in the violent incident?
# Land grabbing
# Best METEOR Score: 0.2046
# Total METEOR Score (normalized): 0.2109
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 8 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim related to restructuring of paramilitary forces?
# Yes
# Best METEOR Score: 0.1750
# Generated Question 2: What is the reason for the government\'s decision to induct ex-armymen into CISF?
# Rehabilitation of ex-armymen
# Best METEOR Score: 0.1149
# Generated Question 3: How many ex-armymen are expected to be inducted into CISF under this move?
# 2,000
# Best METEOR Score: 0.0667
# Generated Question 4: What is the age limit for the ex-armymen to be inducted into CISF?
# Below 50
# Best METEOR Score: 0.1158
# Generated Question 5: What is the purpose of inducting ex-armymen into CISF?
# Rehabilitation of ex-armymen
# Best METEOR Score: 0.0586
# Generated Question 6: Are all the inducted ex-armymen expected to be former soldiers who served under 50?
# Yes
# Best METEOR Score: 0.1692
# Total METEOR Score (normalized): 0.1228
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has NIA filed charges against KLF operative in a narco-terror case?
# Yes
# Best METEOR Score: 0.2133
# Generated Question 2: What is the nature of the case for which NIA has filed charges against KLF operative?
# A narco-terror case
# Best METEOR Score: 0.0951
# Generated Question 3: Were any other individuals or groups involved in the alleged narco-terror activity?
# Unknown
# Best METEOR Score: 0.1735
# Generated Question 4: What is the date or time frame by which the KLF operative was expected to respond to the charges?
# Not provided
# Best METEOR Score: 0.1274
# Generated Question 5: Has the KLF operative denied any involvement in the alleged narco-terror activity?
# Unspecified
# Best METEOR Score: 0.1735
# Generated Question 6: What is the current legal status of the KLF operative after the charges were filed?
# Under investigation
# Best METEOR Score: 0.0958
# Total METEOR Score (normalized): 0.1588
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a girl get murdered in an UP village?
# Yes
# Best METEOR Score: 0.2162
# Generated Question 2: What was the gruesome extent of the girl\'s injuries?
# Eyes gouged out, tongue slit
# Best METEOR Score: 0.0777
# Generated Question 3: Who reported the incident to the police?
# Cops
# Best METEOR Score: 0.1389
# Generated Question 4: What is the jurisdiction where the crime took place?
# UP
# Best METEOR Score: 0.0984
# Generated Question 5: What type of crime did the girl suffer from?
# Rape and murder
# Best METEOR Score: 0.0977
# Generated Question 6: How old was the girl who was murdered?
#
# Best METEOR Score: 0.0694
# Generated Question 7: What is the current investigation status in the case?
# Under investigation
# Best METEOR Score: 0.1459
# Generated Question 8: Did the police get any leads on the case?
#
# Best METEOR Score: 0.2263
# Generated Question 9: Is the identity of the perpetrator(s) known?
# No
# Best METEOR Score: 0.0588
# Generated Question 10: What is the current situation in the village where the crime took place?
# Not specified
# Best METEOR Score: 0.1351
# Total METEOR Score (normalized): 0.1735
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 8 matched with Reference Question 3
# Generated Question 10 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is Joshimath, India, experiencing soil subsidence?
# Yes
# Best METEOR Score: 0.1293
# Generated Question 2: What is causing the soil subsidence in Joshimath?
# Over-extraction of groundwater and natural geology
# Best METEOR Score: 0.0969
# Generated Question 3: What is the effect of the soil subsidence on Joshimath?
# It is causing the city to sink vertically and horizontally, leading to cracks and fissures on the surface.
# Best METEOR Score: 0.1875
# Generated Question 4: What measures have been taken to address the soil subsidence in Joshimath?
# The government has implemented measures such as reducing groundwater extraction, monitoring soil movement, and developing a detailed survey of the affected areas.
# Best METEOR Score: 0.2262
# Generated Question 5: Are there any recorded instances of structures collapsing or damage to infrastructure due to soil subsidence in Joshimath?
# Yes, several structures have collapsed or been damaged, including roads, buildings, and monuments.
# Best METEOR Score: 0.2972
# Generated Question 6: Is Joshimath the only area experiencing soil subsidence in Uttarakhand?
# No, other areas in Uttarakhand are also experiencing similar issues.
# Best METEOR Score: 0.1316
# Total METEOR Score (normalized): 0.2369
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the LAC a recent development in India's military strategy?
# No
# Best METEOR Score: 0.1014
# Generated Question 2: What is the primary role of enhanced airlift capability in India's LAC buildup?
# To rapidly deploy troops and equipment to the Line of Actual Control (LAC)
# Best METEOR Score: 0.1282
# Generated Question 3: Which Indian Air Force (IAF) capabilities are being upgraded to support the LAC buildup?
# The C-17 Globemaster III and the C-130J Super Hercules are being upgraded with modern avionics and communication systems.
# Best METEOR Score: 0.1907
# Generated Question 4: How has India's airlift capability evolved to support the LAC buildup?
# India has indigenously developed the Advanced Light Helicopter (ALH) and the Light Combat Helicopter (LCH) to support airlift operations.
# Best METEOR Score: 0.1250
# Generated Question 5: Was the IAF's airlift capability a major drawback during the 1962 India-China war?
# Yes
# Best METEOR Score: 0.2090
# Generated Question 6: What would be the consequences of not upgrading India's airlift capability to support the LAC buildup?
# It could lead to a strategic disadvantage for India, making it difficult to respond quickly to Chinese aggression.
# Best METEOR Score: 0.1423
# Total METEOR Score (normalized): 0.1783
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 1
# Generated Question 6 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Sadhguru host an event in March that attracted foreigners?
# Yes
# Best METEOR Score: 0.1738
# Generated Question 2: What is the estimated number of foreigners who attended Sadhguru's event in March?
# 150
# Best METEOR Score: 0.1108
# Generated Question 3: What was the outcome of the foreigners attending Sadhguru's event in March in terms of COVID-19 cases in Tamil Nadu?
# Over 1,000 corona cases
# Best METEOR Score: 0.1115
# Generated Question 4: What is the current location of the quarantined foreigners?
# Isha Yoga Center
# Best METEOR Score: 0.0781
# Total METEOR Score (normalized): 0.1320
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Has a chargesheet been filed by the Enforcement Directorate (ED) against Saeed and others in a terror financing case?
# Yes
# Best METEOR Score: 0.1998
# Generated Question 2: What is the nature of the chargesheet filed by the ED against Saeed and others?
# The ED has filed a chargesheet against Saeed and others in a terror financing case.
# Best METEOR Score: 0.1818
# Generated Question 3: Who are the individuals against whom the ED has filed the chargesheet?
# The ED has filed the chargesheet against Saeed and others
# Best METEOR Score: 0.2000
# Generated Question 4: What is the purpose of the chargesheet filed by the ED against Saeed and others?
# The ED has filed the chargesheet to prosecute Saeed and others for terror financing.
# Best METEOR Score: 0.2506
# Generated Question 5: What action would the ED take next after filing the chargesheet against Saeed and others?
# The ED would proceed with the prosecution of Saeed and others after filing the chargesheet.
# Best METEOR Score: 0.2497
# Generated Question 6: Is the ED's chargesheet against Saeed and others the first case against them?
# No
# Best METEOR Score: 0.0965
# Total METEOR Score (normalized): 0.1985
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was a protest held by supporters of former Brazilian president Jair Bolsonaro?
# Yes
# Best METEOR Score: 0.2517
# Generated Question 2: What was the purpose of the gathering of Bolsonaro's supporters?
# The purpose was to ransack the national congress
# Best METEOR Score: 0.1824
# Generated Question 3: What was the outcome of the protest?
# The national congress was damaged during the protest
# Best METEOR Score: 0.1646
# Generated Question 4: How many people were involved in the protest?
# Multiple sources reported thousands of people participated in the protest
# Best METEOR Score: 0.1831
# Generated Question 5: Were any arrests made after the protest?
# Yes, multiple sources reported several people were arrested
# Best METEOR Score: 0.1234
# Generated Question 6: What was the reaction of the government to the protest?
# The government condemned the violent actions of the protesters and promised to increase security measures
# Best METEOR Score: 0.1673
# Generated Question 7: How did the international community respond to the protest?
# Multiple sources reported international leaders denounced the violence and called for peaceful resolution
# Best METEOR Score: 0.1504
# Generated Question 8: Were any police officers injured during the protest?
# Yes, multiple sources reported several police officers were injured
# Best METEOR Score: 0.1218
# Generated Question 9: What has been the long-term impact of the protest on Brazilian politics?
# The protest has led to increased tensions and divisions in Brazilian society
# Best METEOR Score: 0.1679
# Total METEOR Score (normalized): 0.1942
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Were doctors suspended for oxygen supply issues at the Jammu hospital?
# Yes
# Best METEOR Score: 0.1267
# Generated Question 2: What was the reason for the suspension of the hospital staff?
# Oxygen supply issues
# Best METEOR Score: 0.1163
# Generated Question 3: Which hospital in Jammu is involved in the oxygen supply issue incident?
# Jammu hospital
# Best METEOR Score: 0.1981
# Generated Question 4: How many people were suspended for the oxygen supply issues at the Jammu hospital?
# 2
# Best METEOR Score: 0.0965
# Generated Question 5: What authorities took action against the hospital staff for oxygen supply issues?
# Authorities suspended the staff
# Best METEOR Score: 0.1346
# Total METEOR Score (normalized): 0.1300
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did the Supreme court reject a plea for government nominees on mosque trust?
# Yes
# Best METEOR Score: 0.1704
# Generated Question 2: What was the outcome of the plea that was presented to the Supreme court?
# The Supreme court rejected the plea.
# Best METEOR Score: 0.2382
# Generated Question 3: What were the government nominees seeking in the mosque trust?
# Information not available
# Best METEOR Score: 0.1659
# Generated Question 4: What is the significance of the Supreme court's decision in this case?
# The decision has implications for the management of mosque trusts in the country.
# Best METEOR Score: 0.2345
# Generated Question 5: Which court rejected the plea for government nominees on mosque trust?
# The Supreme court
# Best METEOR Score: 0.0775
# Total METEOR Score (normalized): 0.1847
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Defence Minister Rajnath Singh officially open the 44 strategic bridges?
# True
# Best METEOR Score: 0.0586
# Generated Question 2: What is significant about the location of 7 bridges among the 44 strategic bridges?
# They were built in Ladakh.
# Best METEOR Score: 0.1136
# Generated Question 3: Who is credited with building the 44 strategic bridges, according to the claim?
# Bro
# Best METEOR Score: 0.0965
# Generated Question 4: How many strategic bridges were inaugurated by Defence Minister Rajnath Singh, according to the claim?
# 44
# Best METEOR Score: 0.0766
# Generated Question 5: In which region did the Defence Minister inaugurate some bridges, specifically 7 among the 44?
# Ladakh
# Best METEOR Score: 0.0958
# Generated Question 6: Who is the Defence Minister mentioned in the claim, responsible for inaugurating the 44 strategic bridges?
# Rajnath Singh
# Best METEOR Score: 0.1521
# Total METEOR Score (normalized): 0.0984
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# Generated Question 6 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was Tablighi jamaat event linked to the spread of coronavirus in many persons?
# Yes
# Best METEOR Score: 0.2480
# Generated Question 2: What is the claim made by the Ministry of Home Affairs (MHA) about the Tablighi jamaat event and coronavirus spread?
# The MHA claims that the Tablighi jamaat event caused the spread of coronavirus to many persons.
# Best METEOR Score: 0.1767
# Generated Question 3: How many persons were allegedly affected by the spread of coronavirus following the Tablighi jamaat event, according to the MHA claim?
#
# Best METEOR Score: 0.1128
# Generated Question 4: Did the MHA provide evidence to support the claim that Tablighi jamaat event caused coronavirus spread to many persons?
#
# Best METEOR Score: 0.1141
# Generated Question 5: What was the nature of the Tablighi jamaat event that allegedly led to the spread of coronavirus, according to the MHA claim?
# The event was described as a mass gathering or congregation.
# Best METEOR Score: 0.2078
# Generated Question 6: What actions were taken by the authorities in response to the alleged coronavirus spread following the Tablighi jamaat event?
#
# Best METEOR Score: 0.2829
# Total METEOR Score (normalized): 0.2462
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# Generated Question 6 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Prince Charles meet Kanika Kapoor before testing positive for coronavirus?
# Yes
# Best METEOR Score: 0.1267
# Generated Question 2: What was the alleged connection between Prince Charles meeting Kanika Kapoor and his coronavirus diagnosis?
# According to reports, Prince Charles tested positive for coronavirus after meeting Kanika Kapoor, an Indian singer who was in London at the time.
# Best METEOR Score: 0.1671
# Generated Question 3: What action did Prince Charles take after testing positive for coronavirus?
# As a precautionary measure, Prince Charles went into isolation after testing positive for coronavirus.
# Best METEOR Score: 0.2112
# Generated Question 4: Was Prince Charles the first royal to test positive for coronavirus?
# No
# Best METEOR Score: 0.1014
# Generated Question 5: How did Prince Charles' diagnosis affect the royal family\'s activities?
# As a result of Prince Charles\' diagnosis, some royal family events were postponed or cancelled to minimize the risk of transmission.
# Best METEOR Score: 0.1108
# Total METEOR Score (normalized): 0.1683
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is technology used in schools necessary for meeting learning outcomes, according to schools?
# Yes
# Best METEOR Score: 0.2090
# Generated Question 2: What do schools say about the role of technology in meeting learning outcomes?
# They suggest that productive screen time may be necessary
# Best METEOR Score: 0.0940
# Generated Question 3: What learning outcome can technology help achieve, according to schools?
# They imply that it can help achieve learning outcomes
# Best METEOR Score: 0.0758
# Generated Question 4: In what ways can technology be used in schools to meet learning outcomes?
# Productive screen time may be one
# Best METEOR Score: 0.1141
# Generated Question 5: What are the benefits of using technology in schools for meeting learning outcomes, according to schools?
# They suggest that productive screen time can be necessary
# Best METEOR Score: 0.1481
# Generated Question 6: Can technology be used as a tool to enhance learning outcomes in schools, according to schools?
# Yes
# Best METEOR Score: 0.2769
# Generated Question 7: In what subjects or areas of study can technology be used to meet learning outcomes, according to schools?
# ...
# --------------------------------------------------
# Generated Question 1: Did Ed arrest Yash Parikh for alleged fraud?
# Yes
# Best METEOR Score: 0.1293
# Generated Question 2: What is the alleged nature of the fraud for which Yash Parikh was arrested?
# Fraud
# Best METEOR Score: 0.1158
# Generated Question 3: Who is Yash Parikh, the person arrested by Ed for alleged fraud?
# Yes Bank founder
# Best METEOR Score: 0.1234
# Generated Question 4: Are Rana Kapoor and Yash Parikh the same person?
# No
# Best METEOR Score: 0.0787
# Generated Question 5: What action did Ed take in relation to Rana Kapoor's alleged fraud?
# Arrested
# Best METEOR Score: 0.2447
# Total METEOR Score (normalized): 0.1420
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is Shiv Sena skipping NDA meeting during the winter session of Parliament?
# Yes
# Best METEOR Score: 0.1258
# Generated Question 2: Why is Shiv Sena skipping NDA meeting during the winter session of Parliament?
# According to the reports, Shiv Sena is unhappy with the NDA's policy and has decided to sit in opposition.
# Best METEOR Score: 0.1434
# Generated Question 3: What is the reason behind Shiv Sena's decision to skip NDA meeting during the winter session of Parliament?
# The party's discontent with NDA's policy and their refusal to support the government's proposed legislation.
# Best METEOR Score: 0.2071
# Generated Question 4: What is the expected outcome of Shiv Sena's decision to sit in opposition during the winter session of Parliament?
# The move is expected to create tension in the government and may lead to a major crisis.
# Best METEOR Score: 0.3024
# Generated Question 5: Which party is expected to benefit from Shiv Sena's decision to sit in opposition during the winter session of Parliament?
# Only time will tell, but the decision may bring an advantage to the opposition parties.
# Best METEOR Score: 0.1418
# Generated Question 6: Will Shiv Sena's decision to sit in opposition during the winter session of Parliament affect the government's agenda?
# Yes, it's likely to be a major blow to the government\'s legislative agenda.
# Best METEOR Score: 0.2465
# Total METEOR Score (normalized): 0.2391
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was a shutdown observed in Srinagar when envoys were received?
# Yes
# Best METEOR Score: 0.3034
# Generated Question 2: What was the reason for the shutdown in Srinagar during the envoys\' visit?
# Unknown, but it may have been a protest or a response to a political event.
# Best METEOR Score: 0.2497
# Generated Question 3: What were the reactions of the authorities to the shutdown in Srinagar during the envoys\' visit?
# The police maintained law and order, and some protesters were arrested or detained.
# Best METEOR Score: 0.2673
# Generated Question 4: Who were the envoys that were greeted with a shutdown in Srinagar?
# Unspecified, but they may have been diplomatic or government officials.
# Best METEOR Score: 0.0938
# Generated Question 5: What was the impact of the shutdown on the envoys\' activities in Srinagar?
# Their movements and schedule were likely disrupted, and they may have had to take alternative arrangements.
# Best METEOR Score: 0.1812
# Total METEOR Score (normalized): 0.2360
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Wore Arvind Kejriwal shoes at the memorial of Bhagat Singh?
# True
# Best METEOR Score: 0.0392
# Generated Question 2: What did Arvind Kejriwal wear when paying tribute at the Bhagat Singh memorial?
# Shoes
# Best METEOR Score: 0.0775
# Generated Question 3: When paying tribute at the Bhagat Singh memorial, what did Arvind Kejriwal NOT wear?
# Sneakers
# Best METEOR Score: 0.0769
# Generated Question 4: What is the main issue with Arvind Kejriwal's tribute at the Bhagat Singh memorial
# Wearing shoes
# Best METEOR Score: 0.0577
# Generated Question 5: What could be a possible reaction to Arvind Kejriwal's tribute at the Bhagat Singh memorial?
# Criticism for not respecting the memorial's rules
# Best METEOR Score: 0.1119
# Total METEOR Score (normalized): 0.0787
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was Dilip Ghosh heckled by Rohingya and Bangladeshis?
# Yes
# Best METEOR Score: 0.1762
# Generated Question 2: What was the reason for heckling Dilip Ghosh?
# Because he is a Hindu leader
# Best METEOR Score: 0.1000
# Generated Question 3: Who heckled Dilip Ghosh?
# Rohingya and Bangladeshis
# Best METEOR Score: 0.0398
# Generated Question 4: What was the nature of the heckling incident?
# Physical or verbal taunting, etc.
# Best METEOR Score: 0.1158
# Generated Question 5: Did the police take any action against the hecklers?
# Arrests, FIR, etc.
# Best METEOR Score: 0.2255
# Generated Question 6: Was Dilip Ghosh physically harmed during the heckling?
# Yes/No
# Best METEOR Score: 0.0690
# Total METEOR Score (normalized): 0.1599
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did NCP and Congress win elections in western Maharashtra?
# Yes
# Best METEOR Score: 0.1750
# Generated Question 2: What parties have made a comeback in western Maharashtra?
# NCP and Congress
# Best METEOR Score: 0.1014
# Generated Question 3: What is the significance of NCP and Congress winning elections in western Maharashtra?
# It shows their revival in the region
# Best METEOR Score: 0.1817
# Generated Question 4: How did NCP and Congress campaign in western Maharashtra?
# Did not find any information
# Best METEOR Score: 0.0775
# Generated Question 5: Were NCP and Congress the leading contenders in western Maharashtra elections?
# Yes
# Best METEOR Score: 0.1727
# Generated Question 6: What was the outcome of the western Maharashtra elections for NCP and Congress?
# They won the elections
# Best METEOR Score: 0.1341
# Generated Question 7: Who were the main opponents of NCP and Congress in western Maharashtra elections?
# Did not find any information
# Best METEOR Score: 0.0954
# Total METEOR Score (normalized): 0.1447
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the Rajasthan governor constitutionally obligated to act solely according to their own discretion?
# No
# Best METEOR Score: 0.0993
# Generated Question 2: What is the legal basis for the Rajasthan governor's discretion in acting on advices?
# The Rajasthan governor is guided by the Constitution of India and the relevant laws and precedents.
# Best METEOR Score: 0.1812
# Generated Question 3: Can the Rajasthan governor choose to ignore the advice of the cabinet if they disagree?
# No, as per the constitutional provisions, the governor is bound by the cabinet's advice.
# Best METEOR Score: 0.1365
# Generated Question 4: What is the consequence if the Rajasthan governor fails to act in accordance with the cabinet's advice?
# The governor may face impeachment by the state legislature.
# Best METEOR Score: 0.2147
# Generated Question 5: Is the Rajasthan governor's decision binding on the state government?
# No, the governor's decision can be challenged and reversed by the state government and the judiciary.
# Best METEOR Score: 0.1277
# Generated Question 6: Can the Rajasthan governor seek clarification or additional information from the cabinet before taking a decision?
# Yes, the governor may seek additional information or clarification before making a decision.
# Best METEOR Score: 0.1530
# Generated Question 7: Is the Rajasthan governor accountable to Parliament for their actions?
# No, as the governor is a constitutional position and not a member of Parliament.
# Best METEOR Score: 0.1481
# Generated Question 8: What is the role of the Governor in the governance of Rajasthan?
# The Governor has a ceremonial role, but can also reserve bills passed by the state legislature and summon or dissolve the state legislature.
# Best METEOR Score: 0.1601
# Total METEOR Score (normalized): 0.1682
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 6 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did a judge and a lawyer physically fight each other in a courthouse in Maharashtra?
# Yes
# Best METEOR Score: 0.2076
# Generated Question 2: What sparked the altercation between the judge and the lawyer in the Maharashtra courthouse?
# Unknown
# Best METEOR Score: 0.2054
# Generated Question 3: Were there any official reports or statements released regarding the incident?
# No
# Best METEOR Score: 0.0998
# Generated Question 4: Was the incident considered a breach of professional conduct by the legal community in Maharashtra?
# Yes
# Best METEOR Score: 0.2447
# Generated Question 5: What actions was the judge and/or lawyer taken against following the altercation?
# Unknown
# Best METEOR Score: 0.1659
# Generated Question 6: Was the incident widely reported by local and national media outlets in India?
# Unlikely
# Best METEOR Score: 0.1442
# Total METEOR Score (normalized): 0.1715
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is it true that 25 crore Indians will get COVID vaccine by July?
# Yes
# Best METEOR Score: 0.1250
# Generated Question 2: What is the scope of the COVID vaccination drive according to the claim?
# 25 crore Indians
# Best METEOR Score: 0.1346
# Generated Question 3: In which month the COVID vaccination drive is expected to cover 25 crore Indians, according to the claim?
# July
# Best METEOR Score: 0.1282
# Generated Question 4: Has the government announced a specific timeline for the COVID vaccination drive?
# Yes
# Best METEOR Score: 0.1715
# Generated Question 5: What is the objective of the COVID vaccination drive, as per the claim?
# To vaccinate 25 crore Indians
# Best METEOR Score: 0.1331
# Generated Question 6: Will the COVID vaccination drive be a nationwide effort, as suggested by the claim?
# Yes
# Best METEOR Score: 0.1681
# Generated Question 7: What is the total number of people expected to be vaccinated by July, according to the claim?
# 25 crore
# Best METEOR Score: 0.1326
# Generated Question 8: Is the claim about the COVID vaccination drive specific to the month of July, or does it mention a longer timeline?
# No
# Best METEOR Score: 0.1124
# Total METEOR Score (normalized): 0.1363
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Congress leader Ahmed Patel meet with RSS-backed leader Nitin Gadkari?
# Yes
# Best METEOR Score: 0.1267
# Generated Question 2: What was the purpose of the meeting between Ahmed Patel and Nitin Gadkari?
# The meeting was to resolve the ongoing political issues and disputes in the state of Maharashtra.
# Best METEOR Score: 0.2319
# Generated Question 3: Who are Ahmed Patel and Nitin Gadkari, and what is their significance in the Indian political landscape?
# Ahmed Patel is a senior leader of the Indian National Congress, while Nitin Gadkari is a prominent leader of the Rashtriya Swayamsevak Sangh (RSS). The meeting between the two leaders was significant as it involved leaders from different ideological backgrounds.
# Best METEOR Score: 0.1792
# Generated Question 4: Was the meeting between Ahmed Patel and Nitin Gadkari a one-off event or part of a larger dialogue?
# The meeting was a part of ongoing efforts by the two leaders to bridge the gap between their parties.
# Best METEOR Score: 0.1814
# Generated Question 5: Did the meeting receive any public statements or reactions from the leaders or parties involved?
# The leaders did not make any official statements about the meeting, but it was reported by various news outlets.
# Best METEOR Score: 0.2086
# Total METEOR Score (normalized): 0.1840
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Does the WHO recommend wearing masks in crowded areas?
# Yes
# Best METEOR Score: 0.1750
# Generated Question 2: What is the primary method for preventing COVID-19 transmission?
# Social distancing and proper hygiene practices
# Best METEOR Score: 0.0965
# Generated Question 3: What is the effectiveness of face mask usage in reducing transmission?
# According to studies, face mask usage has been shown to reduce transmission rates by approximately 50%.
# Best METEOR Score: 0.1205
# Generated Question 4: Is adequate ventilation in rooms effective in lowering transmission?
# Yes
# Best METEOR Score: 0.1750
# Generated Question 5: What is the role of fresh air in reducing the transmission of COVID-19?
# Fresh air can reduce the concentration of viral particles in the air, making it less likely for transmission to occur.
# Best METEOR Score: 0.2645
# Generated Question 6: Are certain CT values more reliable than others for measuring COVID-19 transmission?
# No
# Best METEOR Score: 0.0778
# Total METEOR Score (normalized): 0.1840
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did a hair dryer and clothes iron being used to dry the pitch during the 2023 IPL final?
# Yes
# Best METEOR Score: 0.2036
# Generated Question 2: What unusual items were used to dry the pitch during the 2023 IPL final?
# Hair dryer and clothes iron
# Best METEOR Score: 0.1141
# Generated Question 3: What was the unusual method used to prepare the pitch for the 2023 IPL final?
# Using a hair dryer and clothes iron to dry the wet pitch
# Best METEOR Score: 0.1661
# Generated Question 4: Who used the hair dryer and clothes iron to dry the pitch during the 2023 IPL final?
# Unknown
# Best METEOR Score: 0.1145
# Generated Question 5: What was the condition of the pitch before the 2023 IPL final?, and what was done to prepare it?
# The pitch was wet and was dried using a hair dryer and clothes iron
# Best METEOR Score: 0.1434
# Generated Question 6: What was the result of the drying process used during the 2023 IPL final?
# The pitch became dry and ready for the game
# Best METEOR Score: 0.2187
# Total METEOR Score (normalized): 0.1828
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# Generated Question 6 matched with Reference Question 3
# --------------------------------------------------
#
# Average METEOR Score: 0.1779
