# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.18.0

# %%
# @title Default title text
import json
import random
from groq import Groq
import nltk
import re
from scipy.optimize import linear_sum_assignment
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data files
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/Modified_true_claims.json'
claims_file_2 = '/content/last_fake_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# %%
# Initialize Groq API client
client = Groq(api_key="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")


import re

def convert_to_json(llm_response):
    responseQuestions = []
    questions_llm = re.findall(r'\{(.*?)\}', llm_response, re.DOTALL)

    for question in questions_llm:
        question_json = {}

        q = re.findall(r'[\"\']question[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if q:
            question_json['question'] = q[0].strip()
        else:
            continue

        a = re.findall(r'[\"\']answer[\"\']:\s*[\"\']?(.*?)[\"\'],', question, re.DOTALL)
        if a:
            question_json['answer'] = a[0].strip()

        at = re.findall(r'[\"\']answerType[\"\']:\s*[\"\']?(.*?)[\"\']', question, re.DOTALL)
        if at:
            question_json['answerType'] = at[0].strip()

        responseQuestions.append(question_json)

    return responseQuestions



def get_response_llm(claim, questions):
  prompt = f"{questions} \n Claim: {claim}. Provide me only with similar questions relevant for the claim given in similar json format. Provide boolean, Abstractive, Extractive questions and answer pairs in a single list json. Do not leave question and answer pair empty"

  try:
      response = client.chat.completions.create(
          messages=[
              {
                  "role": "user",
                  "content": prompt,
              }
          ],
          model="gemma2-9b-it",
          max_tokens=4000,
      )
      response = response.choices[0].message.content.strip()
      response_json = convert_to_json(response)
      return response_json
  except Exception as e:
      print(f"Error processing claim '{claim}': {e}, {response}")
      print("-*"*50)
      return ""

# %%
new_data = []

for data in combined_claims[:5010]:
  questions_prompt = []
  claim = data["claim"]
  for question in combined_claims[0]["questions"]:
    q = {"question": question["question"]}
    answer = question["answers"][0]
    q['answer'] = answer['answer']
    q['answerType'] = answer['answer_type']
    questions_prompt.append(q)
  response = get_response_llm(claim, questions_prompt)
  data = {'claim': claim, 'generatedQuestions': response, 'goldQuestions': questions_prompt}
  new_data.append(data)

# %%
print(len([1 for n in new_data if n['generatedQuestions'] == []]))
new_data
# Out:
# 0
# [{'claim': 'RSS activists are harassing Muslim women.',
#   'generatedQuestions': [{'question': 'Is there evidence of RSS activists harassing Muslim women in India?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Are there any reliable sources that confirm RSS activists are targeting Muslim women?',
#     'answer': 'No, claims of RSS activists targeting Muslim women are often based on misinformation and misrepresented incidents.',
#     'answerType': 'Abstractive'},
#    {'question': 'What are the facts about the video showing Muslim women being harassed?',
#     'answer': 'The video showing Muslim women being harassed originated in Sri Lanka and was falsely attributed to RSS activists in India.',
#     'answerType': 'Extractive'},
#    {'question': 'Has the RSS organization been linked to violence against Muslim women?',
#     'answer': 'There is no credible evidence to support claims that the RSS organization has been linked to violence against Muslim women.',
#     'answerType': 'Abstractive'},
#    {'question': 'What evidence exists to support the claim that RSS activists are responsible for harassment against Muslim women?',
#     'answer': 'There is no credible evidence supporting this claim.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Joe Biden and Kamala Harris, Democrat nominees for president and vice-president in the US elections, are flouting COVID-19 norms during campaigning.',
#   'generatedQuestions': [{'question': 'Did Joe Biden and Kamala Harris violate COVID-19 guidelines during their campaigns?',
#     'answer': 'Yes, there have been allegations and reports of them violating COVID-19 guidelines during their campaigns.',
#     'answerType': 'Abstractive'},
#    {'question': 'Are there instances where Joe Biden and Kamala Harris were seen not following COVID-19 protocols while campaigning?',
#     'answer': 'Yes, some instances have been reported in the media where they appeared to not be adhering to COVID-19 protocols.',
#     'answerType': 'Boolean'},
#    {'question': 'What evidence supports the claim that Joe Biden and Kamala Harris flouted COVID-19 norms during campaigning?',
#     'answer': 'Some evidence includes photos and videos showing them in crowds without masks, not practicing social distancing, and holding large rallies.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A singapore flight hit by turbulence, that claimed the life of one person and injured dozens.',
#   'generatedQuestions': [{'question': 'Was there a Singapore Airlines flight involved in a turbulent incident?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'Can you describe the details of the turbulent incident involving a Singapore Airlines flight?',
#     'answer': 'A Singapore Airlines flight experienced severe turbulence, resulting in one fatality and multiple injuries.',
#     'answerType': 'Abstractive'},
#    {'question': 'How many fatalities and injuries resulted from the turbulent Singapore Airlines flight?',
#     'answer': 'One person died and dozens were injured.',
#     'answerType': 'Extractive'},
#    {'question': 'Where did the turbulent incident involving the Singapore Airlines flight occur?',
#     'answer': 'This information is not available in the provided context.',
#     'answerType': 'Unknown'},
#    {'question': 'What was the flight number of the Singapore Airlines flight involved?',
#     'answer': 'This information is not available in the provided context.',
#     'answerType': 'Unknown'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Priyanka gandhi announces nadi adhikar yatra for up fishermen.',
#   'generatedQuestions': [{'question': 'Is Priyanka Gandhi really starting a Nadi Adhikar Yatra for UP fishermen?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': "What is the purpose of Priyanka Gandhi\\'s announced Nadi Adhikar Yatra?",
#     'answer': 'The Nadi Adhikar Yatra aims to address the rights and concerns of fishermen in Uttar Pradesh.',
#     'answerType': 'Abstractive'},
#    {'question': "When and where will Priyanka Gandhi\\'s Nadi Adhikar Yatra take place?",
#     'answer': 'The Nadi Adhikar Yatra will take place in Uttar Pradesh.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'gyan dev ahuja, the moustachioed muslim-hater, bjp just dropped in rajasthan.',
#   'generatedQuestions': [{'question': 'Is Gyan Dev Ahuja a member of the BJP?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is Gyan Dev Ahuja known for?',
#     'answer': 'Gyan Dev Ahuja is known for making controversial and inflammatory statements against Muslims',
#     'answerType': 'Abstractive'},
#    {'question': 'Has Gyan Dev Ahuja recently visited Rajasthan?',
#     'answer': 'Yes, he recently made a visit to Rajasthan',
#     'answerType': 'Extractive'},
#    {'question': 'Does Gyan Dev Ahuja have anti-Muslim sentiments?',
#     'answer': 'Yes, he is known for expressing strong anti-Muslim views',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'The anti-corruption team arrested a muslim DSP in kanpur for supplying crores of cash and weapons to his friends.',
#   'generatedQuestions': [{'question': 'Did the anti-corruption team arrest a Muslim DSP in Kanpur?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was the Muslim DSP in Kanpur accused of?',
#     'answer': 'The anti-corruption team arrested him for allegedly supplying crores of cash and weapons to his friends.',
#     'answerType': 'Abstractive'},
#    {'question': 'Was the arrested DSP accused of supplying money and weapons?',
#     'answer': 'Yes, the DSP was accused of supplying crores of cash and weapons.',
#     'answerType': 'Extractive'},
#    {'question': 'Why was the Muslim DSP arrested?',
#     'answer': 'The anti-corruption team arrested him for supplying crores of cash and weapons to his friends.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who made the arrest?',
#     'answer': 'The anti-corruption team arrested the Muslim DSP.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Union minister ramdas athawale tests positive, hospitalized in mumbai.',
#   'generatedQuestions': [{'question': 'Is Ramdas Athawale hospitalized?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Where is Ramdas Athawale hospitalized?',
#     'answer': 'He is hospitalized in Mumbai.',
#     'answerType': 'Extractive'},
#    {'question': "What is the reason for Ramdas Athawale's hospitalization?",
#     'answer': 'He has tested positive for COVID-19.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Basti police thrashing a vehicle owner recently during traffic checking.',
#   'generatedQuestions': [{'question': 'Did the Basti police assault a vehicle owner during a traffic check?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'Can you describe the incident where Basti police allegedly thrashed a vehicle owner during a traffic check?',
#     'answer': 'Police in Basti reportedly physically assaulted a vehicle owner during a traffic check. Details about the incident and the reasons behind the assault are likely to be found in news reports or official statements.',
#     'answerType': 'Abstractive'},
#    {'question': 'Where did this alleged assault by the Basti police against a vehicle owner take place?',
#     'answer': 'The incident took place during a traffic check in Basti.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'capt deepak sathe: decorated ex-iaf pilot, killed in kerala plane crash, credited with saving hundreds of lives',
#   'generatedQuestions': [{'question': 'Was Capt. Deepak Sathe an IAF pilot?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What was Capt. Deepak Sathe known for?',
#     'answer': 'He was a decorated ex-IAF pilot credited with saving hundreds of lives.',
#     'answerType': 'Abstractive'},
#    {'question': 'How did Capt. Deepak Sathe die?',
#     'answer': 'He died in a plane crash in Kerala.',
#     'answerType': 'Extractive'},
#    {'question': 'Did Capt. Deepak Sathe die in a plane crash?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Besides his death, what else is noteworthy about Capt. Deepak Sathe?',
#     'answer': 'He was decorated ex-IAF pilot credited with saving hundreds of lives.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Ag nod for contempt case against kunal kamra over tweets.',
#   'generatedQuestions': [{'question': 'Did the Ag (Acting Chief Justice) give the nod for a contempt case against Kunal Kamra?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the possible contempt of court case against Kunal Kamra?',
#     'answer': 'The case stems from tweets made by Kunal Kamra that were deemed disrespectful and contemptuous towards the judiciary.',
#     'answerType': 'Abstractive'},
#    {'question': 'What action is being taken against Kunal Kamra?',
#     'answer': 'The Ag (Acting Chief Justice) has given the nod for a contempt case against Kunal Kamra.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'FIR against ekta kapoor, 2 others for obscene web show: police',
#   'generatedQuestions': [{'question': 'Is there an FIR filed against Ekta Kapoor?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What is the reason behind the FIR filed against Ekta Kapoor?',
#     'answer': 'The FIR alleges that Ekta Kapoor, along with two others, produced an obscene web show.',
#     'answerType': 'Abstractive'},
#    {'question': 'According to the police, what is Ekta Kapoor accused of?',
#     'answer': 'The police have filed an FIR against Ekta Kapoor for producing an obscene web show.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Anant Ambani is angry with Aamir Khan for making a hole in their pocket with his flop film Laal Singh Chaddha.',
#   'generatedQuestions': [{'question': "Did Anant Ambani express anger regarding Aamir Khan\\'s film Laal Singh Chaddha?",
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': "Is there evidence that Anant Ambani is upset about financial losses caused by Aamir Khan\\'s film?",
#     'answer': "No, there is no credible evidence to suggest that Anant Ambani is angry with Aamir Khan over the film\\'s performance. The claim seems to be based on speculation.",
#     'answerType': 'Abstractive'},
#    {'question': 'What is the source of the claim that Anant Ambani is angry with Aamir Khan?',
#     'answer': 'The claim is circulating online and in some media reports, but it lacks factual basis and supporting evidence.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Matuas don't need patta land, we only want caa in west bengal, says bjp mp shantanu thakur.",
#   'generatedQuestions': [{'question': 'Do Matua communities require patta land in West Bengal?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'What is the primary demand of the Matua community according to BJP MP Shantanu Thakur?',
#     'answer': 'BJP MP Shantanu Thakur claims that the Matua community does not need patta land, but wants the Citizenship Amendment Act (CAA) implemented in West Bengal.',
#     'answerType': 'Abstractive'},
#    {'question': 'According to Shantanu Thakur, what do the Matua people want in West Bengal?',
#     'answer': 'The Matuas want the implementation of the Citizenship Amendment Act (CAA).',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Former Congress leader Hardik Patel was greeted with a slap after joining the BJP.',
#   'generatedQuestions': [{'question': 'Did Hardik Patel receive a slap after joining the BJP?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What happened to Hardik Patel when he joined the BJP?',
#     'answer': 'Hardik Patel was slapped by an individual upon joining the BJP.',
#     'answerType': 'Abstractive'},
#    {'question': 'Is it true that Hardik Patel was slapped after joining the BJP?',
#     'answer': 'Yes, reports indicate that Hardik Patel was slapped upon joining the BJP.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Al Jazeera tweet says Taliban has begun abducting minor girls in Afghanistan and killing parents resisting the move.',
#   'generatedQuestions': [{'question': 'Has the Taliban started abducting minor girls in Afghanistan?',
#     'answer': 'The claim made by Al Jazeera needs to be investigated for accuracy.',
#     'answerType': 'Boolean'},
#    {'question': 'Are there credible reports of the Taliban abducting girls and killing their parents who resist?',
#     'answer': 'Al Jazeera made the claim, but it is essential to verify this information from independent and reliable sources.',
#     'answerType': 'Abstractive'},
#    {'question': 'What evidence does Al Jazeera provide to support the claim of Taliban abductions and killings?',
#     'answer': 'It is crucial to examine the evidence presented by Al Jazeera to assess the validity of their claim.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A crowd chanting expletives at president biden during the texas primary.',
#   'generatedQuestions': [{'question': 'Did a crowd chant expletives at President Biden during the Texas primary?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What happened to President Biden when he visited Texas during the primary?',
#     'answer': 'A crowd chanted expletives at him.',
#     'answerType': 'Abstractive'},
#    {'question': 'Was President Biden met with hostility during his visit to Texas for the primary?',
#     'answer': 'Yes, a crowd chanted expletives at him.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Body of a two and a half-year old girl was found on june 2 in aligarh, uttar pradesh. the accused- zahid and aslam have been arrested by the police. several netizens expressed outrage over the incident. many among those who tweeted about the incident have claimed that the young girl was raped before she was murdered. it has also been claimed that her eyes were gouged out and acid was poured on her body.',
#   'generatedQuestions': [{'question': 'Were Zahid and Aslam arrested for the murder of a two and a half-year-old girl in Aligarh?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What are the specific accusations against Zahid and Aslam in connection with the death of the two-and-a-half-year-old girl?',
#     'answer': 'They were arrested for the murder of the girl. Some online reports allege they raped her before killing her and that her eyes were gouged out and acid was poured on her body, but these claims require verification from official sources.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the police confirm the claims of rape, eye-gouging, and acid being poured on the body of the deceased girl?',
#     'answer': 'The police have confirmed the arrests of Zahid and Aslam for the murder, but have not officially confirmed the additional allegations of rape, eye-gouging, and acid being poured on the body.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Alka lamba does a ghar wapsi, becomes first AAP leader in delhi to join congress',
#   'generatedQuestions': [{'question': 'Did Alka Lamba join the Congress Party?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What political party did Alka Lamba switch to?',
#     'answer': 'Alka Lamba joined the Congress Party from the Aam Aadmi Party (AAP).',
#     'answerType': 'Abstractive'},
#    {'question': 'Which political party is Alka Lamba associated with now?',
#     'answer': 'Congress Party',
#     'answerType': 'Extractive'},
#    {'question': 'Is Alka Lamba the first AAP leader to join the Congress in Delhi?',
#     'answer': 'Yes, Alka Lamba is the first AAP leader in Delhi to join the Congress.',
#     'answerType': 'Abstractive'},
#    {'question': "Was Alka Lamba's move to Congress termed as 'Ghar Wapsi'?",
#     'answer': "Yes, Alka Lamba's move to Congress was termed as 'Ghar Wapsi'.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A glimpse of the Cabinet Committee on Security meeting where removal of all Sikhs from the army was being discussed.',
#   'generatedQuestions': [{'question': 'Is the claim about the Cabinet Committee on Security meeting removing Sikhs from the army true?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'What is the truth behind the claim that the Cabinet Committee on Security meeting discussed removing all Sikhs from the army?',
#     'answer': 'The claim is false. There is no evidence to suggest that such a meeting took place or that such a discussion occurred.',
#     'answerType': 'Abstractive'},
#    {'question': 'Was the Cabinet Committee on Security meeting discussing the removal of Sikhs from the army?',
#     'answer': 'No. There is no evidence to support this claim.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'These men were raising ‘Pakistan Zindabad’ slogans after India’s defeat in the T20 World Cup match. Uttar Pradesh police thrashed them black and blue.',
#   'generatedQuestions': [{'question': 'Were men raising Pakistan Zindabad slogans after India’s defeat in the T20 World Cup match?',
#     'answer': 'Yes, according to the claim.',
#     'answerType': 'Boolean'},
#    {'question': 'What happened to the men who raised Pakistan Zindabad slogans after India’s defeat in the T20 World Cup match according to the claim?',
#     'answer': 'Uttar Pradesh police thrashed them black and blue.',
#     'answerType': 'Extractive'},
#    {'question': 'Is the claim that Uttar Pradesh police thrashed men raising Pakistan Zindabad slogans after India’s defeat in the T20 World Cup match true?',
#     'answer': 'The truthfulness of the claim cannot be determined without further investigation and verification of sources.',
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Per a Defence Ministry letter, personnel under other ranks (ORs) attested after January 1, 2019, and not promoted to the rank of naik or equivalent, will now come under the Agnipath scheme.',
#   'generatedQuestions': [{'question': 'Do all ORs attested after January 1, 2019, fall under Agnipath?',
#     'answer': 'No, only ORs who have not been promoted to naik or equivalent rank after January 1, 2019, come under the Agnipath scheme.',
#     'answerType': 'Abstractive'},
#    {'question': 'Is the Agnipath scheme applicable to personnel under other ranks promoted to naik or equivalent?',
#     'answer': 'No, personnel under other ranks who have been promoted to naik or equivalent rank after January 1, 2019, are not included in the Agnipath scheme.',
#     'answerType': 'Boolean'},
#    {'question': 'According to the Defence Ministry letter, what is the specific criterion for Agnipath recruitment among ORs?',
#     'answer': 'ORs attested after January 1, 2019, but not promoted to naik or equivalent rank, are eligible for Agnipath.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'The anti-tuberculosis bacillus Calmette-Guérin (BCG) vaccine protects people against coronavirus infection.',
#   'generatedQuestions': [{'question': 'Does the BCG vaccine protect against COVID-19?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is there scientific evidence supporting the claim that the BCG vaccine prevents coronavirus infection?',
#     'answer': 'No, there is no conclusive scientific evidence that the BCG vaccine protects against COVID-19 despite some preliminary studies showing potential.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the current scientific consensus on the BCG vaccine and COVID-19 protection?',
#     'answer': 'The current scientific consensus is that the BCG vaccine does not provide proven protection against COVID-19.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': "Muslim men assaulting an old man for chanting 'Bharat Mata ki Jai' in Delhi.",
#   'generatedQuestions': [{'question': 'Did Muslim men assault an old man in Delhi for chanting "Bharat Mata ki Jai"?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the incident of the assault on an old man for chanting "Bharat Mata ki Jai" actually in Delhi and committed by Muslim men?',
#     'answer': 'No, the claim is false.  Details surrounding the incident  are disputed and require further investigation. It is important to avoid spreading misinformation without verifying the facts.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim of Muslim men assaulting an old man for chanting "Bharat Mata ki Jai" in Delhi?',
#     'answer': 'The claim is disputed and requires further investigation. It is important to avoid spreading misinformation without verifying the facts.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Rajasthan gurjar leader bainsla threatens to intensify agitation',
#   'generatedQuestions': [{'question': 'Is Bainsla calling for peace?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': "What is Bainsla's reason for threatening to intensify the agitation?",
#     'answer': 'Bainsla has threatened to intensify the agitation because he feels the demands of the Gurjar community are not being met by the government.',
#     'answerType': 'Abstractive'},
#    {'question': "What are the Gurjar community's demands?",
#     'answer': 'The Gurjar community is demanding reservation in education and government jobs.',
#     'answerType': 'Extractive'},
#    {'question': 'Where is Bainsla based?',
#     'answer': 'Bainsla is a leader in Rajasthan.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': "A PTI supporter waving a gun at Pakistan's ex-PM Imran Khan's election rally.",
#   'generatedQuestions': [{'question': 'Are PTI supporters harassing Imran Khan?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the PTI supporter in the video actually harassing Imran Khan?',
#     'answer': 'The context of the video is unclear.  It is important to gather more information about the situation, as simply waving a gun at an event could have multiple interpretations.',
#     'answerType': 'Abstractive'},
#    {'question': "What is the PTI supporter's motive for waving a gun at Imran Khan?",
#     'answer': "This information cannot be determined from the claim alone. Further investigation into the incident and the individual's intentions is required.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Pakistan’s former Prime Minister Imran Khan with his eyes shut during his third night in jail.',
#   'generatedQuestions': [{'question': 'Is the claim about Imran Khan sleeping with his eyes shut during his third night in jail true?',
#     'answer': 'It is unclear if the claim is true. While there are reports and images circulating online, verifying their authenticity and context is crucial.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did Imran Khan sleep with his eyes shut during his imprisonment?',
#     'answer': 'There are images and reports suggesting Imran Khan was sleeping with his eyes shut during his third night in jail, but their authenticity and context require verification.',
#     'answerType': 'Extractive'},
#    {'question': 'Are there images of Imran Khan sleeping with his eyes shut in jail?',
#     'answer': 'Yes, there are images circulating online that appear to show Imran Khan sleeping with his eyes shut during his imprisonment.',
#     'answerType': 'Boolean'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Protesters blocking Union Minister Smriti Irani’s convoy in the run-up to elections in Uttar Pradesh.',
#   'generatedQuestions': [{'question': 'Were protesters blocking Union Minister Smriti Irani’s convoy?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What was the context surrounding the protesters blocking Union Minister Smriti Irani’s convoy?',
#     'answer': 'The incident occurred in the run-up to elections in Uttar Pradesh.',
#     'answerType': 'Abstractive'},
#    {'question': 'In which state did the protesters block Union Minister Smriti Irani’s convoy?',
#     'answer': 'Uttar Pradesh',
#     'answerType': 'Extractive'},
#    {'question': 'Was this incident linked to any political events?',
#     'answer': 'Yes, it happened before the elections in Uttar Pradesh.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the reason behind the protesters blocking Union Minister Smriti Irani’s convoy?',
#     'answer': 'The specific reason for the protest is not mentioned in the provided claim.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': "SCBA president recused from EC meet on resolution condemning ap cm's letter to CJI.",
#   'generatedQuestions': [{'question': "Did the SCBA president recuse themself from the EC meet on the resolution condemning the AP CM\\'s letter to the CJI?",
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': "Can you explain why the SCBA president recused themself from the EC meet regarding the resolution condemning the AP CM\\'s letter?",
#     'answer': "The reason for the president\\'s recusal is not specified in the given information.",
#     'answerType': 'Abstractive'},
#    {'question': "What is the resolution being discussed at the EC meet that prompted the SCBA president\\'s recusal?",
#     'answer': "The resolution condemns the AP CM\\'s letter to the CJI.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Stray dogs force Air India to abort landing in Goa.',
#   'generatedQuestions': [{'question': 'Are stray dogs impacting Air India flights ?',
#     'answer': 'Yes, in this specific instance, a report suggests stray dogs on the runway led to an aborted landing.',
#     'answerType': 'Boolean'},
#    {'question': 'Was the Air India plane forced to abort its landing due to stray dogs?',
#     'answer': 'Yes, according to reports, the pilot was forced to abort the landing because of stray dogs on the runway',
#     'answerType': 'Abstractive'},
#    {'question': 'What caused the Air India plane to abort its landing in Goa?',
#     'answer': 'Stray dogs on the runway',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
# ...
#  {'claim': 'Uttar Pradesh police has blamed the BJP for the recent violence in Kanpur.',
#   'generatedQuestions': [{'question': 'Is the  UP police statement about BJP involvement in Kanpur violence true?',
#     'answer': 'The truthfulness of the statement is disputed and subject to ongoing investigation.',
#     'answerType': 'Abstractive'},
#    {'question': 'Did the UP police officially blame the BJP for the recent violence in Kanpur?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What is the UP police’s stance on the BJP’s alleged involvement in the Kanpur violence?',
#     'answer': 'The UP police have stated that the BJP is responsible for the recent violence in Kanpur.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': ' An old hindu man was lynched and hanged on a statue in bangladesh.',
#   'generatedQuestions': [{'question': 'Was an elderly Hindu man lynched and hanged in Bangladesh?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the claim circulating about an older Hindu man being lynched and hung in Bangladesh true?',
#     'answer': 'No, the claim is false.  There is no credible evidence to support this incident.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim of a lynched Hindu man in Bangladesh?',
#     'answer': 'The claim is false and appears to be based on misinformation.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Govt to modify salary structure of contractual workers under nhm',
#   'generatedQuestions': [{'question': 'Are contractual workers under NHM going to get a salary raise?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'How will the government modify the salary structure of contractual workers under NHM?',
#     'answer': 'The government plans to implement changes to the existing salary structure for contractual workers under the NHM program.  Specific details about the modifications are likely to be announced officially.',
#     'answerType': 'Abstractive'},
#    {'question': "What is the government''''s plan regarding the salary structure of contractual workers under NHM?",
#     'answer': 'The government plans to modify the salary structure of contractual workers under NHM.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Jaishankar makes 8 proposals to stabilise ties with china.',
#   'generatedQuestions': [{'question': 'Are the proposals made by Jaishankar intended to improve relations with China?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What specific proposals did Jaishankar make to stabilise ties with China?',
#     'answer': "Jaishankar proposed eight specific measures to stabilize ties with China. These include proposals  related to communication, confidence-building measures, and collaboration on global issues. However, the exact details of these proposals haven\\'t been publicly disclosed.",
#     'answerType': 'Abstractive'},
#    {'question': 'Has Jaishankar publicly outlined the eight proposals aimed at stabilising ties with China?',
#     'answer': "While Jaishankar has stated he made eight proposals, he hasn\\'t publicly disclosed the details of them.",
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Serum institute ceo on pm modi’s covid-19 vaccine vision: ‘your arrangements will take care of all needs for Indians’',
#   'generatedQuestions': [{'question': "Is the claim about Serum Institute CEO\\'s statement about PM Modi\\'s vaccine vision true?",
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': "What did the Serum Institute CEO say about PM Modi\\'s covid-19 vaccine vision?",
#     'answer': "The Serum Institute CEO stated that PM Modi\\'s arrangements will take care of all needs for Indians regarding the covid-19 vaccine.",
#     'answerType': 'Extractive'},
#    {'question': "Can you elaborate on the context of the Serum Institute CEO\\'s statement about PM Modi\\'s vaccine vision?",
#     'answer': "The Serum Institute CEO made this statement while expressing confidence in PM Modi\\'s leadership and the government\\'s plan to ensure vaccine accessibility for all Indians during the pandemic.",
#     'answerType': 'Abstractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Made in India’ double-decker metro train coaches in Australia.',
#   'generatedQuestions': [{'question': 'Are metro train coaches manufactured in India?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'Is there evidence that the double-decker metro train coaches in Australia were manufactured in India?',
#     'answer': 'Yes, there is evidence to suggest that the double-decker metro train coaches in Australia were manufactured in India.  These coaches were procured from a company based in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'Which company manufactured the double-decker metro train coaches in Australia?',
#     'answer': 'The double-decker metro train coaches in Australia were manufactured by (Name of the Indian company)',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Punjabi singer Ranjit Bawa performed his song ‘Chitta’ in front of CM Bhagwant Mann. In this song, Bawa criticised the state government for the narcotics epidemic.',
#   'generatedQuestions': [{'question': 'Did Ranjit Bawa perform "Chitta" for CM Bhagwant Mann?',
#     'answer': 'Yes',
#     'answerType': 'Boolean'},
#    {'question': 'What did Ranjit Bawa criticize in his song "Chitta" performed for CM Bhagwant Mann?',
#     'answer': 'Ranjit Bawa criticized the state government for the narcotics epidemic in his song "Chitta" performed for CM Bhagwant Mann.',
#     'answerType': 'Abstractive'},
#    {'question': 'What was the subject of Ranjit Bawa\\\'s criticism in the song "Chitta" performed in front of CM Bhagwant Mann?',
#     'answer': 'The state government and the narcotics epidemic',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'The Israeli cargo ship which was set on fire by the Houthi militant group.',
#   'generatedQuestions': [{'question': 'Did the Houthi militant group set fire to the Israeli cargo ship?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'What is the truth about the Israeli cargo ship that was set ablaze?',
#     'answer': 'The Israeli cargo ship was indeed set on fire by the Houthi militant group in an act of maritime terrorism.',
#     'answerType': 'Abstractive'},
#    {'question': 'Who was responsible for the fire on the Israeli cargo ship?',
#     'answer': 'The Houthi militant group.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'A depiction of the notorious dictator of North Korea is being shared on the internet, showing him bowing down in front of a statue of the father of the Indian constitution, Dr. Bhimrao Ramji Ambedkar.',
#   'generatedQuestions': [{'question': "Is the image depicting Kim Jong-un bowing to Dr. Ambedkar\\'s statue authentic?",
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': "What is the truth behind the image of Kim Jong-un bowing before Dr. Ambedkar\\'s statue?",
#     'answer': 'The image is digitally manipulated and does not represent a real event. It is a fabricated image intended to spread misinformation.',
#     'answerType': 'Abstractive'},
#    {'question': "Where did the image of Kim Jong-un bowing to Dr. Ambedkar\\'s statue originate?",
#     'answer': 'The image is a digitally altered photograph and has no basis in reality.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  {'claim': 'Rajasthan crisis: where things stand for bjp.',
#   'generatedQuestions': [{'question': 'Is the BJP facing a crisis in Rajasthan?',
#     'answer': 'Yes.',
#     'answerType': 'Boolean'},
#    {'question': 'Can you summarize the current situation regarding the BJP in Rajasthan?',
#     'answer': "The BJP in Rajasthan is facing internal conflicts and power struggles, leading to uncertainty about the state government\\'s stability.",
#     'answerType': 'Abstractive'},
#    {'question': 'What are the main reasons behind the BJP crisis in Rajasthan?',
#     'answer': 'Internal conflicts between different factions within the BJP, and dissatisfaction among certain leaders regarding governance and party policies are cited as primary reasons.',
#     'answerType': 'Extractive'}],
#   'goldQuestions': [{'question': 'Are RSS activists harassing Muslim women?',
#     'answer': 'No.',
#     'answerType': 'Boolean'},
#    {'question': 'Is the harassment of Muslim women shown in the video committed by RSS activists?',
#     'answer': 'No, the harassment of Muslim women shown in the video was not committed by RSS activists. The incident actually took place in Sri Lanka and was misrepresented as involving RSS activists in India.',
#     'answerType': 'Abstractive'},
#    {'question': 'What is the truth behind the claim that RSS activists are harassing Muslim women?',
#     'answer': 'The claim is false. The video shared is about an incident in Sri Lanka, not involving RSS activists. It was misrepresented as an attack by RSS in India.',
#     'answerType': 'Extractive'}]},
#  ...]

# %%
hungarian_meteor_scores = []

def calculate_meteor_scores(generated_sequences, reference_sequences):
    """
    Calculate the METEOR scores between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A 2D list of METEOR scores where scores[i][j] is the score between generated_sequences[i] and reference_sequences[j]
    """
    scores = []
    for gen_seq in generated_sequences:
        row = []
        for ref_seq in reference_sequences:
            score = meteor_score([ref_seq], gen_seq)
            row.append(score)
        scores.append(row)
    return scores

def hungarian_meteor(generated_sequences, reference_sequences):
    """
    Apply the Hungarian Algorithm to find the optimal matching between generated sequences and reference sequences.

    :param generated_sequences: List of generated sequences (list of strings)
    :param reference_sequences: List of reference sequences (list of strings)
    :return: A list of tuples where each tuple contains the index of the generated sequence and the index of the reference sequence it is matched to
    """

    # Tokenize the sequences
    generated_sequences = [word_tokenize(seq) for seq in generated_sequences]
    reference_sequences = [word_tokenize(seq) for seq in reference_sequences]

    # Calculate the METEOR scores
    scores = calculate_meteor_scores(generated_sequences, reference_sequences)

    # Convert the scores to a cost matrix (negative scores because Hungarian Algorithm minimizes cost)
    cost_matrix = [[-score for score in row] for row in scores]

    # Apply the Hungarian Algorithm to find the optimal assignment
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # Calculate the total score using the Hungarian algorithm
    total_score = 0
    for i, j in zip(row_ind, col_ind):
        total_score += scores[i][j]

    # Normalize the total score by the number of reference sequences
    total_score = total_score / len(reference_sequences)

    # Best score for each generated question (max score across all references)
    best_scores = [max(row) for row in scores]

    return total_score, best_scores, list(zip(row_ind, col_ind))

for data in new_data:
  generated_sequences = [question['question']+'\n'+question.get('answer', "") for question in data['generatedQuestions'] if question.get("question")]
  reference_sequences = [question['question']+'\n'+question['answer'] for question in data['goldQuestions']]
  if not generated_sequences or not reference_sequences:
    continue
  total_score, best_scores, optimal_matching = hungarian_meteor(generated_sequences, reference_sequences)

  # Print the best METEOR score for each generated question
  for i, score in enumerate(best_scores):
      print(f"Generated Question {i+1}: {''.join(generated_sequences[i])}")
      print(f"Best METEOR Score: {score:.4f}")

  # Print the total score (calculated from Hungarian matching)
  hungarian_meteor_scores.append(total_score)
  print(f"Total METEOR Score (normalized): {total_score:.4f}")

  # Optional: If you want to print the optimal matching from the Hungarian algorithm
  print("Optimal Matching from Hungarian Algorithm:")
  for i, j in optimal_matching:
      print(f"Generated Question {i+1} matched with Reference Question {j+1}")
  print("-" * 50)

# Calculate the average of all total METEOR scores
average_meteor_score = sum(hungarian_meteor_scores) / len(hungarian_meteor_scores) if hungarian_meteor_scores else 0
print(f"\nAverage METEOR Score: {average_meteor_score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generated Question 3: What is the nature of the slogans chanted by Hindus in the Maharashtra residential society?
# The slogans were in support of Lord Ram.
# Best METEOR Score: 0.1240
# Total METEOR Score (normalized): 0.1282
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim that BJP accuses Naveen Patnaik of saving culprits in panchayat official's death true?
# This is a complex political claim.  While the BJP has made this accusation, it is important to investigate the evidence and context to form a well-informed opinion.
# Best METEOR Score: 0.2148
# Generated Question 2: Has BJP made any accusations against Naveen Patnaik regarding the panchayat official's death?
# Yes, BJP has accused Naveen Patnaik of protecting the culprits involved in the panchayat official\'s death.
# Best METEOR Score: 0.0913
# Generated Question 3: Are Naveen Patnaik and the BJP involved in a dispute?
# Yes, there is political tension and rivalry between the BJP and Naveen Patnaik\'s BJD in Odisha.
# Best METEOR Score: 0.1351
# Generated Question 4: What evidence does the BJP provide to support their accusation against Naveen Patnaik?
# It is important to review the specific statements made by the BJP and any evidence they present to the public to understand their claims.
# Best METEOR Score: 0.1190
# Total METEOR Score (normalized): 0.1471
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Jawaharlal Nehru renounce his Indian citizenship?
# No.
# Best METEOR Score: 0.3236
# Generated Question 2: What is the truth regarding Nehru's citizenship and allegiance?
# There is no evidence that Jawaharlal Nehru ever accepted British citizenship or pledged allegiance to the Queen of England. This claim is a historical falsehood.
# Best METEOR Score: 0.1601
# Generated Question 3: Is there any historical record of Nehru renouncing his Indian citizenship?
# No, there are no historical records or credible sources supporting the claim that Nehru renounced his Indian citizenship or pledged loyalty to the British Monarchy.
# Best METEOR Score: 0.1667
# Total METEOR Score (normalized): 0.1880
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim that J&K will implement forest rights law by March 1 true?
# Yes
# Best METEOR Score: 0.0680
# Generated Question 2: What is the timeline for J&K implementing the forest rights law mentioned in the claim?
# The claim states that J&K will implement the forest rights law by March 1st.
# Best METEOR Score: 0.2192
# Generated Question 3: Does this implementation of the forest rights law follow the recent eviction drive in J&K?
# Yes, the claim states this implementation is taking place a week after the eviction drive.
# Best METEOR Score: 0.1500
# Total METEOR Score (normalized): 0.1270
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is land in Srinagar being sold after the abrogation of Article 370 and 35A?
# Yes
# Best METEOR Score: 0.0632
# Generated Question 2: What is the current status of land ownership in Srinagar following the removal of Article 370 and 35A?
# After the abrogation of Article 370 and 35A, the land laws in Jammu and Kashmir have been amended, allowing non-residents to purchase land in the region.
# Best METEOR Score: 0.1756
# Generated Question 3: Did the government change land laws in Srinagar after removing Article 370 and 35A?
# Yes. The government implemented changes allowing non-residents to buy land.
# Best METEOR Score: 0.0987
# Total METEOR Score (normalized): 0.1046
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Will Raghubar Das win the Jharkhand elections?
# Yes, he claims the BJP will win by 1 lakh votes.
# Best METEOR Score: 0.0980
# Generated Question 2: Did Raghubar Das say the BJP will win the Jharkhand elections by 1 lakh votes?
# Yes.
# Best METEOR Score: 0.1010
# Generated Question 3: What is Raghubar Das’s prediction for the Jharkhand elections?
# Raghubar Das predicts that the BJP will win the Jharkhand elections by a margin of 1 lakh votes.
# Best METEOR Score: 0.0991
# Generated Question 4: How many votes does Raghubar Das predict the BJP will win by in Jharkhand?
# 1 lakh votes
# Best METEOR Score: 0.0505
# Total METEOR Score (normalized): 0.0875
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Does the Myntra ad depict Draupadi’s ‘vastraharan’?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What does the Myntra ad show regarding Lord Krishna and sarees?
# The ad portrays Lord Krishna shopping  for \"extra long sarees\" using the Myntra app.
# Best METEOR Score: 0.0941
# Generated Question 3: Is the Myntra advertisement based on the "Mahabharata"?
# Yes, it depicts the episode of Draupadi’s 'vastraharan' from the Mahabharata.
# Best METEOR Score: 0.1000
# Generated Question 4: Is Myntra ad  considered controversial?
# Yes, the ad has been criticized for its insensitive portrayal of a sensitive scene from the Mahabharata.
# Best METEOR Score: 0.0943
# Total METEOR Score (normalized): 0.0973
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is West Bengal becoming like Kashmir?
# No.
# Best METEOR Score: 0.3272
# Generated Question 2: Does the BJP claim that West Bengal is becoming like Kashmir due to frequent terrorist arrests?
# Yes, the BJP state chief in West Bengal has made this claim.
# Best METEOR Score: 0.1400
# Generated Question 3: What is the BJP state chief's reason for comparing West Bengal to Kashmir?
# The BJP state chief claims that the reason for comparing West Bengal to Kashmir is the frequent arrests of terrorists in the state.
# Best METEOR Score: 0.1299
# Total METEOR Score (normalized): 0.1892
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are the claims about the bollywood director seeking to retain the foster child true?
# Yes.
# Best METEOR Score: 0.1531
# Generated Question 2: What are the conflicting statements regarding the foster child\'s health?
# The bollywood director claims the foster child needs continued care, while the biological mother asserts the child is now medically fit to return home.
# Best METEOR Score: 0.1261
# Generated Question 3: Who is claiming the foster child is medically fit?
# The biological mother.
# Best METEOR Score: 0.1053
# Generated Question 4: Is the bollywood director contesting the mother\'s statement?
# Yes.
# Best METEOR Score: 0.1075
# Generated Question 5: What is the bollywood director\'s reason for wanting to keep the foster child?
# The director claims the child requires continued care.
# Best METEOR Score: 0.1306
# Total METEOR Score (normalized): 0.1281
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are hospital authorities being held accountable for the oxygen supply issues?
# Yes
# Best METEOR Score: 0.1064
# Generated Question 2: What happened that led to the suspension of the two individuals?
# They were suspended due to their alleged involvement in the oxygen supply issues at the Jammu hospital.
# Best METEOR Score: 0.1104
# Generated Question 3: What were the specific reasons given for the suspensions?
# The specific reasons for the suspensions are related to the oxygen supply problems at the Jammu hospital.
# Best METEOR Score: 0.1376
# Total METEOR Score (normalized): 0.0996
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim about the Bar association chief questioning the urgent listing of Arnab Goswami’s petition in the SC accurate?
# Yes
# Best METEOR Score: 0.1007
# Generated Question 2: What are the specific concerns raised by the Bar association chief regarding the urgent listing of Arnab Goswami’s petition?
# The Bar association chief has expressed concerns about the alleged undue haste in listing Arnab Goswami’s petition, suggesting it might bypass regular procedures and potentially set a precedent for future cases.
# Best METEOR Score: 0.1643
# Generated Question 3: According to the claim, which specific court is involved in the case?
# The Supreme Court (SC)
# Best METEOR Score: 0.1016
# Total METEOR Score (normalized): 0.0989
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did a man put pie on the face of an airline CEO?
# Yes
# Best METEOR Score: 0.0526
# Generated Question 2: What was the reason behind the man putting pie on the airline CEO?
# The man was protesting the CEO\'s mandate requiring all employees to be vaccinated against COVID-19.
# Best METEOR Score: 0.1286
# Generated Question 3: What was the rationale behind the man\'s actions?
# The man opposed the CEO\'s vaccine mandate.
# Best METEOR Score: 0.1557
# Generated Question 4: Was the incident related to a COVID-19 vaccine mandate?
# Yes, the incident was in response to the CEO mandating COVID-19 vaccinations for all employees.
# Best METEOR Score: 0.1029
# Generated Question 5: Did the CEO implement a vaccine policy?
# Yes, the CEO required all employees to be vaccinated against COVID-19.
# Best METEOR Score: 0.0980
# Total METEOR Score (normalized): 0.1189
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is Samzuki Hydaiko a known Yakuza member?
# Yes
# Best METEOR Score: 0.0556
# Generated Question 2: What is Samzuki Hydaiko’s alleged involvement in the assassination of Shinzo Abe?
# Samzuki Hydaiko is alleged to have been the assassin of former Japanese Prime Minister Shinzo Abe.
# Best METEOR Score: 0.0989
# Generated Question 3: Did Samzuki Hydaiko confess to assassinating Shinzo Abe?
# Yes, according to reports.
# Best METEOR Score: 0.1042
# Total METEOR Score (normalized): 0.0748
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did Jyotiraditya Scindia remove "BJP" from his Twitter bio?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What does the removal of "BJP" from Jyotiraditya Scindia\'s Twitter bio suggest about his future in the party?
# It suggests a possible departure from the BJP, especially after he already left the Congress earlier this year.
# Best METEOR Score: 0.1183
# Generated Question 3: What political party did Jyotiraditya Scindia leave in March this year?
# He left the Congress.
# Best METEOR Score: 0.1020
# Generated Question 4: Is it possible that Jyotiraditya Scindia will quit the BJP after removing "BJP" from his Twitter bio?
# Yes, it\'s a possibility.
# Best METEOR Score: 0.0926
# Generated Question 5: What might motivate Jyotiraditya Scindia to quit the BJP
# His reasons for leaving remain unclear, but the removal of "BJP" from his Twitter bio and his previous switch from Congress might indicate dissatisfaction within the party.
# Best METEOR Score: 0.0701
# Total METEOR Score (normalized): 0.0979
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are Tejashwi Yadav and 4 ministers of Nitish Kumar\'s government contesting in the 2nd phase of Bihar elections?
# Yes.
# Best METEOR Score: 0.1456
# Generated Question 2: Can you elaborate on which ministers from Nitish Kumar\'s government are contesting in the 2nd phase of the Bihar elections?
# The text states that 4 ministers from Nitish Kumar\'s government are contesting in the 2nd phase, but it doesn\'t specify their names.
# Best METEOR Score: 0.1678
# Generated Question 3: Which ministers from Nitish Kumar\'s government are contesting in the 2nd phase of the Bihar elections?
# The text does not provide the names of the 4 ministers.
# Best METEOR Score: 0.1351
# Total METEOR Score (normalized): 0.1420
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are RSS supporters involved in circulating fake currency?
# The claim needs further investigation and verification.
# Best METEOR Score: 0.3221
# Generated Question 2: What is the evidence supporting the claim that Ketan Dave was found with fake notes?
# It is important to rely on verified news sources and official statements regarding this claim and avoid spreading unconfirmed information.
# Best METEOR Score: 0.1604
# Generated Question 3: Did the police confirm the seizure of fake notes from Ketan Dave\'s car?
# Reports should be checked with official police statements and court documents for confirmation.
# Best METEOR Score: 0.0909
# Total METEOR Score (normalized): 0.1813
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Israeli forces conduct an undercover operation at Ibn Sina Hospital in Jenin?
# Yes.
# Best METEOR Score: 0.1031
# Generated Question 2: What is the truth about the alleged undercover operation at Ibn Sina Hospital?
# Israeli forces did conduct an operation at Ibn Sina Hospital in Jenin, although the details and nature of the operation are disputed.
# Best METEOR Score: 0.1821
# Generated Question 3: Were Israeli forces involved in the incident at Ibn Sina Hospital?
# Yes, Israeli forces carried out an operation.
# Best METEOR Score: 0.0999
# Total METEOR Score (normalized): 0.1284
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Will the Indian government repeal the CAA?
# No.
# Best METEOR Score: 0.3236
# Generated Question 2: What is the Indian government's stance on the protests against the CAA?
# The government maintains its position on the CAA, stating it will not be repealed. It also permits peaceful protests.
# Best METEOR Score: 0.1858
# Generated Question 3: What did Amit Shah say about the CAA and protests?
# Amit Shah stated that the government will not back down on the CAA and those who wish to protest can continue doing so.
# Best METEOR Score: 0.1092
# Total METEOR Score (normalized): 0.1934
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did LK Advani vote for the Congress party in the 2019 Lok Sabha elections?
# No.
# Best METEOR Score: 0.3005
# Generated Question 2: Is the claim that LK Advani voted for Congress in 2019 and thanked Modi and Shah for it true?
# No, the claim is false. LK Advani did not vote for the Congress party in the 2019 Lok Sabha elections.
# Best METEOR Score: 0.2236
# Generated Question 3: What is LK Advani\'s stance on voting for the Congress party in the 2019 elections?
# LK Advani did not vote for the Congress party in the 2019 Lok Sabha elections.
# Best METEOR Score: 0.1206
# Total METEOR Score (normalized): 0.2108
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did IMD issue a heat wave alert?
# Yes.
# Best METEOR Score: 0.1099
# Generated Question 2: What type of alert did IMD issue for the northwest plains?
# IMD issued an orange alert for the northwest plains, predicting a heat wave.
# Best METEOR Score: 0.0926
# Generated Question 3: Which region is predicted to experience a heat wave according to IMD?
# The northwest plains.
# Best METEOR Score: 0.1020
# Total METEOR Score (normalized): 0.0766
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Are there confirmed COVID-19 positive cases among prison inmates in Uttar Pradesh?
# Yes
# Best METEOR Score: 0.1053
# Generated Question 2: Can you provide details about the number of COVID-19 positive cases reported in Uttar Pradesh prisons?
# Yes, 191 prison inmates tested positive in Basti and 56 in Bareilly.
# Best METEOR Score: 0.0918
# Generated Question 3: What is the situation regarding COVID-19 in Uttar Pradesh prisons?
# There has been an outbreak of COVID-19 in prisons in Uttar Pradesh, with 191 cases reported in Basti and 56 in Bareilly.
# Best METEOR Score: 0.1113
# Total METEOR Score (normalized): 0.1016
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Putin attend Yevgeny Prigozhin’s funeral?
# Yes.
# Best METEOR Score: 0.1087
# Generated Question 2: What is the information regarding Putin's attendance at Yevgeny Prigozhin’s funeral?
# Putin did attend Wagner Group chief Yevgeny Prigozhin’s funeral ceremony in Russia.
# Best METEOR Score: 0.0901
# Generated Question 3: Where did Putin attend Yevgeny Prigozhin’s funeral?
# Putin attended Yevgeny Prigozhin’s funeral in Russia.
# Best METEOR Score: 0.0990
# Total METEOR Score (normalized): 0.0687
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim that a temple priest was set ablaze in Rajasthan true?
# There needs to be further investigation into the claim. While reports emerged about this incident, verifying the details and whether it was indeed set ablaze by external forces is crucial.
# Best METEOR Score: 0.2929
# Generated Question 2: Was the incident involving the temple priest confirmed by the police?
# Yes, the Rajasthan police have confirmed the incident.
# Best METEOR Score: 0.1534
# Generated Question 3: Did the BJP say that the police changed their punchline to "apradhi mast, janata trast"?
# Yes, the BJP has alleged that the police changed their statement to "apradhi mast, janata trast".
# Best METEOR Score: 0.0864
# Generated Question 4: Is the BJP's claim about the police's punchline accurate?
# There needs to be further investigation to verify if the police actually changed their statement as alleged by the BJP.
# Best METEOR Score: 0.1206
# Generated Question 5: What is the BJP's stance on the temple priest incident?
# The BJP has alleged foul play and claimed that the police are not adequately investigating the incident.
# Best METEOR Score: 0.1633
# Total METEOR Score (normalized): 0.1938
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was Prime Minister Modi excluded from an emergency meeting during the G20 summit in Bali?
# Yes
# Best METEOR Score: 0.0568
# Generated Question 2: What happened to Prime Minister Modi during the emergency meeting at the G20 summit in Bali?
# Prime Minister Modi was not invited to attend the emergency meeting of top world leaders during the G20 summit in Bali, Indonesia.
# Best METEOR Score: 0.1293
# Generated Question 3: Why was Prime Minister Modi not present at the emergency meeting during the G20 summit?
# There is no official statement confirming why Prime Minister Modi was excluded from the emergency meeting.
# Best METEOR Score: 0.1316
# Total METEOR Score (normalized): 0.1028
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Does the Rajya Sabha have a wider range of complaints it can now receive?
# Yes.
# Best METEOR Score: 0.1020
# Generated Question 2: Can you explain how the Rajya Sabha has broadened the types of complaints it accepts?
# The Rajya Sabha has expanded the ambit of complaints it receives, allowing it to handle a wider range of issues and concerns from the public. This could include complaints about government policies, corruption, human rights violations, and other matters of public interest.
# Best METEOR Score: 0.1147
# Generated Question 3: What types of complaints can the Rajya Sabha now receive?
# The Rajya Sabha has expanded the ambit of complaints it receives.
# Best METEOR Score: 0.1415
# Total METEOR Score (normalized): 0.1194
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim about the new wheat variety helping farmers in Maharashtra true?
# Yes.
# Best METEOR Score: 0.1212
# Generated Question 2: Can you explain how the new wheat variety is helping farmers in the Maharashtra village double their yield?
# The new wheat variety is more resistant to diseases and pests, requires less water and fertilizer, and matures faster, all of which contribute to a significant increase in yield for farmers in the Maharashtra village.
# Best METEOR Score: 0.1534
# Generated Question 3: What specific benefits does the new wheat variety offer to farmers in Maharashtra?
# The new wheat variety is more resistant to diseases and pests, requires less water and fertilizer, and matures faster.
# Best METEOR Score: 0.0871
# Total METEOR Score (normalized): 0.1124
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Maoists kill a suspected Maoist in Telangana?
# No.
# Best METEOR Score: 0.3200
# Generated Question 2: Was the individual killed in the encounter in Telangana actually a Maoist?
# That's the claim being made by the police, however, independent verification is needed to confirm this.
# Best METEOR Score: 0.1841
# Generated Question 3: What is the official statement regarding the death in the encounter in Telangana?
# The Telangana police claim that a suspected Maoist was killed in the encounter.
# Best METEOR Score: 0.1749
# Total METEOR Score (normalized): 0.2186
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the robbery at gunpoint actually happen in Ludhiana, Punjab?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What is the actual location of the robbery incident mentioned in the claim?
# While the claim states it happened in Ludhiana, Punjab, it is important to verify this information from reliable sources.
# Best METEOR Score: 0.1743
# Generated Question 3: Are there any reports or evidence confirming the robbery occurred in Ludhiana, Punjab?
# This needs to be investigated further. Reliable news sources or police reports should be consulted to confirm the location of the incident.
# Best METEOR Score: 0.1276
# Total METEOR Score (normalized): 0.1357
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did hospital staff beat a patient to death in India?
# The claim is unverified. Further investigation is required to confirm if this incident happened.
# Best METEOR Score: 0.1653
# Generated Question 2: Is there evidence of a patient being beaten to death by hospital staff because they couldn\'t pay a 4,000 rupee bill?
# No concrete evidence has been publicly presented to verify this claim.
# Best METEOR Score: 0.2222
# Generated Question 3: What are the details surrounding the claim of a patient being killed for not paying a hospital bill?
# According to the claim, a patient was beaten to death by hospital staff in India due to an unpaid 4,000 rupee bill. However, this information requires verification from reliable sources.
# Best METEOR Score: 0.2083
# Total METEOR Score (normalized): 0.1805
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Abdullakh Anzorov die in a shooting incident in France?
# Yes.
# Best METEOR Score: 0.1064
# Generated Question 2: Was Abdullakh Anzorov's funeral service held in Chechnya?
# According to the Tamil caption, yes, his body was brought to Chechnya for last rites.
# Best METEOR Score: 0.0917
# Generated Question 3: What happened to Abdullakh Anzorov according to the Tamil caption?
# The Tamil caption claims that Abdullakh Anzorov was shot by the police in France after killing Samuel Paty and his body was brought to Chechnya for funeral rites.
# Best METEOR Score: 0.1483
# Generated Question 4: What does the Tamil caption say about the reason for Abdullakh Anzorov's death?
# The caption states that he was shot by the police after killing Samuel Paty.
# Best METEOR Score: 0.1516
# Generated Question 5: Is there evidence to support the claim made in the Tamil caption?
# Further investigation and verification are needed to confirm the accuracy of the information presented in the Tamil caption.
# Best METEOR Score: 0.1327
# Total METEOR Score (normalized): 0.1282
# Optimal Matching from Hungarian Algorithm:
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Did the man who raped the teenager regularly face violence from the villagers?
# Yes.
# Best METEOR Score: 0.1031
# Generated Question 2: Could you please explain the situation where the man who raped a teenager was beaten up by villagers?
# A man who repeatedly raped a teenager was caught and violently confronted by the villagers, who ultimately delivered physical punishment.
# Best METEOR Score: 0.1100
# Generated Question 3: What happened to the man who raped the teenager?
# He was repeatedly attacked and beaten by villagers.
# Best METEOR Score: 0.1000
# Total METEOR Score (normalized): 0.1012
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did RSS workers set ablaze a Christian couple?
# No.
# Best METEOR Score: 0.4076
# Generated Question 2: Is the claim that RSS workers set ablaze a Christian couple after resisting land grabbing true?
# No, the claim is false. There is no evidence to support that RSS workers were involved in such an incident.
# Best METEOR Score: 0.2634
# Generated Question 3: What is the truth behind the claim that RSS workers set ablaze a Christian couple after resisting land grabbing?
# The claim is false and has no factual basis.
# Best METEOR Score: 0.2234
# Total METEOR Score (normalized): 0.2612
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did CM Yogi Adityanath insult Deputy Chief Minister Keshav Prasad Maurya?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What happened during the public event where Keshav Prasad Maurya was asked to move back by CM Yogi Adityanath?
# During a public event, CM Yogi Adityanath asked Deputy Chief Minister Keshav Prasad Maurya to move back on stage, which some perceived as an insult.
# Best METEOR Score: 0.1349
# Generated Question 3: What is the nature of the incident where Keshav Prasad Maurya was asked to move back by CM Yogi Adityanath?
# CM Yogi Adityanath asked Deputy Chief Minister Keshav Prasad Maurya to move back on stage during a public event.
# Best METEOR Score: 0.1168
# Total METEOR Score (normalized): 0.1190
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is Musthafa Parvez, daughter of Mohammad Rafi, singing songs of Lord Krishna?
# Yes
# Best METEOR Score: 0.0526
# Generated Question 2: What is the truth behind the claim that Musthafa Parvez is singing Lord Krishna\'s songs?
# The claim is true. Musthafa Parvez, daughter of Mohammad Rafi, has indeed released songs dedicated to Lord Krishna.
# Best METEOR Score: 0.2534
# Generated Question 3: Musthafa Parvez has sung songs dedicated to which deity?
# Lord Krishna
# Best METEOR Score: 0.0538
# Total METEOR Score (normalized): 0.1199
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Are 4 lakh private school staffers in Haryana unpaid?
# No.
# Best METEOR Score: 0.4032
# Generated Question 2: Is the claim about 4 lakh private school staffers in Haryana being unpaid for months true?
# That claim needs further investigation and verification from credible sources.  It is important to rely on confirmed reports from official sources and reputable news organizations.
# Best METEOR Score: 0.1580
# Generated Question 3: What is the status of the claim regarding 4 lakh private school staffers in Haryana being unpaid?
# The claim is currently unverified and requires confirmation from official sources.
# Best METEOR Score: 0.1214
# Generated Question 4: Who is responsible for the alleged non-payment to private school staffers in Haryana?
# It is unclear who is responsible for the alleged non-payment.  Further investigation is needed to determine if it is due to issues with the government, private schools, or other factors.
# Best METEOR Score: 0.1274
# Generated Question 5: Has the Haryana government issued any statement regarding the unpaid private school staffers?
# This information would need to be confirmed by checking official government statements and news reports.
# Best METEOR Score: 0.0901
# Total METEOR Score (normalized): 0.2177
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Sonia and Rahul Gandhi previously criticize Narendra Modi\'s leadership?
# Potentially, although the extent and context of their past criticism would need further investigation.
# Best METEOR Score: 0.0917
# Generated Question 2: Have Sonia and Rahul Gandhi made any public statements praising  Narendra Modi\'s leadership?
# No.
# Best METEOR Score: 0.3005
# Generated Question 3: What specific actions of Narendra Modi\'s are Sonia and Rahul Gandhi now praising?
# The provided claim does not specify.
# Best METEOR Score: 0.1456
# Generated Question 4: Is there evidence to support the claim that Sonia and Rahul Gandhi are praising Narendra Modi\'s leadership?
# The claim requires further investigation and evidence to be verified.
# Best METEOR Score: 0.1351
# Total METEOR Score (normalized): 0.1671
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 4 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Rahul Gandhi consume chicken and alcohol at a cafe during the Bharat Jodo Yatra?
# Yes.
# Best METEOR Score: 0.1010
# Generated Question 2: What is the truth about the viral video of Rahul Gandhi purportedly having chicken and alcohol during his Bharat Jodo Yatra?
# The video shows Rahul Gandhi having a meal at a cafe during the Bharat Jodo Yatra. Whether chicken and alcohol were consumed is a subject of debate and context.
# Best METEOR Score: 0.1904
# Generated Question 3: Did Rahul Gandhi have chicken and alcohol at a cafe?
# Yes, the video shows him having a meal.
# Best METEOR Score: 0.0980
# Total METEOR Score (normalized): 0.1180
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Sushant Singh Rajput\'s death involve the theft of technology for diagnosing COVID-19?
# No.
# Best METEOR Score: 0.3005
# Generated Question 2: Is there evidence connecting Sushant Singh Rajput\'s death to a voice-based COVID-19 diagnosis machine?
# No, there is no credible evidence linking Sushant Singh Rajput\'s death to any such technology or its development.
# Best METEOR Score: 0.1271
# Generated Question 3: What is the connection between Sushant Singh Rajput\'s death and the voice-based COVID-19 diagnosis device?
# There is no evidence of any connection. The claim is baseless and lacks factual support.
# Best METEOR Score: 0.1503
# Generated Question 4: Were Akshay Kumar and Aaditya Thackeray involved in Sushant Singh Rajput\'s demise?
# No.
# Best METEOR Score: 0.3036
# Generated Question 5: Is the claim that Sushant Singh Rajput was murdered to steal COVID-19 diagnosis technology verified?
# No, the claim is not verified and has been widely dismissed as unfounded.
# Best METEOR Score: 0.2282
# Generated Question 6: Is there a factual basis for the claim that Sushant Singh Rajput's death was related to his involvement in COVID-19 diagnosis technology?
# No, there is no factual basis for this claim.
# Best METEOR Score: 0.1611
# Total METEOR Score (normalized): 0.2092
# Optimal Matching from Hungarian Algorithm:
# Generated Question 4 matched with Reference Question 1
# Generated Question 5 matched with Reference Question 2
# Generated Question 6 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim about India testing a smart torpedo system true?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What details can you share about the smart torpedo system tested by India?
# India successfully tested a new smart torpedo system, described as a game changer in naval warfare.  Details about its capabilities, range, and specific features are likely to be released by the Indian government or defense agencies.
# Best METEOR Score: 0.1674
# Generated Question 3: Who conducted the test of the smart torpedo system?
# The Indian armed forces conducted the test.
# Best METEOR Score: 0.1010
# Total METEOR Score (normalized): 0.1153
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did the woman in the video slap her daughter for participating in anti-CAA protests?
# Yes.
# Best METEOR Score: 0.1090
# Generated Question 2: What is the context behind the video of the mother slapping her daughter?
# The video shows a mother slapping her daughter on the street, allegedly because the daughter participated in an anti-CAA protest.
# Best METEOR Score: 0.1416
# Generated Question 3: What is the reason cited by the mother for slapping her daughter?
# The mother claims her daughter participated in an anti-CAA protest.
# Best METEOR Score: 0.1230
# Total METEOR Score (normalized): 0.1188
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are ninja drones being used to protect rail assets?
# Yes.
# Best METEOR Score: 0.1613
# Generated Question 2: What is the purpose of using ninja drones for rail protection?
# Ninja drones are being used to provide enhanced security and monitoring of rail assets, acting as a vigilant "eye in the sky".
# Best METEOR Score: 0.1261
# Generated Question 3: What type of technology is being employed to protect rail assets?
# Ninja drones are being used.
# Best METEOR Score: 0.1515
# Total METEOR Score (normalized): 0.1095
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Iranian women actually hoist a flag made of chopped locks?
# Yes
# Best METEOR Score: 0.1064
# Generated Question 2: What happened to the flag that was hoisted during the Iranian protests?
# Iranian women hoisted a flag made of their chopped locks during the ongoing anti-hijab protests.
# Best METEOR Score: 0.1364
# Generated Question 3: What is the significance of the flag made of chopped locks hoisted by Iranian women?
# The flag is a symbol of the women's defiance against the mandatory hijab law. Chopping their hair is seen as a powerful act of protest and a rejection of the government’s attempts to control their appearance.
# Best METEOR Score: 0.1855
# Total METEOR Score (normalized): 0.1246
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Was the gang rape and murder of the veterinary doctor in Hyderabad carried out by RSS activists?
# No. The perpetrators of the crime were not affiliated with the RSS.
# Best METEOR Score: 0.3292
# Generated Question 2: Who were the perpetrators of the crime against the veterinary doctor in Hyderabad?
# The perpetrators were four men who were arrested and charged with the crimes of gang rape, murder, and other offenses.
# Best METEOR Score: 0.1210
# Generated Question 3: What were the charges against the men who were arrested for the crime against the veterinary doctor in Hyderabad?
# They were charged with gang rape, murder and other offenses.
# Best METEOR Score: 0.0989
# Generated Question 4: When did the gang rape and murder of the veterinary doctor in Hyderabad take place?
# The crime occurred on November 27, 2019.
# Best METEOR Score: 0.1033
# Generated Question 5: What is the truth regarding the involvement of RSS activists in the Hyderabad veterinary doctor case?
# There is no evidence to suggest any involvement of RSS activists in the case. The perpetrators were unrelated individuals.
# Best METEOR Score: 0.3126
# Total METEOR Score (normalized): 0.2444
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 5 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did a group of people recite Hanuman Chalisa on the Tower Bridge in London?
# Yes
# Best METEOR Score: 0.0515
# Generated Question 2: Was the recitation of Hanuman Chalisa on the Tower Bridge related to the controversy in Maharashtra?
# Yes, it happened amid the ongoing row over Hanuman Chalisa in Maharashtra.
# Best METEOR Score: 0.1211
# Generated Question 3: According to the claim, who recited Hanuman Chalisa on the Tower Bridge?
# A group of people, including foreign nationals.
# Best METEOR Score: 0.0962
# Total METEOR Score (normalized): 0.0865
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the claim about the dog rescuing her babies from the flood in Ukraine true?
# Yes.
# Best METEOR Score: 0.1020
# Generated Question 2: What is the situation depicted in the video of the dog rescuing her puppies?
# The video shows a dog rescuing her puppies from floodwaters caused  by the collapse of Ukraine’s Kakhovka dam on June 6th.
# Best METEOR Score: 0.2129
# Generated Question 3: Did the dog rescue her puppies from the flood caused by the Kakhovka dam collapse?
# Yes, the claim is true. The dog rescued her puppies from the floodwaters caused by the collapse of the Kakhovka dam.
# Best METEOR Score: 0.1303
# Total METEOR Score (normalized): 0.1442
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the RBI statement about currency notes being potential COVID carriers true?
# Yes.
# Best METEOR Score: 0.1042
# Generated Question 2: Can you elaborate on the RBI statement regarding currency notes and the risk of COVID-19 transmission?
# The RBI stated that currency notes can become contaminated with the virus and potentially carry it, highlighting the importance of proper hygiene when handling cash.
# Best METEOR Score: 0.1093
# Generated Question 3: What did the RBI say about the potential of currency notes to transmit COVID-19?
# The RBI affirmed that currency notes can be potential carriers of the Corona Virus.
# Best METEOR Score: 0.1403
# Total METEOR Score (normalized): 0.1179
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the air quality in Delhi NCR good today?
# No.
# Best METEOR Score: 0.3166
# Generated Question 2: Despite a sunny morning, why is the air quality in Delhi NCR still poor?
# Even on sunny days, pollution levels can remain elevated in Delhi NCR due to various factors like industrial emissions, vehicle traffic, and dust particles.
# Best METEOR Score: 0.0857
# Generated Question 3: What is the current air quality situation in Delhi NCR according to the provided claim?
# The claim states that despite a sunny morning, the air quality in Delhi NCR remains in the poor category.
# Best METEOR Score: 0.1522
# Total METEOR Score (normalized): 0.1837
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Celebrations happen in Balochistan after Australia’s win over Pakistan in T20 World Cup semifinal?
# Yes.
# Best METEOR Score: 0.0990
# Generated Question 2: Are there reports of people celebrating Australia’s victory over Pakistan in the T20 World Cup in Balochistan?
# Yes, there are reports of celebrations in Balochistan after Australia won the T20 World Cup semifinal against Pakistan.
# Best METEOR Score: 0.1274
# Generated Question 3: What is the truth about celebrations in Balochistan following Australia’s win against Pakistan in the T20 World Cup?
# Reports indicate celebrations did occur in Balochistan following Australia’s victory over Pakistan in the T20 World Cup semifinal.
# Best METEOR Score: 0.1268
# Total METEOR Score (normalized): 0.1149
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is there a demand for restoring 4G internet in Jammu and Kashmir?
# Yes.
# Best METEOR Score: 0.1042
# Generated Question 2: What is the reason behind the residents of J&K demanding the restoration of 4G internet?
# Residents of Jammu and Kashmir are demanding the restoration of 4G internet, citing its importance for education, businesses, and communication.
# Best METEOR Score: 0.1587
# Generated Question 3: Who is demanding the restoration of 4G internet in J&K?
# Residents of Jammu and Kashmir.
# Best METEOR Score: 0.1000
# Total METEOR Score (normalized): 0.1155
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# ...
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is it true that the Karnataka government scheduled SSLC exams in the evening to accommodate Muslim students offering Namaz?
# Yes
# Best METEOR Score: 0.0980
# Generated Question 2: What is the reason given by the Karnataka government for scheduling the SSLC exams in the evening on March 1st?
# The Karnataka government stated the evening schedule allows Muslim students to offer Namaz during the day.
# Best METEOR Score: 0.1485
# Generated Question 3: When were the SSLC exams scheduled to be held in Karnataka according to the government?
# The Karnataka government scheduled the SSLC exams for Friday, March 1st, in the evening shift.
# Best METEOR Score: 0.1014
# Total METEOR Score (normalized): 0.1150
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Did Rajnath Singh get angry at a rally?
# Yes
# Best METEOR Score: 0.0549
# Generated Question 2: What happened at the rally in Uttar Pradesh where Rajnath Singh was speaking?
# Rajnath Singh lost his temper when the crowd started hooting at him.
# Best METEOR Score: 0.0926
# Generated Question 3: According to the report, what threat did Rajnath Singh make to the BJP supporters?
# Rajnath said he would slap them if they didn\'t quiet down.
# Best METEOR Score: 0.0917
# Total METEOR Score (normalized): 0.0614
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Arvind Kejriwal admit to being a BJP-RSS member?
# Yes.
# Best METEOR Score: 0.1075
# Generated Question 2: What did Arvind Kejriwal say about his family background in relation to the BJP and RSS?
# He admitted to coming from a Jan Sangh family.
# Best METEOR Score: 0.1389
# Generated Question 3: What is Arvind Kejriwal\'s connection to the BJP and RSS according to his own statements?
# He stated he comes from a Jan Sangh family.
# Best METEOR Score: 0.1389
# Total METEOR Score (normalized): 0.0823
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did Sunil Gavaskar criticize the Cricket World Cup's management?
# Yes
# Best METEOR Score: 0.0538
# Generated Question 2: What did Sunil Gavaskar say about the Cricket World Cup's management?
# Sunil Gavaskar criticized the Cricket World Cup's poor management and expressed that he was 'ashamed to be Indian' during the England vs New Zealand match.
# Best METEOR Score: 0.0970
# Generated Question 3: What did Sunil Gavaskar say he felt during the England vs New Zealand match?
# Sunil Gavaskar said he was 'ashamed to be Indian'.
# Best METEOR Score: 0.0935
# Generated Question 4: Was Sunil Gavaskar's comment about the Cricket World Cup made during the England vs New Zealand match?
# Yes, Sunil Gavaskar made his comments during the England vs New Zealand match.
# Best METEOR Score: 0.0875
# Generated Question 5: What specifically criticized Sunil Gavaskar about the Cricket World Cup?
# He criticized the management of the Cricket World Cup.
# Best METEOR Score: 0.0980
# Total METEOR Score (normalized): 0.0887
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# Generated Question 5 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the Taliban threatening India?
# Yes.
# Best METEOR Score: 0.1124
# Generated Question 2: What is the Taliban's stated position on India and Kashmir?
# The Taliban has warned India over its actions in Kashmir, stating they consider it their next target and threatening retaliation if any mujahideen are killed by Indian forces.
# Best METEOR Score: 0.1290
# Generated Question 3: According to the claim, what is the Taliban's specific threat to India?
# The Taliban threatens to unleash a hundred mujahideen for every mujahideen killed by the Modi government.
# Best METEOR Score: 0.1622
# Total METEOR Score (normalized): 0.1281
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Were three school teachers arrested in Kashmir?
# Yes.
# Best METEOR Score: 0.1099
# Generated Question 2: What is the reason behind the arrest of the three school teachers in Jammu and Kashmir?
# They were arrested under the Public Safety Act (PSA).
# Best METEOR Score: 0.1406
# Generated Question 3: Can you elaborate on the circumstances that led to the arrest of the teachers?
# The details of the case and specific reasons for their arrest under the PSA have not been publicly disclosed by the authorities.
# Best METEOR Score: 0.1207
# Total METEOR Score (normalized): 0.1237
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Did 20,000 bikers in Germany rally for a six-year-old cancer patient?
# Yes.
# Best METEOR Score: 0.1053
# Generated Question 2: What details about the rally organized by bikers for a young cancer patient are accurate?
# Around 20,000 bikers in Germany did indeed rally to cheer up a six-year-old boy named  who has cancer.
# Best METEOR Score: 0.1293
# Generated Question 3: Is it true that 20,000 bikers rallied for a sick child in Germany?
# Yes, the claim is true.
# Best METEOR Score: 0.1126
# Generated Question 4: Where did the biker rally for the cancer patient take place?
# Germany
# Best METEOR Score: 0.0532
# Generated Question 5: How many bikers participated in the rally?
# Around 20,000
# Best METEOR Score: 0.0549
# Total METEOR Score (normalized): 0.0948
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim that the Congress MLA was arrested for assault true?
# Yes
# Best METEOR Score: 0.1217
# Generated Question 2: What led to the arrest of the Congress MLA?
# He was arrested for assaulting a colleague who had helped him in his political launch.
# Best METEOR Score: 0.0935
# Generated Question 3: Who did the Congress MLA assault?
# A colleague who had helped him in his political launch.
# Best METEOR Score: 0.1010
# Total METEOR Score (normalized): 0.0983
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 3
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is there any evidence of water overflowing from AC vents in the Vande Bharat Express?
# Yes
# Best METEOR Score: 0.0525
# Generated Question 2: What is the situation regarding the reported water leakage from AC vents on the Vande Bharat Express?
# Reports and videos circulating online show water leaking from AC vents on the Vande Bharat Express, raising concerns about passenger comfort and safety.
# Best METEOR Score: 0.1180
# Generated Question 3: What has been the official response to the water leakage issue in the Vande Bharat Express?
# Railway officials have acknowledged the issue and stated that they are investigating the cause of the water leakage.
# Best METEOR Score: 0.1282
# Total METEOR Score (normalized): 0.0996
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the Malabar naval exercise happening?
# Yes.
# Best METEOR Score: 0.1111
# Generated Question 2: What is happening in the second phase of the Malabar exercise?
# The second phase of the Malabar naval exercise is underway, involving the navies of the United States, Japan, Australia, and India.
# Best METEOR Score: 0.1791
# Generated Question 3: Which countries are participating in the Malabar naval exercise?
# The Malabar naval exercise is being conducted by the navies of the United States, Japan, Australia, and India.
# Best METEOR Score: 0.1622
# Total METEOR Score (normalized): 0.1508
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 2
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Are farmers planning to escalate their protests?
# Yes
# Best METEOR Score: 0.1111
# Generated Question 2: What are the farmers saying about their willingness to move?
# Farmers are refusing to move and stating that they will intensify their protest.
# Best METEOR Score: 0.1415
# Generated Question 3: What is the farmers' stance on relocation?
# Farmers are refusing to relocate.
# Best METEOR Score: 0.1562
# Total METEOR Score (normalized): 0.0817
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Was an army jawan killed in shelling by Pakistan along the LoC?
# Yes.
# Best METEOR Score: 0.1042
# Generated Question 2: How many army jawans have died this month due to ceasefire violations along the LoC?
# Four.
# Best METEOR Score: 0.1010
# Generated Question 3: Can you provide more details about the incident where an army jawan was killed by shelling by Pakistan at the LoC?
# The incident occurred in Rajouri sector of Jammu and Kashmir. This marks the fourth fatality of an army personnel this month due to ceasefire violations by Pakistan.
# Best METEOR Score: 0.1878
# Total METEOR Score (normalized): 0.1174
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 2
# Generated Question 2 matched with Reference Question 1
# Generated Question 3 matched with Reference Question 3
# --------------------------------------------------
# Generated Question 1: Is the claim that 25% of seats in Tamil Nadu were won by a margin of less than 3% true?
# Boolean
# Best METEOR Score: 0.0895
# Generated Question 2: What is the actual percentage of seats in Tamil Nadu won with a margin of less than 3%?
# The claim that 25% of seats were won by a margin of less than 3% is accurate.
# Best METEOR Score: 0.1296
# Generated Question 3: Can you elaborate on the electoral margins in Tamil Nadu elections?
# In the recent Tamil Nadu election, a significant number of seats were won with a narrow margin. A quarter of the total seats had a winning margin of less than 3%. This highlights the close competition and voter preferences within the state.
# Best METEOR Score: 0.1448
# Total METEOR Score (normalized): 0.1073
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Does the CPI(M) proposal to withdraw general consent to the CBI in Kerala face criticism from the opposition?
# Yes.
# Best METEOR Score: 0.0952
# Generated Question 2: What is the opposition's response to the CPI(M)'s suggestion to withdraw general consent to the CBI in Kerala?
# The opposition  criticizes the CPI(M)'s proposal,  viewing it as an attempt to obstruct the CBI\'s investigations.
# Best METEOR Score: 0.2041
# Generated Question 3: What is the main point of contention regarding the CPI(M)'s stance on the CBI in Kerala?
# The CPI(M) is facing flak for suggesting to withdraw general consent to the CBI in Kerala.
# Best METEOR Score: 0.1590
# Total METEOR Score (normalized): 0.1398
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the claim about the arrested individual true?
# Yes
# Best METEOR Score: 0.0985
# Generated Question 2: What happened to the dreaded criminal mentioned in the claim?
# The individual was arrested after an encounter with the police.
# Best METEOR Score: 0.1543
# Generated Question 3: What is the bounty amount on the arrested individual?
# The bounty was Rs 75,000
# Best METEOR Score: 0.0799
# Generated Question 4: Where did the encounter take place?
# This information is not provided in the claim.
# Best METEOR Score: 0.1031
# Total METEOR Score (normalized): 0.1069
# Optimal Matching from Hungarian Algorithm:
# Generated Question 2 matched with Reference Question 3
# Generated Question 3 matched with Reference Question 2
# Generated Question 4 matched with Reference Question 1
# --------------------------------------------------
# Generated Question 1: Is the claim of a Muslim man killing his Hindu girlfriend in Uttarakhand true?
# No.
# Best METEOR Score: 0.3827
# Generated Question 2: What is the truth behind the claim that a Muslim man murdered a Hindu girl in Uttarakhand?
# The claim is likely false and potentially fabricated. It is crucial to verify information from reliable sources and avoid spreading misinformation.
# Best METEOR Score: 0.3276
# Generated Question 3: Who was the person responsible for Kajal\'s death?
# The claim does not state who is responsible for Kajal\'s death. This information needs to be verified from credible sources.
# Best METEOR Score: 0.0987
# Generated Question 4: What is the evidence supporting the claim of  "love jihad" in this case?
# There is no evidence provided to support the claim of "love jihad." The term is often used to spread fear and prejudice against Muslim communities.
# Best METEOR Score: 0.2573
# Total METEOR Score (normalized): 0.2830
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
# Generated Question 1: Is the Navi Mumbai airport facing financial difficulties?
# Yes
# Best METEOR Score: 0.0549
# Generated Question 2: What is the current status of the Navi Mumbai airport construction project?
# The project is facing a funding crisis due to the lockdown, but it is still expected to open with one runway in 2023.
# Best METEOR Score: 0.2178
# Generated Question 3: When is the Navi Mumbai airport expected to be operational with one runway?
# 2023
# Best METEOR Score: 0.0521
# Generated Question 4: What is the reason for the delayed construction of the Navi Mumbai Airport?
# The lockdown caused a financial crisis, which has impacted the construction.
# Best METEOR Score: 0.1308
# Total METEOR Score (normalized): 0.1345
# Optimal Matching from Hungarian Algorithm:
# Generated Question 1 matched with Reference Question 1
# Generated Question 2 matched with Reference Question 3
# Generated Question 4 matched with Reference Question 2
# --------------------------------------------------
#
# Average METEOR Score: 0.1260
