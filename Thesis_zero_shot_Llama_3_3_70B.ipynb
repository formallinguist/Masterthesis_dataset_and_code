# %%
# Clone the BARTScore repository
# !git clone https://github.com/neulab/BARTScore.git
# Out:
# Cloning into 'BARTScore'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 220 (delta 18), reused 14 (delta 14), pack-reused 194 (from 1)
# Receiving objects: 100% (220/220), 101.98 MiB | 19.19 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (192/192), done.

# %%
# %cd /content/BARTScore
# Out:
# /content/BARTScore

# %%
# Import libraries
from bart_score import BARTScorer
import torch

# %%
# Install necessary libraries
# !pip install --upgrade pip  # ensures that pip is current
# !pip install tensorflow tensorflow_hub transformers
# !pip install git+https://github.com/google-research/bleurt.git
# !pip install pandas
# !pip install groq
# !pip install scikit-learn
# !pip install matplotlib
# !pip install nltk
# !pip install rouge
# !pip install sacrebleu
# !pip install bert-score
# !pip install rouge
# Navigate to the repository directory
# %cd /content/BARTScore

# Download and unzip BLEURT checkpoint
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# !unzip BLEURT-20.zip


# Import libraries
from bart_score import BARTScorer
import torch

# Initialize BART-Scorer
bart_scorer = BARTScorer(device='cuda:0' if torch.cuda.is_available() else 'cpu',
                         checkpoint='facebook/bart-large-cnn')
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (2.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-nluxz98y
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-nluxz98y
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2024.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->BLEURT==0.0.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=bb94e81387f7d691864495f4e1823a90a26f3b1dccb7440fabcbbac48b134216
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4hsaxiia/wheels/64/f4/2c/509a6c31b8ebde891a81029fd94f199b1b92f0e7cfc20d417a
# Successfully built BLEURT
# Installing collected packages: BLEURT
# Successfully installed BLEURT-0.0.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting groq
#   Downloading groq-0.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Downloading groq-0.15.0-py3-none-any.whl (109 kB)
# Installing collected packages: groq
# Successfully installed groq-0.15.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# /content/BARTScore
# --2025-01-14 22:05:09--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.137.207, 142.250.101.207, 142.251.2.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.137.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G   203MB/s    in 9.9s
#
# 2025-01-14 22:05:19 (206 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]
#
# Archive:  BLEURT-20.zip
#    creating: BLEURT-20/
#   inflating: BLEURT-20/bert_config.json
#   inflating: BLEURT-20/saved_model.pb
#    creating: BLEURT-20/variables/
#   inflating: BLEURT-20/variables/variables.index
#   inflating: BLEURT-20/variables/variables.data-00000-of-00001  y
#
#   inflating: BLEURT-20/sent_piece.vocab
#   inflating: BLEURT-20/bleurt_config.json
#   inflating: BLEURT-20/sent_piece.model
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from sacrebleu.metrics import CHRF, TER
from bert_score import score
from bleurt import score as bleurt_score
import json
import pandas as pd
import random
import warnings
from groq import Groq
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
from nltk.translate.meteor_score import meteor_score
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Suppress specific warning messages
import logging
logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)

# Function to read JSON file and extract claims
def read_claims_from_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return []

# Load your dataset from JSON files
claims_file_1 = '/content/last_fake_claims.json'
claims_file_2 = '/content/Modified_true_claims.json'

claims_data_1 = read_claims_from_json(claims_file_1)
claims_data_2 = read_claims_from_json(claims_file_2)

# Combine claims from both files
combined_claims = claims_data_1 + claims_data_2
random.shuffle(combined_claims)

# Extract relevant information and convert to DataFrame
claims_list = []
for claim in combined_claims:
    claims_list.append({
        'Text': claim['claim'],
        'classification_label': claim['label'],
        'justification': claim['justification']
    })

claims_df = pd.DataFrame(claims_list)

# Process only the first 10 claims
claims_df = claims_df.head(5006)

# Initialize Groq API client
client = Groq(api_key="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")

# Initialize label map
label_map = {'true': 'true', 'fake': 'fake', "correct": "true", "false": "fake", "incorrect": "fake", "not true": "fake","true:" : "true","fake:": "fake"}

# Define the function to get predictions
def get_claim_predictions(claim):
    prompt = f"Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: {claim}"

    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="llama-3.3-70b-versatile",
            max_tokens=4000,
        )

        predicted_result = response.choices[0].message.content.strip().splitlines()
        print(predicted_result)
        predicted_label_justification = predicted_result[0].strip(' .,*').lower()
        if ':' in predicted_label_justification:
            predicted_label, predicted_justification = predicted_label_justification.split(':', 1)
            predicted_label = predicted_label.strip()
            predicted_justification = predicted_justification.strip()
        else:
            predicted_label = predicted_label_justification
            predicted_justification = " ".join(predicted_result[1:]).strip().lower()

        if predicted_label in label_map:
            predicted_label = label_map[predicted_label]
        else:
            # Handle cases where the label is not clear
            predicted_label = "unknown"
            predicted_justification = " ".join(predicted_result).strip().lower()
    except Exception as e:
        print(f"Error processing claim '{claim}': {e}")
        return ("", "", "")

    return (prompt, predicted_label, predicted_justification)

# Evaluate claims
results = []
actual_labels = []
predicted_labels = []
predicted_justifications = []
actual_justifications = []

correct_predictions = 0
total_processed_claims = 0

for index, row in claims_df.iterrows():
    claim = row['Text']
    actual_label = str(row['classification_label'].strip().lower())
    actual_justification = str(row['justification'].strip().lower())

    prompt, predicted_label, predicted_justification = get_claim_predictions(claim)

    total_processed_claims += 1

    if (predicted_label, predicted_justification) == ("", ""):
        continue

    actual_labels.append(actual_label)
    actual_justifications.append(actual_justification)
    predicted_labels.append(predicted_label)
    predicted_justifications.append(predicted_justification)

    if predicted_label == actual_label:
        correct_predictions += 1
    print(f"Claim #{total_processed_claims}")
    print(f"Prompt: {prompt}")
    print(f"Claim: {claim}")
    print(f"Predicted Label: {predicted_label}")
    print(f"Actual Label: {actual_label}")
    print(f"Predicted Justification: {predicted_justification}")
    print(f"Actual Justification: {actual_justification}")
    print('-' * 50)

# Metrics initialization
rouge = Rouge()
smoothing_function = SmoothingFunction().method4
chrf = CHRF()
ter = TER()
bleurt_scorer = bleurt_score.BleurtScorer("BLEURT-20")

# Filter out empty justifications
filtered_justifications = [
    (actual, predicted)
    for actual, predicted in zip(actual_justifications, predicted_justifications)
    if predicted.strip()
]

# Calculate metrics
def calculate_metrics_extended(justifications):
    bleu_scores = []
    rouge_scores = []
    meteor_scores = []
    chrf_scores = []
    ter_scores = []
    bert_scores = []
    bleurt_scores = []
    bart_scores = []

    for ref, pred in justifications:
        # BLEU score
        bleu = sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothing_function)
        bleu_scores.append(bleu)

        # ROUGE score
        rouge_score = rouge.get_scores(pred, ref, avg=True)
        rouge_scores.append(rouge_score)

        # METEOR score
        meteor = meteor_score([ref.split()], pred.split())
        meteor_scores.append(meteor)

        # ChrF
        chrf_scores.append(chrf.corpus_score([pred], [[ref]]).score)

        # TER
        ter_scores.append(ter.corpus_score([pred], [[ref]]).score)

        # BERTScore
        P, R, F1 = score([pred], [ref], lang="en")
        bert_scores.append(F1.mean().item())

        # BLEURT
        bleurt_scores.append(bleurt_scorer.score(references=[ref], candidates=[pred])[0])

        # BARTScore
        bart_scores.append(bart_scorer.score([pred], [ref])[0])

    return bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores

# Calculate metrics
bleu_scores, rouge_scores, meteor_scores, chrf_scores, ter_scores, bert_scores, bleurt_scores, bart_scores = calculate_metrics_extended(filtered_justifications)

# Summarize and print results
avg_rouge_1 = sum([score['rouge-1']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_2 = sum([score['rouge-2']['f'] for score in rouge_scores]) / len(rouge_scores)
avg_rouge_l = sum([score['rouge-l']['f'] for score in rouge_scores]) / len(rouge_scores)

print(f"Average BLEU Score: {sum(bleu_scores) / len(bleu_scores):.4f}")
print(f"Average METEOR Score: {sum(meteor_scores) / len(meteor_scores):.4f}")
print(f"Average ChrF Score: {sum(chrf_scores) / len(chrf_scores):.4f}")
print(f"Average TER Score: {sum(ter_scores) / len(ter_scores):.4f}")
print(f"Average BERTScore F1: {sum(bert_scores) / len(bert_scores):.4f}")
print(f"Average BLEURT Score: {sum(bleurt_scores) / len(bleurt_scores):.4f}")
print(f"Average BARTScore: {sum(bart_scores) / len(bart_scores):.4f}")
print(f"Average ROUGE-1 F1 Score: {avg_rouge_1:.4f}")
print(f"Average ROUGE-2 F1 Score: {avg_rouge_2:.4f}")
print(f"Average ROUGE-L F1 Score: {avg_rouge_l:.4f}")

# Calculate accuracy
accuracy = (correct_predictions / total_processed_claims) * 100 if total_processed_claims > 0 else 0
print(f"Model Accuracy: {accuracy:.2f}%")

# Calculate the F1 score
f1 = f1_score(actual_labels, predicted_labels, average='weighted', labels=["true", "fake"])
print(f"F1 Score Average: {f1}")

# Confusion matrix
cm = confusion_matrix(actual_labels, predicted_labels, labels=["true", "fake"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["true", "fake"])
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim that akhilesh yadav performed shradh for his living father mulayam singh yadav is false because shradh is a hindu funeral rite performed for the deceased, not the living.
# Actual Justification: the claim is false. akhilesh yadav did not perform shradh for his living father. the photo that was circulated is from a different event and was shared with misleading claims.
# --------------------------------------------------
# ['FAKE', 'There is no credible source or evidence to support the claim that Yogi Adityanath shouted at Asaduddin Owaisi and Owaisi promptly complied, suggesting this incident may be fabricated or exaggerated.']
# Claim #4452
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: While delivering a speech, Yogi Adityanath shouted at Asaduddin Owaisi by saying 'baith jaiye aap.' Owaisi promptly complied.
# Claim: While delivering a speech, Yogi Adityanath shouted at Asaduddin Owaisi by saying 'baith jaiye aap.' Owaisi promptly complied.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible source or evidence to support the claim that yogi adityanath shouted at asaduddin owaisi and owaisi promptly complied, suggesting this incident may be fabricated or exaggerated.
# Actual Justification: the claim that yogi adityanath shouted at asaduddin owaisi during a speech, telling him to 'baith jaiye aap,' and that owaisi complied, is false. the viral video is edited, and the incident did not occur in this context. the video was misrepresented to suggest an interaction that did not happen.
# --------------------------------------------------
# ['FAKE', 'The Indian Medical Association (IMA) has indeed warned about the potential link between air pollution and increased COVID-19 infections, but without specific data or a credible source to back the exact 13% increase claim, it cannot be verified as true.']
# Claim #4453
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: 13% increase in covid infections in delhi due to air pollution: IMA
# Claim: 13% increase in covid infections in delhi due to air pollution: IMA
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the indian medical association (ima) has indeed warned about the potential link between air pollution and increased covid-19 infections, but without specific data or a credible source to back the exact 13% increase claim, it cannot be verified as true.
# Actual Justification: the indian medical association (ima) reported a 13% rise in covid-19 infections in delhi, attributing the spike to worsening air pollution levels. pollutants weaken respiratory defenses, making individuals more vulnerable to infections, including covid-19.
# --------------------------------------------------
# ['FAKE', 'The claim is likely referencing an incident that was misrepresented or taken out of context, as there have been instances of Muslims being allowed to pray in the streets of France due to a lack of mosque space, but there is no substantial evidence to support the notion that Muslims are being dragged off the road for performing namaz.']
# Claim #4454
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Muslims in France being dragged off the road for blocking traffic while performing namaz.
# Claim: Muslims in France being dragged off the road for blocking traffic while performing namaz.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is likely referencing an incident that was misrepresented or taken out of context, as there have been instances of muslims being allowed to pray in the streets of france due to a lack of mosque space, but there is no substantial evidence to support the notion that muslims are being dragged off the road for performing namaz.
# Actual Justification: the video actually shows climate activists protesting and blocking traffic in france, not muslims performing namaz. the claim is a misrepresentation of the event.
# --------------------------------------------------
# ['TRUE', 'The claim appears to be about a real event where the BMC (Brihanmumbai Municipal Corporation) planned to give a rebate to hoarding owners on an annual ad fee hike, which got approved, and the opposition staged a walkout in response.']
# Claim #4455
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Bmc plan to give rebate to hoarding owners on annual ad fee hike gets nod, opposition stages walkout
# Claim: Bmc plan to give rebate to hoarding owners on annual ad fee hike gets nod, opposition stages walkout
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be about a real event where the bmc (brihanmumbai municipal corporation) planned to give a rebate to hoarding owners on an annual ad fee hike, which got approved, and the opposition staged a walkout in response.
# Actual Justification: the brihanmumbai municipal corporation (bmc) approved a plan to provide a rebate to hoarding owners on the annual advertisement fee hike. this decision was met with opposition, and the opposition party staged a walkout in protest against the plan.
# --------------------------------------------------
# ['TRUE', 'The claim is valid as there have been reported cases of passengers dying onboard Shramik Special trains in India, which were operated to transport migrant workers during the COVID-19 pandemic.']
# Claim #4456
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: three passengers onboard shramik special trains die.
# Claim: three passengers onboard shramik special trains die.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is valid as there have been reported cases of passengers dying onboard shramik special trains in india, which were operated to transport migrant workers during the covid-19 pandemic.
# Actual Justification: the article confirms that three passengers died aboard shramik special trains, with one sample taken for covid-19 testing.
# --------------------------------------------------
# ['FAKE', "The claim is labeled as 'FAKE' because it lacks specific details and context to verify its accuracy, and without more information, it cannot be confirmed as a true statement made by Rahul Gandhi."]
# Claim #4457
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Rahul gandhi accuses bjp of being guilty of making a mistake regarding the rafale deal at a rally in maharashtra.
# Claim: Rahul gandhi accuses bjp of being guilty of making a mistake regarding the rafale deal at a rally in maharashtra.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim is labeled as 'fake' because it lacks specific details and context to verify its accuracy, and without more information, it cannot be confirmed as a true statement made by rahul gandhi.
# Actual Justification: the article reports that during a rally in maharashtra, rahul gandhi criticized the bjp, accusing it of wrongdoing in the rafale deal. he alleged corruption and claimed that the bjp was guilty of a mistake that hurt india's interests.
# --------------------------------------------------
# ['TRUE', 'Justice S. Abdul Nazeer has been involved in several high-profile cases related to religion, including the Ayodhya verdict, suggesting that he is indeed sought after for such matters in the Supreme Court.']
# Claim #4458
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Ayodhya verdict: justice s. abdul nazeer most sought after in matters involving religion in sc.
# Claim: Ayodhya verdict: justice s. abdul nazeer most sought after in matters involving religion in sc.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: justice s. abdul nazeer has been involved in several high-profile cases related to religion, including the ayodhya verdict, suggesting that he is indeed sought after for such matters in the supreme court.
# Actual Justification: the claim is accurate as per the article, which reports that justice s. abdul nazeer, who was part of the ayodhya verdict bench, is considered one of the most sought-after judges in matters related to religion in the supreme court.
# --------------------------------------------------
# ['TRUE', "The claim appears to be a factual news report about Karnataka's COVID-19 updates, specifically mentioning the launch of a hospital and the number of recoveries, which can be verified through reputable news sources."]
# Claim #4459
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Karnataka covid-19 wrap: yediyurappa launches infosys foundation-funded bengaluru broadway hospital; recoveries cross 2 lakh-mark
# Claim: Karnataka covid-19 wrap: yediyurappa launches infosys foundation-funded bengaluru broadway hospital; recoveries cross 2 lakh-mark
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be a factual news report about karnataka's covid-19 updates, specifically mentioning the launch of a hospital and the number of recoveries, which can be verified through reputable news sources.
# Actual Justification: the claim that karnataka chief minister b.s. yediyurappa launched the infosys foundation-funded bengaluru broadway hospital and that covid-19 recoveries in the state have crossed the 2 lakh mark is true. according to the indian express, the broadway super-speciality hospital in shivajinagar, bengaluru, was inaugurated as a covid-19 facility. the hospital, funded by the infosys foundation, is equipped with medical infrastructure worth rs 10.25 crore. additionally, karnataka's covid-19 recoveries have surpassed 2 lakh, with a recovery rate of 70%.
# --------------------------------------------------
# ['FAKE', "The claim is likely referring to a specific incident, but without more context, it's impossible to verify its validity, and such a claim may be an exaggeration or misinformation."]
# Claim #4460
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: CISF police personnel recovering cash from the deputy director of RBI.
# Claim: CISF police personnel recovering cash from the deputy director of RBI.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is likely referring to a specific incident, but without more context, it's impossible to verify its validity, and such a claim may be an exaggeration or misinformation.
# Actual Justification: the claim is misleading. the officer in the video is not the deputy director of rbi. the video shows cisf police personnel recovering cash from a deputy control officer in the bank note press (bnp) at dewas, madhya pradesh. the bnp is a unit of the security printing and minting corporation of india ltd (spmcil) and is not under the control of the rbi.
# --------------------------------------------------
# ['FAKE', 'The claim is likely based on a specific incident or image, and without more context or information, it cannot be verified as true, especially considering the dynamic nature of news and the potential for misinformation.']
# Claim #4461
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pakistan’s former Prime Minister Imran Khan with his eyes shut during his third night in jail.
# Claim: Pakistan’s former Prime Minister Imran Khan with his eyes shut during his third night in jail.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is likely based on a specific incident or image, and without more context or information, it cannot be verified as true, especially considering the dynamic nature of news and the potential for misinformation.
# Actual Justification: the claim is false. the video has been digitally altered. the original footage does not show imran khan in jail. no authentic video or image of imran khan in jail has been released. the altered video has been shared with misleading claims on social media.
# --------------------------------------------------
# ['FAKE', "The juvenile involved in the 2012 Nirbhaya gang rape and murder was released in 2016 after serving three years in a reform home, but the claim about the current status is incomplete as it doesn't provide context about what is being claimed regarding the juvenile now being an adult."]
# Claim #4462
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Juvenile involved in the 2012 Nirbhaya gang rape and murder, who is now an adult.
# Claim: Juvenile involved in the 2012 Nirbhaya gang rape and murder, who is now an adult.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the juvenile involved in the 2012 nirbhaya gang rape and murder was released in 2016 after serving three years in a reform home, but the claim about the current status is incomplete as it doesn't provide context about what is being claimed regarding the juvenile now being an adult.
# Actual Justification: the picture circulating as the juvenile involved in the 2012 nirbhaya case is not of the accused. it is an old image of a different individual and is not connected to the nirbhaya case.
# --------------------------------------------------
# ['TRUE', 'The claim is related to a real event where the Supreme Court of India lifted a media gag order imposed by the Andhra Pradesh High Court regarding the Amaravati land deal case, upon a plea by the Andhra Pradesh government.']
# Claim #4463
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Amaravati land deal fir on andhra plea, sc lifts hc media gag order.
# Claim: Amaravati land deal fir on andhra plea, sc lifts hc media gag order.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is related to a real event where the supreme court of india lifted a media gag order imposed by the andhra pradesh high court regarding the amaravati land deal case, upon a plea by the andhra pradesh government.
# Actual Justification: the claim is accurate as the article reports that the supreme court lifted the gag order imposed by the andhra pradesh high court, allowing media coverage of the fir related to the amaravati land deal case.
# --------------------------------------------------
# ['FAKE', 'The claim that a "flyover minister" (presumably referring to Nitin Gadkari, the Minister of Road Transport and Highways in India) doesn\'t need Modi\'s support for re-election and that Gadkari\'s name is enough, is unsubstantiated and lacks context, as elections in India often involve complex party dynamics and alliances.']
# Claim #4464
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Flyover minister doesn't need modi support for re-election. name gadkari is good enough.
# Claim: Flyover minister doesn't need modi support for re-election. name gadkari is good enough.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim that a "flyover minister" (presumably referring to nitin gadkari, the minister of road transport and highways in india) doesn't need modi's support for re-election and that gadkari's name is enough, is unsubstantiated and lacks context, as elections in india often involve complex party dynamics and alliances.
# Actual Justification: the claim is accurate as the article reports that nitin gadkari, the union minister for road transport and highways, stated that his name is enough for his re-election and that he doesn't require modi's support.
# --------------------------------------------------
# ['TRUE', "The claim appears to be a factual report of a minor fire incident at a specific location, the Prime Minister's residence at 9, Lok Kalyan Marg, and states that it was brought under control, suggesting a real event with no apparent exaggeration or fabrication."]
# Claim #4465
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Minor fire breaks at pm's 9, lok kalyan marg residence, brought under control
# Claim: Minor fire breaks at pm's 9, lok kalyan marg residence, brought under control
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be a factual report of a minor fire incident at a specific location, the prime minister's residence at 9, lok kalyan marg, and states that it was brought under control, suggesting a real event with no apparent exaggeration or fabrication.
# Actual Justification: the article from the statesman confirms that a minor fire broke out at pm's residence at 9, lok kalyan marg, and was brought under control.
# --------------------------------------------------
# ['FAKE', 'The claim appears to be a news headline and without further context or verification, it cannot be confirmed as a true statement.']
# Claim #4466
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Body of priest cremated after administration's assurances to kin; bjp attacks gehlot government.
# Claim: Body of priest cremated after administration's assurances to kin; bjp attacks gehlot government.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim appears to be a news headline and without further context or verification, it cannot be confirmed as a true statement.
# Actual Justification: the family of a rajasthan priest, who was allegedly burnt alive, agreed to cremate the body after receiving assurances from the administration regarding their demands. the bjp criticized the ashok gehlot-led rajasthan government over the incident.
# --------------------------------------------------
# ['TRUE', 'The claim seems plausible as chanting slogans in support of Lord Ram could be a legitimate expression of faith and cultural practice among Hindus in Maharashtra, and residential societies often have communities that come together to practice and celebrate their religion.']
# Claim #4467
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: In Maharashtra, Hindus in a residential society are heard chanting slogans in support of Lord Ram.
# Claim: In Maharashtra, Hindus in a residential society are heard chanting slogans in support of Lord Ram.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the claim seems plausible as chanting slogans in support of lord ram could be a legitimate expression of faith and cultural practice among hindus in maharashtra, and residential societies often have communities that come together to practice and celebrate their religion.
# Actual Justification: the claim that this video from maharashtra shows hindus in a residential society sloganeering in support of lord ram is false. according to india today, the video is actually from uttar pradesh’s kanpur and dates back to february 2022. it has no connection to recent events in maharashtra.
# --------------------------------------------------
# ['FAKE', "The claim is likely referring to a recent discovery, but without more information or context, it's difficult to verify its accuracy. However, it's worth noting that Ayodhya is a city in India known for its historical and cultural significance, and while it's possible that an ancient temple was discovered there, the claim's validity depends on confirmation from reputable sources."]
# Claim #4468
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A 5,000-year-old temple discovered during a road widening exercise in Ayodhya.
# Claim: A 5,000-year-old temple discovered during a road widening exercise in Ayodhya.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is likely referring to a recent discovery, but without more information or context, it's difficult to verify its accuracy. however, it's worth noting that ayodhya is a city in india known for its historical and cultural significance, and while it's possible that an ancient temple was discovered there, the claim's validity depends on confirmation from reputable sources.
# Actual Justification: the claim is false. the image in question does not show a 5,000-year-old temple discovered during road widening in ayodhya. the structure shown in the image is actually from a much later period, and it is not part of a recent discovery. the image was taken out of context and falsely linked to the road widening project in ayodhya.
# --------------------------------------------------
# ['FAKE', 'There is no credible evidence or record of Indian External Affairs Minister Dr. S. Jaishankar making such a statement, and it is unlikely that a high-ranking official would make a claim of attempting to annex another country through a public platform like Twitter.']
# Claim #4469
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Indian External Affairs Minister, Dr. S. Jaishankar, tweeted that India wants to make Sri Lanka part of the country, and in exchange offered to solve its financial crisis.
# Claim: Indian External Affairs Minister, Dr. S. Jaishankar, tweeted that India wants to make Sri Lanka part of the country, and in exchange offered to solve its financial crisis.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there is no credible evidence or record of indian external affairs minister dr. s. jaishankar making such a statement, and it is unlikely that a high-ranking official would make a claim of attempting to annex another country through a public platform like twitter.
# Actual Justification: the tweet attributed to dr. s. jaishankar is fabricated. he has not made any such statement or tweet regarding incorporating sri lanka into india in exchange for resolving its financial crisis.
# --------------------------------------------------
# ['TRUE', 'The statement appears to be a news headline and without more context, it is difficult to assess its validity, but given its structure and content, it seems like a genuine news headline, possibly from a recent or past event.']
# Claim #4470
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Counting begins in bitterly fought hyderabad civic polls today
# Claim: Counting begins in bitterly fought hyderabad civic polls today
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the statement appears to be a news headline and without more context, it is difficult to assess its validity, but given its structure and content, it seems like a genuine news headline, possibly from a recent or past event.
# Actual Justification: the claim is true, as reported by the statesman. counting began for the hyderabad civic polls, which were described as bitterly fought.
# --------------------------------------------------
# ['FAKE', 'The provided statement is incomplete and lacks context to determine its validity, but based on available information, Sushil Modi is a former Deputy Chief Minister of Bihar, and the current Deputy Chief Ministers are Tarkishore Prasad and Renu Devi, not a recent pick by Sushil Modi.']
# Claim #4471
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Bihar new deputy cm's picks of sushil modi
# Claim: Bihar new deputy cm's picks of sushil modi
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the provided statement is incomplete and lacks context to determine its validity, but based on available information, sushil modi is a former deputy chief minister of bihar, and the current deputy chief ministers are tarkishore prasad and renu devi, not a recent pick by sushil modi.
# Actual Justification: the claim is supported by the indian express article, which reports that sushil modi's picks for the new deputy cm posts in bihar were announced.
# --------------------------------------------------
# ['FAKE', 'There is not enough information provided to verify the validity of the claim, and without specific details or context, it is impossible to determine the accuracy of the statement.']
# Claim #4472
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Dalit cooperative society tries to take over its land in rapar, encroachers resist
# Claim: Dalit cooperative society tries to take over its land in rapar, encroachers resist
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is not enough information provided to verify the validity of the claim, and without specific details or context, it is impossible to determine the accuracy of the statement.
# Actual Justification: a dalit cooperative society in rapar attempted to reclaim its land, but faced resistance from encroachers who were occupying it.
# --------------------------------------------------
# ['TRUE', "The claim is supported by reports from human rights organizations and international bodies, including Amnesty International and the United Nations, which have documented Israel's use of white phosphorus in Gaza, particularly during the 2008-2009 Gaza War, despite international conventions restricting its use in populated areas due to its potential to cause severe harm to civilians."]
# Claim #4473
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Israel dropping prohibited white phosphorus bombs on Gaza.
# Claim: Israel dropping prohibited white phosphorus bombs on Gaza.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the claim is supported by reports from human rights organizations and international bodies, including amnesty international and the united nations, which have documented israel's use of white phosphorus in gaza, particularly during the 2008-2009 gaza war, despite international conventions restricting its use in populated areas due to its potential to cause severe harm to civilians.
# Actual Justification: the claim is false. the video is from march 2023 and shows thermite bombs being deployed by russian forces in ukraine's vuhledar. it is not related to the israel-hamas conflict.
# --------------------------------------------------
# ['FAKE', 'There is no information or context provided to verify the claim that a 22-year-old man was beaten to death due to water splatter in Kanpur, and without further details or a credible source, the claim cannot be confirmed.']
# Claim #4474
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Kanpur: 22-year-old man beaten to death due to water splatter
# Claim: Kanpur: 22-year-old man beaten to death due to water splatter
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no information or context provided to verify the claim that a 22-year-old man was beaten to death due to water splatter in kanpur, and without further details or a credible source, the claim cannot be confirmed.
# Actual Justification: the claim that a 22-year-old man was beaten to death due to water splatter in kanpur is true. according to the indian express, the incident occurred in wajidpur village when the victim, pintu nishad, accidentally stepped on a water pouch, causing water to splash on faiz mohammad and his associates. this led to a clash, during which pintu was beaten to death. four people have been arrested, and the police are searching for others involved.
# --------------------------------------------------
# ['FAKE', "There is no information or credible sources confirming the incident of a temple priest being burnt alive over a land dispute in Rajasthan's Karauli, so the claim cannot be verified as true."]
# Claim #4475
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Temple priest, burnt alive over land dispute in rajasthan's karauli
# Claim: Temple priest, burnt alive over land dispute in rajasthan's karauli
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: there is no information or credible sources confirming the incident of a temple priest being burnt alive over a land dispute in rajasthan's karauli, so the claim cannot be verified as true.
# Actual Justification: the claim that a temple priest was burnt alive over a land dispute in rajasthan's karauli is true. according to india today, a temple priest named babu lal vaishnav was burned alive by a group of people during a scuffle over a land dispute in bukna village, karauli district. the priest succumbed to his burn injuries the following day. the main accused, kailash meena, has been arrested, and efforts are ongoing to apprehend the other suspects.
# --------------------------------------------------
# ['FAKE ', "The claim appears to be a quotation from a specific individual, P. Chidambaram, targeting Amit Shah, but without further context or a source to verify the quote, it's difficult to assess its validity, however it can be found that P. Chidambaram did make a statement similar to this."]
# Claim #4476
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Those who despise mahatma gandhi want to get rid of shaheen bagh, chidambaram hits out at amit shah
# Claim: Those who despise mahatma gandhi want to get rid of shaheen bagh, chidambaram hits out at amit shah
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim appears to be a quotation from a specific individual, p. chidambaram, targeting amit shah, but without further context or a source to verify the quote, it's difficult to assess its validity, however it can be found that p. chidambaram did make a statement similar to this.
# Actual Justification: the article from *the statesman* confirms that chidambaram made the statement regarding those who despise mahatma gandhi wanting to get rid of shaheen bagh while hitting out at amit shah.
# --------------------------------------------------
# ['FAKE', "The claim is false because the reverse side of the preamble is not blank, it contains the text of the Constitution's Spanish translation or the national emblem, depending on the country, but in the context of India, it's most likely the national emblem."]
# Claim #4477
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Amit Shah is reading the blank reverse side of the preamble.
# Claim: Amit Shah is reading the blank reverse side of the preamble.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is false because the reverse side of the preamble is not blank, it contains the text of the constitution's spanish translation or the national emblem, depending on the country, but in the context of india, it's most likely the national emblem.
# Actual Justification: the image of amit shah is not showing him reading the blank reverse side of the preamble. the document is the preamble of the indian constitution, and the claim is a misinterpretation.
# --------------------------------------------------
# ['TRUE', 'The claim is valid as it is a common practice in India to fly the national flag at prominent locations, including government buildings and public spaces like Lal Chowk in Srinagar, as part of Independence Day celebrations.']
# Claim #4478
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Indian national flag flying atop a clock tower at Srinagar's Lal Chowk as part of Independence Day celebrations.
# Claim: Indian national flag flying atop a clock tower at Srinagar's Lal Chowk as part of Independence Day celebrations.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the claim is valid as it is a common practice in india to fly the national flag at prominent locations, including government buildings and public spaces like lal chowk in srinagar, as part of independence day celebrations.
# Actual Justification: the image of the indian national flag flying atop a clock tower at lal chowk is morphed. the photo circulating on social media is not genuine and was digitally altered. the flag was not hoisted there on independence day 2020.
# --------------------------------------------------
# ['TRUE', 'The claim can be verified by checking the official website uppbpb.gov.in, which is the official website of the Uttar Pradesh Police Recruitment and Promotion Board, and it is plausible that they would declare results for sub inspector and assistant sub inspector posts on their official website.']
# Claim #4479
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: UP police results 2019 for sub inspector and assistant sub inspector posts declared at uppbpb.gov.in
# Claim: UP police results 2019 for sub inspector and assistant sub inspector posts declared at uppbpb.gov.in
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim can be verified by checking the official website uppbpb.gov.in, which is the official website of the uttar pradesh police recruitment and promotion board, and it is plausible that they would declare results for sub inspector and assistant sub inspector posts on their official website.
# Actual Justification: the uttar pradesh police recruitment and promotion board (uppbpb) has declared the results for sub inspector and assistant sub inspector posts for the year 2019.
# --------------------------------------------------
# ['TRUE', "The claim appears to be based on a real event, as there were reports of Sanjay Raut meeting Rakesh Tikait at the Ghazipur border during the farmers' protest in India."]
# Claim #4480
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Shiv sena's sanjay raut meets bharatiya kisan union leader rakesh tikait at ghazipur border
# Claim: Shiv sena's sanjay raut meets bharatiya kisan union leader rakesh tikait at ghazipur border
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be based on a real event, as there were reports of sanjay raut meeting rakesh tikait at the ghazipur border during the farmers' protest in india.
# Actual Justification: the claim is true, as reported by the print. shiv sena leader sanjay raut met bharatiya kisan union leader rakesh tikait at the ghazipur border.
# --------------------------------------------------
# ['TRUE', 'The claim is true as West Bengal indeed has Lok Sabha seats that go to polls in different phases, and the fifth phase on May 6 could be a possible polling date, depending on the specific election schedule announced by the Election Commission of India.']
# Claim #4481
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: West bengal to vote for 7 lok sabha seats in fifth phase on 6 may.
# Claim: West bengal to vote for 7 lok sabha seats in fifth phase on 6 may.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is true as west bengal indeed has lok sabha seats that go to polls in different phases, and the fifth phase on may 6 could be a possible polling date, depending on the specific election schedule announced by the election commission of india.
# Actual Justification: the article from the print confirms that west bengal was scheduled to vote for 7 lok sabha seats in the fifth phase of elections on may 6, 2019.
# --------------------------------------------------
# ['FAKE', "The claim is labeled as 'FAKE' because there is no concrete evidence or recent official confirmation that Zakir Naik is being extradited from Malaysia due to the efforts of the Narendra Modi-led government."]
# Claim #4482
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Islamic televangelist Zakir Naik is being extradited from Malaysia thanks to the efforts of the Narendra Modi-led government.
# Claim: Islamic televangelist Zakir Naik is being extradited from Malaysia thanks to the efforts of the Narendra Modi-led government.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is labeled as 'fake' because there is no concrete evidence or recent official confirmation that zakir naik is being extradited from malaysia due to the efforts of the narendra modi-led government.
# Actual Justification: the claim is misleading. zakir naik has not been extradited from malaysia to india. there have been no reports of him being sent back to india. the extradition request from india to malaysia is still under process, and there is no concrete evidence that the indian government, under narendra modi, has secured zakir naik's extradition.
# --------------------------------------------------
# ['TRUE', "The claim is likely valid as Tejashwi Yadav and several ministers from Nitish Kumar's government have participated in election phases in Bihar, which aligns with typical election dynamics."]
# Claim #4483
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Bihar elections: tejashwi, 4 ministers of nitish govt in fray in 2nd phase
# Claim: Bihar elections: tejashwi, 4 ministers of nitish govt in fray in 2nd phase
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is likely valid as tejashwi yadav and several ministers from nitish kumar's government have participated in election phases in bihar, which aligns with typical election dynamics.
# Actual Justification: the article confirms that tejashwi yadav, the rashtriya janata dal (rjd) leader, and four ministers from the nitish kumar-led bihar government contested in the second phase of the bihar assembly elections. this phase involved key constituencies and notable political figures.
# --------------------------------------------------
# ['FAKE', 'The claim that 21 states accept the GST borrowing proposal cannot be verified without a specific context or date, as the information may have changed over time or may refer to a particular proposal or agreement related to the Goods and Services Tax (GST) in a specific country, such as India.']
# Claim #4484
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: 21 states accept gst borrowing proposal
# Claim: 21 states accept gst borrowing proposal
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim that 21 states accept the gst borrowing proposal cannot be verified without a specific context or date, as the information may have changed over time or may refer to a particular proposal or agreement related to the goods and services tax (gst) in a specific country, such as india.
# Actual Justification: the claim is true, as reported by the times of india. 21 states have accepted the proposal to borrow rs 97,000 crore to meet the gst shortfall.
# --------------------------------------------------
# ['FAKE', 'The claim is false because there is no credible evidence to suggest that Greta Thunberg ever made such a statement to the BBC, and the idea of "environment-friendly weapons" like biodegradable missiles and vegan grenades is not a real or practical solution proposed by her or any other environmental activist.']
# Claim #4485
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Greta Thunberg told the BBC that if wars were to continue, then environment-friendly weapons such as biodegradable missiles and vegan grenades should be used.
# Claim: Greta Thunberg told the BBC that if wars were to continue, then environment-friendly weapons such as biodegradable missiles and vegan grenades should be used.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is false because there is no credible evidence to suggest that greta thunberg ever made such a statement to the bbc, and the idea of "environment-friendly weapons" like biodegradable missiles and vegan grenades is not a real or practical solution proposed by her or any other environmental activist.
# Actual Justification: the claim is false. the video has been edited and originates from a satirical account. in her original interview with the bbc, thunberg spoke about climate change, not wars.
# --------------------------------------------------
# ['TRUE', "The claim can be verified by looking at news reports and attendance figures from Rahul Gandhi's election rallies in Tamil Nadu, which have shown significant turnouts in the past."]
# Claim #4486
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: A significant number of people attended Rahul Gandhi's election rally in Tamil Nadu.
# Claim: A significant number of people attended Rahul Gandhi's election rally in Tamil Nadu.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the claim can be verified by looking at news reports and attendance figures from rahul gandhi's election rallies in tamil nadu, which have shown significant turnouts in the past.
# Actual Justification: the images being circulated are from a rally held by dmk president mk stalin on march 19, 2021. on the same day, rahul gandhi was campaigning in assam. the claim that the images show a crowd gathered for rahul gandhi's rally in tamil nadu is misleading.
# --------------------------------------------------
# ['TRUE', "The claim is likely referring to the Election Commission of India (ECI) sharing its experiences and strategies for conducting elections, such as the Bihar polls, during the COVID-19 pandemic, which is a plausible scenario given the ECI's role in overseeing elections in India."]
# Claim #4487
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: ECI to tell world how bihar polls are held amid pandemic
# Claim: ECI to tell world how bihar polls are held amid pandemic
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is likely referring to the election commission of india (eci) sharing its experiences and strategies for conducting elections, such as the bihar polls, during the covid-19 pandemic, which is a plausible scenario given the eci's role in overseeing elections in india.
# Actual Justification: the claim is based on the report that the election commission of india (eci) planned to showcase how the bihar elections were conducted amidst the covid-19 pandemic.
# --------------------------------------------------
# ['FAKE', 'The claim appears to be a statement made by Congress leaders Rahul and Priyanka Gandhi regarding the Hathras case and the Uttar Pradesh government, but without further context, it is impossible to verify its accuracy, and thus it cannot be labeled as true.']
# Claim #4488
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Hathras case: up govt being 'unethical', not doing its job, say congress leaders rahul, priyanka gandhi
# Claim: Hathras case: up govt being 'unethical', not doing its job, say congress leaders rahul, priyanka gandhi
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim appears to be a statement made by congress leaders rahul and priyanka gandhi regarding the hathras case and the uttar pradesh government, but without further context, it is impossible to verify its accuracy, and thus it cannot be labeled as true.
# Actual Justification: the claim that congress leaders rahul gandhi and priyanka gandhi vadra accused the uttar pradesh government of being unethical and not doing its job in the hathras case is true. according to the indian express, the congress leaders criticized the up government for being insensitive and unethical, and for indulging in victim-blaming instead of putting criminals in jail. they also launched a social media campaign urging people to speak up for the hathras victim.
# --------------------------------------------------
# ['FAKE', "The claim is unsubstantiated and lacks credible evidence to support the allegation that Raghav Chadha threatened Deep Sidhu's supporters due to the late actor's criticism of the AAP."]
# Claim #4489
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: AAP’s Raghav Chadha threatened Deep Sidhu’s supporters because the late actor was critical of the party.
# Claim: AAP’s Raghav Chadha threatened Deep Sidhu’s supporters because the late actor was critical of the party.
# Predicted Label: fake
# Actual Label: fake
# ...
# --------------------------------------------------
# ['TRUE', "The statement appears to reference a court decision (likely from the High Court, abbreviated as 'hc') quashing an FIR (First Information Report) against a journalist, implying that the court has upheld the principles of free press and fair reporting, protecting the journalist's rights."]
# Claim #4994
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Fair and Frank reporting cannot be curbed, jk hc quashes fir against journalist.
# Claim: Fair and Frank reporting cannot be curbed, jk hc quashes fir against journalist.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the statement appears to reference a court decision (likely from the high court, abbreviated as 'hc') quashing an fir (first information report) against a journalist, implying that the court has upheld the principles of free press and fair reporting, protecting the journalist's rights.
# Actual Justification: the jammu and kashmir high court quashed an fir against a journalist, emphasizing that fair and frank reporting cannot be restricted.
# --------------------------------------------------
# ['TRUE', 'The claim appears to be related to the Indian government, led by Prime Minister Narendra Modi, seeking re-election for another term, which typically lasts 5 years in India.']
# Claim #4995
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Modi govt is asking for another 5 years.
# Claim: Modi govt is asking for another 5 years.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim appears to be related to the indian government, led by prime minister narendra modi, seeking re-election for another term, which typically lasts 5 years in india.
# Actual Justification: the article discusses the unfulfilled tasks that the modi government is citing to ask for another term in office, including reforms and development goals they aim to complete.
# --------------------------------------------------
# ['FAKE', 'The claim appears to be based on a specific incident and lacks concrete evidence or credible sources to verify its authenticity, making it difficult to determine its validity without further context or information.']
# Claim #4996
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Amid the allegations of Pakistani police abusing PTI workers,a woman narrating misconduct at the hands of policemen.
# Claim: Amid the allegations of Pakistani police abusing PTI workers,a woman narrating misconduct at the hands of policemen.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim appears to be based on a specific incident and lacks concrete evidence or credible sources to verify its authenticity, making it difficult to determine its validity without further context or information.
# Actual Justification: the video is not related to the current allegations against pakistani police. it actually shows a woman accusing the police of torture during the imran khan regime in 2021, not recent events involving pti workers.
# --------------------------------------------------
# ['TRUE', 'The statement appears to be a factual report of an event, likely related to a specific incident or period of time at Aligarh Muslim University, and does not contain any inherently false or misleading information.']
# Claim #4997
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Deadlock continues as academic activity remains suspended at aligarh muslim university.
# Claim: Deadlock continues as academic activity remains suspended at aligarh muslim university.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the statement appears to be a factual report of an event, likely related to a specific incident or period of time at aligarh muslim university, and does not contain any inherently false or misleading information.
# Actual Justification: the deadlock continues at aligarh muslim university with academic activities still suspended, as reported by *the statesman*.
# --------------------------------------------------
# ['FAKE', 'There have been reports and allegations of human rights abuses, including torture, by security forces in Balochistan, but labeling the entire claim as universally true without considering the complexity of the issue and the need for verification is not accurate.']
# Claim #4998
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pakistan’s security forces torture people in Balochistan.
# Claim: Pakistan’s security forces torture people in Balochistan.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: there have been reports and allegations of human rights abuses, including torture, by security forces in balochistan, but labeling the entire claim as universally true without considering the complexity of the issue and the need for verification is not accurate.
# Actual Justification: the video being circulated as depicting torture by pakistan’s security forces in balochistan is actually an old video from afghanistan. it has been wrongly associated with balochistan.
# --------------------------------------------------
# ['FAKE', "The claim seems to be related to a specific incident, but without more information or context, such as the date or location of the incident, it's impossible to verify its validity, and thus it should be treated with skepticism."]
# Claim #4999
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: As many as 24 people died in a blast caused by 10 cylinders in Mangalore.
# Claim: As many as 24 people died in a blast caused by 10 cylinders in Mangalore.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim seems to be related to a specific incident, but without more information or context, such as the date or location of the incident, it's impossible to verify its validity, and thus it should be treated with skepticism.
# Actual Justification: the claim about 24 people dying in a cylinder blast in mangalore is false. the video actually shows a blast from roorkee and not mangalore, and the incident did not cause 24 fatalities.
# --------------------------------------------------
# ['TRUE', 'The claim is labeled as TRUE because according to news reports, a Mumbai court did grant bail to Bharti Singh and her husband Haarsh Limbachiyaa in a drugs case.']
# Claim #5000
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Mumbai court grants bail to bharti singh, harsh limbachiya in drugs case.
# Claim: Mumbai court grants bail to bharti singh, harsh limbachiya in drugs case.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is labeled as true because according to news reports, a mumbai court did grant bail to bharti singh and her husband haarsh limbachiyaa in a drugs case.
# Actual Justification: the claim is verified by the article, which reports that a mumbai court granted bail to comedian bharti singh and her husband harsh limbachiya in connection with a drugs case, following their arrest by the narcotics control bureau (ncb).
# --------------------------------------------------
# ['TRUE', 'The Indian Air Force conducted an air strike on a Jaish-e-Mohammed training camp in Balakot, Pakistan, on February 26, 2019, reportedly killing several terrorists.']
# Claim #5001
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Terrorists killed in an air strike by the Indian air force on a jaish-e-mohammed training camp in balakot, pakistan.
# Claim: Terrorists killed in an air strike by the Indian air force on a jaish-e-mohammed training camp in balakot, pakistan.
# Predicted Label: true
# Actual Label: fake
# Predicted Justification: the indian air force conducted an air strike on a jaish-e-mohammed training camp in balakot, pakistan, on february 26, 2019, reportedly killing several terrorists.
# Actual Justification: the claim that terrorists were killed in an air strike by the indian air force on a jaish-e-mohammed training camp in balakot, pakistan, is false. according to boom live, the images being circulated as evidence of casualties are actually from a 2015 heatwave in karachi and have no connection to the balakot air strike. independent sources and satellite imagery have also indicated that no significant targets were hit during the air strike.
# --------------------------------------------------
# ['TRUE', 'The claim is about a specific event, and without more context, it appears to be a statement of fact that can be verified, possibly referring to an actual court proceeding regarding the Aadhaar scheme in India.']
# Claim #5002
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: SC to take up pleas seeking review of verdict upholding validity of aadhaar scheme on june 9.
# Claim: SC to take up pleas seeking review of verdict upholding validity of aadhaar scheme on june 9.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: the claim is about a specific event, and without more context, it appears to be a statement of fact that can be verified, possibly referring to an actual court proceeding regarding the aadhaar scheme in india.
# Actual Justification: the article confirms that the supreme court of india will hear pleas seeking a review of its previous verdict, which upheld the validity of the aadhaar scheme. the review will be taken up on june 9, as stated in the article.
# --------------------------------------------------
# ['FAKE', "The claim appears to be unfounded and lacks credible sources, as there is no recent or notable evidence of Imran Khan's supporters burning police cannons and jeeps in Pakistan, and such an incident would likely be widely reported by reputable news outlets."]
# Claim #5003
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Supporters of Imran Khan burning police cannons and jeeps in Pakistan.
# Claim: Supporters of Imran Khan burning police cannons and jeeps in Pakistan.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim appears to be unfounded and lacks credible sources, as there is no recent or notable evidence of imran khan's supporters burning police cannons and jeeps in pakistan, and such an incident would likely be widely reported by reputable news outlets.
# Actual Justification: the video does not show protests in pakistan. it is a clip from earlier palestinian protests, not related to imran khan's supporters in pakistan.
# --------------------------------------------------
# ['FAKE', 'The claim is false, as there is no credible evidence of Bill Gates making such a statement to CNBC, and reputable fact-checking sources have debunked similar claims as misinformation.']
# Claim #5004
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Microsoft co-founder Bill Gates has said in an interview to CNBC that 7 lakh people face death or disability due to the COVID-19 vaccines.
# Claim: Microsoft co-founder Bill Gates has said in an interview to CNBC that 7 lakh people face death or disability due to the COVID-19 vaccines.
# Predicted Label: fake
# Actual Label: fake
# Predicted Justification: the claim is false, as there is no credible evidence of bill gates making such a statement to cnbc, and reputable fact-checking sources have debunked similar claims as misinformation.
# Actual Justification: in the cnbc interview dated april 9, 2020, bill gates mentioned that 7 lakh people could suffer from side effects due to the covid-19 vaccines. however, he did not say that these side effects would be fatal or cause permanent disability. the claim that gates said 7 lakh people would face death or disability is misleading and incorrect.
# --------------------------------------------------
# ['FAKE', 'The claim appears to be a statement of a specific event rather than a general or universal claim that can be assessed for validity, and without further information or context about the event, it cannot be confirmed as true.']
# Claim #5005
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Fire breaks out at mumbai's iconic crawford market, fire engines rushed.
# Claim: Fire breaks out at mumbai's iconic crawford market, fire engines rushed.
# Predicted Label: fake
# Actual Label: true
# Predicted Justification: the claim appears to be a statement of a specific event rather than a general or universal claim that can be assessed for validity, and without further information or context about the event, it cannot be confirmed as true.
# Actual Justification: a fire broke out at crawford market in mumbai, one of the city's iconic locations, and fire engines were dispatched to the site to control the blaze.
# --------------------------------------------------
# ['TRUE', 'This claim is often reported in the context of ongoing tensions and skirmishes along the Line of Control (LOC) between Pakistan and India, with both sides frequently accusing each other of ceasefire violations.']
# Claim #5006
# Prompt: Determine the validity of the following claim and label it as 'TRUE' or 'FAKE'. Provide only 'TRUE' or 'FAKE' on the first line, followed by a justification on the second line: Pakistan claims 3 of its soldiers killed by Indian forces on LOC.
# Claim: Pakistan claims 3 of its soldiers killed by Indian forces on LOC.
# Predicted Label: true
# Actual Label: true
# Predicted Justification: this claim is often reported in the context of ongoing tensions and skirmishes along the line of control (loc) between pakistan and india, with both sides frequently accusing each other of ceasefire violations.
# Actual Justification: according to *hindustan times*, pakistan has claimed that three of its soldiers were killed by indian forces along the line of control (loc).
# --------------------------------------------------
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Average BLEU Score: 0.0838
# Average METEOR Score: 0.2759
# Average ChrF Score: 38.5411
# Average TER Score: 104.1571
# Average BERTScore F1: 0.8857
# Average BLEURT Score: 0.4897
# Average BARTScore: -3.0990
# Average ROUGE-1 F1 Score: 0.3405
# Average ROUGE-2 F1 Score: 0.1382
# Average ROUGE-L F1 Score: 0.2855
# Model Accuracy: 75.29%
# F1 Score Average: 0.7508441263861763
